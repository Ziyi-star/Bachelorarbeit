# %% [markdown]
# # Data Visualization for Road Roughness

# %%
import sys
import pandas as pd  
import matplotlib.pyplot as plt
sys.path.append('../../')   # Add parent directory to Python path
from utils.visualization import *

# %% [markdown]
# Road Roughness Data:<br>
# a. Asphalt Road<br>
# b. Cobblestone Road<br>
# c. Gravel Road<br>
# d. Paving Stone Road<br>
# e. Dirt Road<br>

# %%
#a. Asphalt Road,P1-P10 People
df_asphalt= pd.read_csv('../../data/RoadRoughness/Raw/Asphalt/P1/E1/HandleBar/Accelerometer/Accelerometer.0.csv')  
df_asphalt
# Out:
#                           Date                      NTP      GNSS-Time  \
# 0      2024-11-25T16:10:49.534  2024-11-25 16:10:49.261  1732547448731
# 1      2024-11-25T16:10:49.540  2024-11-25 16:10:49.267  1732547448737
# 2      2024-11-25T16:10:49.541  2024-11-25 16:10:49.268  1732547448738
# 3      2024-11-25T16:10:49.546  2024-11-25 16:10:49.273  1732547448743
# 4      2024-11-25T16:10:49.551  2024-11-25 16:10:49.278  1732547448748
# ...                        ...                      ...            ...
# 10139  2024-11-25T16:11:30.084  2024-11-25 16:11:29.811  1732547489281
# 10140  2024-11-25T16:11:30.088  2024-11-25 16:11:29.815  1732547489285
# 10141  2024-11-25T16:11:30.091  2024-11-25 16:11:29.818  1732547489288
# 10142  2024-11-25T16:11:30.100  2024-11-25 16:11:29.827  1732547489297
# 10143  2024-11-25T16:11:30.102  2024-11-25 16:11:29.829  1732547489299
#
#           Acc-X     Acc-Y     Acc-Z
# 0      2.645565  3.208177  9.038589
# 1      2.527718  3.234199  8.934800
# ...

# %%
print_sampling_frequency(df_asphalt, timestamp_col='NTP')
df_asphalt_label = pd.read_csv('../../data/RoadRoughness/Raw/Asphalt/P1/E1/HandleBar/Label/Label.0.csv')
df_asphalt_label
# Out:
# Sampling frequency: 250.02 Hz
# Empty DataFrame
# Columns: [Date, NTP, GNSS-Time, Label]
# Index: []

# %%
plot_accelerometer_data(df_asphalt, name='Asphalt Accelerometer Data of P1')

# %%
#b. Cobblestone Road,P1-P10 People
df_cobblestone= pd.read_csv('../../data/RoadRoughness/Raw/Cobblestone/P1/E1/HandleBar/Accelerometer/Accelerometer.0.csv')  
df_cobblestone
# Out:
#                          Date                      NTP  GNSS-Time     Acc-X  \
# 0     2024-11-18T16:19:50.132  2024-11-18 16:19:49.844         -1 -0.215354
# 1     2024-11-18T16:19:50.136  2024-11-18 16:19:49.849         -1 -0.431306
# 2     2024-11-18T16:19:50.141  2024-11-18 16:19:49.853         -1 -0.434297
# 3     2024-11-18T16:19:50.143  2024-11-18 16:19:49.856         -1 -0.202194
# 4     2024-11-18T16:19:50.150  2024-11-18 16:19:49.863         -1 -0.314058
# ...                       ...                      ...        ...       ...
# 9005  2024-11-18T16:20:26.149  2024-11-18 16:20:25.862         -1 -0.480658
# 9006  2024-11-18T16:20:26.165  2024-11-18 16:20:25.878         -1 -0.337986
# 9007  2024-11-18T16:20:26.166  2024-11-18 16:20:25.878         -1 -0.562014
# 9008  2024-11-18T16:20:26.166  2024-11-18 16:20:25.878         -1 -0.807279
# 9009  2024-11-18T16:20:26.166  2024-11-18 16:20:25.878         -1 -0.587139
#
#          Acc-Y     Acc-Z
# 0     3.911667  9.046964
# ...

# %%
print_sampling_frequency(df_cobblestone, timestamp_col='NTP')
plot_accelerometer_data(df_cobblestone, name='Cobblestone Accelerometer Data of P1')
# Out:
# Sampling frequency: 250.01 Hz

# %%
#c. Gravel Road,P1-P10 People
df_gravel= pd.read_csv('../../data/RoadRoughness/Raw/CompactGravel/P1/E1/HandleBar/Accelerometer/Accelerometer.0.csv')  
df_gravel
# Out:
#                          Date                      NTP  GNSS-Time     Acc-X  \
# 0     2024-11-18T15:49:39.322  2024-11-18 15:49:39.034         -1  1.064208
# 1     2024-11-18T15:49:39.327  2024-11-18 15:49:39.039         -1  0.511167
# 2     2024-11-18T15:49:39.329  2024-11-18 15:49:39.041         -1  0.543470
# 3     2024-11-18T15:49:39.333  2024-11-18 15:49:39.046         -1  1.051945
# 4     2024-11-18T15:49:39.346  2024-11-18 15:49:39.058         -1  1.291825
# ...                       ...                      ...        ...       ...
# 9223  2024-11-18T15:50:16.213  2024-11-18 15:50:15.925         -1  0.294616
# 9224  2024-11-18T15:50:16.217  2024-11-18 15:50:15.929         -1  0.167498
# 9225  2024-11-18T15:50:16.221  2024-11-18 15:50:15.934         -1  0.037089
# 9226  2024-11-18T15:50:16.223  2024-11-18 15:50:15.936         -1 -0.043968
# 9227  2024-11-18T15:50:16.228  2024-11-18 15:50:15.941         -1 -0.139083
#
#          Acc-Y     Acc-Z
# 0     3.981059  9.064611
# ...

# %%
print_sampling_frequency(df_gravel, timestamp_col='NTP')
plot_accelerometer_data(df_gravel, name='Gravel Accelerometer Data of P1')
# Out:
# Sampling frequency: 250.01 Hz

# %%
# d. Paving Stone Road<br>
df_PavingStone= pd.read_csv('../../data/RoadRoughness/Raw/PavingStone/P1/E1/HandleBar/Accelerometer/Accelerometer.0.csv')  
df_PavingStone
# Out:
#                           Date                      NTP      GNSS-Time  \
# 0      2024-11-23T13:21:22.664  2024-11-23 13:21:22.376  1732364480621
# 1      2024-11-23T13:21:22.666  2024-11-23 13:21:22.378  1732364480624
# 2      2024-11-23T13:21:22.671  2024-11-23 13:21:22.384  1732364480629
# 3      2024-11-23T13:21:22.676  2024-11-23 13:21:22.388  1732364480634
# 4      2024-11-23T13:21:22.678  2024-11-23 13:21:22.391  1732364480636
# ...                        ...                      ...            ...
# 11575  2024-11-23T13:22:08.967  2024-11-23 13:22:08.680  1732364526925
# 11576  2024-11-23T13:22:08.968  2024-11-23 13:22:08.681  1732364526926
# 11577  2024-11-23T13:22:08.971  2024-11-23 13:22:08.684  1732364526929
# 11578  2024-11-23T13:22:08.977  2024-11-23 13:22:08.689  1732364526934
# 11579  2024-11-23T13:22:08.981  2024-11-23 13:22:08.694  1732364526939
#
#           Acc-X     Acc-Y     Acc-Z
# 0      1.267598  3.824927  8.880363
# 1      1.683949  3.909274  8.982058
# ...

# %%
print_sampling_frequency(df_PavingStone, timestamp_col='NTP')
plot_accelerometer_data(df_PavingStone, name='Paving Stone Accelerometer Data of P1')
# Out:
# Sampling frequency: 249.99 Hz

# %%
# e. Dirt Road
df_DirtRoad= pd.read_csv('../../data/RoadRoughness/Raw/Dirt/P1/E1/HandleBar/Accelerometer/Accelerometer.0.csv')  
df_DirtRoad
# Out:
#                           Date                      NTP  GNSS-Time     Acc-X  \
# 0      2024-11-18T16:43:48.217  2024-11-18 16:43:47.930         -1  0.188734
# 1      2024-11-18T16:43:48.220  2024-11-18 16:43:47.932         -1  0.306281
# 2      2024-11-18T16:43:48.224  2024-11-18 16:43:47.937         -1  0.276371
# 3      2024-11-18T16:43:48.229  2024-11-18 16:43:47.942         -1  0.420539
# 4      2024-11-18T16:43:48.232  2024-11-18 16:43:47.944         -1  0.499801
# ...                        ...                      ...        ...       ...
# 10934  2024-11-18T16:44:31.952  2024-11-18 16:44:31.664         -1  0.355334
# 10935  2024-11-18T16:44:31.956  2024-11-18 16:44:31.669         -1  0.210269
# 10936  2024-11-18T16:44:31.967  2024-11-18 16:44:31.679         -1  0.133699
# 10937  2024-11-18T16:44:31.967  2024-11-18 16:44:31.680         -1  0.365205
# 10938  2024-11-18T16:44:31.968  2024-11-18 16:44:31.681         -1  0.649950
#
#           Acc-Y     Acc-Z
# ...

# %%
print_sampling_frequency(df_DirtRoad, timestamp_col='NTP')
plot_accelerometer_data(df_DirtRoad, name='Dirt Road Accelerometer Data of P1')
# Out:
# Sampling frequency: 250.01 Hz
