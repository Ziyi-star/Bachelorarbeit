# %% [markdown]
# # Data Visualization for Road Roughness

# %%
import sys
import pandas as pd  
import matplotlib.pyplot as plt
sys.path.append('../../')   # Add parent directory to Python path
from utils.visualization import *

# %% [markdown]
# Road Roughness Data:<br>
# a. AB - 08.07<br>
# b. IK - 26.02.25<br>
# c. JG - 03.07<br>
# d. KF - 04.07<br>
# e. LB - 18.06<br>
# f. LCL - 03.07

# %%
#a. AB - 08.07
df_AB= pd.read_csv('../../data/Real_world_cycling/AB - 08.07/Lenker/Accelerometer/Accelerometer.0.csv')  
print_sampling_frequency(df_AB, timestamp_col='NTP')
plot_accelerometer_data(df_AB, name='AB - 08.07 Accelerometer Data')
# Out:
# Sampling frequency: 33.56 Hz

# %%
#b. IK - 26.02.25
df_IK= pd.read_csv('../../data/Real_world_cycling/IK - 26.02.25/Lenker/accelerometer/Accelerometer.0.csv')  
print_sampling_frequency(df_IK, timestamp_col='NTP')
plot_accelerometer_data(df_IK, name='IK - 26.02.25 Accelerometer Data')
# Out:
# Sampling frequency: 30.00 Hz

# %%
# c. JG - 03.07
df_JG = pd.read_csv('../../data/Real_world_cycling/JG - 03.07/Lenker/Accelerometer/Accelerometer.0.csv')
print_sampling_frequency(df_JG, timestamp_col='NTP')
plot_accelerometer_data(df_JG, name='JG - 03.07 Accelerometer Data')
# Out:
# Sampling frequency: 33.55 Hz

# %%
# d. KF - 04.07
df_KF = pd.read_csv('../../data/Real_world_cycling/KF - 04.07/Lenker/Accelerometer/Accelerometer.0.csv')
print_sampling_frequency(df_KF, timestamp_col='NTP')
plot_accelerometer_data(df_KF, name='KF - 04.07 Accelerometer Data')
# Out:
# Sampling frequency: 33.54 Hz

# %%
# e. LB - 18.06
df_LB = pd.read_csv('../../data/Real_world_cycling/LB - 18.06/Lenker/Accelerometer/Accelerometer.0.csv')
print_sampling_frequency(df_LB, timestamp_col='NTP')
plot_accelerometer_data(df_LB, name='LB - 18.06 Accelerometer Data')
# Out:
# Sampling frequency: 33.54 Hz

# %%
# f. LCL - 03.07
df_LCL = pd.read_csv('../../data/Real_world_cycling/LCL - 03.07/Lenker/Accelerometer/Accelerometer.0.csv')
print_sampling_frequency(df_LCL, timestamp_col='NTP')
plot_accelerometer_data(df_LCL, name='LCL - 03.07 Accelerometer Data')
# Out:
# Sampling frequency: 33.54 Hz
