# %% [markdown]
# # Data Visualization for Curb

# %%
import sys
import pandas as pd  
import matplotlib.pyplot as plt
sys.path.append('../../')   # Add parent directory to Python path
from utils.visualization import *

# %% [markdown]
# Curb Dataset: Lab Dataset with ideal Labels<br>
# a. curb 1cm<br>
# b. curb 2cm<br>
# c. curb 3cm<br>
# d. ramp 0cm to 3cm<br>
# e. transition stone 0cm to 3cm<br>
# P3,P6,P11,P12,P18,P21

# %%
df= pd.read_csv('../../data/Curb/P3/handlebar/Accelerometer/Accelerometer_data_merged_ESP1.csv')  
df
# Out:
#         Unnamed: 0                      NTP     Acc-X     Acc-Y     Acc-Z  \
# 0                0  2024-07-29 13:51:06.990  5.094864  3.275269  9.126694
# 1                1  2024-07-29 13:51:07.003  3.260910  2.413361  8.097183
# 2                2  2024-07-29 13:51:07.005  3.160339  3.251327  8.724472
# 3                3  2024-07-29 13:51:07.006  4.654327  3.246536  7.354980
# 4                4  2024-07-29 13:51:07.008  3.045425  2.418137  8.595184
# ...            ...                      ...       ...       ...       ...
# 997336      997336  2024-07-29 15:13:35.185  1.618485  4.314346  8.552093
# 997337      997337  2024-07-29 15:13:35.190  1.690308  4.252106  8.729263
# 997338      997338  2024-07-29 15:13:35.195  1.666367  4.271255  8.676590
# 997339      997339  2024-07-29 15:13:35.202  1.637634  4.357452  8.489838
# 997340      997340  2024-07-29 15:13:35.205  1.661575  4.386185  8.432373
#
#         Timestamp_unix  curb_activity  curb_scene  curb_height_down  \
# 0         1.722261e+12            1.0         0.0               1.0
# 1         1.722261e+12            1.0         0.0               1.0
# 2         1.722261e+12            1.0         0.0               1.0
# 3         1.722261e+12            1.0         0.0               1.0
# 4         1.722261e+12            1.0         0.0               1.0
# ...                ...            ...         ...               ...
# 997336    1.722266e+12            0.0         0.0               3.0
# 997337    1.722266e+12            0.0         0.0               3.0
# 997338    1.722266e+12            0.0         0.0               3.0
# 997339    1.722266e+12            0.0         0.0               3.0
# 997340    1.722266e+12            0.0         0.0               3.0
#
#         curb_height_up  curb_type_down  curb_type_up  roughness
# 0                  3.0             1.0           2.0       -1.0
# 1                  3.0             1.0           2.0       -1.0
# 2                  3.0             1.0           2.0       -1.0
# 3                  3.0             1.0           2.0       -1.0
# 4                  3.0             1.0           2.0       -1.0
# ...                ...             ...           ...        ...
# 997336             1.0             2.0           1.0        0.0
# 997337             1.0             2.0           1.0        0.0
# 997338             1.0             2.0           1.0        0.0
# 997339             1.0             2.0           1.0        0.0
# 997340             1.0             2.0           1.0        0.0
#
# [997341 rows x 13 columns]

# %%
# Show unique values for each attribute in df_one
attributes = [
    'curb_activity',
    'curb_scene',
    'curb_height_down',
    'curb_height_up',
    'curb_type_down',
    'curb_type_up',
    'roughness'
 ]
fig, axes = plt.subplots(2, 4, figsize=(12, 8))
axes = axes.flatten()
axes[0].set_ylabel('Count')
axes[4].set_ylabel('Count')

for i, attr in enumerate(attributes):
    counts = df[attr].value_counts()
    counts.plot(kind='bar', ax=axes[i])
    axes[i].set_xlabel(attr)
    for j, v in enumerate(counts.values):
        axes[i].text(j, v, str(v), ha='center', va='bottom')
plt.tight_layout()
plt.show()

# %%
df_three= pd.read_csv('../../data/Curb/P3/handlebar/Accelerometer/Accelerometer.0.csv')  
print_sampling_frequency(df_three, timestamp_col='NTP')
plot_accelerometer_data(df_three, name='Curb Accelerometer Data of P3')
# Out:
# Sampling frequency: 201.08 Hz

# %%
# Out:
#         Unnamed: 0                      NTP     Acc-X     Acc-Y     Acc-Z  \
# 0                0  2024-07-24 10:26:01.863  1.417374  4.161118  8.762772
# 1                1  2024-07-24 10:26:01.867  1.393433  4.161118  8.753204
# 2                2  2024-07-24 10:26:01.872  1.407791  4.165909  8.762772
# 3                3  2024-07-24 10:26:01.877  1.446091  4.170700  8.781937
# 4                4  2024-07-24 10:26:01.884  1.417374  4.175491  8.753204
# ...            ...                      ...       ...       ...       ...
# 549206      549206  2024-07-24 11:11:20.851  3.806778  2.609680  8.777145
# 549207      549207  2024-07-24 11:11:20.857  3.758896  2.652771  8.681381
# 549208      549208  2024-07-24 11:11:20.866  3.763687  2.796432  8.370132
# 549209      549209  2024-07-24 11:11:20.870  3.734955  2.839523  8.307877
# 549210      549210  2024-07-24 11:11:20.871  3.749313  2.695877  8.571243
#
#         Timestamp_unix  curb_activity  curb_scene  curb_height_down  \
# 0         1.721817e+12            1.0         0.0               1.0
# 1         1.721817e+12            1.0         0.0               1.0
# 2         1.721817e+12            1.0         0.0               1.0
# 3         1.721817e+12            1.0         0.0               1.0
# 4         1.721817e+12            1.0         0.0               1.0
# ...                ...            ...         ...               ...
# 549206    1.721819e+12            0.0         0.0               3.0
# 549207    1.721819e+12            0.0         0.0               3.0
# 549208    1.721819e+12            0.0         0.0               3.0
# 549209    1.721819e+12            0.0         0.0               3.0
# 549210    1.721819e+12            0.0         0.0               3.0
#
#         curb_height_up  curb_type_down  curb_type_up  roughness
# 0                  3.0             1.0           2.0       -1.0
# 1                  3.0             1.0           2.0       -1.0
# 2                  3.0             1.0           2.0       -1.0
# 3                  3.0             1.0           2.0       -1.0
# 4                  3.0             1.0           2.0       -1.0
# ...                ...             ...           ...        ...
# 549206             1.0             2.0           1.0        0.0
# 549207             1.0             2.0           1.0        0.0
# 549208             1.0             2.0           1.0        0.0
# 549209             1.0             2.0           1.0        0.0
# 549210             1.0             2.0           1.0        0.0
#
# [549211 rows x 13 columns]

# %%
# P6
df_P6 = pd.read_csv('../../data/Curb/P6/handlebar/Accelerometer/Accelerometer_data_merged_ESP1.csv')
print_sampling_frequency(df_P6, timestamp_col='NTP')
plot_accelerometer_data(df_P6, name='Curb Accelerometer Data of P6')
# Out:
# Sampling frequency: 201.44 Hz
