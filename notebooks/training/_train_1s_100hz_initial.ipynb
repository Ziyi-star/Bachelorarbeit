# %% [markdown]
# <a href="https://colab.research.google.com/github/Ziyi-star/Bachelorarbeit/blob/main/notebooks/training/_train_simclr_har_1s_100hz.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # SimCLR Training

# %%
# For VSCode
# %load_ext autoreload
# %autoreload 2

import os
import pickle
import scipy
import datetime
import numpy as np
import tensorflow as tf
import simclr_utitlities
import transformations
import simclr_models
import sys
import matplotlib.pyplot as plt

sys.path.append('../')   # Add parent directory to Python path
working_directory = "../models/"

seed = 1
tf.random.set_seed(seed)
np.random.seed(seed)

with open('../data_1s_100hz/TrainTest/X_train_normalized.pkl', 'rb') as f:
    np_train_data = pickle.load(f)
with open('../data_1s_100hz/TrainTest/y_train_onehot.pkl', 'rb') as f:
    np_train_labels = pickle.load(f)
with open('../data_1s_100hz/TrainTest/X_val_normalized.pkl', 'rb') as f:
    np_val_data = pickle.load(f)
with open('../data_1s_100hz/TrainTest/y_val_onehot.pkl', 'rb') as f:
    np_val_labels = pickle.load(f)
with open('../data_1s_100hz/TrainTest/X_test_data.pkl', 'rb') as f:
    np_test_data = pickle.load(f)
with open('../data_1s_100hz/TrainTest/y_test_onehot.pkl', 'rb') as f:
    np_test_labels = pickle.load(f)

np_train_data.shape, np_train_labels.shape, np_val_data.shape, np_val_labels.shape, np_test_labels.shape
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# ((2788, 100, 3), (2788, 7), (698, 100, 3), (698, 7), (872, 7))
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
# For Google Colab
# 1. Clone your repository to go to access your notebook and .py files
# !git clone https://github.com/Ziyi-star/Bachelorarbeit.git
# 2. Change working directory to where your notebook and .py files are
import os
os.chdir('/content/Bachelorarbeit/notebooks/training')
import os
import pickle
import scipy
import datetime
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import simclr_utitlities
import transformations
import simclr_models
import sys

seed = 1
tf.random.set_seed(seed)
np.random.seed(seed)

# Load data
# Download the file from GitHub
# !rm -f *.pkl # Remove existing pickle files
# !wget https://raw.githubusercontent.com/Ziyi-star/Bachelorarbeit/main/notebooks/data_1s_100hz/TrainTest/X_train_normalized.pkl
# !wget https://raw.githubusercontent.com/Ziyi-star/Bachelorarbeit/main/notebooks/data_1s_100hz/TrainTest/y_train_onehot.pkl
# !wget https://raw.githubusercontent.com/Ziyi-star/Bachelorarbeit/main/notebooks/data_1s_100hz/TrainTest/X_val_normalized.pkl
# !wget https://raw.githubusercontent.com/Ziyi-star/Bachelorarbeit/main/notebooks/data_1s_100hz/TrainTest/y_val_onehot.pkl
# !wget https://raw.githubusercontent.com/Ziyi-star/Bachelorarbeit/main/notebooks/data_1s_100hz/TrainTest/X_test_data.pkl
# !wget https://raw.githubusercontent.com/Ziyi-star/Bachelorarbeit/main/notebooks/data_1s_100hz/TrainTest/y_test_onehot.pkl


working_directory = "../models/"  # Relative path to models folder

# Load as usual
import pickle

with open('X_train_normalized.pkl', 'rb') as f:
    np_train_data = pickle.load(f)
with open('y_train_onehot.pkl', 'rb') as f:
    np_train_labels = pickle.load(f)
with open('X_val_normalized.pkl', 'rb') as f:
    np_val_data = pickle.load(f)
with open('y_val_onehot.pkl', 'rb') as f:
    np_val_labels = pickle.load(f)
with open('X_test_data.pkl', 'rb') as f:
    np_test_data = pickle.load(f)
with open('y_test_onehot.pkl', 'rb') as f:
    np_test_labels = pickle.load(f)

print(np_train_data.shape, np_train_labels.shape)
print(np_val_data.shape, np_val_labels.shape)
# Out:
# Cloning into 'Bachelorarbeit'...
# remote: Enumerating objects: 632, done.
# remote: Counting objects: 100% (10/10), done.
# remote: Compressing objects: 100% (8/8), done.
# remote: Total 632 (delta 2), reused 6 (delta 2), pack-reused 622 (from 1)
# Receiving objects: 100% (632/632), 158.55 MiB | 29.14 MiB/s, done.
# Resolving deltas: 100% (392/392), done.
# Updating files: 100% (64/64), done.
# /content/Bachelorarbeit/notebooks/training/transformations.py:35: SyntaxWarning: invalid escape sequence '\&'
#   @inproceedings{TerryUm_ICMI2017, author = {Um, Terry T. and Pfister, Franz M. J. and Pichler, Daniel and Endo, Satoshi and Lang, Muriel and Hirche, Sandra and Fietzek, Urban and Kuli\'{c}, Dana}, title = {Data Augmentation of Wearable Sensor Data for Parkinson's Disease Monitoring Using Convolutional Neural Networks}, booktitle = {Proceedings of the 19th ACM International Conference on Multimodal Interaction}, series = {ICMI 2017}, year = {2017}, isbn = {978-1-4503-5543-8}, location = {Glasgow, UK}, pages = {216--220}, numpages = {5}, doi = {10.1145/3136755.3136817}, acmid = {3136817}, publisher = {ACM}, address = {New York, NY, USA}, keywords = {Parkinson\&#39;s disease, convolutional neural networks, data augmentation, health monitoring, motor state detection, wearable sensor}, }
# --2025-09-30 09:28:11--  https://raw.githubusercontent.com/Ziyi-star/Bachelorarbeit/main/notebooks/data_1s_100hz/TrainTest/X_train_normalized.pkl
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 6216165 (5.9M) [application/octet-stream]
# Saving to: ‘X_train_normalized.pkl’
#
# X_train_normalized. 100%[===================>]   5.93M  --.-KB/s    in 0.06s
#
# 2025-09-30 09:28:12 (101 MB/s) - ‘X_train_normalized.pkl’ saved [6216165/6216165]
#
# --2025-09-30 09:28:12--  https://raw.githubusercontent.com/Ziyi-star/Bachelorarbeit/main/notebooks/data_1s_100hz/TrainTest/y_train_onehot.pkl
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 145203 (142K) [application/octet-stream]
# Saving to: ‘y_train_onehot.pkl’
#
# y_train_onehot.pkl  100%[===================>] 141.80K  --.-KB/s    in 0.01s
#
# 2025-09-30 09:28:12 (9.29 MB/s) - ‘y_train_onehot.pkl’ saved [145203/145203]
#
# --2025-09-30 09:28:12--  https://raw.githubusercontent.com/Ziyi-star/Bachelorarbeit/main/notebooks/data_1s_100hz/TrainTest/X_val_normalized.pkl
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1555365 (1.5M) [application/octet-stream]
# Saving to: ‘X_val_normalized.pkl’
#
# X_val_normalized.pk 100%[===================>]   1.48M  --.-KB/s    in 0.04s
#
# 2025-09-30 09:28:13 (38.5 MB/s) - ‘X_val_normalized.pkl’ saved [1555365/1555365]
#
# --2025-09-30 09:28:13--  https://raw.githubusercontent.com/Ziyi-star/Bachelorarbeit/main/notebooks/data_1s_100hz/TrainTest/y_val_onehot.pkl
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 36442 (36K) [application/octet-stream]
# Saving to: ‘y_val_onehot.pkl’
#
# y_val_onehot.pkl    100%[===================>]  35.59K  --.-KB/s    in 0.002s
#
# 2025-09-30 09:28:13 (14.1 MB/s) - ‘y_val_onehot.pkl’ saved [36442/36442]
#
# --2025-09-30 09:28:13--  https://raw.githubusercontent.com/Ziyi-star/Bachelorarbeit/main/notebooks/data_1s_100hz/TrainTest/X_test_data.pkl
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1972903 (1.9M) [application/octet-stream]
# Saving to: ‘X_test_data.pkl’
#
# X_test_data.pkl     100%[===================>]   1.88M  --.-KB/s    in 0.04s
#
# 2025-09-30 09:28:13 (44.4 MB/s) - ‘X_test_data.pkl’ saved [1972903/1972903]
#
# --2025-09-30 09:28:13--  https://raw.githubusercontent.com/Ziyi-star/Bachelorarbeit/main/notebooks/data_1s_100hz/TrainTest/y_test_onehot.pkl
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 45514 (44K) [application/octet-stream]
# Saving to: ‘y_test_onehot.pkl’
#
# y_test_onehot.pkl   100%[===================>]  44.45K  --.-KB/s    in 0.007s
#
# 2025-09-30 09:28:14 (6.28 MB/s) - ‘y_test_onehot.pkl’ saved [45514/45514]
#
# (2590, 100, 3) (2590, 7)
# (648, 100, 3) (648, 7)

# %% [markdown]
# ## 1.1 Pretraining with SimCLR

# %%
# Parameters for all experiments
window_size = 100
input_shape = (window_size, 3)
batch_size = 512
#Number of samples processed together in one training step. Larger batch sizes can speed up training but require more memory.
decay_steps = 1000
#Number of steps after which the learning rate decays (used for learning rate scheduling).
epochs = 200
temperature = 0.1

# %%
#A parameter for the SimCLR loss function that controls how sharply similarities are measured.
# transform_funcs = [
#     transformations.scaling_transform_vectorized, # Use Scaling trasnformation
#     transformations.rotation_transform_vectorized # Use rotation trasnformation
# ]
transform_funcs = [
    transformations.time_segment_permutation_transform_improved,
    transformations.channel_shuffle_transform_vectorized
]
#List of data augmentation functions to apply to the input data. Here, only rotation is used.
transformation_function = simclr_utitlities.generate_composite_transform_function_simple(transform_funcs)
# Out:
# 0 <function time_segment_permutation_transform_improved at 0x7c7ff47dfec0>
# 1 <function channel_shuffle_transform_vectorized at 0x7c7ff47dfe20>

# %%
# Time
start_time = datetime.datetime.now()
start_time_str = start_time.strftime("%Y%m%d-%H%M%S")
#Formats the date and time as a string like 20250827-153045 (for filenames, logs, etc.).
tf.keras.backend.set_floatx('float32')
#Sets TensorFlow to use 32-bit floating point numbers for all computations (standard for deep learning).

# %%
# Create a cosine-decayed learning rate schedule and SGD optimizer for training.
lr_decayed_fn = tf.keras.optimizers.schedules.CosineDecay(initial_learning_rate=0.1, decay_steps=decay_steps)
optimizer = tf.keras.optimizers.SGD(lr_decayed_fn)

# Build the base model and attach the SimCLR head for contrastive learning.
base_model = simclr_models.create_base_model(input_shape, model_name="base_model")
simclr_model = simclr_models.attach_simclr_head(base_model)
simclr_model.summary()

# Train the SimCLR model using the specified transformation function and optimizer.
trained_simclr_model, epoch_losses = simclr_utitlities.simclr_train_model(
    simclr_model,
    np_train_data,
    optimizer,
    batch_size,
    transformation_function,
    temperature=temperature,
    epochs=epochs,
    is_trasnform_function_vectorized=True,
    verbose=1
)

# Save the trained SimCLR model to disk for later use.
simclr_model_save_path = f"{working_directory}{start_time_str}_simclr.hdf5"
trained_simclr_model.save(simclr_model_save_path)
# Out:
# Model: "base_model_simclr"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input (InputLayer)              │ (None, 100, 3)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d (Conv1D)                 │ (None, 77, 32)         │         2,336 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 77, 32)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_1 (Conv1D)               │ (None, 62, 64)         │        32,832 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 62, 64)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_2 (Conv1D)               │ (None, 55, 96)         │        49,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 55, 96)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_max_pooling1d            │ (None, 96)             │             0 │
# │ (GlobalMaxPooling1D)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 256)            │        24,832 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation (Activation)         │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_1 (Activation)       │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 50)             │         6,450 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 148,594 (580.45 KB)
#  Trainable params: 148,594 (580.45 KB)
#  Non-trainable params: 0 (0.00 B)
# epoch: 1 loss: 11.417
# epoch: 2 loss: 12.773
# epoch: 3 loss: 11.401
# epoch: 4 loss: 10.934
# epoch: 5 loss: 9.954
# epoch: 6 loss: 9.451
# epoch: 7 loss: 9.951
# epoch: 8 loss: 9.171
# epoch: 9 loss: 8.969
# epoch: 10 loss: 8.625
# epoch: 11 loss: 8.722
# epoch: 12 loss: 9.163
# epoch: 13 loss: 8.119
# epoch: 14 loss: 8.572
# epoch: 15 loss: 8.159
# epoch: 16 loss: 7.931
# epoch: 17 loss: 7.804
# epoch: 18 loss: 7.662
# epoch: 19 loss: 7.779
# epoch: 20 loss: 6.988
# epoch: 21 loss: 6.945
# epoch: 22 loss: 7.242
# epoch: 23 loss: 6.994
# epoch: 24 loss: 6.641
# Epoch 3/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - auc: 0.8593 - categorical_accuracy: 0.5435 - loss: 1.3428 - precision: 0.8884 - recall: 0.2079 - val_auc: 0.8558 - val_categorical_accuracy: 0.5540 - val_loss: 1.3459 - val_precision: 0.9128 - val_recall: 0.2099
# Epoch 4/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - auc: 0.8665 - categorical_accuracy: 0.5592 - loss: 1.3003 - precision: 0.8883 - recall: 0.2340 - val_auc: 0.8611 - val_categorical_accuracy: 0.5586 - val_loss: 1.3158 - val_precision: 0.9177 - val_recall: 0.2238
# Epoch 5/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - auc: 0.8717 - categorical_accuracy: 0.5800 - loss: 1.2675 - precision: 0.8842 - recall: 0.2524 - val_auc: 0.8644 - val_categorical_accuracy: 0.5664 - val_loss: 1.2943 - val_precision: 0.9157 - val_recall: 0.2346
# Epoch 6/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - auc: 0.8747 - categorical_accuracy: 0.5840 - loss: 1.2491 - precision: 0.8753 - recall: 0.2621 - val_auc: 0.8672 - val_categorical_accuracy: 0.5679 - val_loss: 1.2779 - val_precision: 0.9240 - val_recall: 0.2438
# Epoch 7/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - auc: 0.8782 - categorical_accuracy: 0.5943 - loss: 1.2292 - precision: 0.8628 - recall: 0.2710 - val_auc: 0.8696 - val_categorical_accuracy: 0.5694 - val_loss: 1.2647 - val_precision: 0.9106 - val_recall: 0.2515
# Epoch 8/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - auc: 0.8789 - categorical_accuracy: 0.5904 - loss: 1.2231 - precision: 0.8448 - recall: 0.2757 - val_auc: 0.8722 - val_categorical_accuracy: 0.5756 - val_loss: 1.2494 - val_precision: 0.8913 - val_recall: 0.2531
# Epoch 9/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - auc: 0.8817 - categorical_accuracy: 0.5954 - loss: 1.2072 - precision: 0.8437 - recall: 0.2825 - val_auc: 0.8735 - val_categorical_accuracy: 0.5741 - val_loss: 1.2431 - val_precision: 0.8936 - val_recall: 0.2593
# Epoch 10/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - auc: 0.8832 - categorical_accuracy: 0.5982 - loss: 1.2007 - precision: 0.8374 - recall: 0.2889 - val_auc: 0.8752 - val_categorical_accuracy: 0.5756 - val_loss: 1.2334 - val_precision: 0.8936 - val_recall: 0.2593
# Epoch 11/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - auc: 0.8840 - categorical_accuracy: 0.5982 - loss: 1.1911 - precision: 0.8480 - recall: 0.2979 - val_auc: 0.8765 - val_categorical_accuracy: 0.5772 - val_loss: 1.2257 - val_precision: 0.8808 - val_recall: 0.2623
# Epoch 12/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - auc: 0.8861 - categorical_accuracy: 0.6018 - loss: 1.1818 - precision: 0.8439 - recall: 0.3064 - val_auc: 0.8782 - val_categorical_accuracy: 0.5802 - val_loss: 1.2179 - val_precision: 0.8763 - val_recall: 0.2623
# Epoch 13/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - auc: 0.8876 - categorical_accuracy: 0.5957 - loss: 1.1748 - precision: 0.8412 - recall: 0.3138 - val_auc: 0.8792 - val_categorical_accuracy: 0.5818 - val_loss: 1.2122 - val_precision: 0.8731 - val_recall: 0.2654
# Epoch 14/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - auc: 0.8878 - categorical_accuracy: 0.6023 - loss: 1.1704 - precision: 0.8422 - recall: 0.3161 - val_auc: 0.8810 - val_categorical_accuracy: 0.5849 - val_loss: 1.2037 - val_precision: 0.8794 - val_recall: 0.2701
# Epoch 15/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - auc: 0.8882 - categorical_accuracy: 0.6049 - loss: 1.1691 - precision: 0.8253 - recall: 0.3177 - val_auc: 0.8818 - val_categorical_accuracy: 0.5849 - val_loss: 1.1980 - val_precision: 0.8806 - val_recall: 0.2731
# Epoch 16/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - auc: 0.8898 - categorical_accuracy: 0.6094 - loss: 1.1590 - precision: 0.8377 - recall: 0.3251 - val_auc: 0.8817 - val_categorical_accuracy: 0.5833 - val_loss: 1.1968 - val_precision: 0.8762 - val_recall: 0.2731
# Epoch 17/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - auc: 0.8901 - categorical_accuracy: 0.6041 - loss: 1.1594 - precision: 0.8283 - recall: 0.3230 - val_auc: 0.8829 - val_categorical_accuracy: 0.5895 - val_loss: 1.1916 - val_precision: 0.8719 - val_recall: 0.2731
# Epoch 18/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - auc: 0.8915 - categorical_accuracy: 0.6061 - loss: 1.1528 - precision: 0.8386 - recall: 0.3310 - val_auc: 0.8840 - val_categorical_accuracy: 0.5895 - val_loss: 1.1858 - val_precision: 0.8780 - val_recall: 0.2778
# Epoch 19/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - auc: 0.8923 - categorical_accuracy: 0.6083 - loss: 1.1465 - precision: 0.8350 - recall: 0.3382 - val_auc: 0.8844 - val_categorical_accuracy: 0.5895 - val_loss: 1.1834 - val_precision: 0.8719 - val_recall: 0.2731
# Epoch 20/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - auc: 0.8919 - categorical_accuracy: 0.6022 - loss: 1.1457 - precision: 0.8326 - recall: 0.3382 - val_auc: 0.8856 - val_categorical_accuracy: 0.5926 - val_loss: 1.1779 - val_precision: 0.8732 - val_recall: 0.2762
# Epoch 21/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - auc: 0.8932 - categorical_accuracy: 0.6088 - loss: 1.1388 - precision: 0.8285 - recall: 0.3407 - val_auc: 0.8853 - val_categorical_accuracy: 0.5864 - val_loss: 1.1777 - val_precision: 0.8606 - val_recall: 0.2762
# Epoch 22/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - auc: 0.8927 - categorical_accuracy: 0.6086 - loss: 1.1421 - precision: 0.8283 - recall: 0.3485 - val_auc: 0.8863 - val_categorical_accuracy: 0.5864 - val_loss: 1.1732 - val_precision: 0.8744 - val_recall: 0.2793
# Epoch 23/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - auc: 0.8937 - categorical_accuracy: 0.6148 - loss: 1.1363 - precision: 0.8323 - recall: 0.3451 - val_auc: 0.8862 - val_categorical_accuracy: 0.5849 - val_loss: 1.1724 - val_precision: 0.8702 - val_recall: 0.2793
# Epoch 24/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - auc: 0.8943 - categorical_accuracy: 0.6082 - loss: 1.1332 - precision: 0.8293 - recall: 0.3501 - val_auc: 0.8868 - val_categorical_accuracy: 0.5864 - val_loss: 1.1705 - val_precision: 0.8702 - val_recall: 0.2793
# Epoch 25/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - auc: 0.8940 - categorical_accuracy: 0.6135 - loss: 1.1349 - precision: 0.8286 - recall: 0.3478 - val_auc: 0.8877 - val_categorical_accuracy: 0.5864 - val_loss: 1.1655 - val_precision: 0.8714 - val_recall: 0.2824
# Epoch 26/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - auc: 0.8947 - categorical_accuracy: 0.6173 - loss: 1.1301 - precision: 0.8306 - recall: 0.3499 - val_auc: 0.8880 - val_categorical_accuracy: 0.5910 - val_loss: 1.1630 - val_precision: 0.8638 - val_recall: 0.2840
# Epoch 27/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - auc: 0.8959 - categorical_accuracy: 0.6139 - loss: 1.1249 - precision: 0.8350 - recall: 0.3563 - val_auc: 0.8880 - val_categorical_accuracy: 0.5880 - val_loss: 1.1633 - val_precision: 0.8638 - val_recall: 0.2840
# Epoch 28/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - auc: 0.8955 - categorical_accuracy: 0.6142 - loss: 1.1259 - precision: 0.8258 - recall: 0.3607 - val_auc: 0.8889 - val_categorical_accuracy: 0.5910 - val_loss: 1.1591 - val_precision: 0.8744 - val_recall: 0.2901
# Epoch 29/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - auc: 0.
# Epoch 43/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - auc: 0.8997 - categorical_accuracy: 0.6266 - loss: 1.0986 - precision: 0.8178 - recall: 0.3798 - val_auc: 0.8917 - val_categorical_accuracy: 0.5988 - val_loss: 1.1398 - val_precision: 0.8577 - val_recall: 0.3164
# Epoch 44/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - auc: 0.9003 - categorical_accuracy: 0.6244 - loss: 1.0992 - precision: 0.8269 - recall: 0.3825 - val_auc: 0.8923 - val_categorical_accuracy: 0.5957 - val_loss: 1.1376 - val_precision: 0.8655 - val_recall: 0.3179
# Epoch 45/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - auc: 0.9005 - categorical_accuracy: 0.6229 - loss: 1.0975 - precision: 0.8310 - recall: 0.3869 - val_auc: 0.8924 - val_categorical_accuracy: 0.5941 - val_loss: 1.1364 - val_precision: 0.8672 - val_recall: 0.3225
# Epoch 46/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - auc: 0.9003 - categorical_accuracy: 0.6183 - loss: 1.0978 - precision: 0.8232 - recall: 0.3813 - val_auc: 0.8921 - val_categorical_accuracy: 0.5957 - val_loss: 1.1388 - val_precision: 0.8484 - val_recall: 0.3194
# Epoch 47/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - auc: 0.9005 - categorical_accuracy: 0.6205 - loss: 1.0969 - precision: 0.8295 - recall: 0.3847 - val_auc: 0.8922 - val_categorical_accuracy: 0.5972 - val_loss: 1.1362 - val_precision: 0.8577 - val_recall: 0.3256
# Epoch 48/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - auc: 0.8994 - categorical_accuracy: 0.6127 - loss: 1.1009 - precision: 0.8139 - recall: 0.3826 - val_auc: 0.8927 - val_categorical_accuracy: 0.5957 - val_loss: 1.1348 - val_precision: 0.8642 - val_recall: 0.3241
# Epoch 49/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - auc: 0.9013 - categorical_accuracy: 0.6245 - loss: 1.0924 - precision: 0.8290 - recall: 0.3954 - val_auc: 0.8929 - val_categorical_accuracy: 0.5972 - val_loss: 1.1330 - val_precision: 0.8683 - val_recall: 0.3256
# Epoch 50/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - auc: 0.9005 - categorical_accuracy: 0.6112 - loss: 1.0952 - precision: 0.8169 - recall: 0.3885 - val_auc: 0.8930 - val_categorical_accuracy: 0.5972 - val_loss: 1.1329 - val_precision: 0.8642 - val_recall: 0.3241

# %%
# Training and Validation Loss

plt.figure(figsize=(12,6))
plt.plot(training_history.history['loss'], label='Training Loss')
plt.plot(training_history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training and Validation Loss')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Training and Validation Accuracy
plt.figure(figsize=(12,6))
plt.plot(training_history.history['categorical_accuracy'], label='Training Accuracy')
plt.plot(training_history.history['val_categorical_accuracy'], label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Training and Validation Accuracy')
plt.legend()
plt.grid(True)
plt.ylim([0, 1])
plt.show()

# %% [markdown]
# #### Test:

# %%
# Load models and evaluate on test set on vscode
linear_eval_model_path =  linear_eval_best_model_file_name

# Load both models
# simclr_model = tf.keras.models.load_model(simclr_model_path)
linear_eval_best_model = tf.keras.models.load_model(linear_eval_model_path)

# %% [markdown]
# #### Normalize test data

# %%
from sklearn.preprocessing import StandardScaler

def normalize_3d_data(data):
    """
    Normalize 3D sensor data (samples, timesteps, features) using StandardScaler.

    Parameters:
    -----------
    data : list or numpy.ndarray
        Input data. If a list of arrays, it will be stacked first.
        Shape should be (N, L, C) where:
        N = number of samples, L = segment length (timesteps), C = number of channels/features

    Returns:
    --------
    numpy.ndarray
        Normalized data with the same shape as input
    """
    # Stack data if it's a list
    if isinstance(data, list):
        data_array = np.stack(data)  # shape: (N, L, C)
    else:
        data_array = data

    # Get dimensions
    N, L, C = data_array.shape

    # Reshape to 2D for scaling: (N*L, C)
    data_reshaped = data_array.reshape(-1, C)

    # Apply standard scaling
    scaler = StandardScaler()
    data_scaled = scaler.fit_transform(data_reshaped)

    # Reshape back to original 3D shape
    data_normalized = data_scaled.reshape(N, L, C)

    return data_normalized

# %%
# You can also use it for test data (but should fit the scaler only on training data)
X_test_normalized = normalize_3d_data(np_test_data)

# %%
linear_eval_best_model = tf.keras.models.load_model(linear_eval_best_model_file_name)

print("Model with lowest validation Loss:")
print(simclr_utitlities.evaluate_model_simple(linear_eval_best_model.predict(X_test_normalized), np_test_labels, return_dict=True))
print("Model in last epoch")
print(simclr_utitlities.evaluate_model_simple(linear_evaluation_model.predict(X_test_normalized), np_test_labels, return_dict=True))
# Out:
# Model with lowest validation Loss:
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step
# {'Confusion Matrix': array([[103,   1,  11,   5,   0,   5,  14],
#        [  6,  66,   3,   5,   2,  11,   4],
#        [ 25,   1,  21,   4,   6,  21,  17],
#        [  6,   0,   1,  77,   1,  27,   6],
#        [  0,   4,   1,   3, 108,   1,   1],
#        [ 13,   0,   4,   5,   1,  73,  19],
#        [ 34,   2,   2,   7,   1,  43,  39]]), 'F1 Macro': 0.591774343229084, 'F1 Micro': 0.6012345679012345, 'F1 Weighted': 0.5935880774612219, 'Precision': 0.6226227372327656, 'Recall': 0.5928198451175309, 'Kappa': np.float64(0.5316988825425691)}
# Model in last epoch
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step
# {'Confusion Matrix': array([[103,   1,  11,   5,   0,   5,  14],
#        [  6,  66,   3,   5,   2,  11,   4],
#        [ 25,   1,  21,   4,   6,  21,  17],
#        [  6,   0,   1,  77,   1,  27,   6],
#        [  0,   4,   1,   3, 108,   1,   1],
#        [ 13,   0,   4,   5,   1,  73,  19],
#        [ 34,   2,   2,   7,   1,  43,  39]]), 'F1 Macro': 0.591774343229084, 'F1 Micro': 0.6012345679012345, 'F1 Weighted': 0.5935880774612219, 'Precision': 0.6226227372327656, 'Recall': 0.5928198451175309, 'Kappa': np.float64(0.5316988825425691)}

# %% [markdown]
# ### 1.2.2 Full HAR Model

# %% [markdown]
# #### Train

# %%
total_epochs = 50
batch_size = 200
tag = "full_eval"

simclr_model = tf.keras.models.load_model(simclr_model_save_path)
full_evaluation_model = simclr_models.create_full_classification_model_from_base_model(
    simclr_model, output_shape, model_name="TPN", intermediate_layer=7, last_freeze_layer=4)

full_eval_best_model_file_name = f"{working_directory}{start_time_str}_simclr_{tag}.keras"

best_model_callback = tf.keras.callbacks.ModelCheckpoint(full_eval_best_model_file_name,
    monitor='val_loss', mode='min', save_best_only=True, save_weights_only=False, verbose=0
)

training_history = full_evaluation_model.fit(
    x = np_train_data,
    y = np_train_labels,
    batch_size=batch_size,
    shuffle=True,
    epochs=total_epochs,
    callbacks=[best_model_callback],
    validation_data=(np_val_data, np_val_labels)
)
# Out:
# WARNING:absl:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# Epoch 1/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 24s 1s/step - auc: 0.6890 - categorical_accuracy: 0.3041 - loss: 1.8101 - precision: 0.5421 - recall: 0.1379 - val_auc: 0.8681 - val_categorical_accuracy: 0.5586 - val_loss: 1.2547 - val_precision: 0.8538 - val_recall: 0.2793
# Epoch 2/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - auc: 0.8845 - categorical_accuracy: 0.5862 - loss: 1.1857 - precision: 0.7861 - recall: 0.3604 - val_auc: 0.8891 - val_categorical_accuracy: 0.5772 - val_loss: 1.1536 - val_precision: 0.8282 - val_recall: 0.3719
# Epoch 3/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - auc: 0.9021 - categorical_accuracy: 0.6096 - loss: 1.0939 - precision: 0.7938 - recall: 0.4123 - val_auc: 0.8969 - val_categorical_accuracy: 0.5988 - val_loss: 1.1094 - val_precision: 0.8414 - val_recall: 0.4012
# Epoch 4/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - auc: 0.9125 - categorical_accuracy: 0.6340 - loss: 1.0354 - precision: 0.8042 - recall: 0.4440 - val_auc: 0.9011 - val_categorical_accuracy: 0.5988 - val_loss: 1.0843 - val_precision: 0.8506 - val_recall: 0.4306
# Epoch 5/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - auc: 0.9186 - categorical_accuracy: 0.6390 - loss: 0.9968 - precision: 0.8071 - recall: 0.4663 - val_auc: 0.9039 - val_categorical_accuracy: 0.6049 - val_loss: 1.0674 - val_precision: 0.8511 - val_recall: 0.4321
# Epoch 6/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - auc: 0.9238 - categorical_accuracy: 0.6429 - loss: 0.9641 - precision: 0.7981 - recall: 0.4876 - val_auc: 0.9058 - val_categorical_accuracy: 0.6096 - val_loss: 1.0583 - val_precision: 0.8421 - val_recall: 0.4444
# Epoch 7/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - auc: 0.9279 - categorical_accuracy: 0.6544 - loss: 0.9373 - precision: 0.8121 - recall: 0.5034 - val_auc: 0.9085 - val_categorical_accuracy: 0.6157 - val_loss: 1.0414 - val_precision: 0.8377 - val_recall: 0.4460
# Epoch 8/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - auc: 0.9306 - categorical_accuracy: 0.6581 - loss: 0.9194 - precision: 0.8199 - recall: 0.5097 - val_auc: 0.9093 - val_categorical_accuracy: 0.6157 - val_loss: 1.0353 - val_precision: 0.8215 - val_recall: 0.4475
# Epoch 9/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - auc: 0.9334 - categorical_accuracy: 0.6645 - loss: 0.9019 - precision: 0.8113 - recall: 0.5167 - val_auc: 0.9100 - val_categorical_accuracy: 0.6127 - val_loss: 1.0317 - val_precision: 0.8199 - val_recall: 0.4568
# Epoch 10/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - auc: 0.9361 - categorical_accuracy: 0.6674 - loss: 0.8842 - precision: 0.8131 - recall: 0.5285 - val_auc: 0.9107 - val_categorical_accuracy: 0.6111 - val_loss: 1.0271 - val_precision: 0.8043 - val_recall: 0.4630
# Epoch 11/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - auc: 0.9393 - categorical_accuracy: 0.6767 - loss: 0.8624 - precision: 0.8192 - recall: 0.5431 - val_auc: 0.9118 - val_categorical_accuracy: 0.6219 - val_loss: 1.0215 - val_precision: 0.8079 - val_recall: 0.4738
# Epoch 12/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - auc: 0.9427 - categorical_accuracy: 0.6878 - loss: 0.8396 - precision: 0.8273 - recall: 0.5457 - val_auc: 0.9108 - val_categorical_accuracy: 0.6111 - val_loss: 1.0274 - val_precision: 0.8000 - val_recall: 0.4630
# Epoch 13/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - auc: 0.9459 - categorical_accuracy: 0.6872 - loss: 0.8182 - precision: 0.8178 - recall: 0.5488 - val_auc: 0.9122 - val_categorical_accuracy: 0.6003 - val_loss: 1.0220 - val_precision: 0.8005 - val_recall: 0.4583
# Epoch 14/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - auc: 0.9484 - categorical_accuracy: 0.7140 - loss: 0.8008 - precision: 0.8309 - recall: 0.5613 - val_auc: 0.9119 - val_categorical_accuracy: 0.6096 - val_loss: 1.0210 - val_precision: 0.8000 - val_recall: 0.4753
# Epoch 15/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - auc: 0.9511 - categorical_accuracy: 0.7127 - loss: 0.7804 - precision: 0.8316 - recall: 0.5834 - val_auc: 0.9103 - val_categorical_accuracy: 0.6142 - val_loss: 1.0297 - val_precision: 0.7933 - val_recall: 0.4738
# Epoch 16/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - auc: 0.9518 - categorical_accuracy: 0.7125 - loss: 0.7765 - precision: 0.8366 - recall: 0.5862 - val_auc: 0.9103 - val_categorical_accuracy: 0.6065 - val_loss: 1.0320 - val_precision: 0.7825 - val_recall: 0.4830
# Epoch 17/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - auc: 0.9544 - categorical_accuracy: 0.7177 - loss: 0.7554 - precision: 0.8325 - recall: 0.5919 - val_auc: 0.9102 - val_categorical_accuracy: 0.6049 - val_loss: 1.0363 - val_precision: 0.7606 - val_recall: 0.5000
# Epoch 18/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - auc: 0.9567 - categorical_accuracy: 0.7370 - loss: 0.7350 - precision: 0.8417 - recall: 0.6120 - val_auc: 0.9123 - val_categorical_accuracy: 0.6034 - val_loss: 1.0281 - val_precision: 0.7780 - val_recall: 0.5031
# Epoch 19/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - auc: 0.9585 - categorical_accuracy: 0.7307 - loss: 0.7235 - precision: 0.8407 - recall: 0.6098 - val_auc: 0.9112 - val_categorical_accuracy: 0.6096 - val_loss: 1.0389 - val_precision: 0.7724 - val_recall: 0.5185
# Epoch 20/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - auc: 0.9605 - categorical_accuracy: 0.7335 - loss: 0.7052 - precision: 0.8457 - recall: 0.6254 - val_auc: 0.9113 - val_categorical_accuracy: 0.6173 - val_loss: 1.0378 - val_precision: 0.7742 - val_recall: 0.5185
# Epoch 21/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - auc: 0.9629 - categorical_accuracy: 0.7417 - loss: 0.6865 - precision: 0.8430 - recall: 0.6355 - val_auc: 0.9107 - val_categorical_accuracy: 0.6127 - val_loss: 1.0475 - val_precision: 0.7535 - val_recall: 0.5046
# Epoch 22/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - auc: 0.9637 - categorical_accuracy: 0.7472 - loss: 0.6791 - precision: 0.8425 - recall: 0.6389 - val_auc: 0.9120 - val_categorical_accuracy: 0.6111 - val_loss: 1.0453 - val_precision: 0.7566 - val_recall: 0.5324
# Epoch 23/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - auc: 0.9666 - categorical_accuracy: 0.7738 - loss: 0.6518 - precision: 0.8677 - recall: 0.6639 - val_auc: 0.9137 - val_categorical_accuracy: 0.6173 - val_loss: 1.0341 - val_precision: 0.7643 - val_recall: 0.5355
# Epoch 24/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - auc: 0.9680 - categorical_accuracy: 0.7634 - loss: 0.6403 - precision: 0.8630 - recall: 0.6633 - val_auc: 0.9121 - val_categorical_accuracy: 0.5988 - val_loss: 1.0438 - val_precision: 0.7611 - val_recall: 0.5309
# Epoch 25/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - auc: 0.9703 - categorical_accuracy: 0.7836 - loss: 0.6227 - precision: 0.8780 - recall: 0.6720 - val_auc: 0.9133 - val_categorical_accuracy: 0.6250 - val_loss: 1.0401 - val_precision: 0.7757 - val_recall: 0.5231
# Epoch 26/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - auc: 0.9708 - categorical_accuracy: 0.7712 - loss: 0.6181 - precision: 0.8676 - recall: 0.6720 - val_auc: 0.9117 - val_categorical_accuracy: 0.6235 - val_loss: 1.0632 - val_precision: 0.7598 - val_recall: 0.5370
# Epoch 27/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - auc: 0.9727 - categorical_accuracy: 0.7786 - loss: 0.5994 - precision: 0.8755 - recall: 0.6763 - val_auc: 0.9128 - val_categorical_accuracy: 0.6142 - val_loss: 1.0504 - val_precision: 0.7431 - val_recall: 0.5401
# Epoch 28/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - auc: 0.9735 - categorical_accuracy: 0.7813 - loss: 0.5875 - precision: 0.8799 - recall: 0.6957 - val_auc: 0.9119 - val_categorical_accuracy: 0.6204 - val_loss: 1.0646 - val_precision: 0.7505 - val_recall: 0.5478
# Epoch 29/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - auc: 0.9747 - categorical_accuracy: 0.7912 - loss: 0.5783 - precision: 0.8802 - recall: 0.6975 - val_auc: 0.9083 - val_categorical_accuracy: 0.6065 - val_loss: 1.1044 - val_precision: 0.7213 - val_recall: 0.5432
# Epoch 30/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - auc: 0.9746 - categorical_accuracy: 0.7918 - loss: 0.5729 - precision: 0.8787 - recall: 0.7058 - val_auc: 0.9089 - val_categorical_accuracy: 0.6250 - val_loss: 1.0979 - val_precision: 0.7175 - val_recall: 0.5370
# Epoch 31/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - auc: 0.9763 - categorical_accuracy: 0.8042 - loss: 0.5596 - precision: 0.8957 - recall: 0.7134 - val_auc: 0.9111 - val_categorical_accuracy: 0.6173 - val_loss: 1.0959 - val_precision: 0.7247 - val_recall: 0.5525
# Epoch 32/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - auc: 0.9780 - categorical_accuracy: 0.8062 - loss: 0.5368 - precision: 0.8866 - recall: 0.7288 - val_auc: 0.9108 - val_categorical_accuracy: 0.6127 - val_loss: 1.0981 - val_precision: 0.7112 - val_recall: 0.5509
# Epoch 33/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - auc: 0.9787 - categorical_accuracy: 0.8142 - loss: 0.5323 - precision: 0.8851 - recall: 0.7328 - val_auc: 0.9117 - val_categorical_accuracy: 0.6096 - val_loss: 1.0919 - val_precision: 0.7267 - val_recall: 0.5417
# Epoch 34/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - auc: 0.9795 - categorical_accuracy: 0.8076 - loss: 0.5213 - precision: 0.8972 - recall: 0.7310 - val_auc: 0.9141 - val_categorical_accuracy: 0.6281 - val_loss: 1.0789 - val_precision: 0.7213 - val_recall: 0.5432
# Epoch 35/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - auc: 0.9811 - categorical_accuracy: 0.8255 - loss: 0.5056 - precision: 0.8914 - recall: 0.7499 - val_auc: 0.9128 - val_categorical_accuracy: 0.6296 - val_loss: 1.0874 - val_precision: 0.7277 - val_recall: 0.5401
# Epoch 36/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - auc: 0.9804 - categorical_accuracy: 0.8154 - loss: 0.5106 - precision: 0.8972 - recall: 0.7390 - val_auc: 0.9096 - val_categorical_accuracy: 0.6188 - val_loss: 1.1117 - val_precision: 0.7183 - val_recall: 0.5509
# Epoch 37/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - auc: 0.9820 - categorical_accuracy: 0.8245 - loss: 0.4932 - precision: 0.8927 - recall: 0.7415 - val_auc: 0.9085 - val_categorical_accuracy: 0.6188 - val_loss: 1.1365 - val_precision: 0.7197 - val_recall: 0.5309
# Epoch 38/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - auc: 0.9799 - categorical_accuracy: 0.8198 - loss: 0.5143 - precision: 0.8863 - recall: 0.7533 - val_auc: 0.9091 - val_categorical_accuracy: 0.6235 - val_loss: 1.1339 - val_precision: 0.7305 - val_recall: 0.5478
# Epoch 39/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - auc: 0.9798 - categorical_accuracy: 0.8209 - loss: 0.5154 - precision: 0.8904 - recall: 0.7366 - val_auc: 0.8981 - val_categorical_accuracy: 0.5957 - val_loss: 1.2586 - val_precision: 0.6832 - val_recall: 0.5324
# Epoch 40/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - auc: 0.9790 - categorical_accuracy: 0.8173 - loss: 0.5247 - precision: 0.8945 - recall: 0.7414 - val_auc: 0.8988 - val_categorical_accuracy: 0.6080 - val_loss: 1.2513 - val_precision: 0.6719 - val_recall: 0.5309
# Epoch 41/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - auc: 0.9783 - categorical_accuracy: 0.8056 - loss: 0.5287 - precision: 0.8757 - recall: 0.7415 - val_auc: 0.8978 - val_categorical_accuracy: 0.6080 - val_loss: 1.2517 - val_precision: 0.6755 - val_recall: 0.5525
# Epoch 42/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - auc: 0.9770 - categorical_accuracy: 0.8145 - loss: 0.5388 - precision: 0.8639 - recall: 0.7530 - val_auc: 0.9087 - val_categorical_accuracy: 0.6157 - val_loss: 1.1567 - val_precision: 0.6840 - val_recall: 0.5478
# Epoch 43/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - auc: 0.9839 - categorical_accuracy: 0.8405 - loss: 0.4630 - precision: 0.8979 - recall: 0.7776 - val_auc: 0.9054 - val_categorical_accuracy: 0.6111 - val_loss: 1.1861 - val_precision: 0.6845 - val_recall: 0.5525
# Epoch 44/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - auc: 0.9864 - categorical_accuracy: 0.8448 - loss: 0.4345 - precision: 0.9170 - recall: 0.7878 - val_auc: 0.9084 - val_categorical_accuracy: 0.6265 - val_loss: 1.1462 - val_precision: 0.6868 - val_recall: 0.5617
# Epoch 45/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - auc: 0.9874 - categorical_accuracy: 0.8609 - loss: 0.4178 - precision: 0.9012 - recall: 0.7944 - val_auc: 0.9100 - val_categorical_accuracy: 0.6281 - val_loss: 1.1521 - val_precision: 0.7021 - val_recall: 0.5710
# Epoch 46/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - auc: 0.9867 - categorical_accuracy: 0.8550 - loss: 0.4237 - precision: 0.9104 - recall: 0.7986 - val_auc: 0.9088 - val_categorical_accuracy: 0.6219 - val_loss: 1.1641 - val_precision: 0.6852 - val_recall: 0.5710
# Epoch 47/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - auc: 0.9890 - categorical_accuracy: 0.8678 - loss: 0.3949 - precision: 0.9130 - recall: 0.8098 - val_auc: 0.9040 - val_categorical_accuracy: 0.6204 - val_loss: 1.2042 - val_precision: 0.6906 - val_recall: 0.5787
# Epoch 48/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - auc: 0.9904 - categorical_accuracy: 0.8727 - loss: 0.3752 - precision: 0.9193 - recall: 0.8195 - val_auc: 0.9052 - val_categorical_accuracy: 0.6096 - val_loss: 1.1965 - val_precision: 0.6923 - val_recall: 0.5694
# Epoch 49/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - auc: 0.9897 - categorical_accuracy: 0.8765 - loss: 0.3825 - precision: 0.9171 - recall: 0.8232 - val_auc: 0.9086 - val_categorical_accuracy: 0.6127 - val_loss: 1.1920 - val_precision: 0.6798 - val_recall: 0.5602
# Epoch 50/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - auc: 0.9910 - categorical_accuracy: 0.8729 - loss: 0.3647 - precision: 0.9217 - recall: 0.8235 - val_auc: 0.9060 - val_categorical_accuracy: 0.6173 - val_loss: 1.2257 - val_precision: 0.6735 - val_recall: 0.5602

# %% [markdown]
# #### Plot metrics

# %%
# Training and Validation Loss

plt.figure(figsize=(12,6))
plt.plot(training_history.history['loss'], label='Training Loss')
plt.plot(training_history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training and Validation Loss')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Training and Validation Accuracy
plt.figure(figsize=(12,6))
plt.plot(training_history.history['categorical_accuracy'], label='Training Accuracy')
plt.plot(training_history.history['val_categorical_accuracy'], label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Training and Validation Accuracy')
plt.legend()
plt.grid(True)
plt.ylim([0, 1])
plt.show()

# %% [markdown]
# #### Test:

# %%
full_eval_best_model = tf.keras.models.load_model(full_eval_best_model_file_name)

print("Model with lowest validation Loss:")
print(simclr_utitlities.evaluate_model_simple(full_eval_best_model.predict(X_test_normalized), np_test_labels, return_dict=True))
print("Model in last epoch")
print(simclr_utitlities.evaluate_model_simple(full_evaluation_model.predict(X_test_normalized), np_test_labels, return_dict=True))

# %% [markdown]
# ## Extra: t-SNE Plots

# %% [markdown]
# ### Parameters

# %%
import sklearn.manifold
import seaborn as sns

# %% [markdown]
# ### t-SNE Representations

# %%
# First load the model from the file path
target_model_path = simclr_model_save_path
loaded_model = tf.keras.models.load_model(target_model_path)
perplexity = 30.0

# Then extract the intermediate model
intermediate_model = simclr_models.extract_intermediate_model_from_base_model(loaded_model, intermediate_layer=7)
intermediate_model.summary()

# Continue with your t-SNE code
embeddings = intermediate_model.predict(X_test_normalized, batch_size=600)
tsne_model = sklearn.manifold.TSNE(perplexity=perplexity, verbose=1, random_state=42)
tsne_projections = tsne_model.fit_transform(embeddings)
# Out:
# WARNING:absl:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# Model: "base_model_simclr_layer_7"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input (InputLayer)              │ (None, 100, 3)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d (Conv1D)                 │ (None, 77, 32)         │         2,336 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 77, 32)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_1 (Conv1D)               │ (None, 62, 64)         │        32,832 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 62, 64)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_2 (Conv1D)               │ (None, 55, 96)         │        49,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 55, 96)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_max_pooling1d            │ (None, 96)             │             0 │
# │ (GlobalMaxPooling1D)            │                        │               │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 84,416 (329.75 KB)
#  Trainable params: 84,416 (329.75 KB)
#  Non-trainable params: 0 (0.00 B)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 690ms/step
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 810 samples in 0.001s...
# [t-SNE] Computed neighbors for 810 samples in 0.065s...
# [t-SNE] Computed conditional probabilities for sample 810 / 810
# [t-SNE] Mean sigma: 1.590212
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 60.765652
# [t-SNE] KL divergence after 1000 iterations: 0.666885

# %% [markdown]
# ### Plotting

# %%
# Get the true labels (class indices) from the one-hot encoded test labels
labels_argmax = np.argmax(np_test_labels, axis=1)
unique_labels = np.unique(labels_argmax)

# Create the t-SNE visualization
plt.figure(figsize=(16,8))
graph = sns.scatterplot(
    x=tsne_projections[:,0], y=tsne_projections[:,1],
    hue=labels_argmax,
    palette=sns.color_palette("hsv", len(unique_labels)),
    s=50,
    alpha=1.0,
    rasterized=True
)
plt.xticks([], [])
plt.yticks([], [])

plt.title("t-SNE Visualization of SimCLR Embeddings")

# If you have class names, use them for the legend
# Define your activity names if needed
label_list_full_name = ["asphalt", "cobblestone", "compact_gravel", "curb_0", "curb_1", "dirt", "paving_stone"]  # Replace with your actual class names

# Update legend with class names if available
try:
    plt.legend(loc='lower left', bbox_to_anchor=(0.25, -0.3), ncol=2)
    legend = graph.legend_
    if 'label_list_full_name' in globals():  # Check if variable exists
        for j, label in enumerate(unique_labels):
            if label < len(label_list_full_name):
                legend.get_texts()[j].set_text(label_list_full_name[label])
except Exception as e:
    print(f"Warning: Could not customize legend - {e}")
    plt.legend(loc='lower left', bbox_to_anchor=(0.25, -0.3), ncol=2)

# %%
# Create a figure with 6 subplots (3x2 grid) to compare curb_1 with each other class
plt.figure(figsize=(20, 15))

# Get the true labels (class indices) from the one-hot encoded test labels
labels_argmax = np.argmax(np_test_labels, axis=1)
unique_labels = np.unique(labels_argmax)
curb_1_index = 4  # Based on your label_list_full_name where "curb_1" is at index 4

# Define your surface type names
label_list_full_name = ["asphalt", "cobblestone", "compact_gravel", "curb_0", "curb_1", "dirt", "paving_stone"]

# Loop through each class (except curb_1) and create a subplot
subplot_index = 1
for class_index in unique_labels:
    # Skip curb_1 as we're comparing others against it
    if class_index == curb_1_index:
        continue

    # Create binary mask for current pair (curb_1 and current class)
    mask = np.logical_or(labels_argmax == curb_1_index, labels_argmax == class_index)

    # Create binary labels: 0 for current class, 1 for curb_1
    binary_labels = np.zeros(np.sum(mask))
    binary_labels[labels_argmax[mask] == curb_1_index] = 1

    # Get the filtered t-SNE projections
    filtered_projections = tsne_projections[mask]

    # Create subplot
    plt.subplot(3, 2, subplot_index)

    # Plot the scatter points
    sns.scatterplot(
        x=filtered_projections[:, 0],
        y=filtered_projections[:, 1],
        hue=binary_labels,
        palette=["#1f77b4", "#ff7f0e"],  # Blue for other class, Orange for curb_1
        s=60,
        alpha=0.8
    )

    # Remove axes ticks for cleaner visualization
    plt.xticks([], [])
    plt.yticks([], [])

    # Set subplot title
    plt.title(f"curb_1 vs. {label_list_full_name[class_index]}", fontsize=14)

    # Custom legend
    plt.legend([label_list_full_name[class_index], "curb_1"], fontsize=12)

    # Increment subplot index
    subplot_index += 1

# Add overall title
plt.suptitle("t-SNE Comparison of Curb_1 vs. Each Other Surface Type", fontsize=18, y=0.98)
plt.tight_layout()
plt.show()
