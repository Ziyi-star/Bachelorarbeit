# %% [markdown]
# <a href="https://colab.research.google.com/github/Ziyi-star/Bachelorarbeit/blob/main/notebooks/training/train_1s_30hz_2class_real_world_phase_1_to_3_version_b.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Training using real world data phase 1 to 3

# %% [markdown]
# ## 1. VSCode: data loading

# %%
# %load_ext autoreload
# %autoreload 2

import os
import pickle
import scipy
import datetime
import numpy as np
import tensorflow as tf
import simclr_utitlities
import transformations
import simclr_models
import sys
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from keras.utils import to_categorical

sys.path.append('../')   # Add parent directory to Python path
working_directory = "../models/"
sys.path.append('../../')
from utils.preprocessing import *

seed = 1
tf.random.set_seed(seed)
np.random.seed(seed)

# %%
# Save combined balanced data as pickle file
with open('../training_data/lab_real_world_2class_balanced_version_b/X_train_normalized.pkl', 'wb') as f:
    np_train_balanced_data = pickle.load(f)
# Out:
# Saved combined balanced data with shape: (2048, 30, 3)

# %%
# load unbalanced data
with open('../training_data/lab_real_world_2class_unbalanced_version_b/X_train_normalized.pkl', 'rb') as f:
    np_train_unbalanced_data = pickle.load(f)
with open('../training_data/lab_real_world_2class_unbalanced_version_b/y_train_onehot.pkl', 'rb') as f:
    np_train_unbalanced_labels = pickle.load(f)
with open('../training_data/lab_real_world_2class_unbalanced_version_b/X_val_normalized.pkl', 'rb') as f:
    np_val_unbalanced_data = pickle.load(f)
with open('../training_data/lab_real_world_2class_unbalanced_version_b/y_val_onehot.pkl', 'rb') as f:
    np_val_unbalanced_labels = pickle.load(f)
with open('../training_data/lab_real_world_2class_unbalanced_version_b/X_test_normalized.pkl', 'rb') as f:
    np_test_unbalanced_data = pickle.load(f)
with open('../training_data/lab_real_world_2class_unbalanced_version_b/y_test_onehot.pkl', 'rb') as f:
    np_test_unbalanced_labels = pickle.load(f)
np_train_unbalanced_data.shape, np_train_unbalanced_labels.shape, np_val_unbalanced_data.shape, np_val_unbalanced_labels.shape, np_test_unbalanced_data.shape, np_test_unbalanced_labels.shape
# Out:
# ((27877, 30, 3),
#  (27877, 2),
#  (6970, 30, 3),
#  (6970, 2),
#  (3441, 30, 3),
#  (3441, 2))

# %%
# For Google Colab

# %%
# 1. Clone your repository to go to access your notebook and .py files
# !git clone https://github.com/Ziyi-star/Bachelorarbeit.git
# 2. Change working directory to where your notebook and .py files are
import os
os.chdir('/content/Bachelorarbeit/notebooks/training')
import os
import pickle
import scipy
import datetime
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import simclr_utitlities
import transformations
import simclr_models
import sys
sys.path.append('../../')
from utils.preprocessing import *



seed = 1
tf.random.set_seed(seed)
np.random.seed(seed)

# Load balanced data for simclr pretraining
# Download the file from GitHub
# !rm -f *.pkl # Remove existing pickle files
# !wget https://raw.githubusercontent.com/Ziyi-star/Bachelorarbeit/main/notebooks/training_data/lab_real_world_2class_balanced_version_b/X_train_normalized.pkl

working_directory = "../models/"  # Relative path to models folder

# Load as usual
import pickle

with open('X_train_normalized.pkl', 'rb') as f:
    np_train_balanced_data = pickle.load(f)

print(np_train_balanced_data.shape)
# Out:
# Cloning into 'Bachelorarbeit'...
# remote: Enumerating objects: 1533, done.
# remote: Counting objects: 100% (18/18), done.
# remote: Compressing objects: 100% (15/15), done.
# remote: Total 1533 (delta 4), reused 9 (delta 3), pack-reused 1515 (from 2)
# Receiving objects: 100% (1533/1533), 392.42 MiB | 13.52 MiB/s, done.
# Resolving deltas: 100% (878/878), done.
# Updating files: 100% (66/66), done.
# /content/Bachelorarbeit/notebooks/training/transformations.py:35: SyntaxWarning: invalid escape sequence '\&'
#   @inproceedings{TerryUm_ICMI2017, author = {Um, Terry T. and Pfister, Franz M. J. and Pichler, Daniel and Endo, Satoshi and Lang, Muriel and Hirche, Sandra and Fietzek, Urban and Kuli\'{c}, Dana}, title = {Data Augmentation of Wearable Sensor Data for Parkinson's Disease Monitoring Using Convolutional Neural Networks}, booktitle = {Proceedings of the 19th ACM International Conference on Multimodal Interaction}, series = {ICMI 2017}, year = {2017}, isbn = {978-1-4503-5543-8}, location = {Glasgow, UK}, pages = {216--220}, numpages = {5}, doi = {10.1145/3136755.3136817}, acmid = {3136817}, publisher = {ACM}, address = {New York, NY, USA}, keywords = {Parkinson\&#39;s disease, convolutional neural networks, data augmentation, health monitoring, motor state detection, wearable sensor}, }
# --2025-12-08 10:31:12--  https://raw.githubusercontent.com/Ziyi-star/Bachelorarbeit/main/notebooks/training_data/lab_real_world_2class_balanced_version_b/X_train_normalized.pkl
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1525845 (1.5M) [application/octet-stream]
# Saving to: ‘X_train_normalized.pkl’
#
# X_train_normalized. 100%[===================>]   1.46M  --.-KB/s    in 0.008s
#
# 2025-12-08 10:31:12 (175 MB/s) - ‘X_train_normalized.pkl’ saved [1525845/1525845]
#
# (2119, 30, 3)

# %%
# Load unbalanced data for evluation
# Download the file from GitHub
# !rm -f *.pkl # Remove existing pickle files
# !wget https://raw.githubusercontent.com/Ziyi-star/Bachelorarbeit/main/notebooks/training_data/lab_real_world_2class_unbalanced_version_b/X_train_normalized.pkl
# !wget https://raw.githubusercontent.com/Ziyi-star/Bachelorarbeit/main/notebooks/training_data/lab_real_world_2class_unbalanced_version_b/y_train_onehot.pkl
# !wget https://raw.githubusercontent.com/Ziyi-star/Bachelorarbeit/main/notebooks/training_data/lab_real_world_2class_unbalanced_version_b/X_val_normalized.pkl
# !wget https://raw.githubusercontent.com/Ziyi-star/Bachelorarbeit/main/notebooks/training_data/lab_real_world_2class_unbalanced_version_b/y_val_onehot.pkl
# !wget https://raw.githubusercontent.com/Ziyi-star/Bachelorarbeit/main/notebooks/training_data/lab_real_world_2class_unbalanced_version_b/X_test_normalized.pkl
# !wget https://raw.githubusercontent.com/Ziyi-star/Bachelorarbeit/main/notebooks/training_data/lab_real_world_2class_unbalanced_version_b/y_test_onehot.pkl


working_directory = "../models/"  # Relative path to models folder


# Load as usual
import pickle

with open('X_train_normalized.pkl', 'rb') as f:
    np_train_unbalanced_data = pickle.load(f)
with open('y_train_onehot.pkl', 'rb') as f:
    np_train_unbalanced_labels = pickle.load(f)
with open('X_val_normalized.pkl', 'rb') as f:
    np_val_unbalanced_data = pickle.load(f)
with open('y_val_onehot.pkl', 'rb') as f:
    np_val_unbalanced_labels = pickle.load(f)
with open('X_test_normalized.pkl', 'rb') as f:
    np_test_unbalanced_data = pickle.load(f)
with open('y_test_onehot.pkl', 'rb') as f:
    np_test_unbalanced_labels = pickle.load(f)

print(np_train_unbalanced_data.shape, np_train_unbalanced_labels.shape)
print(np_val_unbalanced_data.shape, np_val_unbalanced_labels.shape)
print(np_test_unbalanced_data.shape, np_test_unbalanced_labels.shape)
# Out:
# --2025-12-08 10:31:59--  https://raw.githubusercontent.com/Ziyi-star/Bachelorarbeit/main/notebooks/training_data/lab_real_world_2class_unbalanced_version_b/X_train_normalized.pkl
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 20071605 (19M) [application/octet-stream]
# Saving to: ‘X_train_normalized.pkl’
#
# X_train_normalized. 100%[===================>]  19.14M  --.-KB/s    in 0.04s
#
# 2025-12-08 10:31:59 (501 MB/s) - ‘X_train_normalized.pkl’ saved [20071605/20071605]
#
# --2025-12-08 10:31:59--  https://raw.githubusercontent.com/Ziyi-star/Bachelorarbeit/main/notebooks/training_data/lab_real_world_2class_unbalanced_version_b/y_train_onehot.pkl
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.111.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length:
# Epoch 6/50
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - auc: 0.9894 - categorical_accuracy: 0.9695 - loss: 0.1057 - precision: 0.9695 - recall: 0.9695 - val_auc: 0.9936 - val_categorical_accuracy: 0.9742 - val_loss: 0.0921 - val_precision: 0.9742 - val_recall: 0.9742
# Epoch 7/50
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - auc: 0.9894 - categorical_accuracy: 0.9697 - loss: 0.1061 - precision: 0.9697 - recall: 0.9697 - val_auc: 0.9936 - val_categorical_accuracy: 0.9753 - val_loss: 0.0897 - val_precision: 0.9753 - val_recall: 0.9753
# Epoch 8/50
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - auc: 0.9889 - categorical_accuracy: 0.9694 - loss: 0.1073 - precision: 0.9694 - recall: 0.9694 - val_auc: 0.9937 - val_categorical_accuracy: 0.9749 - val_loss: 0.0891 - val_precision: 0.9749 - val_recall: 0.9749
# Epoch 9/50
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - auc: 0.9897 - categorical_accuracy: 0.9691 - loss: 0.1066 - precision: 0.9691 - recall: 0.9691 - val_auc: 0.9939 - val_categorical_accuracy: 0.9740 - val_loss: 0.0901 - val_precision: 0.9740 - val_recall: 0.9740
# Epoch 10/50
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - auc: 0.9896 - categorical_accuracy: 0.9691 - loss: 0.1061 - precision: 0.9691 - recall: 0.9691 - val_auc: 0.9936 - val_categorical_accuracy: 0.9750 - val_loss: 0.0880 - val_precision: 0.9750 - val_recall: 0.9750
# Epoch 11/50
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - auc: 0.9901 - categorical_accuracy: 0.9698 - loss: 0.1035 - precision: 0.9698 - recall: 0.9698 - val_auc: 0.9940 - val_categorical_accuracy: 0.9746 - val_loss: 0.0886 - val_precision: 0.9746 - val_recall: 0.9746
# Epoch 12/50
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - auc: 0.9897 - categorical_accuracy: 0.9688 - loss: 0.1067 - precision: 0.9688 - recall: 0.9688 - val_auc: 0.9939 - val_categorical_accuracy: 0.9758 - val_loss: 0.0865 - val_precision: 0.9758 - val_recall: 0.9758
# Epoch 13/50
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - auc: 0.9903 - categorical_accuracy: 0.9702 - loss: 0.1036 - precision: 0.9702 - recall: 0.9702 - val_auc: 0.9941 - val_categorical_accuracy: 0.9749 - val_loss: 0.0876 - val_precision: 0.9749 - val_recall: 0.9749
# Epoch 14/50
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - auc: 0.9910 - categorical_accuracy: 0.9698 - loss: 0.1000 - precision: 0.9698 - recall: 0.9698 - val_auc: 0.9939 - val_categorical_accuracy: 0.9760 - val_loss: 0.0862 - val_precision: 0.9760 - val_recall: 0.9760
# Epoch 15/50
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - auc: 0.9903 - categorical_accuracy: 0.9691 - loss: 0.1049 - precision: 0.9691 - recall: 0.9691 - val_auc: 0.9938 - val_categorical_accuracy: 0.9755 - val_loss: 0.0855 - val_precision: 0.9755 - val_recall: 0.9755
# Epoch 16/50
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - auc: 0.9901 - categorical_accuracy: 0.9686 - loss: 0.1055 - precision: 0.9686 - recall: 0.9686 - val_auc: 0.9939 - val_categorical_accuracy: 0.9756 - val_loss: 0.0852 - val_precision: 0.9756 - val_recall: 0.9756
# Epoch 17/50
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - auc: 0.9908 - categorical_accuracy: 0.9709 - loss: 0.1004 - precision: 0.9709 - recall: 0.9709 - val_auc: 0.9939 - val_categorical_accuracy: 0.9752 - val_loss: 0.0853 - val_precision: 0.9752 - val_recall: 0.9752
# Epoch 18/50
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - auc: 0.9900 - categorical_accuracy: 0.9705 - loss: 0.1044 - precision: 0.9705 - recall: 0.9705 - val_auc: 0.9936 - val_categorical_accuracy: 0.9753 - val_loss: 0.0868 - val_precision: 0.9753 - val_recall: 0.9753
# Epoch 19/50
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - auc: 0.9909 - categorical_accuracy: 0.9694 - loss: 0.1011 - precision: 0.9694 - recall: 0.9694 - val_auc: 0.9941 - val_categorical_accuracy: 0.9759 - val_loss: 0.0852 - val_precision: 0.9759 - val_recall: 0.9759
# Epoch 20/50
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - auc: 0.9908 - categorical_accuracy: 0.9709 - loss: 0.1011 - precision: 0.9709 - recall: 0.9709 - val_auc: 0.9938 - val_categorical_accuracy: 0.9756 - val_loss: 0.0860 - val_precision: 0.9756 - val_recall: 0.9756
# Epoch 21/50
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - auc: 0.9913 - categorical_accuracy: 0.9707 - loss: 0.0986 - precision: 0.9707 - recall: 0.9707 - val_auc: 0.9940 - val_categorical_accuracy: 0.9745 - val_loss: 0.0850 - val_precision: 0.9745 - val_recall: 0.9745
# Epoch 22/50
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - auc: 0.9905 - categorical_accuracy: 0.9711 - loss: 0.1010 - precision: 0.9711 - recall: 0.9711 - val_auc: 0.9941 - val_categorical_accuracy: 0.9758 - val_loss: 0.0849 - val_precision: 0.9758 - val_recall: 0.9758
# Epoch 23/50
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - auc: 0.9905 - categorical_accuracy: 0.9694 - loss: 0.1019 - precision: 0.9694 - recall: 0.9694 - val_auc: 0.9939 - val_categorical_accuracy: 0.9758 - val_loss: 0.0847 - val_precision: 0.9758 - val_recall: 0.9758
# Epoch 24/50
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - auc: 0.9908 - categorical_accuracy: 0.9694 - loss: 0.1036 - precision: 0.9694 - recall: 0.9694 - val_auc: 0.9940 - val_categorical_accuracy: 0.9750 - val_loss: 0.0847 - val_precision: 0.9750 - val_recall: 0.9750
# Epoch 25/50
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - auc: 0.9903 - categorical_accuracy: 0.9697 - loss: 0.1044 - precision: 0.9697 - recall: 0.9697 - val_auc: 0.9938 - val_categorical_accuracy: 0.9755 - val_loss: 0.0851 - val_precision: 0.9755 - val_recall: 0.9755
# Epoch 26/50
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - auc: 0.9906 - categorical_accuracy: 0.9700 - loss: 0.1031 - precision: 0.9700 - recall: 0.9700 - val_auc: 0.9937 - val_categorical_accuracy: 0.9753 - val_loss: 0.0852 - val_precision: 0.9753 - val_recall: 0.9753
# Epoch 27/50
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - auc: 0.9913 - categorical_accuracy: 0.9703 - loss: 0.0985 - precision: 0.9703 - recall: 0.9703 - val_auc: 0.9938 - val_categorical_accuracy: 0.9755 - val_loss: 0.0856 - val_precision: 0.9755 - val_recall: 0.9755
# Epoch 28/50
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - auc: 0.9905 - categorical_accuracy: 0.9709 - loss: 0.1018 - precision: 0.9709 - recall: 0.9709 - val_auc: 0.9939 - val_categorical_accuracy: 0.9756 - val_loss: 0.0848 - val_precision: 0.9756 - val_recall: 0.9756
# Epoch 29/50
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - auc: 0.9911 - categorical_accuracy: 0.9708 - loss: 0.0978 - precision: 0.9708 - recall: 0.9708 - val_auc: 0.9943 - val_categorical_accuracy: 0.9753 - val_loss: 0.0833 - val_precision: 0.9753 - val_recall: 0.9753
# Epoch 30/50
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - auc: 0.9912 - categorical_accuracy: 0.9704 - loss: 0.0989 - precision: 0.9704 - recall: 0.9704 - val_auc: 0.9939 - val_categorical_accuracy: 0.9758 - val_loss: 0.0844 - val_precision: 0.9758 - val_recall: 0.9758
# Epoch 31/50
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - auc: 0.9907 - categorical_accuracy: 0.9699 - loss: 0.1020 - precision: 0.9699 - recall: 0.9699 - val_auc: 0.9942 - val_categorical_accuracy: 0.9762 - val_loss: 0.0836 - val_precision: 0.9762 - val_recall: 0.9762
# Epoch 32/50
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - auc: 0.9904 - categorical_accuracy: 0.9695 - loss: 0.1033 - precision: 0.9695 - recall: 0.9695 - val_auc: 0.9936 - val_categorical_accuracy: 0.9753 - val_loss: 0.0862 - val_precision: 0.9753 - val_recall: 0.9753
# Epoch 33/50
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - auc: 0.9913 - categorical_accuracy: 0.9699 - loss: 0.1006 - precision: 0.9699 - recall: 0.9699 - val_auc: 0.9940 - val_categorical_accuracy: 0.9755 - val_loss: 0.0836 - val_precision: 0.9755 - val_recall: 0.9755
# Epoch 34/50
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - auc: 0.9912 - categorical_accuracy: 0.9713 - loss: 0.0980 - precision: 0.9713 - recall: 0.9713 - val_auc: 0.9940 - val_categorical_accuracy: 0.9756 - val_loss: 0.0842 - val_precision: 0.9756 - val_recall: 0.9756
# Epoch 35/50
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - auc: 0.9911 - categorical_accuracy: 0.9695 - loss: 0.1032 - precision: 0.9695 - recall: 0.9695 - val_auc: 0.9941 - val_categorical_accuracy: 0.9765 - val_loss: 0.0835 - val_precision: 0.9765 - val_recall: 0.9765
# Epoch 36/50
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - auc: 0.9905 - categorical_accuracy: 0.9705 - loss: 0.1041 - precision: 0.9705 - recall: 0.9705 - val_auc: 0.9942 - val_categorical_accuracy: 0.9755 - val_loss: 0.0832 - val_precision: 0.9755 - val_recall: 0.9755
# Epoch 37/50
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - auc: 0.9913 - categorical_accuracy: 0.9695 - loss: 0.1009 - precision: 0.9695 - recall: 0.9695 - val_auc: 0.9942 - val_categorical_accuracy: 0.9762 - val_loss: 0.0834 - val_precision: 0.9762 - val_recall: 0.9762
# Epoch 38/50
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - auc: 0.9914 - categorical_accuracy: 0.9716 - loss: 0.0977 - precision: 0.9716 - recall: 0.9716 - val_auc: 0.9938 - val_categorical_accuracy: 0.9755 - val_loss: 0.0841 - val_precision: 0.9755 - val_recall: 0.9755
# Epoch 39/50
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - auc: 0.9909 - categorical_accuracy: 0.9705 - loss: 0.1022 - precision: 0.9705 - recall: 0.9705 - val_auc: 0.9934 - val_categorical_accuracy: 0.9753 - val_loss: 0.0860 - val_precision: 0.9753 - val_recall: 0.9753
# Epoch 40/50
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - auc: 0.9908 - categorical_accuracy: 0.9700 - loss: 0.1004 - precision: 0.9700 - recall: 0.9700 - val_auc: 0.9943 - val_categorical_accuracy: 0.9750 - val_loss: 0.0835 - val_precision: 0.9750 - val_recall: 0.9750
# Epoch 41/50
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - auc: 0.9909 - categorical_accuracy: 0.9708 - loss: 0.1002 - precision: 0.9708 - recall: 0.9708 - val_auc: 0.9939 - val_categorical_accuracy: 0.9752 - val_loss: 0.0847 - val_precision: 0.9752 - val_recall: 0.9752
# Epoch 42/50
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - auc: 0.9910 - categorical_accuracy: 0.9704 - loss: 0.1002 - precision: 0.9704 - recall: 0.9704 - val_auc: 0.9938 - val_categorical_accuracy: 0.9759 - val_loss: 0.0840 - val_precision: 0.9759 - val_recall: 0.9759
# Epoch 43/50
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - auc: 0.9908 - categorical_accuracy: 0.9708 - loss: 0.0990 - precision: 0.9708 - recall: 0.9708 - val_auc: 0.9938 - val_categorical_accuracy: 0.9752 - val_loss: 0.0852 - val_precision: 0.9752 - val_recall: 0.9752
# Epoch 44/50
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - auc: 0.9913 - categorical_accuracy: 0.9708 - loss: 0.0996 - precision: 0.9708 - recall: 0.9708 - val_auc: 0.9935 - val_categorical_accuracy: 0.9752 - val_loss: 0.0856 - val_precision: 0.9752 - val_recall: 0.9752
# Epoch 45/50
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - auc: 0.9907 - categorical_accuracy: 0.9708 - loss: 0.0995 - precision: 0.9708 - recall: 0.9708 - val_auc: 0.9941 - val_categorical_accuracy: 0.9763 - val_loss: 0.0831 - val_precision: 0.9763 - val_recall: 0.9763
# Epoch 46/50
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - auc: 0.9906 - categorical_accuracy: 0.9701 - loss: 0.1021 - precision: 0.9701 - recall: 0.9701 - val_auc: 0.9937 - val_categorical_accuracy: 0.9753 - val_loss: 0.0845 - val_precision: 0.9753 - val_recall: 0.9753
# Epoch 47/50
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - auc: 0.9908 - categorical_accuracy: 0.9704 - loss: 0.1017 - precision: 0.9704 - recall: 0.9704 - val_auc: 0.9941 - val_categorical_accuracy: 0.9769 - val_loss: 0.0832 - val_precision: 0.9769 - val_recall: 0.9769
# Epoch 48/50
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - auc: 0.9910 - categorical_accuracy: 0.9709 - loss: 0.1001 - precision: 0.9709 - recall: 0.9709 - val_auc: 0.9941 - val_categorical_accuracy: 0.9756 - val_loss: 0.0831 - val_precision: 0.9756 - val_recall: 0.9756
# Epoch 49/50
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - auc: 0.9903 - categorical_accuracy: 0.9699 - loss: 0.1036 - precision: 0.9699 - recall: 0.9699 - val_auc: 0.9944 - val_categorical_accuracy: 0.9750 - val_loss: 0.0829 - val_precision: 0.9750 - val_recall: 0.9750
# Epoch 50/50
# 218/218 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - auc: 0.9911 - categorical_accuracy: 0.9711 - loss: 0.1009 - precision: 0.9711 - recall: 0.9711 - val_auc: 0.9939 - val_categorical_accuracy: 0.9759 - val_loss: 0.0832 - val_precision: 0.9759 - val_recall: 0.9759

# %%
# Training and Validation Loss

plt.figure(figsize=(12,6))
plt.plot(training_history.history['loss'], label='Training Loss')
plt.plot(training_history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training and Validation Loss')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Training and Validation Accuracy
plt.figure(figsize=(12,6))
plt.plot(training_history.history['categorical_accuracy'], label='Training Accuracy')
plt.plot(training_history.history['val_categorical_accuracy'], label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Training and Validation Accuracy')
plt.legend()
plt.grid(True)
plt.ylim([0, 1])
plt.show()

# %% [markdown]
# #### Test:

# %%
# Load models and evaluate on test set on vscode
linear_eval_model_path =  linear_eval_best_model_file_name

# Load both models
# simclr_model = tf.keras.models.load_model(simclr_model_path)
linear_eval_best_model = tf.keras.models.load_model(linear_eval_model_path)

# %%
linear_eval_best_model = tf.keras.models.load_model(linear_eval_best_model_file_name)

print("Model with lowest validation Loss:")
print(simclr_utitlities.evaluate_model_simple(linear_eval_best_model.predict(np_test_unbalanced_data), np_test_unbalanced_labels, return_dict=True))
print("Model in last epoch")
print(simclr_utitlities.evaluate_model_simple(linear_evaluation_model.predict(np_test_unbalanced_data), np_test_unbalanced_labels, return_dict=True))
# Out:
# Model with lowest validation Loss:
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step
# {'Confusion Matrix': array([[3301,   74],
#        [  53,   13]]), 'F1 Macro': 0.5755305540257417, 'F1 Micro': 0.963092124382447, 'F1 Weighted': 0.9655674263829004, 'Precision': 0.5668116299631937, 'Recall': 0.5875218855218856, 'Kappa': np.float64(0.1514245935350076)}
# Model in last epoch
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step
# {'Confusion Matrix': array([[3309,   66],
#        [  54,   12]]), 'F1 Macro': 0.5744286138319976, 'F1 Micro': 0.96512641673932, 'F1 Weighted': 0.9665484287608207, 'Precision': 0.5688945309819529, 'Recall': 0.5811313131313132, 'Kappa': np.float64(0.148983528713459)}

# %% [markdown]
# ### 1.2.2 Full HAR Model

# %% [markdown]
# #### Train

# %%
total_epochs = 50
batch_size = 256
tag = "full_eval"
output_shape = np_train_unbalanced_labels.shape[1]  # Number of classes for classification

simclr_model = tf.keras.models.load_model(simclr_model_save_path)
full_evaluation_model = simclr_models.create_full_classification_model_from_base_model(
    simclr_model, output_shape, model_name="TPN", intermediate_layer=7, last_freeze_layer=4)

full_eval_best_model_file_name = f"{working_directory}{start_time_str}_simclr_{tag}.keras"

best_model_callback = tf.keras.callbacks.ModelCheckpoint(full_eval_best_model_file_name,
    monitor='val_loss', mode='min', save_best_only=True, save_weights_only=False, verbose=0
)

training_history = full_evaluation_model.fit(
    x = np_train_unbalanced_data,
    y = np_train_unbalanced_labels,
    batch_size=batch_size,
    shuffle=True,
    epochs=total_epochs,
    callbacks=[best_model_callback],
    validation_data=(np_val_unbalanced_data, np_val_unbalanced_labels)
)
# Out:
# WARNING:absl:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# Epoch 1/50
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 13s 60ms/step - auc: 0.9623 - categorical_accuracy: 0.9250 - loss: 0.2706 - precision: 0.9250 - recall: 0.9250 - val_auc: 0.9952 - val_categorical_accuracy: 0.9704 - val_loss: 0.0901 - val_precision: 0.9704 - val_recall: 0.9704
# Epoch 2/50
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - auc: 0.9944 - categorical_accuracy: 0.9720 - loss: 0.0914 - precision: 0.9720 - recall: 0.9720 - val_auc: 0.9958 - val_categorical_accuracy: 0.9706 - val_loss: 0.0869 - val_precision: 0.9706 - val_recall: 0.9706
# Epoch 3/50
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - auc: 0.9951 - categorical_accuracy: 0.9731 - loss: 0.0856 - precision: 0.9731 - recall: 0.9731 - val_auc: 0.9960 - val_categorical_accuracy: 0.9760 - val_loss: 0.0779 - val_precision: 0.9760 - val_recall: 0.9760
# Epoch 4/50
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - auc: 0.9953 - categorical_accuracy: 0.9760 - loss: 0.0818 - precision: 0.9760 - recall: 0.9760 - val_auc: 0.9964 - val_categorical_accuracy: 0.9783 - val_loss: 0.0751 - val_precision: 0.9783 - val_recall: 0.9783
# Epoch 5/50
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - auc: 0.9955 - categorical_accuracy: 0.9783 - loss: 0.0775 - precision: 0.9783 - recall: 0.9783 - val_auc: 0.9965 - val_categorical_accuracy: 0.9791 - val_loss: 0.0741 - val_precision: 0.9791 - val_recall: 0.9791
# Epoch 6/50
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - auc: 0.9957 - categorical_accuracy: 0.9793 - loss: 0.0752 - precision: 0.9793 - recall: 0.9793 - val_auc: 0.9966 - val_categorical_accuracy: 0.9803 - val_loss: 0.0707 - val_precision: 0.9803 - val_recall: 0.9803
# Epoch 7/50
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - auc: 0.9961 - categorical_accuracy: 0.9809 - loss: 0.0713 - precision: 0.9809 - recall: 0.9809 - val_auc: 0.9970 - val_categorical_accuracy: 0.9808 - val_loss: 0.0677 - val_precision: 0.9808 - val_recall: 0.9808
# Epoch 8/50
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - auc: 0.9965 - categorical_accuracy: 0.9823 - loss: 0.0668 - precision: 0.9823 - recall: 0.9823 - val_auc: 0.9963 - val_categorical_accuracy: 0.9801 - val_loss: 0.0703 - val_precision: 0.9801 - val_recall: 0.9801
# Epoch 9/50
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - auc: 0.9963 - categorical_accuracy: 0.9823 - loss: 0.0671 - precision: 0.9823 - recall: 0.9823 - val_auc: 0.9967 - val_categorical_accuracy: 0.9811 - val_loss: 0.0678 - val_precision: 0.9811 - val_recall: 0.9811
# Epoch 10/50
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - auc: 0.9966 - categorical_accuracy: 0.9828 - loss: 0.0649 - precision: 0.9828 - recall: 0.9828 - val_auc: 0.9970 - val_categorical_accuracy: 0.9822 - val_loss: 0.0665 - val_precision: 0.9822 - val_recall: 0.9822
# Epoch 11/50
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - auc: 0.9964 - categorical_accuracy: 0.9834 - loss: 0.0652 - precision: 0.9834 - recall: 0.9834 - val_auc: 0.9967 - val_categorical_accuracy: 0.9809 - val_loss: 0.0696 - val_precision: 0.9809 - val_recall: 0.9809
# Epoch 12/50
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - auc: 0.9969 - categorical_accuracy: 0.9831 - loss: 0.0629 - precision: 0.9831 - recall: 0.9831 - val_auc: 0.9969 - val_categorical_accuracy: 0.9801 - val_loss: 0.0713 - val_precision: 0.9801 - val_recall: 0.9801
# Epoch 13/50
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - auc: 0.9971 - categorical_accuracy: 0.9841 - loss: 0.0617 - precision: 0.9841 - recall: 0.9841 - val_auc: 0.9973 - val_categorical_accuracy: 0.9826 - val_loss: 0.0635 - val_precision: 0.9826 - val_recall: 0.9826
# Epoch 14/50
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - auc: 0.9970 - categorical_accuracy: 0.9834 - loss: 0.0603 - precision: 0.9834 - recall: 0.9834 - val_auc: 0.9970 - val_categorical_accuracy: 0.9832 - val_loss: 0.0647 - val_precision: 0.9832 - val_recall: 0.9832
# Epoch 15/50
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - auc: 0.9971 - categorical_accuracy: 0.9849 - loss: 0.0588 - precision: 0.9849 - recall: 0.9849 - val_auc: 0.9966 - val_categorical_accuracy: 0.9812 - val_loss: 0.0676 - val_precision: 0.9812 - val_recall: 0.9812
# Epoch 16/50
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - auc: 0.9973 - categorical_accuracy: 0.9848 - loss: 0.0582 - precision: 0.9848 - recall: 0.9848 - val_auc: 0.9960 - val_categorical_accuracy: 0.9819 - val_loss: 0.0699 - val_precision: 0.9819 - val_recall: 0.9819
# Epoch 17/50
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - auc: 0.9975 - categorical_accuracy: 0.9848 - loss: 0.0572 - precision: 0.9848 - recall: 0.9848 - val_auc: 0.9964 - val_categorical_accuracy: 0.9816 - val_loss: 0.0689 - val_precision: 0.9816 - val_recall: 0.9816
# Epoch 18/50
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - auc: 0.9974 - categorical_accuracy: 0.9856 - loss: 0.0565 - precision: 0.9856 - recall: 0.9856 - val_auc: 0.9968 - val_categorical_accuracy: 0.9839 - val_loss: 0.0623 - val_precision: 0.9839 - val_recall: 0.9839
# Epoch 19/50
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - auc: 0.9974 - categorical_accuracy: 0.9847 - loss: 0.0577 - precision: 0.9847 - recall: 0.9847 - val_auc: 0.9964 - val_categorical_accuracy: 0.9818 - val_loss: 0.0694 - val_precision: 0.9818 - val_recall: 0.9818
# Epoch 20/50
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - auc: 0.9975 - categorical_accuracy: 0.9855 - loss: 0.0557 - precision: 0.9855 - recall: 0.9855 - val_auc: 0.9966 - val_categorical_accuracy: 0.9822 - val_loss: 0.0674 - val_precision: 0.9822 - val_recall: 0.9822
# Epoch 21/50
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - auc: 0.9979 - categorical_accuracy: 0.9867 - loss: 0.0519 - precision: 0.9867 - recall: 0.9867 - val_auc: 0.9970 - val_categorical_accuracy: 0.9824 - val_loss: 0.0648 - val_precision: 0.9824 - val_recall: 0.9824
# Epoch 22/50
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - auc: 0.9980 - categorical_accuracy: 0.9869 - loss: 0.0524 - precision: 0.9869 - recall: 0.9869 - val_auc: 0.9949 - val_categorical_accuracy: 0.9811 - val_loss: 0.0784 - val_precision: 0.9811 - val_recall: 0.9811
# Epoch 23/50
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - auc: 0.9978 - categorical_accuracy: 0.9856 - loss: 0.0540 - precision: 0.9856 - recall: 0.9856 - val_auc: 0.9961 - val_categorical_accuracy: 0.9819 - val_loss: 0.0691 - val_precision: 0.9819 - val_recall: 0.9819
# Epoch 24/50
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - auc: 0.9979 - categorical_accuracy: 0.9862 - loss: 0.0537 - precision: 0.9862 - recall: 0.9862 - val_auc: 0.9966 - val_categorical_accuracy: 0.9831 - val_loss: 0.0669 - val_precision: 0.9831 - val_recall: 0.9831
# Epoch 25/50
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - auc: 0.9981 - categorical_accuracy: 0.9863 - loss: 0.0515 - precision: 0.9863 - recall: 0.9863 - val_auc: 0.9963 - val_categorical_accuracy: 0.9826 - val_loss: 0.0679 - val_precision: 0.9826 - val_recall: 0.9826
# Epoch 26/50
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - auc: 0.9982 - categorical_accuracy: 0.9877 - loss: 0.0492 - precision: 0.9877 - recall: 0.9877 - val_auc: 0.9955 - val_categorical_accuracy: 0.9826 - val_loss: 0.0684 - val_precision: 0.9826 - val_recall: 0.9826
# Epoch 27/50
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - auc: 0.9980 - categorical_accuracy: 0.9865 - loss: 0.0512 - precision: 0.9865 - recall: 0.9865 - val_auc: 0.9961 - val_categorical_accuracy: 0.9842 - val_loss: 0.0652 - val_precision: 0.9842 - val_recall: 0.9842
# Epoch 28/50
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - auc: 0.9980 - categorical_accuracy: 0.9871 - loss: 0.0506 - precision: 0.9871 - recall: 0.9871 - val_auc: 0.9961 - val_categorical_accuracy: 0.9835 - val_loss: 0.0680 - val_precision: 0.9835 - val_recall: 0.9835
# Epoch 29/50
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - auc: 0.9982 - categorical_accuracy: 0.9865 - loss: 0.0508 - precision: 0.9865 - recall: 0.9865 - val_auc: 0.9950 - val_categorical_accuracy: 0.9844 - val_loss: 0.0703 - val_precision: 0.9844 - val_recall: 0.9844
# Epoch 30/50
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - auc: 0.9980 - categorical_accuracy: 0.9871 - loss: 0.0490 - precision: 0.9871 - recall: 0.9871 - val_auc: 0.9964 - val_categorical_accuracy: 0.9835 - val_loss: 0.0653 - val_precision: 0.9835 - val_recall: 0.9835
# Epoch 31/50
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - auc: 0.9979 - categorical_accuracy: 0.9871 - loss: 0.0500 - precision: 0.9871 - recall: 0.9871 - val_auc: 0.9947 - val_categorical_accuracy: 0.9809 - val_loss: 0.0774 - val_precision: 0.9809 - val_recall: 0.9809
# Epoch 32/50
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - auc: 0.9981 - categorical_accuracy: 0.9879 - loss: 0.0487 - precision: 0.9879 - recall: 0.9879 - val_auc: 0.9936 - val_categorical_accuracy: 0.9819 - val_loss: 0.0795 - val_precision: 0.9819 - val_recall: 0.9819
# Epoch 33/50
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - auc: 0.9986 - categorical_accuracy: 0.9880 - loss: 0.0459 - precision: 0.9880 - recall: 0.9880 - val_auc: 0.9933 - val_categorical_accuracy: 0.9829 - val_loss: 0.0783 - val_precision: 0.9829 - val_recall: 0.9829
# Epoch 34/50
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - auc: 0.9979 - categorical_accuracy: 0.9874 - loss: 0.0489 - precision: 0.9874 - recall: 0.9874 - val_auc: 0.9954 - val_categorical_accuracy: 0.9841 - val_loss: 0.0684 - val_precision: 0.9841 - val_recall: 0.9841
# Epoch 35/50
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - auc: 0.9981 - categorical_accuracy: 0.9890 - loss: 0.0466 - precision: 0.9890 - recall: 0.9890 - val_auc: 0.9946 - val_categorical_accuracy: 0.9834 - val_loss: 0.0752 - val_precision: 0.9834 - val_recall: 0.9834
# Epoch 36/50
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - auc: 0.9986 - categorical_accuracy: 0.9882 - loss: 0.0444 - precision: 0.9882 - recall: 0.9882 - val_auc: 0.9950 - val_categorical_accuracy: 0.9836 - val_loss: 0.0720 - val_precision: 0.9836 - val_recall: 0.9836
# Epoch 37/50
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - auc: 0.9982 - categorical_accuracy: 0.9881 - loss: 0.0463 - precision: 0.9881 - recall: 0.9881 - val_auc: 0.9922 - val_categorical_accuracy: 0.9821 - val_loss: 0.0871 - val_precision: 0.9821 - val_recall: 0.9821
# Epoch 38/50
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - auc: 0.9980 - categorical_accuracy: 0.9888 - loss: 0.0471 - precision: 0.9888 - recall: 0.9888 - val_auc: 0.9945 - val_categorical_accuracy: 0.9835 - val_loss: 0.0757 - val_precision: 0.9835 - val_recall: 0.9835
# Epoch 39/50
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - auc: 0.9987 - categorical_accuracy: 0.9890 - loss: 0.0438 - precision: 0.9890 - recall: 0.9890 - val_auc: 0.9944 - val_categorical_accuracy: 0.9822 - val_loss: 0.0768 - val_precision: 0.9822 - val_recall: 0.9822
# Epoch 40/50
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - auc: 0.9984 - categorical_accuracy: 0.9877 - loss: 0.0464 - precision: 0.9877 - recall: 0.9877 - val_auc: 0.9952 - val_categorical_accuracy: 0.9831 - val_loss: 0.0718 - val_precision: 0.9831 - val_recall: 0.9831
# Epoch 41/50
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - auc: 0.9988 - categorical_accuracy: 0.9883 - loss: 0.0447 - precision: 0.9883 - recall: 0.9883 - val_auc: 0.9947 - val_categorical_accuracy: 0.9842 - val_loss: 0.0770 - val_precision: 0.9842 - val_recall: 0.9842
# Epoch 42/50
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - auc: 0.9989 - categorical_accuracy: 0.9888 - loss: 0.0409 - precision: 0.9888 - recall: 0.9888 - val_auc: 0.9936 - val_categorical_accuracy: 0.9828 - val_loss: 0.0802 - val_precision: 0.9828 - val_recall: 0.9828
# Epoch 43/50
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - auc: 0.9985 - categorical_accuracy: 0.9888 - loss: 0.0445 - precision: 0.9888 - recall: 0.9888 - val_auc: 0.9953 - val_categorical_accuracy: 0.9832 - val_loss: 0.0718 - val_precision: 0.9832 - val_recall: 0.9832
# Epoch 44/50
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - auc: 0.9988 - categorical_accuracy: 0.9894 - loss: 0.0438 - precision: 0.9894 - recall: 0.9894 - val_auc: 0.9942 - val_categorical_accuracy: 0.9832 - val_loss: 0.0795 - val_precision: 0.9832 - val_recall: 0.9832
# Epoch 45/50
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - auc: 0.9988 - categorical_accuracy: 0.9887 - loss: 0.0438 - precision: 0.9887 - recall: 0.9887 - val_auc: 0.9949 - val_categorical_accuracy: 0.9838 - val_loss: 0.0755 - val_precision: 0.9838 - val_recall: 0.9838
# Epoch 46/50
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - auc: 0.9988 - categorical_accuracy: 0.9901 - loss: 0.0413 - precision: 0.9901 - recall: 0.9901 - val_auc: 0.9939 - val_categorical_accuracy: 0.9829 - val_loss: 0.0816 - val_precision: 0.9829 - val_recall: 0.9829
# Epoch 47/50
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - auc: 0.9988 - categorical_accuracy: 0.9901 - loss: 0.0417 - precision: 0.9901 - recall: 0.9901 - val_auc: 0.9938 - val_categorical_accuracy: 0.9825 - val_loss: 0.0828 - val_precision: 0.9825 - val_recall: 0.9825
# Epoch 48/50
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - auc: 0.9990 - categorical_accuracy: 0.9903 - loss: 0.0392 - precision: 0.9903 - recall: 0.9903 - val_auc: 0.9949 - val_categorical_accuracy: 0.9826 - val_loss: 0.0758 - val_precision: 0.9826 - val_recall: 0.9826
# Epoch 49/50
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - auc: 0.9984 - categorical_accuracy: 0.9881 - loss: 0.0474 - precision: 0.9881 - recall: 0.9881 - val_auc: 0.9936 - val_categorical_accuracy: 0.9829 - val_loss: 0.0831 - val_precision: 0.9829 - val_recall: 0.9829
# Epoch 50/50
# 109/109 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - auc: 0.9990 - categorical_accuracy: 0.9897 - loss: 0.0416 - precision: 0.9897 - recall: 0.9897 - val_auc: 0.9941 - val_categorical_accuracy: 0.9826 - val_loss: 0.0802 - val_precision: 0.9826 - val_recall: 0.9826

# %% [markdown]
# #### Plot metrics

# %%
# Training and Validation Loss

plt.figure(figsize=(12,6))
plt.plot(training_history.history['loss'], label='Training Loss')
plt.plot(training_history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training and Validation Loss')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Training and Validation Accuracy
plt.figure(figsize=(12,6))
plt.plot(training_history.history['categorical_accuracy'], label='Training Accuracy')
plt.plot(training_history.history['val_categorical_accuracy'], label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Training and Validation Accuracy')
plt.legend()
plt.grid(True)
plt.ylim([0, 1])
plt.show()

# %% [markdown]
# # Evaluation of real world test data

# %%
full_eval_best_model = tf.keras.models.load_model(full_eval_best_model_file_name)

print("Model with lowest validation Loss:")
print(simclr_utitlities.evaluate_model_simple(full_eval_best_model.predict(np_test_unbalanced_data), np_test_unbalanced_labels, return_dict=True))
print("Model in last epoch")
print(simclr_utitlities.evaluate_model_simple(full_evaluation_model.predict(np_test_unbalanced_data), np_test_unbalanced_labels, return_dict=True))
# Out:
# Model with lowest validation Loss:
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step
# {'Confusion Matrix': array([[3312,   63],
#        [  54,   12]]), 'F1 Macro': 0.5764281453285232, 'F1 Micro': 0.9659982563208369, 'F1 Weighted': 0.967060720259907, 'Precision': 0.5719786096256685, 'Recall': 0.5815757575757575, 'Kappa': np.float64(0.15292847810032384)}
# Model in last epoch
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step
# {'Confusion Matrix': array([[3290,   85],
#        [  49,   17]]), 'F1 Macro': 0.591211328141623, 'F1 Micro': 0.9610578320255739, 'F1 Weighted': 0.9651258045705853, 'Precision': 0.5759958071278826, 'Recall': 0.6161952861952862, 'Kappa': np.float64(0.18336096233953925)}

# %% [markdown]
# #### Optimize

# %%
import numpy as np
import matplotlib.pyplot as plt


def evaluate_with_threshold(model, X_test, y_test, threshold=0.5):
    """
    Evaluate model with custom threshold.
    """
    y_pred_proba = model.predict(X_test)
    y_pred = (y_pred_proba[:, 1] >= threshold).astype(int)

    # Convert to one-hot for evaluate_model_simple
    y_pred_onehot = np.zeros_like(y_pred_proba)
    y_pred_onehot[np.arange(len(y_pred)), y_pred] = 1

    results = simclr_utitlities.evaluate_model_simple(y_pred_onehot, y_test, return_dict=True)

    return results, y_pred_proba
# Out:
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step
# === Threshold Analysis ===
# === Optimal Thresholds ===
# F1: Threshold = 0.121, Score = 0.209
# PRECISION: Threshold = 0.889, Score = 0.182
# RECALL: Threshold = 0.000, Score = 1.000
# YOUDEN: Threshold = 0.020, Score = 0.695
#
# === Default Threshold (0.5) ===
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# {'Confusion Matrix': array([[3312,   63],
#        [  54,   12]]), 'F1 Macro': 0.5764281453285232, 'F1 Micro': 0.9659982563208369, 'F1 Weighted': 0.967060720259907, 'Precision': 0.5719786096256685, 'Recall': 0.5815757575757575, 'Kappa': np.float64(0.15292847810032384)}
#
# === Optimal F1 Threshold (0.121) ===
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# {'Confusion Matrix': array([[3149,  226],
#        [  32,   34]]), 'F1 Macro': 0.5846178464348679, 'F1 Micro': 0.9250217959895379, 'F1 Weighted': 0.9462219135540986, 'Precision': 0.5603547505622325, 'Recall': 0.7240942760942761, 'Kappa': np.float64(0.18361187590004469)}
#
# === Comparison: Linear vs Full Model ===
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step
# Linear Model - Optimal F1 Threshold: 0.182
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# {'Confusion Matrix': array([[3174,  201],
#        [  26,   40]]), 'F1 Macro': 0.6130308021946719, 'F1 Micro': 0.934030804998547, 'F1 Weighted': 0.9519551829470722, 'Precision': 0.5789250518672199, 'Recall': 0.7732525252525253, 'Kappa': np.float64(0.23762828489861654)}
#
# Full Model - Optimal F1 Threshold: 0.121
# {'Confusion Matrix': array([[3149,  226],
#        [  32,   34]]), 'F1 Macro': 0.5846178464348679, 'F1 Micro': 0.9250217959895379, 'F1 Weighted': 0.9462219135540986, 'Precision': 0.5603547505622325, 'Recall': 0.7240942760942761, 'Kappa': np.float64(0.18361187590004469)}

# %%
# Get predictions for both models
y_pred_proba = full_eval_best_model.predict(np_test_unbalanced_data)
y_pred_proba_linear = linear_eval_best_model.predict(np_test_unbalanced_data)

# Set threshold
threshold = 0.1

# Evaluate Full Model with threshold 0.1
print(f"\n=== Full Model - Threshold {threshold} ===")
results_full, _ = evaluate_with_threshold(full_eval_best_model, np_test_unbalanced_data, np_test_unbalanced_labels, threshold=threshold)
print(results_full)

# Evaluate Linear Model with threshold 0.1
print(f"\n=== Linear Model - Threshold {threshold} ===")
results_linear, _ = evaluate_with_threshold(linear_eval_best_model, np_test_unbalanced_data, np_test_unbalanced_labels, threshold=threshold)
print(results_linear)

# Compare both models
print("\n=== Comparison: Linear vs Full Model (Threshold 0.1) ===")
print(f"Linear Model - Threshold: {threshold}")
print(results_linear)
print(f"\nFull Model - Threshold: {threshold}")
print(results_full)

# %% [markdown]
# ## Extra: t-SNE Plots

# %%
import sklearn.manifold
import seaborn as sns

# %% [markdown]
# ### t-SNE Representations

# %%
# First load the model from the file path
target_model_path = simclr_model_save_path
loaded_model = tf.keras.models.load_model(target_model_path)
perplexity = 30.0

# Then extract the intermediate model
intermediate_model = simclr_models.extract_intermediate_model_from_base_model(loaded_model, intermediate_layer=7)
intermediate_model.summary()

# Continue with your t-SNE code
embeddings = intermediate_model.predict(np_test_unbalanced_data, batch_size=600)
tsne_model = sklearn.manifold.TSNE(perplexity=perplexity, verbose=1, random_state=42)
tsne_projections = tsne_model.fit_transform(embeddings)
# Out:
# WARNING:absl:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# Model: "base_model_simclr_layer_7"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input (InputLayer)              │ (None, 30, 3)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_3 (Conv1D)               │ (None, 30, 32)         │         2,336 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 30, 32)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_4 (Conv1D)               │ (None, 30, 64)         │        32,832 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 30, 64)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_5 (Conv1D)               │ (None, 30, 96)         │        49,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_5 (Dropout)             │ (None, 30, 96)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_max_pooling1d            │ (None, 96)             │             0 │
# │ (GlobalMaxPooling1D)            │                        │               │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 84,416 (329.75 KB)
#  Trainable params: 84,416 (329.75 KB)
#  Non-trainable params: 0 (0.00 B)
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 161ms/step
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 3441 samples in 0.001s...
# [t-SNE] Computed neighbors for 3441 samples in 0.345s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 3441
# [t-SNE] Computed conditional probabilities for sample 2000 / 3441
# [t-SNE] Computed conditional probabilities for sample 3000 / 3441
# [t-SNE] Computed conditional probabilities for sample 3441 / 3441
# [t-SNE] Mean sigma: 0.039950
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 67.793518
# [t-SNE] KL divergence after 1000 iterations: 0.978581

# %% [markdown]
# ### Plotting

# %%
# Define colors
other_class_color = "#1f77b4"  # Blue
curb_1_color = "#ff7f0e"      # Yellow

# Get the true labels (class indices) from the one-hot encoded test labels
labels_argmax = np.argmax(np_test_unbalanced_labels, axis=1)
unique_labels = np.unique(labels_argmax)

# Create custom color palette
custom_palette = [other_class_color, curb_1_color]  # First color for non_curb (0), second for curb_1 (1)

# Create the t-SNE visualization
plt.figure(figsize=(16,8))
graph = sns.scatterplot(
    x=tsne_projections[:,0], y=tsne_projections[:,1],
    hue=labels_argmax,
    palette=custom_palette,  # Use custom palette instead of "hsv"
    s=50,
    alpha=1.0,
    rasterized=True
)
plt.xticks([], [])
plt.yticks([], [])

plt.title("t-SNE Visualization of SimCLR Embeddings")

# Define your activity names
label_list_full_name = ["non_curb", "curb_1"]

# Update legend with custom colors
try:
    plt.legend(loc='lower left', bbox_to_anchor=(0.25, -0.3), ncol=2)
    legend = graph.legend_
    if 'label_list_full_name' in globals():
        for j, label in enumerate(unique_labels):
            if label < len(label_list_full_name):
                legend.get_texts()[j].set_text(label_list_full_name[label])
except Exception as e:
    print(f"Warning: Could not customize legend - {e}")
    plt.legend(loc='lower left', bbox_to_anchor=(0.25, -0.3), ncol=2)
