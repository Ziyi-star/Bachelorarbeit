# %% [markdown]
# <a href="https://colab.research.google.com/github/Ziyi-star/Bachelorarbeit/blob/main/notebooks/training/train_simclr_har_0.5s.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # SimCLR Training

# %%
# For VSCode
# %load_ext autoreload
# %autoreload 2

import os
import pickle
import scipy
import datetime
import numpy as np
import tensorflow as tf
import simclr_utitlities
import transformations
import simclr_models
import sys
import matplotlib.pyplot as plt

sys.path.append('../')   # Add parent directory to Python path
working_directory = "../models/"
from utils.preprocessing import *

seed = 1
tf.random.set_seed(seed)
np.random.seed(seed)

with open('../data_1s_100hz/TrainTest/X_train_normalized.pkl', 'rb') as f:
    np_train_data = pickle.load(f)
with open('../data_1s_100hz/TrainTest/y_train_onehot.pkl', 'rb') as f:
    np_train_labels = pickle.load(f)
with open('../data_1s_100hz/TrainTest/X_val_normalized.pkl', 'rb') as f:
    np_val_data = pickle.load(f)
with open('../data_1s_100hz/TrainTest/y_val_onehot.pkl', 'rb') as f:
    np_val_labels = pickle.load(f)
with open('../data_1s_100hz/TrainTest/X_test_data.pkl', 'rb') as f:
    np_test_data = pickle.load(f)
with open('../data_1s_100hz/TrainTest/y_test_onehot.pkl', 'rb') as f:
    np_test_labels = pickle.load(f)

np_train_data.shape, np_train_labels.shape, np_val_data.shape, np_val_labels.shape, np_test_labels.shape
# Out:
# ((5254, 50, 3), (5254, 7), (1314, 50, 3), (1314, 7), (1643, 7))

# %%
# For Google Colab
# 1. Clone your repository to go to access your notebook and .py files
# !git clone https://github.com/Ziyi-star/Bachelorarbeit.git
# 2. Change working directory to where your notebook and .py files are
import os
os.chdir('/content/Bachelorarbeit/notebooks/training')
import os
import pickle
import scipy
import datetime
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import simclr_utitlities
import transformations
import simclr_models
import sys
from utils.preprocessing import *

seed = 1
tf.random.set_seed(seed)
np.random.seed(seed)

# Load data
# Download the file from GitHub
# !rm -f *.pkl # Remove existing pickle files
# !wget https://raw.githubusercontent.com/Ziyi-star/Bachelorarbeit/main/notebooks/data_1s_100hz/TrainTest/X_train_normalized.pkl
# !wget https://raw.githubusercontent.com/Ziyi-star/Bachelorarbeit/main/notebooks/data_1s_100hz/TrainTest/y_train_onehot.pkl
# !wget https://raw.githubusercontent.com/Ziyi-star/Bachelorarbeit/main/notebooks/data_1s_100hz/TrainTest/X_val_normalized.pkl
# !wget https://raw.githubusercontent.com/Ziyi-star/Bachelorarbeit/main/notebooks/data_1s_100hz/TrainTest/y_val_onehot.pkl
# !wget https://raw.githubusercontent.com/Ziyi-star/Bachelorarbeit/main/notebooks/data_1s_100hz/TrainTest/X_test_data.pkl
# !wget https://raw.githubusercontent.com/Ziyi-star/Bachelorarbeit/main/notebooks/data_1s_100hz/TrainTest/y_test_onehot.pkl


working_directory = "../models/"  # Relative path to models folder

# Load as usual
import pickle

with open('X_train_normalized.pkl', 'rb') as f:
    np_train_data = pickle.load(f)
with open('y_train_onehot.pkl', 'rb') as f:
    np_train_labels = pickle.load(f)
with open('X_val_normalized.pkl', 'rb') as f:
    np_val_data = pickle.load(f)
with open('y_val_onehot.pkl', 'rb') as f:
    np_val_labels = pickle.load(f)
with open('X_test_data.pkl', 'rb') as f:
    np_test_data = pickle.load(f)
with open('y_test_onehot.pkl', 'rb') as f:
    np_test_labels = pickle.load(f)

print(np_train_data.shape, np_train_labels.shape)
print(np_val_data.shape, np_val_labels.shape)
# Out:
# Cloning into 'Bachelorarbeit'...
# remote: Enumerating objects: 449, done.
# remote: Counting objects: 100% (50/50), done.
# remote: Compressing objects: 100% (34/34), done.
# remote: Total 449 (delta 24), reused 37 (delta 16), pack-reused 399 (from 2)
# Receiving objects: 100% (449/449), 144.36 MiB | 27.31 MiB/s, done.
# Resolving deltas: 100% (249/249), done.
# Updating files: 100% (69/69), done.
# --2025-09-18 11:02:57--  https://raw.githubusercontent.com/Ziyi-star/Bachelorarbeit/main/notebooks/data_all/TrainTest/X_train_normalized.pkl
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 6304965 (6.0M) [application/octet-stream]
# Saving to: ‘X_train_normalized.pkl’
#
# X_train_normalized. 100%[===================>]   6.01M  --.-KB/s    in 0.06s
#
# 2025-09-18 11:02:58 (92.7 MB/s) - ‘X_train_normalized.pkl’ saved [6304965/6304965]
#
# --2025-09-18 11:02:58--  https://raw.githubusercontent.com/Ziyi-star/Bachelorarbeit/main/notebooks/data_all/TrainTest/y_train_onehot.pkl
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.111.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 294387 (287K) [application/octet-stream]
# Saving to: ‘y_train_onehot.pkl’
#
# y_train_onehot.pkl  100%[===================>] 287.49K  --.-KB/s    in 0.03s
#
# 2025-09-18 11:02:58 (10.2 MB/s) - ‘y_train_onehot.pkl’ saved [294387/294387]
#
# --2025-09-18 11:02:58--  https://raw.githubusercontent.com/Ziyi-star/Bachelorarbeit/main/notebooks/data_all/TrainTest/X_val_normalized.pkl
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.111.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1576965 (1.5M) [application/octet-stream]
# Saving to: ‘X_val_normalized.pkl’
#
# X_val_normalized.pk 100%[===================>]   1.50M  --.-KB/s    in 0.04s
#
# 2025-09-18 11:02:58 (40.0 MB/s) - ‘X_val_normalized.pkl’ saved [1576965/1576965]
#
# --2025-09-18 11:02:59--  https://raw.githubusercontent.com/Ziyi-star/Bachelorarbeit/main/notebooks/data_all/TrainTest/y_val_onehot.pkl
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 73747 (72K) [application/octet-stream]
# Saving to: ‘y_val_onehot.pkl’
#
# y_val_onehot.pkl    100%[===================>]  72.02K  --.-KB/s    in 0.01s
#
# 2025-09-18 11:02:59 (6.24 MB/s) - ‘y_val_onehot.pkl’ saved [73747/73747]
#
# --2025-09-18 11:02:59--  https://raw.githubusercontent.com/Ziyi-star/Bachelorarbeit/main/notebooks/data_all/TrainTest/X_test_data.pkl
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2029669 (1.9M) [application/octet-stream]
# Saving to: ‘X_test_data.pkl’
#
# X_test_data.pkl     100%[===================>]   1.94M  --.-KB/s    in 0.04s
#
# 2025-09-18 11:02:59 (43.9 MB/s) - ‘X_test_data.pkl’ saved [2029669/2029669]
#
# --2025-09-18 11:02:59--  https://raw.githubusercontent.com/Ziyi-star/Bachelorarbeit/main/notebooks/data_all/TrainTest/y_test_onehot.pkl
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.110.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 92171 (90K) [application/octet-stream]
# Saving to: ‘y_test_onehot.pkl’
#
# y_test_onehot.pkl   100%[===================>]  90.01K  --.-KB/s    in 0.01s
#
# 2025-09-18 11:02:59 (6.40 MB/s) - ‘y_test_onehot.pkl’ saved [92171/92171]
#
# (5254, 50, 3) (5254, 7)
# (1314, 50, 3) (1314, 7)

# %% [markdown]
# ## 1.2 Fine-tuning and Evaluation

# %% [markdown]
# ### 1.2.1 Linear Model

# %% [markdown]
# #### Train

# %%
# Time
start_time = datetime.datetime.now()
start_time_str = start_time.strftime("%Y%m%d-%H%M%S")
#Formats the date and time as a string like 20250827-153045 (for filenames, logs, etc.).
tf.keras.backend.set_floatx('float32')
#Sets TensorFlow to use 32-bit floating point numbers for all computations (standard for deep learning).

# %%
# This block performs linear evaluation on top of the pretrained SimCLR base model.
total_epochs = 50
batch_size = 200
tag = "linear_eval"
output_shape = np_train_labels.shape[1]  # Number of classes for classification

# 1. Loads the SimCLR model and attaches a linear classification head on top.
simclr_model = tf.keras.models.load_model('../models/simclr_pretrained_model_best.hdf5')
linear_evaluation_model = simclr_models.create_linear_model_from_base_model(simclr_model, output_shape, intermediate_layer=7)

# 2. Sets up a ModelCheckpoint callback to save the best model (lowest validation loss).
# This ensures we keep the model version that performs best on validation data
linear_eval_best_model_file_name = f"{working_directory}{start_time_str}_simclr_{tag}.keras"
best_model_callback = tf.keras.callbacks.ModelCheckpoint(
    linear_eval_best_model_file_name,
    monitor='val_loss',
    mode='min',
    save_best_only=True,
    save_weights_only=False,
    verbose=0
)

# 3. Trains the linear evaluation model using the training and validation data.
training_history = linear_evaluation_model.fit(
    x = np_train_data,
    y = np_train_labels,
    batch_size=batch_size,
    shuffle=True,
    epochs=total_epochs,
    callbacks=[best_model_callback],
    validation_data=(np_val_data, np_val_labels)
)
# Out:
# WARNING:absl:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# Epoch 1/50
# c:\Users\liuzi\miniconda3\Lib\site-packages\keras\src\models\functional.py:238: UserWarning: The structure of `inputs` doesn't match the expected structure.
# Expected: ['input']
# Received: inputs=Tensor(shape=(None, 50, 3))
#   warnings.warn(msg)
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - auc: 0.5832 - categorical_accuracy: 0.1409 - loss: 1.8593 - precision: 0.8567 - recall: 0.0295 - val_auc: 0.6624 - val_categorical_accuracy: 0.2801 - val_loss: 1.7768 - val_precision: 1.0000 - val_recall: 0.0533
# Epoch 2/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - auc: 0.6538 - categorical_accuracy: 0.2820 - loss: 1.7627 - precision: 0.9997 - recall: 0.0622 - val_auc: 0.7239 - val_categorical_accuracy: 0.3607 - val_loss: 1.7201 - val_precision: 1.0000 - val_recall: 0.0578
# Epoch 3/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - auc: 0.7030 - categorical_accuracy: 0.3366 - loss: 1.7124 - precision: 0.9916 - recall: 0.0839 - val_auc: 0.7608 - val_categorical_accuracy: 0.3775 - val_loss: 1.6796 - val_precision: 0.9843 - val_recall: 0.0951
# Epoch 4/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - auc: 0.7376 - categorical_accuracy: 0.3567 - loss: 1.6766 - precision: 0.9839 - recall: 0.1043 - val_auc: 0.7797 - val_categorical_accuracy: 0.3828 - val_loss: 1.6490 - val_precision: 0.9853 - val_recall: 0.1020
# Epoch 5/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - auc: 0.7585 - categorical_accuracy: 0.3733 - loss: 1.6504 - precision: 0.9769 - recall: 0.1160 - val_auc: 0.7917 - val_categorical_accuracy: 0.3973 - val_loss: 1.6249 - val_precision: 0.9733 - val_recall: 0.1111
# Epoch 6/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - auc: 0.7716 - categorical_accuracy: 0.3851 - loss: 1.6279 - precision: 0.9558 - recall: 0.1189 - val_auc: 0.7984 - val_categorical_accuracy: 0.3995 - val_loss: 1.6048 - val_precision: 0.9759 - val_recall: 0.1233
# Epoch 7/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - auc: 0.7800 - categorical_accuracy: 0.3884 - loss: 1.6098 - precision: 0.9447 - recall: 0.1216 - val_auc: 0.8041 - val_categorical_accuracy: 0.4064 - val_loss: 1.5879 - val_precision: 0.9709 - val_recall: 0.1271
# Epoch 8/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - auc: 0.7869 - categorical_accuracy: 0.4023 - loss: 1.5935 - precision: 0.9433 - recall: 0.1239 - val_auc: 0.8077 - val_categorical_accuracy: 0.4132 - val_loss: 1.5734 - val_precision: 0.9714 - val_recall: 0.1294
# Epoch 9/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - auc: 0.7915 - categorical_accuracy: 0.4074 - loss: 1.5806 - precision: 0.9427 - recall: 0.1252 - val_auc: 0.8107 - val_categorical_accuracy: 0.4239 - val_loss: 1.5605 - val_precision: 0.9609 - val_recall: 0.1309
# Epoch 10/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - auc: 0.7955 - categorical_accuracy: 0.4158 - loss: 1.5684 - precision: 0.9209 - recall: 0.1271 - val_auc: 0.8131 - val_categorical_accuracy: 0.4277 - val_loss: 1.5492 - val_precision: 0.9558 - val_recall: 0.1317
# Epoch 11/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - auc: 0.7985 - categorical_accuracy: 0.4189 - loss: 1.5577 - precision: 0.9146 - recall: 0.1299 - val_auc: 0.8155 - val_categorical_accuracy: 0.4330 - val_loss: 1.5391 - val_precision: 0.9563 - val_recall: 0.1332
# Epoch 12/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - auc: 0.8010 - categorical_accuracy: 0.4259 - loss: 1.5496 - precision: 0.9040 - recall: 0.1299 - val_auc: 0.8174 - val_categorical_accuracy: 0.4353 - val_loss: 1.5297 - val_precision: 0.9563 - val_recall: 0.1332
# Epoch 13/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - auc: 0.8032 - categorical_accuracy: 0.4309 - loss: 1.5398 - precision: 0.8952 - recall: 0.1308 - val_auc: 0.8185 - val_categorical_accuracy: 0.4429 - val_loss: 1.5213 - val_precision: 0.9563 - val_recall: 0.1332
# Epoch 14/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - auc: 0.8057 - categorical_accuracy: 0.4343 - loss: 1.5331 - precision: 0.9009 - recall: 0.1317 - val_auc: 0.8197 - val_categorical_accuracy: 0.4444 - val_loss: 1.5137 - val_precision: 0.9570 - val_recall: 0.1355
# Epoch 15/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - auc: 0.8079 - categorical_accuracy: 0.4397 - loss: 1.5241 - precision: 0.9033 - recall: 0.1325 - val_auc: 0.8209 - val_categorical_accuracy: 0.4482 - val_loss: 1.5066 - val_precision: 0.9572 - val_recall: 0.1362
# Epoch 16/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - auc: 0.8082 - categorical_accuracy: 0.4412 - loss: 1.5194 - precision: 0.8969 - recall: 0.1333 - val_auc: 0.8220 - val_categorical_accuracy: 0.4536 - val_loss: 1.5000 - val_precision: 0.9521 - val_recall: 0.1362
# Epoch 17/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - auc: 0.8105 - categorical_accuracy: 0.4494 - loss: 1.5122 - precision: 0.8998 - recall: 0.1364 - val_auc: 0.8229 - val_categorical_accuracy: 0.4551 - val_loss: 1.4940 - val_precision: 0.9521 - val_recall: 0.1362
# Epoch 18/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - auc: 0.8122 - categorical_accuracy: 0.4577 - loss: 1.5049 - precision: 0.8928 - recall: 0.1362 - val_auc: 0.8236 - val_categorical_accuracy: 0.4566 - val_loss: 1.4883 - val_precision: 0.9524 - val_recall: 0.1370
# Epoch 19/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - auc: 0.8143 - categorical_accuracy: 0.4571 - loss: 1.4973 - precision: 0.8897 - recall: 0.1377 - val_auc: 0.8245 - val_categorical_accuracy: 0.4589 - val_loss: 1.4828 - val_precision: 0.9524 - val_recall: 0.1370
# Epoch 20/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - auc: 0.8152 - categorical_accuracy: 0.4582 - loss: 1.4936 - precision: 0.8896 - recall: 0.1387 - val_auc: 0.8249 - val_categorical_accuracy: 0.4597 - val_loss: 1.4775 - val_precision: 0.9524 - val_recall: 0.1370
# Epoch 21/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - auc: 0.8141 - categorical_accuracy: 0.4669 - loss: 1.4895 - precision: 0.8968 - recall: 0.1386 - val_auc: 0.8258 - val_categorical_accuracy: 0.4589 - val_loss: 1.4732 - val_precision: 0.9529 - val_recall: 0.1385
# Epoch 22/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - auc: 0.8161 - categorical_accuracy: 0.4643 - loss: 1.4855 - precision: 0.8854 - recall: 0.1399 - val_auc: 0.8262 - val_categorical_accuracy: 0.4619 - val_loss: 1.4687 - val_precision: 0.9529 - val_recall: 0.1385
# Epoch 23/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - auc: 0.8159 - categorical_accuracy: 0.4680 - loss: 1.4804 - precision: 0.8795 - recall: 0.1405 - val_auc: 0.8267 - val_categorical_accuracy: 0.4658 - val_loss: 1.4643 - val_precision: 0.9531 - val_recall: 0.1393
# Epoch 24/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - auc: 0.8194 - categorical_accuracy: 0.4699 - loss: 1.4714 - precision: 0.8984 - recall: 0.1414 - val_auc: 0.8274 - val_categorical_accuracy: 0.4658 - val_loss: 1.4604 - val_precision: 0.9534 - val_recall: 0.1400
# Epoch 25/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - auc: 0.8186 - categorical_accuracy: 0.4695 - loss: 1.4711 - precision: 0.8831 - recall: 0.1421 - val_auc: 0.8274 - val_categorical_accuracy: 0.4658 - val_loss: 1.4570 - val_precision: 0.9534 - val_recall: 0.1400
# Epoch 26/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - auc: 0.8193 - categorical_accuracy: 0.4677 - loss: 1.4703 - precision: 0.8602 - recall: 0.1444 - val_auc: 0.8280 - val_categorical_accuracy: 0.4696 - val_loss: 1.4536 - val_precision: 0.9534 - val_recall: 0.1400
# Epoch 27/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - auc: 0.8199 - categorical_accuracy: 0.4704 - loss: 1.4619 - precision: 0.8944 - recall: 0.1427 - val_auc: 0.8282 - val_categorical_accuracy: 0.4680 - val_loss: 1.4505 - val_precision: 0.9536 - val_recall: 0.1408
# Epoch 28/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - auc: 0.8196 - categorical_accuracy: 0.4711 - loss: 1.4620 - precision: 0.8817 - recall: 0.1449 - val_auc: 0.8285 - val_categorical_accuracy: 0.4703 - val_loss: 1.4473 - val_precision: 0.9487 - val_recall: 0.1408
# Epoch 29/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - auc: 0.8212 - categorical_accuracy: 0.4717 - loss: 1.4577 - precision: 0.8814 - recall: 0.1466 - val_auc: 0.8289 - val_categorical_accuracy: 0.4726 - val_loss: 1.4443 - val_precision: 0.9487 - val_recall: 0.1408
# Epoch 30/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - auc: 0.8214 - categorical_accuracy: 0.4798 - loss: 1.4538 - precision: 0.8978 - recall: 0.1483 - val_auc: 0.8294 - val_categorical_accuracy: 0.4726 - val_loss: 1.4412 - val_precision: 0.9487 - val_recall: 0.1408
# Epoch 31/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - auc: 0.8224 - categorical_accuracy: 0.4803 - loss: 1.4525 - precision: 0.8843 - recall: 0.1459 - val_auc: 0.8294 - val_categorical_accuracy: 0.4718 - val_loss: 1.4388 - val_precision: 0.9490 - val_recall: 0.1416
# Epoch 32/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - auc: 0.8221 - categorical_accuracy: 0.4814 - loss: 1.4495 - precision: 0.8726 - recall: 0.1504 - val_auc: 0.8296 - val_categorical_accuracy: 0.4734 - val_loss: 1.4361 - val_precision: 0.9490 - val_recall: 0.1416
# Epoch 33/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - auc: 0.8232 - categorical_accuracy: 0.4767 - loss: 1.4459 - precision: 0.8850 - recall: 0.1463 - val_auc: 0.8299 - val_categorical_accuracy: 0.4749 - val_loss: 1.4334 - val_precision: 0.9492 - val_recall: 0.1423
# Epoch 34/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - auc: 0.8228 - categorical_accuracy: 0.4811 - loss: 1.4437 - precision: 0.8862 - recall: 0.1502 - val_auc: 0.8305 - val_categorical_accuracy: 0.4749 - val_loss: 1.4308 - val_precision: 0.9492 - val_recall: 0.1423
# Epoch 35/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - auc: 0.8242 - categorical_accuracy: 0.4862 - loss: 1.4421 - precision: 0.8853 - recall: 0.1489 - val_auc: 0.8307 - val_categorical_accuracy: 0.4741 - val_loss: 1.4287 - val_precision: 0.9492 - val_recall: 0.1423
# Epoch 36/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - auc: 0.8250 - categorical_accuracy: 0.4876 - loss: 1.4375 - precision: 0.8786 - recall: 0.1455 - val_auc: 0.8310 - val_categorical_accuracy: 0.4749 - val_loss: 1.4266 - val_precision: 0.9492 - val_recall: 0.1423
# Epoch 37/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - auc: 0.8241 - categorical_accuracy: 0.4858 - loss: 1.4373 - precision: 0.8829 - recall: 0.1519 - val_auc: 0.8313 - val_categorical_accuracy: 0.4756 - val_loss: 1.4244 - val_precision: 0.9492 - val_recall: 0.1423
# Epoch 38/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - auc: 0.8249 - categorical_accuracy: 0.4834 - loss: 1.4367 - precision: 0.8685 - recall: 0.1512 - val_auc: 0.8314 - val_categorical_accuracy: 0.4764 - val_loss: 1.4225 - val_precision: 0.9495 - val_recall: 0.1431
# Epoch 39/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - auc: 0.8241 - categorical_accuracy: 0.4867 - loss: 1.4364 - precision: 0.8969 - recall: 0.1496 - val_auc: 0.8318 - val_categorical_accuracy: 0.4756 - val_loss: 1.4206 - val_precision: 0.9495 - val_recall: 0.1431
# Epoch 40/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - auc: 0.8252 - categorical_accuracy: 0.4870 - loss: 1.4317 - precision: 0.8797 - recall: 0.1515 - val_auc: 0.8319 - val_categorical_accuracy: 0.4749 - val_loss: 1.4189 - val_precision: 0.9495 - val_recall: 0.1431
# Epoch 41/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - auc: 0.8263 - categorical_accuracy: 0.4850 - loss: 1.4267 - precision: 0.8729 - recall: 0.1527 - val_auc: 0.8323 - val_categorical_accuracy: 0.4749 - val_loss: 1.4168 - val_precision: 0.9447 - val_recall: 0.1431
# Epoch 42/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - auc: 0.8282 - categorical_accuracy: 0.4913 - loss: 1.4236 - precision: 0.8821 - recall: 0.1528 - val_auc: 0.8324 - val_categorical_accuracy: 0.4764 - val_loss: 1.4151 - val_precision: 0.9447 - val_recall: 0.1431
# Epoch 43/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - auc: 0.8274 - categorical_accuracy: 0.4851 - loss: 1.4227 - precision: 0.8692 - recall: 0.1562 - val_auc: 0.8325 - val_categorical_accuracy: 0.4779 - val_loss: 1.4135 - val_precision: 0.9450 - val_recall: 0.1438
# Epoch 44/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - auc: 0.8272 - categorical_accuracy: 0.4882 - loss: 1.4223 - precision: 0.8785 - recall: 0.1534 - val_auc: 0.8327 - val_categorical_accuracy: 0.4779 - val_loss: 1.4119 - val_precision: 0.9453 - val_recall: 0.1446
# Epoch 45/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - auc: 0.8268 - categorical_accuracy: 0.4888 - loss: 1.4230 - precision: 0.8679 - recall: 0.1552 - val_auc: 0.8330 - val_categorical_accuracy: 0.4795 - val_loss: 1.4103 - val_precision: 0.9453 - val_recall: 0.1446
# Epoch 46/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - auc: 0.8287 - categorical_accuracy: 0.4860 - loss: 1.4163 - precision: 0.8897 - recall: 0.1570 - val_auc: 0.8333 - val_categorical_accuracy: 0.4802 - val_loss: 1.4088 - val_precision: 0.9406 - val_recall: 0.1446
# Epoch 47/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - auc: 0.8271 - categorical_accuracy: 0.4851 - loss: 1.4190 - precision: 0.8861 - recall: 0.1569 - val_auc: 0.8334 - val_categorical_accuracy: 0.4810 - val_loss: 1.4071 - val_precision: 0.9406 - val_recall: 0.1446
# Epoch 48/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - auc: 0.8284 - categorical_accuracy: 0.4916 - loss: 1.4156 - precision: 0.8806 - recall: 0.1593 - val_auc: 0.8334 - val_categorical_accuracy: 0.4802 - val_loss: 1.4059 - val_precision: 0.9406 - val_recall: 0.1446
# Epoch 49/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - auc: 0.8284 - categorical_accuracy: 0.4929 - loss: 1.4154 - precision: 0.8802 - recall: 0.1582 - val_auc: 0.8335 - val_categorical_accuracy: 0.4795 - val_loss: 1.4046 - val_precision: 0.9406 - val_recall: 0.1446
# Epoch 50/50
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - auc: 0.8289 - categorical_accuracy: 0.4891 - loss: 1.4111 - precision: 0.8798 - recall: 0.1580 - val_auc: 0.8338 - val_categorical_accuracy: 0.4795 - val_loss: 1.4031 - val_precision: 0.9409 - val_recall: 0.1454

# %%
# Training and Validation Loss

plt.figure(figsize=(12,6))
plt.plot(training_history.history['loss'], label='Training Loss')
plt.plot(training_history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training and Validation Loss')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Training and Validation Accuracy
plt.figure(figsize=(12,6))
plt.plot(training_history.history['categorical_accuracy'], label='Training Accuracy')
plt.plot(training_history.history['val_categorical_accuracy'], label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Training and Validation Accuracy')
plt.legend()
plt.grid(True)
plt.ylim([0, 1])
plt.show()

# %% [markdown]
# #### Test:

# %%
# Load models and evaluate on test set on vscode
# simclr_model_path = "../models/20250918-072951_simclr.hdf5"
linear_eval_model_path = "../models/20250925-092319_simclr_linear_eval.keras"

# Load both models
# simclr_model = tf.keras.models.load_model(simclr_model_path)
linear_eval_best_model = tf.keras.models.load_model(linear_eval_model_path)

# %% [markdown]
# #### Normalize test data

# %%
# You can also use it for test data (but should fit the scaler only on training data)
X_test_normalized = normalize_3d_data(np_test_data)

# %%
linear_eval_best_model = tf.keras.models.load_model(linear_eval_best_model_file_name)

print("Model with lowest validation Loss:")
print(simclr_utitlities.evaluate_model_simple(linear_eval_best_model.predict(X_test_normalized), np_test_labels, return_dict=True))
print("Model in last epoch")
print(simclr_utitlities.evaluate_model_simple(linear_evaluation_model.predict(X_test_normalized), np_test_labels, return_dict=True))
# Out:
# Model with lowest validation Loss:
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step
# {'Confusion Matrix': array([[227,   5,   2,  14,   1,  13,  21],
#        [ 16, 119,   2,  10,  28,  17,   5],
#        [ 90,  17,   0,  16,   5,  38,  28],
#        [ 23,   6,   0, 136,   1,  46,  26],
#        [  0,  19,   0,   7, 201,   9,   2],
#        [ 38,   8,   2,  21,   0, 120,  44],
#        [116,   5,   1,  20,   3,  58,  57]]), 'F1 Macro': 0.47768208726628625, 'F1 Micro': 0.5234327449786975, 'F1 Weighted': 0.48633193174823264, 'Precision': 0.4668851508448979, 'Recall': 0.5080570957230285, 'Kappa': np.float64(0.4383680892835081)}
# Model in last epoch
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step
# {'Confusion Matrix': array([[228,   4,   3,  15,   1,  13,  19],
#        [ 16, 110,   3,   9,  37,  17,   5],
#        [ 91,  16,   0,  16,   6,  35,  30],
#        [ 23,   5,   0, 138,   2,  46,  24],
#        [  0,  16,   0,   8, 204,   8,   2],
#        [ 39,   5,   2,  21,   0, 123,  43],
#        [115,   3,   2,  22,   3,  58,  57]]), 'F1 Macro': 0.4763079226435816, 'F1 Micro': 0.5234327449786975, 'F1 Weighted': 0.48532900116831784, 'Precision': 0.46753532343513093, 'Recall': 0.5068759856600009, 'Kappa': np.float64(0.438192232411041)}

# %% [markdown]
# ## Extra: t-SNE Plots

# %%
import sklearn.manifold
import seaborn as sns

# First load the model from the file path
target_model_path = "../models/simclr_pretrained_model_best.hdf5"
loaded_model = tf.keras.models.load_model(target_model_path)
perplexity = 30.0

# Then extract the intermediate model
intermediate_model = simclr_models.extract_intermediate_model_from_base_model(loaded_model, intermediate_layer=7)
intermediate_model.summary()

# Continue with your t-SNE code
embeddings = intermediate_model.predict(X_test_normalized, batch_size=600)
tsne_model = sklearn.manifold.TSNE(perplexity=perplexity, verbose=1, random_state=42)
tsne_projections = tsne_model.fit_transform(embeddings)
# Out:
# WARNING:absl:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# Model: "base_model_simclr_layer_7"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input (InputLayer)              │ (None, 50, 3)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_33 (Conv1D)              │ (None, 27, 32)         │         2,336 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_33 (Dropout)            │ (None, 27, 32)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_34 (Conv1D)              │ (None, 12, 64)         │        32,832 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_34 (Dropout)            │ (None, 12, 64)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_35 (Conv1D)              │ (None, 5, 96)          │        49,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_35 (Dropout)            │ (None, 5, 96)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_max_pooling1d            │ (None, 96)             │             0 │
# │ (GlobalMaxPooling1D)            │                        │               │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 84,416 (329.75 KB)
#  Trainable params: 84,416 (329.75 KB)
#  Non-trainable params: 0 (0.00 B)
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# c:\Users\liuzi\miniconda3\Lib\site-packages\keras\src\models\functional.py:238: UserWarning: The structure of `inputs` doesn't match the expected structure.
# Expected: ['input']
# Received: inputs=Tensor(shape=(600, 50, 3))
#   warnings.warn(msg)
# c:\Users\liuzi\miniconda3\Lib\site-packages\keras\src\models\functional.py:238: UserWarning: The structure of `inputs` doesn't match the expected structure.
# Expected: ['input']
# Received: inputs=Tensor(shape=(None, 50, 3))
#   warnings.warn(msg)
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 1643 samples in 0.000s...
# [t-SNE] Computed neighbors for 1643 samples in 0.444s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 1643
# [t-SNE] Computed conditional probabilities for sample 1643 / 1643
# [t-SNE] Mean sigma: 0.284461
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 64.329514
# [t-SNE] KL divergence after 1000 iterations: 0.817751

# %%
# Get the true labels (class indices) from the one-hot encoded test labels
labels_argmax = np.argmax(np_test_labels, axis=1)
unique_labels = np.unique(labels_argmax)

# Create the t-SNE visualization
plt.figure(figsize=(16,8))
graph = sns.scatterplot(
    x=tsne_projections[:,0], y=tsne_projections[:,1],
    hue=labels_argmax,
    palette=sns.color_palette("hsv", len(unique_labels)),
    s=50,
    alpha=1.0,
    rasterized=True
)
plt.xticks([], [])
plt.yticks([], [])

plt.title("t-SNE Visualization of SimCLR Embeddings")

# If you have class names, use them for the legend
# Define your activity names if needed
label_list_full_name = ["asphalt", "cobblestone", "compact_gravel", "curb_0", "curb_1", "dirt", "paving_stone"]  # Replace with your actual class names

# Update legend with class names if available
plt.legend(loc='lower left', bbox_to_anchor=(0.25, -0.3), ncol=2)
legend = graph.legend_
if 'label_list_full_name' in globals():  # Check if variable exists
    for j, label in enumerate(unique_labels):
        if label < len(label_list_full_name):
            legend.get_texts()[j].set_text(label_list_full_name[label])

# %%
# Create a figure with 6 subplots (3x2 grid) to compare curb_1 with each other class
plt.figure(figsize=(20, 15))

# Get the true labels (class indices) from the one-hot encoded test labels
labels_argmax = np.argmax(np_test_labels, axis=1)
unique_labels = np.unique(labels_argmax)
curb_1_index = 4  # Based on your label_list_full_name where "curb_1" is at index 4

# Define your surface type names
label_list_full_name = ["asphalt", "cobblestone", "compact_gravel", "curb_0", "curb_1", "dirt", "paving_stone"]

# Loop through each class (except curb_1) and create a subplot
subplot_index = 1
for class_index in unique_labels:
    # Skip curb_1 as we're comparing others against it
    if class_index == curb_1_index:
        continue
        
    # Create binary mask for current pair (curb_1 and current class)
    mask = np.logical_or(labels_argmax == curb_1_index, labels_argmax == class_index)
    
    # Create binary labels: 0 for current class, 1 for curb_1
    binary_labels = np.zeros(np.sum(mask))
    binary_labels[labels_argmax[mask] == curb_1_index] = 1
    
    # Get the filtered t-SNE projections
    filtered_projections = tsne_projections[mask]
    
    # Create subplot
    plt.subplot(3, 2, subplot_index)
    
    # Plot the scatter points
    sns.scatterplot(
        x=filtered_projections[:, 0], 
        y=filtered_projections[:, 1],
        hue=binary_labels,
        palette=["#1f77b4", "#ff7f0e"],  # Blue for other class, Orange for curb_1
        s=60,
        alpha=0.8
    )
    
    # Remove axes ticks for cleaner visualization
    plt.xticks([], [])
    plt.yticks([], [])
    
    # Set subplot title
    plt.title(f"curb_1 vs. {label_list_full_name[class_index]}", fontsize=14)
    
    # Custom legend
    plt.legend([label_list_full_name[class_index], "curb_1"], fontsize=12)
    
    # Increment subplot index
    subplot_index += 1

# Add overall title
plt.suptitle("t-SNE Comparison of Curb_1 vs. Each Other Surface Type", fontsize=18, y=0.98)
plt.tight_layout()
plt.show()
