# %% [markdown]
# <a href="https://colab.research.google.com/github/Ziyi-star/Bachelorarbeit/blob/main/notebooks/training/train_1s_30hz_initial_2class.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# For VSCode
# %load_ext autoreload
# %autoreload 2

import os
import pickle
import scipy
import datetime
import numpy as np
import tensorflow as tf
import simclr_utitlities
import transformations
import simclr_models
import sys
import matplotlib.pyplot as plt

sys.path.append('../')   # Add parent directory to Python path
working_directory = "../models/"
sys.path.append('../../')
from utils.preprocessing import *

seed = 1
tf.random.set_seed(seed)
np.random.seed(seed)

# %% [markdown]
# # SimCLR Training

# %%
with open('../training_data/X_train_normalized.pkl', 'rb') as f:
    np_train_data = pickle.load(f)
with open('../training_data/y_train_onehot.pkl', 'rb') as f:
    np_train_labels = pickle.load(f)
with open('../training_data/X_val_normalized.pkl', 'rb') as f:
    np_val_data = pickle.load(f)
with open('../training_data/y_val_onehot.pkl', 'rb') as f:
    np_val_labels = pickle.load(f)


np_train_data.shape, np_train_labels.shape, np_val_data.shape, np_val_labels.shape
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# ((1404, 30, 3), (1404, 2), (352, 30, 3), (352, 2), (352, 2))

# %%
# For Google Colab
# 1. Clone your repository to go to access your notebook and .py files
# !git clone https://github.com/Ziyi-star/Bachelorarbeit.git
# 2. Change working directory to where your notebook and .py files are
import os
os.chdir('/content/Bachelorarbeit/notebooks/training')
import os
import pickle
import scipy
import datetime
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import simclr_utitlities
import transformations
import simclr_models
import sys
sys.path.append('../../')
from utils.preprocessing import *



seed = 1
tf.random.set_seed(seed)
np.random.seed(seed)

# Load data
# Download the file from GitHub
# !rm -f *.pkl # Remove existing pickle files
# !wget https://raw.githubusercontent.com/Ziyi-star/Bachelorarbeit/main/notebooks/training_data/X_train_normalized.pkl
# !wget https://raw.githubusercontent.com/Ziyi-star/Bachelorarbeit/main/notebooks/training_data/y_train_onehot.pkl
# !wget https://raw.githubusercontent.com/Ziyi-star/Bachelorarbeit/main/notebooks/training_data/X_val_normalized.pkl
# !wget https://raw.githubusercontent.com/Ziyi-star/Bachelorarbeit/main/notebooks/training_data/y_val_onehot.pkl

working_directory = "../models/"  # Relative path to models folder

# Load as usual
import pickle

with open('X_train_normalized.pkl', 'rb') as f:
    np_train_data = pickle.load(f)
with open('y_train_onehot.pkl', 'rb') as f:
    np_train_labels = pickle.load(f)
with open('X_val_normalized.pkl', 'rb') as f:
    np_val_data = pickle.load(f)
with open('y_val_onehot.pkl', 'rb') as f:
    np_val_labels = pickle.load(f)
# with open('X_test_data.pkl', 'rb') as f:
#     np_test_data = pickle.load(f)
# with open('y_test_onehot.pkl', 'rb') as f:
#     np_test_labels = pickle.load(f)

print(np_train_data.shape, np_train_labels.shape)
print(np_val_data.shape, np_val_labels.shape)
# Out:
# fatal: destination path 'Bachelorarbeit' already exists and is not an empty directory.
# --2025-11-02 14:12:16--  https://raw.githubusercontent.com/Ziyi-star/Bachelorarbeit/main/notebooks/training_data/X_train_normalized.pkl
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1011045 (987K) [application/octet-stream]
# Saving to: ‘X_train_normalized.pkl’
#
# X_train_normalized. 100%[===================>] 987.35K  --.-KB/s    in 0.005s
#
# 2025-11-02 14:12:16 (212 MB/s) - ‘X_train_normalized.pkl’ saved [1011045/1011045]
#
# --2025-11-02 14:12:16--  https://raw.githubusercontent.com/Ziyi-star/Bachelorarbeit/main/notebooks/training_data/y_train_onehot.pkl
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.111.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 22618 (22K) [application/octet-stream]
# Saving to: ‘y_train_onehot.pkl’
#
# y_train_onehot.pkl  100%[===================>]  22.09K  --.-KB/s    in 0s
#
# 2025-11-02 14:12:17 (167 MB/s) - ‘y_train_onehot.pkl’ saved [22618/22618]
#
# --2025-11-02 14:12:17--  https://raw.githubusercontent.com/Ziyi-star/Bachelorarbeit/main/notebooks/training_data/X_val_normalized.pkl
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 253605 (248K) [application/octet-stream]
# Saving to: ‘X_val_normalized.pkl’
#
# X_val_normalized.pk 100%[===================>] 247.66K  --.-KB/s    in 0.002s
#
# 2025-11-02 14:12:17 (115 MB/s) - ‘X_val_normalized.pkl’ saved [253605/253605]
#
# --2025-11-02 14:12:17--  https://raw.githubusercontent.com/Ziyi-star/Bachelorarbeit/main/notebooks/training_data/y_val_onehot.pkl
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.108.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 5786 (5.7K) [application/octet-stream]
# Saving to: ‘y_val_onehot.pkl’
#
# y_val_onehot.pkl    100%[===================>]   5.65K  --.-KB/s    in 0s
#
# 2025-11-02 14:12:17 (91.7 MB/s) - ‘y_val_onehot.pkl’ saved [5786/5786]
#
# (1404, 30, 3) (1404, 2)
# (352, 30, 3) (352, 2)

# %% [markdown]
# ## 1.1 Pretraining with SimCLR

# %%
# Parameters for all experiments
window_size = 30
input_shape = (window_size, 3)
batch_size = 512
#Number of samples processed together in one training step. Larger batch sizes can speed up training but require more memory.
decay_steps = 1000
#Number of steps after which the learning rate decays (used for learning rate scheduling).
epochs = 200
temperature = 0.1

# %%
#A parameter for the SimCLR loss function that controls how sharply similarities are measured.
# transform_funcs = [
#     transformations.scaling_transform_vectorized, # Use Scaling trasnformation
#     transformations.rotation_transform_vectorized # Use rotation trasnformation
# ]
transform_funcs = [
    transformations.time_segment_permutation_transform_improved,
    transformations.channel_shuffle_transform_vectorized
]
#List of data augmentation functions to apply to the input data. Here, only rotation is used.
transformation_function = simclr_utitlities.generate_composite_transform_function_simple(transform_funcs)
# Out:
# 0 <function time_segment_permutation_transform_improved at 0x7c37a8aa4400>
# 1 <function channel_shuffle_transform_vectorized at 0x7c37a8aa4360>

# %%
# Time
start_time = datetime.datetime.now()
start_time_str = start_time.strftime("%Y%m%d-%H%M%S")
#Formats the date and time as a string like 20250827-153045 (for filenames, logs, etc.).
tf.keras.backend.set_floatx('float32')
#Sets TensorFlow to use 32-bit floating point numbers for all computations (standard for deep learning).

# %%
# Create a cosine-decayed learning rate schedule and SGD optimizer for training.
lr_decayed_fn = tf.keras.optimizers.schedules.CosineDecay(initial_learning_rate=0.1, decay_steps=decay_steps)
optimizer = tf.keras.optimizers.SGD(lr_decayed_fn)

# Build the base model and attach the SimCLR head for contrastive learning.
base_model = simclr_models.create_base_model_small_dimensions(input_shape, model_name="base_model")
simclr_model = simclr_models.attach_simclr_head(base_model)
simclr_model.summary()

# Train the SimCLR model using the specified transformation function and optimizer.
trained_simclr_model, epoch_losses = simclr_utitlities.simclr_train_model(
    simclr_model,
    np_train_data,
    optimizer,
    batch_size,
    transformation_function,
    temperature=temperature,
    epochs=epochs,
    is_trasnform_function_vectorized=True,
    verbose=1
)

# Save the trained SimCLR model to disk for later use.
simclr_model_save_path = f"{working_directory}{start_time_str}_simclr.hdf5"
trained_simclr_model.save(simclr_model_save_path)
# Out:
# Model: "base_model_simclr"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input (InputLayer)              │ (None, 30, 3)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d (Conv1D)                 │ (None, 30, 32)         │         2,336 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 30, 32)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_1 (Conv1D)               │ (None, 30, 64)         │        32,832 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 30, 64)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_2 (Conv1D)               │ (None, 30, 96)         │        49,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 30, 96)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_max_pooling1d            │ (None, 96)             │             0 │
# │ (GlobalMaxPooling1D)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 256)            │        24,832 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation (Activation)         │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_1 (Activation)       │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 50)             │         6,450 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 148,594 (580.45 KB)
#  Trainable params: 148,594 (580.45 KB)
#  Non-trainable params: 0 (0.00 B)
# epoch: 1 loss: 12.834
# epoch: 2 loss: 10.802
# epoch: 3 loss: 10.818
# epoch: 4 loss: 10.589
# epoch: 5 loss: 11.020
# epoch: 6 loss: 10.394
# epoch: 7 loss: 10.002
# epoch: 8 loss: 9.353
# epoch: 9 loss: 8.867
# epoch: 10 loss: 9.484
# epoch: 11 loss: 9.213
# epoch: 12 loss: 9.196
# epoch: 13 loss: 8.558
# epoch: 14 loss: 8.974
# epoch: 15 loss: 8.636
# epoch: 16 loss: 8.142
# epoch: 17 loss: 8.172
# epoch: 18 loss: 8.316
# epoch: 19 loss: 8.161
# epoch: 20 loss: 8.011
# epoch: 21 loss: 8.333
# epoch: 22 loss: 7.481
# epoch: 23 loss: 7.749
# epoch: 24 loss: 7.381
# epoch: 25 loss: 7.706
# epoch: 26 loss: 7.439
# epoch: 27 loss: 7.443
# epoch: 28 loss: 7.826
# epoch: 29 loss: 8.715
# epoch: 30 loss: 7.818
# epoch: 31 loss: 6.727
# epoch: 32 loss: 7.374
# epoch: 33 loss: 7.025
# epoch: 34 loss: 6.925
# epoch: 35 loss: 6.811
# epoch: 36 loss: 6.939
# epoch: 37 loss: 6.483
# epoch: 38 loss: 6.435
# epoch: 39 loss: 6.784
# epoch: 40 loss: 6.411
# epoch: 41 loss: 6.387
# epoch: 42 loss: 6.378
# epoch: 43 loss: 6.600
# epoch: 44 loss: 6.076
# epoch: 45 loss: 6.218
# epoch: 46 loss: 6.261
# epoch: 47 loss: 5.962
# epoch: 48 loss: 5.932
# epoch: 49 loss: 6.520
# epoch: 50 loss: 6.477
# epoch: 51 loss: 5.728
# epoch: 52 loss: 6.148
# epoch: 53 loss: 5.904
# epoch: 54 loss: 5.901
# epoch: 55 loss: 5.850
# epoch: 56 loss: 5.727
# epoch: 57 loss: 5.893
# epoch: 58 loss: 5.345
# epoch: 59 loss: 5.615
# epoch: 60 loss: 5.657
# epoch: 61 loss: 6.068
# epoch: 62 loss: 5.595
# epoch: 63 loss: 5.337
# epoch: 64 loss: 5.818
# epoch: 65 loss: 5.281
# epoch: 66 loss: 4.963
# epoch: 67 loss: 5.442
# epoch: 68 loss: 5.635
# epoch: 69 loss: 5.097
# epoch: 70 loss: 5.270
# epoch: 71 loss: 5.216
# epoch: 72 loss: 4.805
# epoch: 73 loss: 4.898
# epoch: 74 loss: 5.002
# epoch: 75 loss: 5.335
# epoch: 76 loss: 4.898
# epoch: 77 loss: 4.991
# epoch: 78 loss: 4.748
# epoch: 79 loss: 4.998
# epoch: 80 loss: 4.751
# epoch: 81 loss: 4.666
# epoch: 82 loss: 4.831
# epoch: 83 loss: 4.689
# epoch: 84 loss: 4.808
# epoch: 85 loss: 5.479
# epoch: 86 loss: 5.006
# epoch: 87 loss: 4.467
# epoch: 88 loss: 4.718
# epoch: 89 loss: 4.976
# epoch: 90 loss: 4.561
# epoch: 91 loss: 4.813
# epoch: 92 loss: 4.852
# epoch: 93 loss: 4.234
# epoch: 94 loss: 4.204
# epoch: 95 loss: 4.310
# epoch: 96 loss: 4.619
# epoch: 97 loss: 4.580
# epoch: 98 loss: 4.234
# epoch: 99 loss: 4.262
# epoch: 100 loss: 4.197
# epoch: 101 loss: 4.286
# epoch: 102 loss: 4.412
# epoch: 103 loss: 4.300
# epoch: 104 loss: 4.368
# epoch: 105 loss: 4.407
# epoch: 106 loss: 4.495
# epoch: 107 loss: 4.084
# epoch: 108 loss: 3.724
# epoch: 109 loss: 3.953
# epoch: 110 loss: 3.895
# epoch: 111 loss: 4.036
# epoch: 112 loss: 3.919
# epoch: 113 loss: 4.204
# epoch: 114 loss: 3.875
# epoch: 115 loss: 4.026
# epoch: 116 loss: 4.267
# epoch: 117 loss: 4.049
# epoch: 118 loss: 3.858
# epoch: 119 loss: 3.801
# epoch: 120 loss: 4.116
# epoch: 121 loss: 3.832
# epoch: 122 loss: 3.827
# epoch: 123 loss: 3.925
# epoch: 124 loss: 4.354
# epoch: 125 loss: 3.873
# epoch: 126 loss: 3.790
# epoch: 127 loss: 3.659
# epoch: 128 loss: 3.937
# epoch: 129 loss: 3.807
# epoch: 130 loss: 3.469
# epoch: 131 loss: 3.516
# epoch: 132 loss: 3.724
# epoch: 133 loss: 3.605
# epoch: 134 loss: 3.558
# epoch: 135 loss: 3.568
# epoch: 136 loss: 3.610
# epoch: 137 loss: 3.572
# epoch: 138 loss: 3.592
# epoch: 139 loss: 3.453
# epoch: 140 loss: 3.498
# epoch: 141 loss: 3.671
# epoch: 142 loss: 3.861
# epoch: 143 loss: 3.626
# epoch: 144 loss: 3.783
# epoch: 145 loss: 3.523
# epoch: 146 loss: 3.401
# epoch: 147 loss: 3.301
# epoch: 148 loss: 3.414
# epoch: 149 loss: 3.306
# epoch: 150 loss: 3.246
# epoch: 151 loss: 3.218
# epoch: 152 loss: 3.390
# epoch: 153 loss: 3.145
# epoch: 154 loss: 3.221
# epoch: 155 loss: 3.286
# epoch: 156 loss: 3.200
# epoch: 157 loss: 3.464
# epoch: 158 loss: 3.223
# epoch: 159 loss: 3.172
# epoch: 160 loss: 3.243
# epoch: 161 loss: 3.244
# epoch: 162 loss: 3.047
# epoch: 163 loss: 3.138
# epoch: 164 loss: 3.062
# epoch: 165 loss: 3.187
# epoch: 166 loss: 2.960
# epoch: 167 loss: 3.097
# epoch: 168 loss: 3.095
# epoch: 169 loss: 3.101
# epoch: 170 loss: 3.067
# epoch: 171 loss: 2.958
# epoch: 172 loss: 3.036
# epoch: 173 loss: 2.995
# epoch: 174 loss: 3.016
# epoch: 175 loss: 2.914
# epoch: 176 loss: 2.928
# epoch: 177 loss: 2.953
# epoch: 178 loss: 2.813
# epoch: 179 loss: 2.995
# epoch: 180 loss: 3.208
# epoch: 181 loss: 2.877
# epoch: 182 loss: 2.784
# epoch: 183 loss: 2.702
# epoch: 184 loss: 2.826
# epoch: 185 loss: 2.765
# epoch: 186 loss: 2.909
# epoch: 187 loss: 2.862
# epoch: 188 loss: 2.757
# epoch: 189 loss: 2.837
# epoch: 190 loss: 2.731
# epoch: 191 loss: 2.771
# epoch: 192 loss: 2.616
# epoch: 193 loss: 2.674
# epoch: 194 loss: 2.819
# epoch: 195 loss: 2.605
# epoch: 196 loss: 2.630
# epoch: 197 loss: 2.625
# epoch: 198 loss: 2.516
# epoch: 199 loss: 2.550
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# epoch: 200 loss: 2.560

# %%
# Plot history of training losses over epochs.
plt.figure(figsize=(12,8))
plt.plot(epoch_losses)
plt.ylabel("Loss")
plt.xlabel("Epoch")
plt.show()

# %% [markdown]
# ## 1.2 Fine-tuning and Evaluation

# %% [markdown]
# ### 1.2.1 Linear Model

# %% [markdown]
# #### Train

# %%
# This block performs linear evaluation on top of the pretrained SimCLR base model.
total_epochs = 50
batch_size = 200
tag = "linear_eval"
output_shape = np_train_labels.shape[1]  # Number of classes for classification

# 1. Loads the SimCLR model and attaches a linear classification head on top.
simclr_model = tf.keras.models.load_model(simclr_model_save_path)
linear_evaluation_model = simclr_models.create_linear_model_from_base_model(simclr_model, output_shape, intermediate_layer=7)

# 2. Sets up a ModelCheckpoint callback to save the best model (lowest validation loss).
# This ensures we keep the model version that performs best on validation data
linear_eval_best_model_file_name = f"{working_directory}{start_time_str}_simclr_{tag}.keras"
best_model_callback = tf.keras.callbacks.ModelCheckpoint(
    linear_eval_best_model_file_name,
    monitor='val_loss',
    mode='min',
    save_best_only=True,
    save_weights_only=False,
    verbose=0
)

# 3. Trains the linear evaluation model using the training and validation data.
training_history = linear_evaluation_model.fit(
    x = np_train_data,
    y = np_train_labels,
    batch_size=batch_size,
    shuffle=True,
    epochs=total_epochs,
    callbacks=[best_model_callback],
    validation_data=(np_val_data, np_val_labels)
)
# Out:
# WARNING:absl:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# Epoch 1/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 11s 673ms/step - auc: 0.7709 - categorical_accuracy: 0.7231 - loss: 0.5673 - precision: 0.7231 - recall: 0.7231 - val_auc: 0.9530 - val_categorical_accuracy: 0.9006 - val_loss: 0.3713 - val_precision: 0.9006 - val_recall: 0.9006
# Epoch 2/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - auc: 0.9327 - categorical_accuracy: 0.8790 - loss: 0.3837 - precision: 0.8790 - recall: 0.8790 - val_auc: 0.9576 - val_categorical_accuracy: 0.9034 - val_loss: 0.3230 - val_precision: 0.9034 - val_recall: 0.9034
# Epoch 3/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - auc: 0.9372 - categorical_accuracy: 0.8821 - loss: 0.3518 - precision: 0.8821 - recall: 0.8821 - val_auc: 0.9599 - val_categorical_accuracy: 0.9006 - val_loss: 0.2996 - val_precision: 0.9006 - val_recall: 0.9006
# Epoch 4/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - auc: 0.9410 - categorical_accuracy: 0.8845 - loss: 0.3358 - precision: 0.8845 - recall: 0.8845 - val_auc: 0.9614 - val_categorical_accuracy: 0.9006 - val_loss: 0.2862 - val_precision: 0.9006 - val_recall: 0.9006
# Epoch 5/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - auc: 0.9437 - categorical_accuracy: 0.8889 - loss: 0.3215 - precision: 0.8889 - recall: 0.8889 - val_auc: 0.9625 - val_categorical_accuracy: 0.9034 - val_loss: 0.2763 - val_precision: 0.9034 - val_recall: 0.9034
# Epoch 6/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - auc: 0.9459 - categorical_accuracy: 0.8805 - loss: 0.3140 - precision: 0.8805 - recall: 0.8805 - val_auc: 0.9632 - val_categorical_accuracy: 0.9006 - val_loss: 0.2700 - val_precision: 0.9006 - val_recall: 0.9006
# Epoch 7/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - auc: 0.9458 - categorical_accuracy: 0.8863 - loss: 0.3123 - precision: 0.8863 - recall: 0.8863 - val_auc: 0.9641 - val_categorical_accuracy: 0.9006 - val_loss: 0.2647 - val_precision: 0.9006 - val_recall: 0.9006
# Epoch 8/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - auc: 0.9462 - categorical_accuracy: 0.8858 - loss: 0.3070 - precision: 0.8858 - recall: 0.8858 - val_auc: 0.9647 - val_categorical_accuracy: 0.9006 - val_loss: 0.2612 - val_precision: 0.9006 - val_recall: 0.9006
# Epoch 9/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - auc: 0.9454 - categorical_accuracy: 0.8815 - loss: 0.3105 - precision: 0.8815 - recall: 0.8815 - val_auc: 0.9655 - val_categorical_accuracy: 0.9006 - val_loss: 0.2579 - val_precision: 0.9006 - val_recall: 0.9006
# Epoch 10/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - auc: 0.9462 - categorical_accuracy: 0.8876 - loss: 0.3055 - precision: 0.8876 - recall: 0.8876 - val_auc: 0.9656 - val_categorical_accuracy: 0.9006 - val_loss: 0.2558 - val_precision: 0.9006 - val_recall: 0.9006
# Epoch 11/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - auc: 0.9476 - categorical_accuracy: 0.8913 - loss: 0.3008 - precision: 0.8913 - recall: 0.8913 - val_auc: 0.9661 - val_categorical_accuracy: 0.9006 - val_loss: 0.2533 - val_precision: 0.9006 - val_recall: 0.9006
# Epoch 12/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - auc: 0.9471 - categorical_accuracy: 0.8891 - loss: 0.3015 - precision: 0.8891 - recall: 0.8891 - val_auc: 0.9660 - val_categorical_accuracy: 0.9006 - val_loss: 0.2529 - val_precision: 0.9006 - val_recall: 0.9006
# Epoch 13/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - auc: 0.9477 - categorical_accuracy: 0.8823 - loss: 0.3020 - precision: 0.8823 - recall: 0.8823 - val_auc: 0.9663 - val_categorical_accuracy: 0.9006 - val_loss: 0.2513 - val_precision: 0.9006 - val_recall: 0.9006
# Epoch 14/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - auc: 0.9491 - categorical_accuracy: 0.8841 - loss: 0.2966 - precision: 0.8841 - recall: 0.8841 - val_auc: 0.9669 - val_categorical_accuracy: 0.9006 - val_loss: 0.2487 - val_precision: 0.9006 - val_recall: 0.9006
# Epoch 15/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - auc: 0.9485 - categorical_accuracy: 0.8885 - loss: 0.2998 - precision: 0.8885 - recall: 0.8885 - val_auc: 0.9672 - val_categorical_accuracy: 0.9006 - val_loss: 0.2472 - val_precision: 0.9006 - val_recall: 0.9006
# Epoch 16/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - auc: 0.9478 - categorical_accuracy: 0.8876 - loss: 0.2973 - precision: 0.8876 - recall: 0.8876 - val_auc: 0.9672 - val_categorical_accuracy: 0.9006 - val_loss: 0.2474 - val_precision: 0.9006 - val_recall: 0.9006
# Epoch 17/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - auc: 0.9492 - categorical_accuracy: 0.8913 - loss: 0.2966 - precision: 0.8913 - recall: 0.8913 - val_auc: 0.9674 - val_categorical_accuracy: 0.9006 - val_loss: 0.2457 - val_precision: 0.9006 - val_recall: 0.9006
# Epoch 18/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - auc: 0.9506 - categorical_accuracy: 0.8856 - loss: 0.2908 - precision: 0.8856 - recall: 0.8856 - val_auc: 0.9672 - val_categorical_accuracy: 0.9006 - val_loss: 0.2456 - val_precision: 0.9006 - val_recall: 0.9006
# Epoch 19/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - auc: 0.9493 - categorical_accuracy: 0.8872 - loss: 0.2980 - precision: 0.8872 - recall: 0.8872 - val_auc: 0.9676 - val_categorical_accuracy: 0.9006 - val_loss: 0.2443 - val_precision: 0.9006 - val_recall: 0.9006
# Epoch 20/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - auc: 0.9496 - categorical_accuracy: 0.8925 - loss: 0.2956 - precision: 0.8925 - recall: 0.8925 - val_auc: 0.9676 - val_categorical_accuracy: 0.9006 - val_loss: 0.2441 - val_precision: 0.9006 - val_recall: 0.9006
# Epoch 21/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - auc: 0.9495 - categorical_accuracy: 0.8907 - loss: 0.2969 - precision: 0.8907 - recall: 0.8907 - val_auc: 0.9678 - val_categorical_accuracy: 0.9006 - val_loss: 0.2434 - val_precision: 0.9006 - val_recall: 0.9006
# Epoch 22/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - auc: 0.9501 - categorical_accuracy: 0.8896 - loss: 0.2923 - precision: 0.8896 - recall: 0.8896 - val_auc: 0.9678 - val_categorical_accuracy: 0.9006 - val_loss: 0.2426 - val_precision: 0.9006 - val_recall: 0.9006
# Epoch 23/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - auc: 0.9514 - categorical_accuracy: 0.8891 - loss: 0.2925 - precision: 0.8891 - recall: 0.8891 - val_auc: 0.9676 - val_categorical_accuracy: 0.9034 - val_loss: 0.2438 - val_precision: 0.9034 - val_recall: 0.9034
# Epoch 24/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - auc: 0.9530 - categorical_accuracy: 0.8912 - loss: 0.2874 - precision: 0.8912 - recall: 0.8912 - val_auc: 0.9677 - val_categorical_accuracy: 0.9006 - val_loss: 0.2423 - val_precision: 0.9006 - val_recall: 0.9006
# Epoch 25/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - auc: 0.9501 - categorical_accuracy: 0.8882 - loss: 0.2942 - precision: 0.8882 - recall: 0.8882 - val_auc: 0.9679 - val_categorical_accuracy: 0.9034 - val_loss: 0.2414 - val_precision: 0.9034 - val_recall: 0.9034
# Epoch 26/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - auc: 0.9520 - categorical_accuracy: 0.8910 - loss: 0.2897 - precision: 0.8910 - recall: 0.8910 - val_auc: 0.9681 - val_categorical_accuracy: 0.9006 - val_loss: 0.2412 - val_precision: 0.9006 - val_recall: 0.9006
# Epoch 27/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - auc: 0.9505 - categorical_accuracy: 0.8926 - loss: 0.2952 - precision: 0.8926 - recall: 0.8926 - val_auc: 0.9682 - val_categorical_accuracy: 0.9034 - val_loss: 0.2408 - val_precision: 0.9034 - val_recall: 0.9034
# Epoch 28/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - auc: 0.9517 - categorical_accuracy: 0.8916 - loss: 0.2894 - precision: 0.8916 - recall: 0.8916 - val_auc: 0.9681 - val_categorical_accuracy: 0.9034 - val_loss: 0.2411 - val_precision: 0.9034 - val_recall: 0.9034
# Epoch 29/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - auc: 0.9519 - categorical_accuracy: 0.8907 - loss: 0.2889 - precision: 0.8907 - recall: 0.8907 - val_auc: 0.9680 - val_categorical_accuracy: 0.9034 - val_loss: 0.2405 - val_precision: 0.9034 - val_recall: 0.9034
# Epoch 30/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - auc: 0.9516 - categorical_accuracy: 0.8924 - loss: 0.2915 - precision: 0.8924 - recall: 0.8924 - val_auc: 0.9682 - val_categorical_accuracy: 0.9034 - val_loss: 0.2404 - val_precision: 0.9034 - val_recall: 0.9034
# Epoch 31/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - auc: 0.9526 - categorical_accuracy: 0.8956 - loss: 0.2885 - precision: 0.8956 - recall: 0.8956 - val_auc: 0.9684 - val_categorical_accuracy: 0.9034 - val_loss: 0.2401 - val_precision: 0.9034 - val_recall: 0.9034
# Epoch 32/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - auc: 0.9526 - categorical_accuracy: 0.8905 - loss: 0.2875 - precision: 0.8905 - recall: 0.8905 - val_auc: 0.9685 - val_categorical_accuracy: 0.9034 - val_loss: 0.2398 - val_precision: 0.9034 - val_recall: 0.9034
# Epoch 33/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - auc: 0.9520 - categorical_accuracy: 0.8912 - loss: 0.2886 - precision: 0.8912 - recall: 0.8912 - val_auc: 0.9682 - val_categorical_accuracy: 0.9034 - val_loss: 0.2409 - val_precision: 0.9034 - val_recall: 0.9034
# Epoch 34/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - auc: 0.9533 - categorical_accuracy: 0.8904 - loss: 0.2854 - precision: 0.8904 - recall: 0.8904 - val_auc: 0.9687 - val_categorical_accuracy: 0.9034 - val_loss: 0.2390 - val_precision: 0.9034 - val_recall: 0.9034
# Epoch 35/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - auc: 0.9525 - categorical_accuracy: 0.8909 - loss: 0.2846 - precision: 0.8909 - recall: 0.8909 - val_auc: 0.9686 - val_categorical_accuracy: 0.9034 - val_loss: 0.2392 - val_precision: 0.9034 - val_recall: 0.9034
# Epoch 36/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - auc: 0.9549 - categorical_accuracy: 0.8940 - loss: 0.2818 - precision: 0.8940 - recall: 0.8940 - val_auc: 0.9688 - val_categorical_accuracy: 0.9034 - val_loss: 0.2387 - val_precision: 0.9034 - val_recall: 0.9034
# Epoch 37/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - auc: 0.9535 - categorical_accuracy: 0.8930 - loss: 0.2835 - precision: 0.8930 - recall: 0.8930 - val_auc: 0.9688 - val_categorical_accuracy: 0.9034 - val_loss: 0.2387 - val_precision: 0.9034 - val_recall: 0.9034
# Epoch 38/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - auc: 0.9539 - categorical_accuracy: 0.8938 - loss: 0.2849 - precision: 0.8938 - recall: 0.8938 - val_auc: 0.9688 - val_categorical_accuracy: 0.9034 - val_loss: 0.2386 - val_precision: 0.9034 - val_recall: 0.9034
# Epoch 39/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - auc: 0.9531 - categorical_accuracy: 0.8958 - loss: 0.2863 - precision: 0.8958 - recall: 0.8958 - val_auc: 0.9685 - val_categorical_accuracy: 0.9034 - val_loss: 0.2390 - val_precision: 0.9034 - val_recall: 0.9034
# Epoch 40/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - auc: 0.9534 - categorical_accuracy: 0.8937 - loss: 0.2861 - precision: 0.8937 - recall: 0.8937 - val_auc: 0.9690 - val_categorical_accuracy: 0.9034 - val_loss: 0.2378 - val_precision: 0.9034 - val_recall: 0.9034
# Epoch 41/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - auc: 0.9534 - categorical_accuracy: 0.8939 - loss: 0.2838 - precision: 0.8939 - recall: 0.8939 - val_auc: 0.9687 - val_categorical_accuracy: 0.9034 - val_loss: 0.2383 - val_precision: 0.9034 - val_recall: 0.9034
# Epoch 42/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - auc: 0.9519 - categorical_accuracy: 0.8928 - loss: 0.2857 - precision: 0.8928 - recall: 0.8928 - val_auc: 0.9689 - val_categorical_accuracy: 0.9034 - val_loss: 0.2383 - val_precision: 0.9034 - val_recall: 0.9034
# Epoch 43/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - auc: 0.9534 - categorical_accuracy: 0.8957 - loss: 0.2843 - precision: 0.8957 - recall: 0.8957 - val_auc: 0.9685 - val_categorical_accuracy: 0.9034 - val_loss: 0.2383 - val_precision: 0.9034 - val_recall: 0.9034
# Epoch 44/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - auc: 0.9535 - categorical_accuracy: 0.8914 - loss: 0.2851 - precision: 0.8914 - recall: 0.8914 - val_auc: 0.9691 - val_categorical_accuracy: 0.9034 - val_loss: 0.2372 - val_precision: 0.9034 - val_recall: 0.9034
# Epoch 45/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - auc: 0.9538 - categorical_accuracy: 0.8952 - loss: 0.2822 - precision: 0.8952 - recall: 0.8952 - val_auc: 0.9687 - val_categorical_accuracy: 0.9034 - val_loss: 0.2373 - val_precision: 0.9034 - val_recall: 0.9034
# Epoch 46/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - auc: 0.9545 - categorical_accuracy: 0.8959 - loss: 0.2805 - precision: 0.8959 - recall: 0.8959 - val_auc: 0.9689 - val_categorical_accuracy: 0.9034 - val_loss: 0.2370 - val_precision: 0.9034 - val_recall: 0.9034
# Epoch 47/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - auc: 0.9528 - categorical_accuracy: 0.8904 - loss: 0.2850 - precision: 0.8904 - recall: 0.8904 - val_auc: 0.9688 - val_categorical_accuracy: 0.9034 - val_loss: 0.2375 - val_precision: 0.9034 - val_recall: 0.9034
# Epoch 48/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - auc: 0.9525 - categorical_accuracy: 0.8943 - loss: 0.2875 - precision: 0.8943 - recall: 0.8943 - val_auc: 0.9690 - val_categorical_accuracy: 0.9034 - val_loss: 0.2372 - val_precision: 0.9034 - val_recall: 0.9034
# Epoch 49/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - auc: 0.9536 - categorical_accuracy: 0.8953 - loss: 0.2852 - precision: 0.8953 - recall: 0.8953 - val_auc: 0.9688 - val_categorical_accuracy: 0.9034 - val_loss: 0.2373 - val_precision: 0.9034 - val_recall: 0.9034
# Epoch 50/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - auc: 0.9547 - categorical_accuracy: 0.8930 - loss: 0.2826 - precision: 0.8930 - recall: 0.8930 - val_auc: 0.9688 - val_categorical_accuracy: 0.9034 - val_loss: 0.2381 - val_precision: 0.9034 - val_recall: 0.9034

# %%
# Training and Validation Loss

plt.figure(figsize=(12,6))
plt.plot(training_history.history['loss'], label='Training Loss')
plt.plot(training_history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training and Validation Loss')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Training and Validation Accuracy
plt.figure(figsize=(12,6))
plt.plot(training_history.history['categorical_accuracy'], label='Training Accuracy')
plt.plot(training_history.history['val_categorical_accuracy'], label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Training and Validation Accuracy')
plt.legend()
plt.grid(True)
plt.ylim([0, 1])
plt.show()

# %% [markdown]
# ### 1.2.2 Full HAR Model

# %% [markdown]
# #### Train

# %%
total_epochs = 50
batch_size = 200
tag = "full_eval"

simclr_model = tf.keras.models.load_model(simclr_model_save_path)
full_evaluation_model = simclr_models.create_full_classification_model_from_base_model(
    simclr_model, output_shape, model_name="TPN", intermediate_layer=7, last_freeze_layer=4)

full_eval_best_model_file_name = f"{working_directory}{start_time_str}_simclr_{tag}.keras"

best_model_callback = tf.keras.callbacks.ModelCheckpoint(full_eval_best_model_file_name,
    monitor='val_loss', mode='min', save_best_only=True, save_weights_only=False, verbose=0
)

training_history = full_evaluation_model.fit(
    x = np_train_data,
    y = np_train_labels,
    batch_size=batch_size,
    shuffle=True,
    epochs=total_epochs,
    callbacks=[best_model_callback],
    validation_data=(np_val_data, np_val_labels)
)
# Out:
# WARNING:absl:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# Epoch 1/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 18s 1s/step - auc: 0.8566 - categorical_accuracy: 0.7485 - loss: 0.4515 - precision: 0.7485 - recall: 0.7485 - val_auc: 0.9695 - val_categorical_accuracy: 0.9091 - val_loss: 0.2395 - val_precision: 0.9091 - val_recall: 0.9091
# Epoch 2/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - auc: 0.9460 - categorical_accuracy: 0.8820 - loss: 0.3382 - precision: 0.8820 - recall: 0.8820 - val_auc: 0.9638 - val_categorical_accuracy: 0.9034 - val_loss: 0.2512 - val_precision: 0.9034 - val_recall: 0.9034
# Epoch 3/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - auc: 0.9541 - categorical_accuracy: 0.8859 - loss: 0.2965 - precision: 0.8859 - recall: 0.8859 - val_auc: 0.9593 - val_categorical_accuracy: 0.8835 - val_loss: 0.2733 - val_precision: 0.8835 - val_recall: 0.8835
# Epoch 4/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - auc: 0.9535 - categorical_accuracy: 0.8907 - loss: 0.2867 - precision: 0.8907 - recall: 0.8907 - val_auc: 0.9688 - val_categorical_accuracy: 0.9261 - val_loss: 0.2350 - val_precision: 0.9261 - val_recall: 0.9261
# Epoch 5/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - auc: 0.9620 - categorical_accuracy: 0.9080 - loss: 0.2578 - precision: 0.9080 - recall: 0.9080 - val_auc: 0.9737 - val_categorical_accuracy: 0.9261 - val_loss: 0.2219 - val_precision: 0.9261 - val_recall: 0.9261
# Epoch 6/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - auc: 0.9657 - categorical_accuracy: 0.9145 - loss: 0.2468 - precision: 0.9145 - recall: 0.9145 - val_auc: 0.9743 - val_categorical_accuracy: 0.9233 - val_loss: 0.2177 - val_precision: 0.9233 - val_recall: 0.9233
# Epoch 7/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - auc: 0.9695 - categorical_accuracy: 0.9140 - loss: 0.2321 - precision: 0.9140 - recall: 0.9140 - val_auc: 0.9731 - val_categorical_accuracy: 0.9290 - val_loss: 0.2194 - val_precision: 0.9290 - val_recall: 0.9290
# Epoch 8/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - auc: 0.9712 - categorical_accuracy: 0.9165 - loss: 0.2249 - precision: 0.9165 - recall: 0.9165 - val_auc: 0.9734 - val_categorical_accuracy: 0.9261 - val_loss: 0.2190 - val_precision: 0.9261 - val_recall: 0.9261
# Epoch 9/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - auc: 0.9752 - categorical_accuracy: 0.9212 - loss: 0.2101 - precision: 0.9212 - recall: 0.9212 - val_auc: 0.9705 - val_categorical_accuracy: 0.9261 - val_loss: 0.2242 - val_precision: 0.9261 - val_recall: 0.9261
# Epoch 10/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - auc: 0.9761 - categorical_accuracy: 0.9200 - loss: 0.2086 - precision: 0.9200 - recall: 0.9200 - val_auc: 0.9696 - val_categorical_accuracy: 0.9205 - val_loss: 0.2246 - val_precision: 0.9205 - val_recall: 0.9205
# Epoch 11/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - auc: 0.9772 - categorical_accuracy: 0.9180 - loss: 0.2028 - precision: 0.9180 - recall: 0.9180 - val_auc: 0.9664 - val_categorical_accuracy: 0.9176 - val_loss: 0.2318 - val_precision: 0.9176 - val_recall: 0.9176
# Epoch 12/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - auc: 0.9784 - categorical_accuracy: 0.9218 - loss: 0.1983 - precision: 0.9218 - recall: 0.9218 - val_auc: 0.9702 - val_categorical_accuracy: 0.9205 - val_loss: 0.2231 - val_precision: 0.9205 - val_recall: 0.9205
# Epoch 13/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - auc: 0.9814 - categorical_accuracy: 0.9277 - loss: 0.1831 - precision: 0.9277 - recall: 0.9277 - val_auc: 0.9764 - val_categorical_accuracy: 0.9290 - val_loss: 0.2056 - val_precision: 0.9290 - val_recall: 0.9290
# Epoch 14/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - auc: 0.9838 - categorical_accuracy: 0.9312 - loss: 0.1741 - precision: 0.9312 - recall: 0.9312 - val_auc: 0.9759 - val_categorical_accuracy: 0.9290 - val_loss: 0.2066 - val_precision: 0.9290 - val_recall: 0.9290
# Epoch 15/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - auc: 0.9840 - categorical_accuracy: 0.9303 - loss: 0.1731 - precision: 0.9303 - recall: 0.9303 - val_auc: 0.9777 - val_categorical_accuracy: 0.9261 - val_loss: 0.2027 - val_precision: 0.9261 - val_recall: 0.9261
# Epoch 16/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - auc: 0.9866 - categorical_accuracy: 0.9348 - loss: 0.1593 - precision: 0.9348 - recall: 0.9348 - val_auc: 0.9716 - val_categorical_accuracy: 0.9148 - val_loss: 0.2234 - val_precision: 0.9148 - val_recall: 0.9148
# Epoch 17/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - auc: 0.9864 - categorical_accuracy: 0.9404 - loss: 0.1611 - precision: 0.9404 - recall: 0.9404 - val_auc: 0.9591 - val_categorical_accuracy: 0.9119 - val_loss: 0.2622 - val_precision: 0.9119 - val_recall: 0.9119
# Epoch 18/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - auc: 0.9831 - categorical_accuracy: 0.9261 - loss: 0.1752 - precision: 0.9261 - recall: 0.9261 - val_auc: 0.9734 - val_categorical_accuracy: 0.9148 - val_loss: 0.2208 - val_precision: 0.9148 - val_recall: 0.9148
# Epoch 19/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - auc: 0.9871 - categorical_accuracy: 0.9476 - loss: 0.1505 - precision: 0.9476 - recall: 0.9476 - val_auc: 0.9791 - val_categorical_accuracy: 0.9148 - val_loss: 0.1960 - val_precision: 0.9148 - val_recall: 0.9148
# Epoch 20/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - auc: 0.9888 - categorical_accuracy: 0.9482 - loss: 0.1470 - precision: 0.9482 - recall: 0.9482 - val_auc: 0.9815 - val_categorical_accuracy: 0.9205 - val_loss: 0.1873 - val_precision: 0.9205 - val_recall: 0.9205
# Epoch 21/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - auc: 0.9919 - categorical_accuracy: 0.9545 - loss: 0.1263 - precision: 0.9545 - recall: 0.9545 - val_auc: 0.9785 - val_categorical_accuracy: 0.9119 - val_loss: 0.2007 - val_precision: 0.9119 - val_recall: 0.9119
# Epoch 22/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - auc: 0.9914 - categorical_accuracy: 0.9506 - loss: 0.1304 - precision: 0.9506 - recall: 0.9506 - val_auc: 0.9708 - val_categorical_accuracy: 0.9119 - val_loss: 0.2366 - val_precision: 0.9119 - val_recall: 0.9119
# Epoch 23/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - auc: 0.9929 - categorical_accuracy: 0.9574 - loss: 0.1221 - precision: 0.9574 - recall: 0.9574 - val_auc: 0.9709 - val_categorical_accuracy: 0.9119 - val_loss: 0.2329 - val_precision: 0.9119 - val_recall: 0.9119
# Epoch 24/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - auc: 0.9935 - categorical_accuracy: 0.9571 - loss: 0.1162 - precision: 0.9571 - recall: 0.9571 - val_auc: 0.9787 - val_categorical_accuracy: 0.9119 - val_loss: 0.2132 - val_precision: 0.9119 - val_recall: 0.9119
# Epoch 25/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - auc: 0.9948 - categorical_accuracy: 0.9576 - loss: 0.1055 - precision: 0.9576 - recall: 0.9576 - val_auc: 0.9768 - val_categorical_accuracy: 0.9148 - val_loss: 0.2093 - val_precision: 0.9148 - val_recall: 0.9148
# Epoch 26/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - auc: 0.9951 - categorical_accuracy: 0.9596 - loss: 0.1064 - precision: 0.9596 - recall: 0.9596 - val_auc: 0.9734 - val_categorical_accuracy: 0.9233 - val_loss: 0.2306 - val_precision: 0.9233 - val_recall: 0.9233
# Epoch 27/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - auc: 0.9894 - categorical_accuracy: 0.9470 - loss: 0.1400 - precision: 0.9470 - recall: 0.9470 - val_auc: 0.9728 - val_categorical_accuracy: 0.9148 - val_loss: 0.2315 - val_precision: 0.9148 - val_recall: 0.9148
# Epoch 28/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - auc: 0.9910 - categorical_accuracy: 0.9506 - loss: 0.1305 - precision: 0.9506 - recall: 0.9506 - val_auc: 0.9716 - val_categorical_accuracy: 0.9006 - val_loss: 0.2363 - val_precision: 0.9006 - val_recall: 0.9006
# Epoch 29/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - auc: 0.9958 - categorical_accuracy: 0.9644 - loss: 0.0970 - precision: 0.9644 - recall: 0.9644 - val_auc: 0.9767 - val_categorical_accuracy: 0.9148 - val_loss: 0.2250 - val_precision: 0.9148 - val_recall: 0.9148
# Epoch 30/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - auc: 0.9957 - categorical_accuracy: 0.9598 - loss: 0.0978 - precision: 0.9598 - recall: 0.9598 - val_auc: 0.9577 - val_categorical_accuracy: 0.9091 - val_loss: 0.2983 - val_precision: 0.9091 - val_recall: 0.9091
# Epoch 31/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - auc: 0.9881 - categorical_accuracy: 0.9393 - loss: 0.1492 - precision: 0.9393 - recall: 0.9393 - val_auc: 0.9423 - val_categorical_accuracy: 0.8920 - val_loss: 0.3810 - val_precision: 0.8920 - val_recall: 0.8920
# Epoch 32/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - auc: 0.9738 - categorical_accuracy: 0.9209 - loss: 0.2284 - precision: 0.9209 - recall: 0.9209 - val_auc: 0.9366 - val_categorical_accuracy: 0.8693 - val_loss: 0.4117 - val_precision: 0.8693 - val_recall: 0.8693
# Epoch 33/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - auc: 0.9647 - categorical_accuracy: 0.8892 - loss: 0.2852 - precision: 0.8892 - recall: 0.8892 - val_auc: 0.9724 - val_categorical_accuracy: 0.9205 - val_loss: 0.2423 - val_precision: 0.9205 - val_recall: 0.9205
# Epoch 34/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - auc: 0.9831 - categorical_accuracy: 0.9403 - loss: 0.1758 - precision: 0.9403 - recall: 0.9403 - val_auc: 0.9709 - val_categorical_accuracy: 0.9119 - val_loss: 0.2342 - val_precision: 0.9119 - val_recall: 0.9119
# Epoch 35/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - auc: 0.9859 - categorical_accuracy: 0.9422 - loss: 0.1587 - precision: 0.9422 - recall: 0.9422 - val_auc: 0.9677 - val_categorical_accuracy: 0.9233 - val_loss: 0.2388 - val_precision: 0.9233 - val_recall: 0.9233
# Epoch 36/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - auc: 0.9921 - categorical_accuracy: 0.9488 - loss: 0.1302 - precision: 0.9488 - recall: 0.9488 - val_auc: 0.9752 - val_categorical_accuracy: 0.9148 - val_loss: 0.2180 - val_precision: 0.9148 - val_recall: 0.9148
# Epoch 37/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - auc: 0.9936 - categorical_accuracy: 0.9548 - loss: 0.1149 - precision: 0.9548 - recall: 0.9548 - val_auc: 0.9794 - val_categorical_accuracy: 0.9148 - val_loss: 0.2031 - val_precision: 0.9148 - val_recall: 0.9148
# Epoch 38/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - auc: 0.9964 - categorical_accuracy: 0.9661 - loss: 0.0953 - precision: 0.9661 - recall: 0.9661 - val_auc: 0.9779 - val_categorical_accuracy: 0.9119 - val_loss: 0.2140 - val_precision: 0.9119 - val_recall: 0.9119
# Epoch 39/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - auc: 0.9959 - categorical_accuracy: 0.9646 - loss: 0.0984 - precision: 0.9646 - recall: 0.9646 - val_auc: 0.9746 - val_categorical_accuracy: 0.9062 - val_loss: 0.2294 - val_precision: 0.9062 - val_recall: 0.9062
# Epoch 40/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - auc: 0.9968 - categorical_accuracy: 0.9642 - loss: 0.0908 - precision: 0.9642 - recall: 0.9642 - val_auc: 0.9783 - val_categorical_accuracy: 0.9148 - val_loss: 0.2151 - val_precision: 0.9148 - val_recall: 0.9148
# Epoch 41/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - auc: 0.9977 - categorical_accuracy: 0.9720 - loss: 0.0781 - precision: 0.9720 - recall: 0.9720 - val_auc: 0.9752 - val_categorical_accuracy: 0.9062 - val_loss: 0.2303 - val_precision: 0.9062 - val_recall: 0.9062
# Epoch 42/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - auc: 0.9980 - categorical_accuracy: 0.9767 - loss: 0.0759 - precision: 0.9767 - recall: 0.9767 - val_auc: 0.9792 - val_categorical_accuracy: 0.9091 - val_loss: 0.2192 - val_precision: 0.9091 - val_recall: 0.9091
# Epoch 43/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - auc: 0.9981 - categorical_accuracy: 0.9727 - loss: 0.0748 - precision: 0.9727 - recall: 0.9727 - val_auc: 0.9724 - val_categorical_accuracy: 0.9034 - val_loss: 0.2450 - val_precision: 0.9034 - val_recall: 0.9034
# Epoch 44/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - auc: 0.9978 - categorical_accuracy: 0.9746 - loss: 0.0762 - precision: 0.9746 - recall: 0.9746 - val_auc: 0.9744 - val_categorical_accuracy: 0.9091 - val_loss: 0.2366 - val_precision: 0.9091 - val_recall: 0.9091
# Epoch 45/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - auc: 0.9986 - categorical_accuracy: 0.9805 - loss: 0.0654 - precision: 0.9805 - recall: 0.9805 - val_auc: 0.9769 - val_categorical_accuracy: 0.9091 - val_loss: 0.2337 - val_precision: 0.9091 - val_recall: 0.9091
# Epoch 46/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - auc: 0.9989 - categorical_accuracy: 0.9842 - loss: 0.0623 - precision: 0.9842 - recall: 0.9842 - val_auc: 0.9746 - val_categorical_accuracy: 0.9091 - val_loss: 0.2399 - val_precision: 0.9091 - val_recall: 0.9091
# Epoch 47/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - auc: 0.9989 - categorical_accuracy: 0.9811 - loss: 0.0605 - precision: 0.9811 - recall: 0.9811 - val_auc: 0.9737 - val_categorical_accuracy: 0.9119 - val_loss: 0.2445 - val_precision: 0.9119 - val_recall: 0.9119
# Epoch 48/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - auc: 0.9985 - categorical_accuracy: 0.9806 - loss: 0.0644 - precision: 0.9806 - recall: 0.9806 - val_auc: 0.9731 - val_categorical_accuracy: 0.9119 - val_loss: 0.2502 - val_precision: 0.9119 - val_recall: 0.9119
# Epoch 49/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - auc: 0.9989 - categorical_accuracy: 0.9798 - loss: 0.0590 - precision: 0.9798 - recall: 0.9798 - val_auc: 0.9674 - val_categorical_accuracy: 0.9148 - val_loss: 0.2600 - val_precision: 0.9148 - val_recall: 0.9148
# Epoch 50/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - auc: 0.9988 - categorical_accuracy: 0.9835 - loss: 0.0562 - precision: 0.9835 - recall: 0.9835 - val_auc: 0.9689 - val_categorical_accuracy: 0.9119 - val_loss: 0.2723 - val_precision: 0.9119 - val_recall: 0.9119

# %% [markdown]
# #### Plot metrics

# %%
# Training and Validation Loss

plt.figure(figsize=(12,6))
plt.plot(training_history.history['loss'], label='Training Loss')
plt.plot(training_history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training and Validation Loss')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Training and Validation Accuracy
plt.figure(figsize=(12,6))
plt.plot(training_history.history['categorical_accuracy'], label='Training Accuracy')
plt.plot(training_history.history['val_categorical_accuracy'], label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Training and Validation Accuracy')
plt.legend()
plt.grid(True)
plt.ylim([0, 1])
plt.show()

# %% [markdown]
# # Evaluation of real-world test data

# %%
# load data
with open('../training_data/X_test_normalized.pkl', 'rb') as f:
    np_test_data_real_world = pickle.load(f)
with open('../training_data/y_test_onehot.pkl', 'rb') as f:
    np_test_labels_real_world = pickle.load(f)

# %%
full_eval_best_model_file_name = "../models/20251102-141233_simclr_full_eval_1s_30hz_realworld.keras"
full_eval_best_model = tf.keras.models.load_model(full_eval_best_model_file_name)


print(simclr_utitlities.evaluate_model_simple(full_eval_best_model.predict(np_test_data_real_world), np_test_labels_real_world, return_dict=True))
# Out:
# c:\Users\liuzi\miniconda3\Lib\site-packages\keras\src\models\functional.py:238: UserWarning: The structure of `inputs` doesn't match the expected structure.
# Expected: ['input']
# Received: inputs=Tensor(shape=(32, 30, 3))
#   warnings.warn(msg)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step
# {'Confusion Matrix': array([[211,  36],
#        [ 50, 197]]), 'F1 Macro': 0.825770997375328, 'F1 Micro': 0.8259109311740891, 'F1 Weighted': 0.8257709973753281, 'Precision': 0.8269613405028531, 'Recall': 0.8259109311740891, 'Kappa': np.float64(0.6518218623481782)}
# c:\Users\liuzi\miniconda3\Lib\site-packages\keras\src\models\functional.py:238: UserWarning: The structure of `inputs` doesn't match the expected structure.
# Expected: ['input']
# Received: inputs=Tensor(shape=(None, 30, 3))
#   warnings.warn(msg)

# %%
# save the predicted labels in a pickle file
predicted_labels = full_eval_best_model.predict(np_test_data_real_world)
with open('../training_data/y_test_predicted_labels.pkl', 'wb') as f:
    pickle.dump(predicted_labels, f)
# Out:
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
