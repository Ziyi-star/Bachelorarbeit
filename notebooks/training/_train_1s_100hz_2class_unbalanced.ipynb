# %% [markdown]
# <a href="https://colab.research.google.com/github/Ziyi-star/Bachelorarbeit/blob/main/notebooks/training/_train_1s_100hz_2class_initial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # SimCLR Training

# %%
# For VSCode
# %load_ext autoreload
# %autoreload 2
import os
import pickle
import scipy
import datetime
import numpy as np
import tensorflow as tf
import simclr_utitlities
import transformations
import simclr_models
import sys
import matplotlib.pyplot as plt

sys.path.append('../')   # Add parent directory to Python path
working_directory = "../models/"
sys.path.append('../../')
from utils.preprocessing import *

seed = 1
tf.random.set_seed(seed)
np.random.seed(seed)
# Update the file paths in your notebook
with open('../../data/Training/1s_100hz/2class_unbalanced/X_train_normalized.pkl', 'rb') as f:
    np_train_data = pickle.load(f)
with open('../../data/Training/1s_100hz/2class_unbalanced/y_train_onehot.pkl', 'rb') as f:
    np_train_labels = pickle.load(f)
with open('../../data/Training/1s_100hz/2class_unbalanced/X_val_normalized.pkl', 'rb') as f:
    np_val_data = pickle.load(f)
with open('../../data/Training/1s_100hz/2class_unbalanced/y_val_onehot.pkl', 'rb') as f:
    np_val_labels = pickle.load(f)
with open('../../data/Training/1s_100hz/2class_unbalanced/X_test_normalized.pkl', 'rb') as f:
    np_test_data = pickle.load(f)
with open('../../data/Training/1s_100hz/2class_unbalanced/y_test_onehot.pkl', 'rb') as f:
    np_test_labels = pickle.load(f)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# For Google Colab
# 1. Clone your repository to go to access your notebook and .py files
# !git clone https://github.com/Ziyi-star/Bachelorarbeit.git
# 2. Change working directory to where your notebook and .py files are
import os
os.chdir('/content/Bachelorarbeit/notebooks/training')
import os
import pickle
import scipy
import datetime
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import simclr_utitlities
import transformations
import simclr_models
import sys
sys.path.append('../../')
from utils.preprocessing import *



seed = 1
tf.random.set_seed(seed)
np.random.seed(seed)

# Load data
# Download the file from GitHub
# !rm -f *.pkl # Remove existing pickle files
# !wget https://raw.githubusercontent.com/Ziyi-star/Bachelorarbeit/main/notebooks/training_data/X_train_normalized.pkl
# !wget https://raw.githubusercontent.com/Ziyi-star/Bachelorarbeit/main/notebooks/training_data/y_train_onehot.pkl
# !wget https://raw.githubusercontent.com/Ziyi-star/Bachelorarbeit/main/notebooks/training_data/X_val_normalized.pkl
# !wget https://raw.githubusercontent.com/Ziyi-star/Bachelorarbeit/main/notebooks/training_data/y_val_onehot.pkl
# !wget https://raw.githubusercontent.com/Ziyi-star/Bachelorarbeit/main/notebooks/training_data/X_test_normalized.pkl
# !wget https://raw.githubusercontent.com/Ziyi-star/Bachelorarbeit/main/notebooks/training_data/y_test_onehot.pkl

working_directory = "../models/"  # Relative path to models folder

# Load as usual
import pickle

with open('X_train_normalized.pkl', 'rb') as f:
    np_train_data = pickle.load(f)
with open('y_train_onehot.pkl', 'rb') as f:
    np_train_labels = pickle.load(f)
with open('X_val_normalized.pkl', 'rb') as f:
    np_val_data = pickle.load(f)
with open('y_val_onehot.pkl', 'rb') as f:
    np_val_labels = pickle.load(f)
with open('X_test_data.pkl', 'rb') as f:
    np_test_data = pickle.load(f)
with open('y_test_onehot.pkl', 'rb') as f:
    np_test_labels = pickle.load(f)

print(np_train_data.shape, np_train_labels.shape)
print(np_val_data.shape, np_val_labels.shape)
# Out:
# Cloning into 'Bachelorarbeit'...
# remote: Enumerating objects: 953, done.
# remote: Counting objects: 100% (33/33), done.
# remote: Compressing objects: 100% (24/24), done.
# remote: Total 953 (delta 12), reused 25 (delta 9), pack-reused 920 (from 2)
# Receiving objects: 100% (953/953), 237.47 MiB | 23.39 MiB/s, done.
# Resolving deltas: 100% (579/579), done.
# Updating files: 100% (108/108), done.
# /content/Bachelorarbeit/notebooks/training/transformations.py:35: SyntaxWarning: invalid escape sequence '\&'
#   @inproceedings{TerryUm_ICMI2017, author = {Um, Terry T. and Pfister, Franz M. J. and Pichler, Daniel and Endo, Satoshi and Lang, Muriel and Hirche, Sandra and Fietzek, Urban and Kuli\'{c}, Dana}, title = {Data Augmentation of Wearable Sensor Data for Parkinson's Disease Monitoring Using Convolutional Neural Networks}, booktitle = {Proceedings of the 19th ACM International Conference on Multimodal Interaction}, series = {ICMI 2017}, year = {2017}, isbn = {978-1-4503-5543-8}, location = {Glasgow, UK}, pages = {216--220}, numpages = {5}, doi = {10.1145/3136755.3136817}, acmid = {3136817}, publisher = {ACM}, address = {New York, NY, USA}, keywords = {Parkinson\&#39;s disease, convolutional neural networks, data augmentation, health monitoring, motor state detection, wearable sensor}, }
# --2025-10-26 09:50:46--  https://raw.githubusercontent.com/Ziyi-star/Bachelorarbeit/main/notebooks/data_1s_30hz_2class/X_train_normalized.pkl
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 566085 (553K) [application/octet-stream]
# Saving to: ‘X_train_normalized.pkl’
#
# X_train_normalized. 100%[===================>] 552.82K  --.-KB/s    in 0.03s
#
# 2025-10-26 09:50:46 (19.0 MB/s) - ‘X_train_normalized.pkl’ saved [566085/566085]
#
# --2025-10-26 09:50:46--  https://raw.githubusercontent.com/Ziyi-star/Bachelorarbeit/main/notebooks/data_1s_30hz_2class/y_train_onehot.pkl
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 12730 (12K) [application/octet-stream]
# Saving to: ‘y_train_onehot.pkl’
#
# y_train_onehot.pkl  100%[===================>]  12.43K  --.-KB/s    in 0.001s
#
# 2025-10-26 09:50:46 (15.7 MB/s) - ‘y_train_onehot.pkl’ saved [12730/12730]
#
# --2025-10-26 09:50:46--  https://raw.githubusercontent.com/Ziyi-star/Bachelorarbeit/main/notebooks/data_1s_30hz_2class/X_val_normalized.pkl
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 142004 (139K) [application/octet-stream]
# Saving to: ‘X_val_normalized.pkl’
#
# X_val_normalized.pk 100%[===================>] 138.68K  --.-KB/s    in 0.02s
#
# 2025-10-26 09:50:47 (8.67 MB/s) - ‘X_val_normalized.pkl’ saved [142004/142004]
#
# --2025-10-26 09:50:47--  https://raw.githubusercontent.com/Ziyi-star/Bachelorarbeit/main/notebooks/data_1s_30hz_2class/y_val_onehot.pkl
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3305 (3.2K) [application/octet-stream]
# Saving to: ‘y_val_onehot.pkl’
#
# y_val_onehot.pkl    100%[===================>]   3.23K  --.-KB/s    in 0s
#
# 2025-10-26 09:50:47 (56.6 MB/s) - ‘y_val_onehot.pkl’ saved [3305/3305]
#
# --2025-10-26 09:50:47--  https://raw.githubusercontent.com/Ziyi-star/Bachelorarbeit/main/notebooks/data_1s_30hz_2class/X_test_data.pkl
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 186040 (182K) [application/octet-stream]
# Saving to: ‘X_test_data.pkl’
#
# X_test_data.pkl     100%[===================>] 181.68K  --.-KB/s    in 0.01s
#
# 2025-10-26 09:50:47 (11.9 MB/s) - ‘X_test_data.pkl’ saved [186040/186040]
#
# --2025-10-26 09:50:47--  https://raw.githubusercontent.com/Ziyi-star/Bachelorarbeit/main/notebooks/data_1s_30hz_2class/y_test_onehot.pkl
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4089 (4.0K) [application/octet-stream]
# Saving to: ‘y_test_onehot.pkl’
#
# y_test_onehot.pkl   100%[===================>]   3.99K  --.-KB/s    in 0s
#
# 2025-10-26 09:50:47 (100 MB/s) - ‘y_test_onehot.pkl’ saved [4089/4089]
#
# (786, 30, 3) (786, 2)
# (197, 30, 3) (197, 2)

# %% [markdown]
# ## 1.1 Pretraining with SimCLR

# %%
# Parameters for all experiments
window_size = 100
input_shape = (window_size, 3)
batch_size = 512
#Number of samples processed together in one training step. Larger batch sizes can speed up training but require more memory.
decay_steps = 1000
#Number of steps after which the learning rate decays (used for learning rate scheduling).
epochs = 200
temperature = 0.1

# %%
#A parameter for the SimCLR loss function that controls how sharply similarities are measured.
# transform_funcs = [
#     transformations.scaling_transform_vectorized, # Use Scaling trasnformation
#     transformations.rotation_transform_vectorized # Use rotation trasnformation
# ]
transform_funcs = [
    transformations.time_segment_permutation_transform_improved,
    transformations.channel_shuffle_transform_vectorized
]
#List of data augmentation functions to apply to the input data. Here, only rotation is used.
transformation_function = simclr_utitlities.generate_composite_transform_function_simple(transform_funcs)
# Out:
# 0 <function time_segment_permutation_transform_improved at 0x00000257B6961440>
# 1 <function channel_shuffle_transform_vectorized at 0x00000257B69613A0>

# %%
# Time
start_time = datetime.datetime.now()
start_time_str = start_time.strftime("%Y%m%d-%H%M%S")
#Formats the date and time as a string like 20250827-153045 (for filenames, logs, etc.).
tf.keras.backend.set_floatx('float32')
#Sets TensorFlow to use 32-bit floating point numbers for all computations (standard for deep learning).

# %%
# Create a cosine-decayed learning rate schedule and SGD optimizer for training.
lr_decayed_fn = tf.keras.optimizers.schedules.CosineDecay(initial_learning_rate=0.1, decay_steps=decay_steps)
optimizer = tf.keras.optimizers.SGD(lr_decayed_fn)

# Build the base model and attach the SimCLR head for contrastive learning.
base_model = simclr_models.create_base_model_small_dimensions(input_shape, model_name="base_model")
simclr_model = simclr_models.attach_simclr_head(base_model)
simclr_model.summary()

# Train the SimCLR model using the specified transformation function and optimizer.
trained_simclr_model, epoch_losses = simclr_utitlities.simclr_train_model(
    simclr_model,
    np_train_data,
    optimizer,
    batch_size,
    transformation_function,
    temperature=temperature,
    epochs=epochs,
    is_trasnform_function_vectorized=True,
    verbose=1
)

# Save the trained SimCLR model to disk for later use.
simclr_model_save_path = f"{working_directory}{start_time_str}_simclr.hdf5"
trained_simclr_model.save(simclr_model_save_path)
# Out:
# Model: "base_model_simclr"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input (InputLayer)              │ (None, 100, 3)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_3 (Conv1D)               │ (None, 100, 32)        │         2,336 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 100, 32)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_4 (Conv1D)               │ (None, 100, 64)        │        32,832 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 100, 64)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_5 (Conv1D)               │ (None, 100, 96)        │        49,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_5 (Dropout)             │ (None, 100, 96)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_max_pooling1d            │ (None, 96)             │             0 │
# │ (GlobalMaxPooling1D)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 256)            │        24,832 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_2 (Activation)       │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_3 (Activation)       │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 50)             │         6,450 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 148,594 (580.45 KB)
#  Trainable params: 148,594 (580.45 KB)
#  Non-trainable params: 0 (0.00 B)
# epoch: 1 loss: 13.472
# epoch: 2 loss: 12.176
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_8304\598561450.py in ?()
#       7 simclr_model = simclr_models.attach_simclr_head(base_model)
#       8 simclr_model.summary()
#       9
#      10 # Train the SimCLR model using the specified transformation function and optimizer.
# ---> 11 trained_simclr_model, epoch_losses = simclr_utitlities.simclr_train_model(
#      12     simclr_model,
#      13     np_train_data,
#      14     optimizer,
#
# c:\Users\liuzi\Desktop\Code\Bachelorarbeit\Bachelorarbeit\notebooks\training\simclr_utitlities.py in ?(model, dataset, optimizer, batch_size, transformation_function, temperature, epochs, is_trasnform_function_vectorized, verbose)
#     233                 transform_1 = np.array([transformation_function(data) for data in data_batch])
#     234                 transform_2 = np.array([transformation_function(data) for data in data_batch])
#     235
#     236             # Forward propagation
# --> 237             loss, gradients = get_NT_Xent_loss_gradients(model, transform_1, transform_2, normalize=True, temperature=temperature, weights=1.0)
#     238
#     239             optimizer.apply_gradients(zip(gradients, model.trainable_variables))
#     240             step_wise_loss.append(loss)
#
# c:\Users\liuzi\Desktop\Code\Bachelorarbeit\Bachelorarbeit\notebooks\training\simclr_utitlities.py in ?(model, samples_transform_1, samples_transform_2, normalize, temperature, weights)
#     159         hidden_features_transform_1 = model(samples_transform_1)
#     160         hidden_features_transform_2 = model(samples_transform_2)
#     161         loss = NT_Xent_loss(hidden_features_transform_1, hidden_features_transform_2, normalize=normalize, temperature=temperature, weights=weights)
#     162
# --> 163     gradients = tape.gradient(loss, model.trainable_variables)
#     164     return loss, gradients
#
# c:\Users\liuzi\miniconda3\Lib\site-packages\tensorflow\python\eager\backprop.py in ?(self, target, sources, output_gradients, unconnected_gradients)
#    1062               output_gradients))
#    1063       output_gradients = [None if x is None else ops.convert_to_tensor(x)
#    1064                           for x in output_gradients]
#    1065
# -> 1066     flat_grad = imperative_grad.imperative_grad(
#    1067         self._tape,
#    1068         flat_targets,
#    1069         flat_sources,
#
# c:\Users\liuzi\miniconda3\Lib\site-packages\tensorflow\python\eager\imperative_grad.py in ?(tape, target, sources, output_gradients, sources_raw, unconnected_gradients)
#      63   except ValueError:
#      64     raise ValueError(
#      65         "Unknown value for unconnected_gradients: %r" % unconnected_gradients)
#      66
# ---> 67   return pywrap_tfe.TFE_Py_TapeGradient(
#      68       tape._tape,  # pylint: disable=protected-access
#      69       target,
#      70       sources,
#
# c:\Users\liuzi\miniconda3\Lib\site-packages\tensorflow\python\eager\backprop.py in ?(op_name, attr_tuple, num_inputs, inputs, outputs, out_grads, skip_input_indices, forward_pass_name_scope)
#     144     gradient_name_scope = "gradient_tape/"
#     145     if forward_pass_name_scope:
#     146       gradient_name_scope += forward_pass_name_scope + "/"
#     147     with ops.name_scope(gradient_name_scope):
# --> 148       return grad_fn(mock_op, *out_grads)
#     149   else:
#     150     return grad_fn(mock_op, *out_grads)
#
# c:\Users\liuzi\miniconda3\Lib\site-packages\tensorflow\python\ops\nn_grad.py in ?(op, grad)
#     590           padding=padding,
#     591           explicit_paddings=explicit_paddings,
#     592           use_cudnn_on_gpu=use_cudnn_on_gpu,
#     593           data_format=data_format),
# --> 594       gen_nn_ops.conv2d_backprop_filter(
#     595           op.inputs[0],
#     596           shape_1,
#     597           grad,
#
# c:\Users\liuzi\miniconda3\Lib\site-packages\tensorflow\python\ops\gen_nn_ops.py in ?(input, filter_sizes, out_backprop, strides, padding, use_cudnn_on_gpu, explicit_paddings, data_format, dilations, name)
#    1631         data_format, "dilations", dilations)
#    1632       return _result
#    1633     except _core._NotOkStatusException as e:
#    1634       _ops.raise_from_not_ok_status(e, name)
# -> 1635     except _core._FallbackException:
#    1636       pass
#    1637     try:
#    1638       return conv2d_backprop_filter_eager_fallback(
#
# KeyboardInterrupt:

# %%
# Plot history of training losses over epochs.
plt.figure(figsize=(12,8))
plt.plot(epoch_losses)
plt.ylabel("Loss")
plt.xlabel("Epoch")
plt.show()

# %% [markdown]
# ## 1.2 Fine-tuning and Evaluation

# %% [markdown]
# ### 1.2.1 Linear Model

# %% [markdown]
# #### Train

# %%
# This block performs linear evaluation on top of the pretrained SimCLR base model.
total_epochs = 50
batch_size = 200
tag = "linear_eval"
output_shape = np_train_labels.shape[1]  # Number of classes for classification

# 1. Loads the SimCLR model and attaches a linear classification head on top.
simclr_model = tf.keras.models.load_model(simclr_model_save_path)
linear_evaluation_model = simclr_models.create_linear_model_from_base_model(simclr_model, output_shape, intermediate_layer=7)

# 2. Sets up a ModelCheckpoint callback to save the best model (lowest validation loss).
# This ensures we keep the model version that performs best on validation data
linear_eval_best_model_file_name = f"{working_directory}{start_time_str}_simclr_{tag}.keras"
best_model_callback = tf.keras.callbacks.ModelCheckpoint(
    linear_eval_best_model_file_name,
    monitor='val_loss',
    mode='min',
    save_best_only=True,
    save_weights_only=False,
    verbose=0
)

# 3. Trains the linear evaluation model using the training and validation data.
training_history = linear_evaluation_model.fit(
    x = np_train_data,
    y = np_train_labels,
    batch_size=batch_size,
    shuffle=True,
    epochs=total_epochs,
    callbacks=[best_model_callback],
    validation_data=(np_val_data, np_val_labels)
)
# Out:
# WARNING:absl:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# Epoch 1/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - auc: 0.5714 - categorical_accuracy: 0.4745 - loss: 0.6057 - precision: 0.4745 - recall: 0.4745 - val_auc: 0.9665 - val_categorical_accuracy: 0.9188 - val_loss: 0.4459 - val_precision: 0.9188 - val_recall: 0.9188
# Epoch 2/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - auc: 0.9704 - categorical_accuracy: 0.9094 - loss: 0.4119 - precision: 0.9094 - recall: 0.9094 - val_auc: 0.9608 - val_categorical_accuracy: 0.8985 - val_loss: 0.3896 - val_precision: 0.8985 - val_recall: 0.8985
# Epoch 3/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - auc: 0.9769 - categorical_accuracy: 0.9209 - loss: 0.3553 - precision: 0.9209 - recall: 0.9209 - val_auc: 0.9571 - val_categorical_accuracy: 0.9036 - val_loss: 0.3598 - val_precision: 0.9036 - val_recall: 0.9036
# Epoch 4/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - auc: 0.9806 - categorical_accuracy: 0.9345 - loss: 0.3201 - precision: 0.9345 - recall: 0.9345 - val_auc: 0.9560 - val_categorical_accuracy: 0.9086 - val_loss: 0.3395 - val_precision: 0.9086 - val_recall: 0.9086
# Epoch 5/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - auc: 0.9816 - categorical_accuracy: 0.9350 - loss: 0.2977 - precision: 0.9350 - recall: 0.9350 - val_auc: 0.9561 - val_categorical_accuracy: 0.9086 - val_loss: 0.3248 - val_precision: 0.9086 - val_recall: 0.9086
# Epoch 6/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - auc: 0.9804 - categorical_accuracy: 0.9311 - loss: 0.2838 - precision: 0.9311 - recall: 0.9311 - val_auc: 0.9558 - val_categorical_accuracy: 0.9086 - val_loss: 0.3140 - val_precision: 0.9086 - val_recall: 0.9086
# Epoch 7/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - auc: 0.
- val_precision: 0.9137 - val_recall: 0.9137
# Epoch 39/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - auc: 0.9842 - categorical_accuracy: 0.9435 - loss: 0.1799 - precision: 0.9435 - recall: 0.9435 - val_auc: 0.9683 - val_categorical_accuracy: 0.9137 - val_loss: 0.2263 - val_precision: 0.9137 - val_recall: 0.9137
# Epoch 40/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - auc: 0.9849 - categorical_accuracy: 0.9410 - loss: 0.1803 - precision: 0.9410 - recall: 0.9410 - val_auc: 0.9683 - val_categorical_accuracy: 0.9137 - val_loss: 0.2260 - val_precision: 0.9137 - val_recall: 0.9137
# Epoch 41/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - auc: 0.9843 - categorical_accuracy: 0.9348 - loss: 0.1799 - precision: 0.9348 - recall: 0.9348 - val_auc: 0.9687 - val_categorical_accuracy: 0.9137 - val_loss: 0.2254 - val_precision: 0.9137 - val_recall: 0.9137
# Epoch 42/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - auc: 0.9839 - categorical_accuracy: 0.9350 - loss: 0.1796 - precision: 0.9350 - recall: 0.9350 - val_auc: 0.9690 - val_categorical_accuracy: 0.9137 - val_loss: 0.2242 - val_precision: 0.9137 - val_recall: 0.9137
# Epoch 43/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - auc: 0.9849 - categorical_accuracy: 0.9429 - loss: 0.1780 - precision: 0.9429 - recall: 0.9429 - val_auc: 0.9689 - val_categorical_accuracy: 0.9137 - val_loss: 0.2240 - val_precision: 0.9137 - val_recall: 0.9137
# Epoch 44/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - auc: 0.9842 - categorical_accuracy: 0.9417 - loss: 0.1781 - precision: 0.9417 - recall: 0.9417 - val_auc: 0.9695 - val_categorical_accuracy: 0.9137 - val_loss: 0.2217 - val_precision: 0.9137 - val_recall: 0.9137
# Epoch 45/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - auc: 0.9847 - categorical_accuracy: 0.9393 - loss: 0.1763 - precision: 0.9393 - recall: 0.9393 - val_auc: 0.9697 - val_categorical_accuracy: 0.9137 - val_loss: 0.2213 - val_precision: 0.9137 - val_recall: 0.9137
# Epoch 46/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - auc: 0.9848 - categorical_accuracy: 0.9400 - loss: 0.1751 - precision: 0.9400 - recall: 0.9400 - val_auc: 0.9697 - val_categorical_accuracy: 0.9137 - val_loss: 0.2201 - val_precision: 0.9137 - val_recall: 0.9137
# Epoch 47/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - auc: 0.9846 - categorical_accuracy: 0.9440 - loss: 0.1765 - precision: 0.9440 - recall: 0.9440 - val_auc: 0.9696 - val_categorical_accuracy: 0.9137 - val_loss: 0.2198 - val_precision: 0.9137 - val_recall: 0.9137
# Epoch 48/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - auc: 0.9859 - categorical_accuracy: 0.9412 - loss: 0.1712 - precision: 0.9412 - recall: 0.9412 - val_auc: 0.9698 - val_categorical_accuracy: 0.9137 - val_loss: 0.2194 - val_precision: 0.9137 - val_recall: 0.9137
# Epoch 49/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - auc: 0.9857 - categorical_accuracy: 0.9395 - loss: 0.1717 - precision: 0.9395 - recall: 0.9395 - val_auc: 0.9701 - val_categorical_accuracy: 0.9137 - val_loss: 0.2179 - val_precision: 0.9137 - val_recall: 0.9137
# Epoch 50/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - auc: 0.9866 - categorical_accuracy: 0.9462 - loss: 0.1695 - precision: 0.9462 - recall: 0.9462 - val_auc: 0.9698 - val_categorical_accuracy: 0.9137 - val_loss: 0.2179 - val_precision: 0.9137 - val_recall: 0.9137

# %%
# Training and Validation Loss

plt.figure(figsize=(12,6))
plt.plot(training_history.history['loss'], label='Training Loss')
plt.plot(training_history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training and Validation Loss')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Training and Validation Accuracy
plt.figure(figsize=(12,6))
plt.plot(training_history.history['categorical_accuracy'], label='Training Accuracy')
plt.plot(training_history.history['val_categorical_accuracy'], label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Training and Validation Accuracy')
plt.legend()
plt.grid(True)
plt.ylim([0, 1])
plt.show()

# %% [markdown]
# #### Test:

# %%
# Load models and evaluate on test set on vscode
linear_eval_model_path =  linear_eval_best_model_file_name

# Load both models
# simclr_model = tf.keras.models.load_model(simclr_model_path)
linear_eval_best_model = tf.keras.models.load_model(linear_eval_model_path)

# %% [markdown]
# #### Normalize test data

# %%
# You can also use it for test data (but should fit the scaler only on training data)
X_test_normalized = normalize_3d_data(np_test_data)

# %%
linear_eval_best_model = tf.keras.models.load_model(linear_eval_best_model_file_name)

print("Model with lowest validation Loss:")
print(simclr_utitlities.evaluate_model_simple(linear_eval_best_model.predict(X_test_normalized), np_test_labels, return_dict=True))
print("Model in last epoch")
print(simclr_utitlities.evaluate_model_simple(linear_evaluation_model.predict(X_test_normalized), np_test_labels, return_dict=True))
# Out:
# Model with lowest validation Loss:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 59ms/step
# {'Confusion Matrix': array([[119,   3],
#        [ 17, 107]]), 'F1 Macro': 0.9185052673424766, 'F1 Micro': 0.9186991869918699, 'F1 Weighted': 0.9184729474009111, 'Precision': 0.9238636363636363, 'Recall': 0.9191565309360127, 'Kappa': np.float64(0.8375379738475762)}
# Model in last epoch
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step
# {'Confusion Matrix': array([[119,   3],
#        [ 17, 107]]), 'F1 Macro': 0.9185052673424766, 'F1 Micro': 0.9186991869918699, 'F1 Weighted': 0.9184729474009111, 'Precision': 0.9238636363636363, 'Recall': 0.9191565309360127, 'Kappa': np.float64(0.8375379738475762)}

# %% [markdown]
# ### 1.2.2 Full HAR Model

# %% [markdown]
# #### Train

# %%
total_epochs = 50
batch_size = 200
tag = "full_eval"

simclr_model = tf.keras.models.load_model(simclr_model_save_path)
full_evaluation_model = simclr_models.create_full_classification_model_from_base_model(
    simclr_model, output_shape, model_name="TPN", intermediate_layer=7, last_freeze_layer=4)

full_eval_best_model_file_name = f"{working_directory}{start_time_str}_simclr_{tag}.keras"

best_model_callback = tf.keras.callbacks.ModelCheckpoint(full_eval_best_model_file_name,
    monitor='val_loss', mode='min', save_best_only=True, save_weights_only=False, verbose=0
)

training_history = full_evaluation_model.fit(
    x = np_train_data,
    y = np_train_labels,
    batch_size=batch_size,
    shuffle=True,
    epochs=total_epochs,
    callbacks=[best_model_callback],
    validation_data=(np_val_data, np_val_labels)
)
# Out:
# WARNING:absl:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# Epoch 1/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 20s 4s/step - auc: 0.7566 - categorical_accuracy: 0.7058 - loss: 0.5539 - precision: 0.7058 - recall: 0.7058 - val_auc: 0.9356 - val_categorical_accuracy: 0.8934 - val_loss: 0.3356 - val_precision: 0.8934 - val_recall: 0.8934
# Epoch 2/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - auc: 0.9706 - categorical_accuracy: 0.9081 - loss: 0.2458 - precision: 0.9081 - recall: 0.9081 - val_auc: 0.9700 - val_categorical_accuracy: 0.9188 - val_loss: 0.2299 - val_precision: 0.9188 - val_recall: 0.9188
# Epoch 3/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - auc: 0.9818 - categorical_accuracy: 0.9509 - loss: 0.1816 - precision: 0.9509 - recall: 0.9509 - val_auc: 0.9649 - val_categorical_accuracy: 0.9188 - val_loss: 0.2422 - val_precision: 0.9188 - val_recall: 0.9188
# Epoch 4/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - auc: 0.9863 - categorical_accuracy: 0.9499 - loss: 0.1543 - precision: 0.9499 - recall: 0.9499 - val_auc: 0.9778 - val_categorical_accuracy: 0.9239 - val_loss: 0.1949 - val_precision: 0.9239 - val_recall: 0.9239
# Epoch 5/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - auc: 0.9896 - categorical_accuracy: 0.9565 - loss: 0.1321 - precision: 0.9565 - recall: 0.9565 - val_auc: 0.9815 - val_categorical_accuracy: 0.9289 - val_loss: 0.1786 - val_precision: 0.9289 - val_recall: 0.9289
# Epoch 6/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - auc: 0.9931 - categorical_accuracy: 0.9654 - loss: 0.1131 - precision: 0.9654 - recall: 0.9654 - val_auc: 0.9833 - val_categorical_accuracy: 0.9391 - val_loss: 0.1718 - val_precision: 0.9391 - val_recall: 0.9391
# Epoch 7/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - auc: 0.9939 - categorical_accuracy: 0.9656 - loss: 0.1063 - precision: 0.9656 - recall: 0.9656 - val_auc: 0.9865 - val_categorical_accuracy: 0.9391 - val_loss: 0.1539 - val_precision: 0.9391 - val_recall: 0.9391
# Epoch 8/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - auc: 0.9945 - categorical_accuracy: 0.9726 - loss: 0.1011 - precision: 0.9726 - recall: 0.9726 - val_auc: 0.9836 - val_categorical_accuracy: 0.9391 - val_loss: 0.1754 - val_precision: 0.9391 - val_recall: 0.9391
# Epoch 9/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - auc: 0.9957 - categorical_accuracy: 0.9644 - loss: 0.0945 - precision: 0.9644 - recall: 0.9644 - val_auc: 0.9840 - val_categorical_accuracy: 0.9391 - val_loss: 0.1551 - val_precision: 0.9391 - val_recall: 0.9391
# Epoch 10/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - auc: 0.9964 - categorical_accuracy: 0.9753 - loss: 0.0867 - precision: 0.9753 - recall: 0.9753 - val_auc: 0.9828 - val_categorical_accuracy: 0.9340 - val_loss: 0.1738 - val_precision: 0.9340 - val_recall: 0.9340
# Epoch 11/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - auc: 0.9967 - categorical_accuracy: 0.9788 - loss: 0.0826 - precision: 0.9788 - recall: 0.9788 - val_auc: 0.9833 - val_categorical_accuracy: 0.9391 - val_loss: 0.1689 - val_precision: 0.9391 - val_recall: 0.9391
# Epoch 12/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - auc: 0.9979 - categorical_accuracy: 0.9785 - loss: 0.0707 - precision: 0.9785 - recall: 0.9785 - val_auc: 0.9871 - val_categorical_accuracy: 0.9391 - val_loss: 0.1550 - val_precision: 0.9391 - val_recall: 0.9391
# Epoch 13/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - auc: 0.9973 - categorical_accuracy: 0.9808 - loss: 0.0739 - precision: 0.9808 - recall: 0.9808 - val_auc: 0.9831 - val_categorical_accuracy: 0.9340 - val_loss: 0.1642 - val_precision: 0.9340 - val_recall: 0.9340
# Epoch 14/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - auc: 0.
# Epoch 44/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - auc: 0.9999 - categorical_accuracy: 0.9946 - loss: 0.0237 - precision: 0.9946 - recall: 0.9946 - val_auc: 0.9821 - val_categorical_accuracy: 0.9391 - val_loss: 0.2262 - val_precision: 0.9391 - val_recall: 0.9391
# Epoch 45/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - auc: 1.0000 - categorical_accuracy: 0.9981 - loss: 0.0166 - precision: 0.9981 - recall: 0.9981 - val_auc: 0.9786 - val_categorical_accuracy: 0.9492 - val_loss: 0.2088 - val_precision: 0.9492 - val_recall: 0.9492
# Epoch 46/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - auc: 1.0000 - categorical_accuracy: 0.9958 - loss: 0.0187 - precision: 0.9958 - recall: 0.9958 - val_auc: 0.9821 - val_categorical_accuracy: 0.9391 - val_loss: 0.2370 - val_precision: 0.9391 - val_recall: 0.9391
# Epoch 47/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - auc: 1.0000 - categorical_accuracy: 0.9968 - loss: 0.0185 - precision: 0.9968 - recall: 0.9968 - val_auc: 0.9774 - val_categorical_accuracy: 0.9442 - val_loss: 0.2080 - val_precision: 0.9442 - val_recall: 0.9442
# Epoch 48/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - auc: 0.9999 - categorical_accuracy: 0.9925 - loss: 0.0252 - precision: 0.9925 - recall: 0.9925 - val_auc: 0.9712 - val_categorical_accuracy: 0.9289 - val_loss: 0.3296 - val_precision: 0.9289 - val_recall: 0.9289
# Epoch 49/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - auc: 0.9998 - categorical_accuracy: 0.9923 - loss: 0.0272 - precision: 0.9923 - recall: 0.9923 - val_auc: 0.9751 - val_categorical_accuracy: 0.9391 - val_loss: 0.2382 - val_precision: 0.9391 - val_recall: 0.9391
# Epoch 50/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - auc: 0.9993 - categorical_accuracy: 0.9868 - loss: 0.0430 - precision: 0.9868 - recall: 0.9868 - val_auc: 0.9716 - val_categorical_accuracy: 0.9289 - val_loss: 0.3403 - val_precision: 0.9289 - val_recall: 0.9289

# %% [markdown]
# #### Plot metrics

# %%
# Training and Validation Loss

plt.figure(figsize=(12,6))
plt.plot(training_history.history['loss'], label='Training Loss')
plt.plot(training_history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training and Validation Loss')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Training and Validation Accuracy
plt.figure(figsize=(12,6))
plt.plot(training_history.history['categorical_accuracy'], label='Training Accuracy')
plt.plot(training_history.history['val_categorical_accuracy'], label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Training and Validation Accuracy')
plt.legend()
plt.grid(True)
plt.ylim([0, 1])
plt.show()

# %% [markdown]
# #### Test:

# %%
full_eval_best_model = tf.keras.models.load_model(full_eval_best_model_file_name)

print("Model with lowest validation Loss:")
print(simclr_utitlities.evaluate_model_simple(full_eval_best_model.predict(X_test_normalized), np_test_labels, return_dict=True))
print("Model in last epoch")
print(simclr_utitlities.evaluate_model_simple(full_evaluation_model.predict(X_test_normalized), np_test_labels, return_dict=True))
# Out:
# Model with lowest validation Loss:
# WARNING:tensorflow:5 out of the last 17 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7a68ac0eaf20> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 266ms/step
# {'Confusion Matrix': array([[116,   6],
#        [  8, 116]]), 'F1 Macro': 0.943089430894309, 'F1 Micro': 0.943089430894309, 'F1 Weighted': 0.943089430894309, 'Precision': 0.9431517715494446, 'Recall': 0.9431517715494446, 'Kappa': np.float64(0.886186384666226)}
# Model in last epoch
# WARNING:tensorflow:5 out of the last 17 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7a68ac0e99e0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 63ms/step
# {'Confusion Matrix': array([[122,   0],
#        [ 12, 112]]), 'F1 Macro': 0.9511387711864407, 'F1 Micro': 0.9512195121951219, 'F1 Weighted': 0.9511226229847044, 'Precision': 0.9552238805970149, 'Recall': 0.9516129032258065, 'Kappa': np.float64(0.9025099075297226)}

# %% [markdown]
# ## Extra: t-SNE Plots

# %% [markdown]
# ### Parameters

# %%
import sklearn.manifold
import seaborn as sns

# %% [markdown]
# ### t-SNE Representations

# %%
# First load the model from the file path
target_model_path = simclr_model_save_path
loaded_model = tf.keras.models.load_model(target_model_path)
perplexity = 30.0

# Then extract the intermediate model
intermediate_model = simclr_models.extract_intermediate_model_from_base_model(loaded_model, intermediate_layer=7)
intermediate_model.summary()

# Continue with your t-SNE code
embeddings = intermediate_model.predict(X_test_normalized, batch_size=600)
tsne_model = sklearn.manifold.TSNE(perplexity=perplexity, verbose=1, random_state=42)
tsne_projections = tsne_model.fit_transform(embeddings)
# Out:
# WARNING:absl:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# Model: "base_model_simclr_layer_7"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input (InputLayer)              │ (None, 30, 3)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d (Conv1D)                 │ (None, 30, 32)         │         2,336 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 30, 32)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_1 (Conv1D)               │ (None, 30, 64)         │        32,832 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 30, 64)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_2 (Conv1D)               │ (None, 30, 96)         │        49,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 30, 96)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_max_pooling1d            │ (None, 96)             │             0 │
# │ (GlobalMaxPooling1D)            │                        │               │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 84,416 (329.75 KB)
#  Trainable params: 84,416 (329.75 KB)
#  Non-trainable params: 0 (0.00 B)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 418ms/step
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 246 samples in 0.001s...
# [t-SNE] Computed neighbors for 246 samples in 0.048s...
# [t-SNE] Computed conditional probabilities for sample 246 / 246
# [t-SNE] Mean sigma: 2.050442
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 50.918167
# [t-SNE] KL divergence after 1000 iterations: 0.279240

# %% [markdown]
# ### Plotting

# %%
# Define colors
other_class_color = "#1f77b4"  # Blue
curb_1_color = "#ff7f0e"      # Yellow

# Get the true labels (class indices) from the one-hot encoded test labels
labels_argmax = np.argmax(np_test_labels, axis=1)
unique_labels = np.unique(labels_argmax)

# Create custom color palette
custom_palette = [other_class_color, curb_1_color]  # First color for non_curb (0), second for curb_1 (1)

# Create the t-SNE visualization
plt.figure(figsize=(16,8))
graph = sns.scatterplot(
    x=tsne_projections[:,0], y=tsne_projections[:,1],
    hue=labels_argmax,
    palette=custom_palette,  # Use custom palette instead of "hsv"
    s=50,
    alpha=1.0,
    rasterized=True
)
plt.xticks([], [])
plt.yticks([], [])

plt.title("t-SNE Visualization of SimCLR Embeddings")

# Define your activity names
label_list_full_name = ["non_curb", "curb_1"]

# Update legend with custom colors
try:
    plt.legend(loc='lower left', bbox_to_anchor=(0.25, -0.3), ncol=2)
    legend = graph.legend_
    if 'label_list_full_name' in globals():
        for j, label in enumerate(unique_labels):
            if label < len(label_list_full_name):
                legend.get_texts()[j].set_text(label_list_full_name[label])
except Exception as e:
    print(f"Warning: Could not customize legend - {e}")
    plt.legend(loc='lower left', bbox_to_anchor=(0.25, -0.3), ncol=2)
