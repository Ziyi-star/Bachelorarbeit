# %% [markdown]
# <a href="https://colab.research.google.com/github/Ziyi-star/Bachelorarbeit/blob/main/notebooks/training/train_1s_30hz_2class_real_world_phase_4_to_5_version_a.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1. Data loading

# %% [markdown]
# ## a)VS Code

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import os
import pickle
import scipy
import datetime
import numpy as np
import tensorflow as tf
import simclr_utitlities
import transformations
import simclr_models
import sys
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from keras.utils import to_categorical

sys.path.append('../')   # Add parent directory to Python path
working_directory = "../models/"
sys.path.append('../../')
from utils.preprocessing import *

seed = 1
tf.random.set_seed(seed)
np.random.seed(seed)

# %%
# load balanced data
with open('../training_data/lab_real_world_2class_balanced_version_a/X_train_normalized.pkl', 'rb') as f:
    np_train_balanced_data = pickle.load(f)
np_train_balanced_data.shape
# Out:
# (2048, 30, 3)

# %%
# load unbalanced data
with open('../training_data/lab_real_world_2class_unbalanced_version_a_pseudo/X_train_normalized.pkl', 'rb') as f:
    np_train_unbalanced_data = pickle.load(f)
with open('../training_data/lab_real_world_2class_unbalanced_version_a_pseudo/y_train_onehot.pkl', 'rb') as f:
    np_train_unbalanced_labels = pickle.load(f)
with open('../training_data/lab_real_world_2class_unbalanced_version_a_pseudo/X_val_normalized.pkl', 'rb') as f:
    np_val_unbalanced_data = pickle.load(f)
with open('../training_data/lab_real_world_2class_unbalanced_version_a_pseudo/y_val_onehot.pkl', 'rb') as f:
    np_val_unbalanced_labels = pickle.load(f)
np_train_unbalanced_data.shape, np_train_unbalanced_labels.shape, np_val_unbalanced_data.shape, np_val_unbalanced_labels.shape
# Out:
# ((30630, 30, 3), (30630, 2), (7658, 30, 3), (7658, 2))

# %% [markdown]
# ## b)For Google Colab

# %%
# 1. Clone your repository to go to access your notebook and .py files
# !git clone https://github.com/Ziyi-star/Bachelorarbeit.git
# 2. Change working directory to where your notebook and .py files are
import os
os.chdir('/content/Bachelorarbeit/notebooks/training')
import os
import pickle
import scipy
import datetime
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import simclr_utitlities
import transformations
import simclr_models
import sys
sys.path.append('../../')
from utils.preprocessing import *



seed = 1
tf.random.set_seed(seed)
np.random.seed(seed)

# Load balanced data for simclr pretraining
# Download the file from GitHub
# !rm -f *.pkl # Remove existing pickle files
# !wget https://raw.githubusercontent.com/Ziyi-star/Bachelorarbeit/main/notebooks/training_data/lab_real_world_2class_balanced_version_a/X_train_normalized.pkl

working_directory = "../models/"  # Relative path to models folder

# Load as usual
import pickle

with open('X_train_normalized.pkl', 'rb') as f:
    np_train_balanced_data = pickle.load(f)

print(np_train_balanced_data.shape)
# Out:
# Cloning into 'Bachelorarbeit'...
# remote: Enumerating objects: 1651, done.
# remote: Counting objects: 100% (10/10), done.
# remote: Compressing objects: 100% (8/8), done.
# remote: Total 1651 (delta 3), reused 4 (delta 2), pack-reused 1641 (from 2)
# Receiving objects: 100% (1651/1651), 466.91 MiB | 17.48 MiB/s, done.
# Resolving deltas: 100% (937/937), done.
# Updating files: 100% (59/59), done.
# /content/Bachelorarbeit/notebooks/training/transformations.py:35: SyntaxWarning: invalid escape sequence '\&'
#   @inproceedings{TerryUm_ICMI2017, author = {Um, Terry T. and Pfister, Franz M. J. and Pichler, Daniel and Endo, Satoshi and Lang, Muriel and Hirche, Sandra and Fietzek, Urban and Kuli\'{c}, Dana}, title = {Data Augmentation of Wearable Sensor Data for Parkinson's Disease Monitoring Using Convolutional Neural Networks}, booktitle = {Proceedings of the 19th ACM International Conference on Multimodal Interaction}, series = {ICMI 2017}, year = {2017}, isbn = {978-1-4503-5543-8}, location = {Glasgow, UK}, pages = {216--220}, numpages = {5}, doi = {10.1145/3136755.3136817}, acmid = {3136817}, publisher = {ACM}, address = {New York, NY, USA}, keywords = {Parkinson\&#39;s disease, convolutional neural networks, data augmentation, health monitoring, motor state detection, wearable sensor}, }
# --2025-12-11 13:24:27--  https://raw.githubusercontent.com/Ziyi-star/Bachelorarbeit/main/notebooks/training_data/lab_real_world_2class_balanced_version_a/X_train_normalized.pkl
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1474725 (1.4M) [application/octet-stream]
# Saving to: ‘X_train_normalized.pkl’
#
# X_train_normalized. 100%[===================>]   1.41M  --.-KB/s    in 0.03s
#
# 2025-12-11 13:24:27 (47.8 MB/s) - ‘X_train_normalized.pkl’ saved [1474725/1474725]
#
# (2048, 30, 3)

# %%
# Load unbalanced data for evluation
# Download the file from GitHub
# !rm -f *.pkl # Remove existing pickle files
# !wget https://raw.githubusercontent.com/Ziyi-star/Bachelorarbeit/main/notebooks/training_data/lab_real_world_2class_unbalanced_version_a_pseudo/X_train_normalized.pkl
# !wget https://raw.githubusercontent.com/Ziyi-star/Bachelorarbeit/main/notebooks/training_data/lab_real_world_2class_unbalanced_version_a_pseudo/y_train_onehot.pkl
# !wget https://raw.githubusercontent.com/Ziyi-star/Bachelorarbeit/main/notebooks/training_data/lab_real_world_2class_unbalanced_version_a_pseudo/X_val_normalized.pkl
# !wget https://raw.githubusercontent.com/Ziyi-star/Bachelorarbeit/main/notebooks/training_data/lab_real_world_2class_unbalanced_version_a_pseudo/y_val_onehot.pkl


working_directory = "../models/"  # Relative path to models folder


# Load as usual
import pickle

with open('X_train_normalized.pkl', 'rb') as f:
    np_train_unbalanced_data = pickle.load(f)
with open('y_train_onehot.pkl', 'rb') as f:
    np_train_unbalanced_labels = pickle.load(f)
with open('X_val_normalized.pkl', 'rb') as f:
    np_val_unbalanced_data = pickle.load(f)
with open('y_val_onehot.pkl', 'rb') as f:
    np_val_unbalanced_labels = pickle.load(f)

print(np_train_unbalanced_data.shape, np_train_unbalanced_labels.shape)
print(np_val_unbalanced_data.shape, np_val_unbalanced_labels.shape)
# Out:
# --2025-12-11 13:24:52--  https://raw.githubusercontent.com/Ziyi-star/Bachelorarbeit/main/notebooks/training_data/lab_real_world_2class_unbalanced_version_a_pseudo/X_train_normalized.pkl
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 22053765 (21M) [application/octet-stream]
# Saving to: ‘X_train_normalized.pkl’
#
# X_train_normalized. 100%[===================>]  21.03M  --.-KB/s    in 0.09s
#
# 2025-12-11 13:24:53 (235 MB/s) - ‘X_train_normalized.pkl’ saved [22053765/22053765]
#
# --2025-12-11 13:24:53--  https://raw.githubusercontent.com/Ziyi-star/Bachelorarbeit/main/notebooks/training_data/lab_real_world_2class_unbalanced_version_a_pseudo/y_train_onehot.pkl
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 490243 (479K) [application/octet-stream]
# Saving to: ‘y_train_onehot.pkl’
#
# y_train_onehot.pkl  100%[===================>] 478.75K  --.-KB/s    in 0.02s
#
# 2025-12-11 13:24:53 (21.4 MB/s) - ‘y_train_onehot.pkl’ saved [490243/490243]
#
# --2025-12-11 13:24:53--  https://raw.githubusercontent.com/Ziyi-star/Bachelorarbeit/main/notebooks/training_data/lab_real_world_2class_unbalanced_version_a_pseudo/X_val_normalized.pkl
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 5513925 (5.3M) [application/octet-stream]
# Saving to: ‘X_val_normalized.pkl’
#
# X_val_normalized.pk 100%[===================>]   5.26M  --.-KB/s    in 0.05s
#
# 2025-12-11 13:24:54 (114 MB/s) - ‘X_val_normalized.pkl’ saved [5513925/5513925]
#
# --2025-12-11 13:24:54--  https://raw.githubusercontent.com/Ziyi-star/Bachelorarbeit/main/notebooks/training_data/lab_real_world_2class_unbalanced_version_a_pseudo/y_val_onehot.pkl
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 122691 (120K) [application/octet-stream]
# Saving to: ‘y_val_onehot.pkl’
#
# y_val_onehot.pkl    100%[===================>] 119.82K  --.-KB/s    in 0.01s
#
# 2025-12-11 13:24:54 (8.47 MB/s) - ‘y_val_onehot.pkl’ saved [122691/122691]
#
# (30630, 30, 3) (30630, 2)
# (7658, 30, 3) (7658, 2)

# %% [markdown]
# # 2.SimCLR Training

# %% [markdown]
# ##  2.1Pretraining with SimCLR

# %%
# Parameters for all experiments
window_size = 30
input_shape = (window_size, 3)
batch_size = 128
#Number of samples processed together in one training step. Larger batch sizes can speed up training but require more memory.
decay_steps = 1000
#Number of steps after which the learning rate decays (used for learning rate scheduling).
epochs = 100
temperature = 0.1

# %%
#A parameter for the SimCLR loss function that controls how sharply similarities are measured.
# transform_funcs = [
#     transformations.scaling_transform_vectorized, # Use Scaling trasnformation
#     transformations.rotation_transform_vectorized # Use rotation trasnformation
# ]
transform_funcs = [
    transformations.time_segment_permutation_transform_improved,
    transformations.channel_shuffle_transform_vectorized
]
#List of data augmentation functions to apply to the input data. Here, only rotation is used.
transformation_function = simclr_utitlities.generate_composite_transform_function_simple(transform_funcs)
# Out:
# 0 <function time_segment_permutation_transform_improved at 0x7fe04a94eca0>
# 1 <function channel_shuffle_transform_vectorized at 0x7fe04a94ec00>

# %%
# Time
start_time = datetime.datetime.now()
start_time_str = start_time.strftime("%Y%m%d-%H%M%S")
#Formats the date and time as a string like 20250827-153045 (for filenames, logs, etc.).
tf.keras.backend.set_floatx('float32')
#Sets TensorFlow to use 32-bit floating point numbers for all computations (standard for deep learning).

# %%
# Create a cosine-decayed learning rate schedule and SGD optimizer for training.
lr_decayed_fn = tf.keras.optimizers.schedules.CosineDecay(initial_learning_rate=0.1, decay_steps=decay_steps)
optimizer = tf.keras.optimizers.SGD(lr_decayed_fn)

# Build the base model and attach the SimCLR head for contrastive learning.
base_model = simclr_models.create_base_model_small_dimensions(input_shape, model_name="base_model")
simclr_model = simclr_models.attach_simclr_head(base_model)
simclr_model.summary()

# Train the SimCLR model using the specified transformation function and optimizer.
trained_simclr_model, epoch_losses = simclr_utitlities.simclr_train_model(
    simclr_model,
    np_train_balanced_data,
    optimizer,
    batch_size,
    transformation_function,
    temperature=temperature,
    epochs=epochs,
    is_trasnform_function_vectorized=True,
    verbose=1
)

# Save the trained SimCLR model to disk for later use.
simclr_model_save_path = f"{working_directory}{start_time_str}_simclr.hdf5"
trained_simclr_model.save(simclr_model_save_path)
# Out:
# Model: "base_model_simclr"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input (InputLayer)              │ (None, 30, 3)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d (Conv1D)                 │ (None, 30, 32)         │         2,336 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 30, 32)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_1 (Conv1D)               │ (None, 30, 64)         │        32,832 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 30, 64)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_2 (Conv1D)               │ (None, 30, 96)         │        49,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 30, 96)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_max_pooling1d            │ (None, 96)             │             0 │
# │ (GlobalMaxPooling1D)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 256)            │        24,832 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation (Activation)         │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_1 (Activation)       │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 50)             │         6,450 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 148,594 (580.45 KB)
#  Trainable params: 148,594 (580.45 KB)
#  Non-trainable params: 0 (0.00 B)
# epoch: 1 loss: 9.085
# epoch: 2 loss: 7.392
# epoch: 3 loss: 6.467
# epoch: 4 loss: 6.252
# epoch: 5 loss: 6.318
# epoch: 6 loss: 5.609
# epoch: 7 loss: 5.028
# epoch: 8 loss: 5.087
# epoch: 9 loss: 5.070
# epoch: 10 loss: 4.229
# epoch: 11 loss: 4.527
# epoch: 12 loss: 3.950
# epoch: 13 loss: 4.034
# epoch: 14 loss: 3.548
# epoch: 15 loss: 3.455
# epoch: 16 loss: 3.235
# epoch: 17 loss: 3.434
# epoch: 18 loss: 3.101
# epoch: 19 loss: 3.112
# epoch: 20 loss: 2.857
# epoch: 21 loss: 2.612
# epoch: 22 loss: 2.545
# epoch: 23 loss: 2.569
# epoch: 24 loss: 2.381
# epoch: 25 loss: 2.471
# epoch: 26 loss: 2.216
# epoch: 27 loss: 2.220
# epoch: 28 loss: 2.057
# epoch: 29 loss: 2.032
# epoch: 30 loss: 2.022
# epoch: 31 loss: 1.874
# epoch: 32 loss: 1.846
# epoch: 33 loss: 1.797
# epoch: 34 loss: 1.720
# epoch: 35 loss: 1.641
# epoch: 36 loss: 1.655
# epoch: 37 loss: 1.557
# epoch: 38 loss: 1.526
# epoch: 39 loss: 1.486
# epoch: 40 loss: 1.486
# epoch: 41 loss: 1.433
# epoch: 42 loss: 1.448
# epoch: 43 loss: 1.393
# epoch: 44 loss: 1.386
# epoch: 45 loss: 1.353
# epoch: 46 loss: 1.328
# epoch: 47 loss: 1.239
# epoch: 48 loss: 1.297
# epoch: 49 loss: 1.239
# epoch: 50 loss: 1.304
# epoch: 51 loss: 1.229
# epoch: 52 loss: 1.210
# epoch: 53 loss: 1.213
# epoch: 54 loss: 1.204
# epoch: 55 loss: 1.185
# epoch: 56 loss: 1.205
# epoch: 57 loss: 1.183
# epoch: 58 loss: 1.166
# epoch: 59 loss: 1.176
# epoch: 60 loss: 1.177
# epoch: 61 loss: 1.165
# epoch: 62 loss: 1.172
# epoch: 63 loss: 1.152
# epoch: 64 loss: 1.201
# epoch: 65 loss: 1.157
# epoch: 66 loss: 1.155
# epoch: 67 loss: 1.173
# epoch: 68 loss: 1.157
# epoch: 69 loss: 1.144
# epoch: 70 loss: 1.219
# epoch: 71 loss: 1.153
# epoch: 72 loss: 1.178
# epoch: 73 loss: 1.194
# epoch: 74 loss: 1.163
# epoch: 75 loss: 1.199
# epoch: 76 loss: 1.216
# epoch: 77 loss: 1.185
# epoch: 78 loss: 1.188
# epoch: 79 loss: 1.119
# epoch: 80 loss: 1.171
# epoch: 81 loss: 1.199
# epoch: 82 loss: 1.171
# epoch: 83 loss: 1.145
# epoch: 84 loss: 1.171
# epoch: 85 loss: 1.180
# epoch: 86 loss: 1.159
# epoch: 87 loss: 1.191
# epoch: 88 loss: 1.220
# epoch: 89 loss: 1.190
# epoch: 90 loss: 1.180
# epoch: 91 loss: 1.139
# epoch: 92 loss: 1.187
# epoch: 93 loss: 1.172
# epoch: 94 loss: 1.187
# epoch: 95 loss: 1.144
# epoch: 96 loss: 1.202
# epoch: 97 loss: 1.169
# epoch: 98 loss: 1.191
# epoch: 99 loss: 1.168
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# epoch: 100 loss: 1.168

# %%
# Plot history of training losses over epochs.
plt.figure(figsize=(12,8))
plt.plot(epoch_losses)
plt.ylabel("Loss")
plt.xlabel("Epoch")
plt.show()

# %% [markdown]
# ## 2.2Fine-tuning and Evaluation

# %% [markdown]
# ### 2.2.1 Linear Model

# %% [markdown]
# #### Train

# %%
# This block performs linear evaluation on top of the pretrained SimCLR base model.
total_epochs = 50
batch_size = 128
tag = "linear_eval"
output_shape = np_train_unbalanced_labels.shape[1]  # Number of classes for classification

# 1. Loads the SimCLR model and attaches a linear classification head on top.
simclr_model = tf.keras.models.load_model(simclr_model_save_path)
linear_evaluation_model = simclr_models.create_linear_model_from_base_model(simclr_model, output_shape, intermediate_layer=7)

# 2. Sets up a ModelCheckpoint callback to save the best model (lowest validation loss).
# This ensures we keep the model version that performs best on validation data
linear_eval_best_model_file_name = f"{working_directory}{start_time_str}_simclr_{tag}.keras"
best_model_callback = tf.keras.callbacks.ModelCheckpoint(
    linear_eval_best_model_file_name,
    monitor='val_loss',
    mode='min',
    save_best_only=True,
    save_weights_only=False,
    verbose=0
)

# 3. Trains the linear evaluation model using the training and validation data.
training_history = linear_evaluation_model.fit(
    x = np_train_unbalanced_data,
    y = np_train_unbalanced_labels,
    batch_size=batch_size,
    shuffle=True,
    epochs=total_epochs,
    callbacks=[best_model_callback],
    validation_data=(np_val_unbalanced_data, np_val_unbalanced_labels)
)
# Out:
# WARNING:absl:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# Epoch 1/50
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 12s 23ms/step - auc: 0.9449 - categorical_accuracy: 0.9337 - loss: 1.1577 - precision: 0.9337 - recall: 0.9337 - val_auc: 0.9584 - val_categorical_accuracy: 0.9615 - val_loss: 1.3925 - val_precision: 0.9615 - val_recall: 0.9615
# Epoch 2/50
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - auc: 0.9571 - categorical_accuracy: 0.9428 - loss: 0.9513 - precision: 0.9428 - recall: 0.9428 - val_auc: 0.9615 - val_categorical_accuracy: 0.9500 - val_loss: 0.9091 - val_precision: 0.9500 - val_recall: 0.9500
# Epoch 3/50
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - auc: 0.9554 - categorical_accuracy: 0.9422 - loss: 1.0327 - precision: 0.9422 - recall: 0.9422 - val_auc: 0.9658 - val_categorical_accuracy: 0.9529 - val_loss: 0.9337 - val_precision: 0.9529 - val_recall: 0.9529
# Epoch 4/50
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - auc: 0.9572 - categorical_accuracy: 0.9434 - loss: 0.9401 - precision: 0.9434 - recall: 0.9434 - val_auc: 0.9659 - val_categorical_accuracy: 0.9557 - val_loss: 0.3343 - val_precision: 0.9557 - val_recall: 0.9557
# Epoch 5/50
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - auc: 0.9557 - categorical_accuracy: 0.9435 - loss: 0.9359 - precision: 0.9435 - recall: 0.9435 - val_auc: 0.9617 - val_categorical_accuracy: 0.9488 - val_loss: 0.4329 - val_precision: 0.9488 - val_recall: 0.9488
# Epoch 6/50
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - auc: 0.9544 - categorical_accuracy: 0.9420 - loss: 0.9748 - precision: 0.9420 - recall: 0.9420 - val_auc: 0.9620 - val_categorical_accuracy: 0.9478 - val_loss: 0.6168 - val_precision: 0.9478 - val_recall: 0.9478
# Epoch 7/50
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - auc: 0.9565 - categorical_accuracy: 0.9432 - loss: 0.9268 - precision: 0.9432 - recall: 0.9432 - val_auc: 0.9599 - val_categorical_accuracy: 0.9444 - val_loss: 0.6485 - val_precision: 0.9444 - val_recall: 0.9444
# Epoch 8/50
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - auc: 0.9577 - categorical_accuracy: 0.9429 - loss: 0.9243 - precision: 0.9429 - recall: 0.9429 - val_auc: 0.9644 - val_categorical_accuracy: 0.9497 - val_loss: 0.6109 - val_precision: 0.9497 - val_recall: 0.9497
# Epoch 9/50
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - auc: 0.9568 - categorical_accuracy: 0.9440 - loss: 0.9495 - precision: 0.9440 - recall: 0.9440 - val_auc: 0.9675 - val_categorical_accuracy: 0.9534 - val_loss: 0.3786 - val_precision: 0.9534 - val_recall: 0.9534
# Epoch 10/50
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - auc: 0.9592 - categorical_accuracy: 0.9449 - loss: 0.8913 - precision: 0.9449 - recall: 0.9449 - val_auc: 0.9637 - val_categorical_accuracy: 0.9482 - val_loss: 0.4733 - val_precision: 0.9482 - val_recall: 0.9482
# Epoch 11/50
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - auc: 0.9564 - categorical_accuracy: 0.9436 - loss: 1.0182 - precision: 0.9436 - recall: 0.9436 - val_auc: 0.9655 - val_categorical_accuracy: 0.9486 - val_loss: 0.2808 - val_precision: 0.9486 - val_recall: 0.9486
# Epoch 12/50
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - auc: 0.9625 - categorical_accuracy: 0.9466 - loss: 0.8110 - precision: 0.9466 - recall: 0.9466 - val_auc: 0.9678 - val_categorical_accuracy: 0.9518 - val_loss: 0.3013 - val_precision: 0.9518 - val_recall: 0.9518
# Epoch 13/50
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - auc: 0.9603 - categorical_accuracy: 0.9457 - loss: 0.9069 - precision: 0.9457 - recall: 0.9457 - val_auc: 0.9634 - val_categorical_accuracy: 0.9465 - val_loss: 0.6038 - val_precision: 0.9465 - val_recall: 0.9465
# Epoch 14/50
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - auc: 0.9572 - categorical_accuracy: 0.9428 - loss: 0.9919 - precision: 0.9428 - recall: 0.9428 - val_auc: 0.9630 - val_categorical_accuracy: 0.9462 - val_loss: 0.5108 - val_precision: 0.9462 - val_recall: 0.9462
# Epoch 15/50
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - auc: 0.9595 - categorical_accuracy: 0.9447 - loss: 0.8463 - precision: 0.9447 - recall: 0.9447 - val_auc: 0.9661 - val_categorical_accuracy: 0.9502 - val_loss: 0.5428 - val_precision: 0.9502 - val_recall: 0.9502
# Epoch 16/50
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - auc: 0.9608 - categorical_accuracy: 0.9461 - loss: 0.8528 - precision: 0.9461 - recall: 0.9461 - val_auc: 0.9705 - val_categorical_accuracy: 0.9630 - val_loss: 0.5654 - val_precision: 0.9630 - val_recall: 0.9630
# Epoch 17/50
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - auc: 0.9598 - categorical_accuracy: 0.9459 - loss: 0.8399 - precision: 0.9459 - recall: 0.9459 - val_auc: 0.9694 - val_categorical_accuracy: 0.9616 - val_loss: 0.7277 - val_precision: 0.9616 - val_recall: 0.9616
# Epoch 18/50
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - auc: 0.9599 - categorical_accuracy: 0.9460 - loss: 0.8836 - precision: 0.9460 - recall: 0.9460 - val_auc: 0.9645 - val_categorical_accuracy: 0.9469 - val_loss: 0.4081 - val_precision: 0.9469 - val_recall: 0.9469
# Epoch 19/50
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - auc: 0.9588 - categorical_accuracy: 0.9436 - loss: 0.8938 - precision: 0.9436 - recall: 0.9436 - val_auc: 0.9700 - val_categorical_accuracy: 0.9542 - val_loss: 0.3868 - val_precision: 0.9542 - val_recall: 0.9542
# Epoch 20/50
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - auc: 0.9620 - categorical_accuracy: 0.9463 - loss: 0.7670 - precision: 0.9463 - recall: 0.9463 - val_auc: 0.9702 - val_categorical_accuracy: 0.9553 - val_loss: 0.3561 - val_precision: 0.9553 - val_recall: 0.9553
# Epoch 21/50
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - auc: 0.9620 - categorical_accuracy: 0.9458 - loss: 0.8042 - precision: 0.9458 - recall: 0.9458 - val_auc: 0.9722 - val_categorical_accuracy: 0.9612 - val_loss: 0.5207 - val_precision: 0.9612 - val_recall: 0.9612
# Epoch 22/50
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - auc: 0.9602 - categorical_accuracy: 0.9463 - loss: 0.8173 - precision: 0.9463 - recall: 0.9463 - val_auc: 0.9651 - val_categorical_accuracy: 0.9467 - val_loss: 0.5174 - val_precision: 0.9467 - val_recall: 0.9467
# Epoch 23/50
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - auc: 0.9585 - categorical_accuracy: 0.9445 - loss: 0.8584 - precision: 0.9445 - recall: 0.9445 - val_auc: 0.9721 - val_categorical_accuracy: 0.9615 - val_loss: 0.4189 - val_precision: 0.9615 - val_recall: 0.9615
# Epoch 24/50
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - auc: 0.9604 - categorical_accuracy: 0.9462 - loss: 0.8123 - precision: 0.9462 - recall: 0.9462 - val_auc: 0.9666 - val_categorical_accuracy: 0.9486 - val_loss: 0.3062 - val_precision: 0.9486 - val_recall: 0.9486
# Epoch 25/50
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - auc: 0.9591 - categorical_accuracy: 0.9452 - loss: 0.8755 - precision: 0.9452 - recall: 0.9452 - val_auc: 0.9697 - val_categorical_accuracy: 0.9636 - val_loss: 0.6173 - val_precision: 0.9636 - val_recall: 0.9636
# Epoch 26/50
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - auc: 0.9617 - categorical_accuracy: 0.9455 - loss: 0.8254 - precision: 0.9455 - recall: 0.9455 - val_auc: 0.9669 - val_categorical_accuracy: 0.9495 - val_loss: 0.6483 - val_precision: 0.9495 - val_recall: 0.9495
# Epoch 27/50
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - auc: 0.9608 - categorical_accuracy: 0.9438 - loss: 0.8844 - precision: 0.9438 - recall: 0.9438 - val_auc: 0.9646 - val_categorical_accuracy: 0.9462 - val_loss: 0.8377 - val_precision: 0.9462 - val_recall: 0.9462
# Epoch 28/50
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - auc: 0.9623 - categorical_accuracy: 0.9456 - loss: 0.8060 - precision: 0.9456 - recall: 0.9456 - val_auc: 0.9646 - val_categorical_accuracy: 0.9466 - val_loss: 0.8045 - val_precision: 0.9466 - val_recall: 0.9466
# Epoch 29/50
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - auc: 0.9614 - categorical_accuracy: 0.9453 - loss: 0.8727 - precision: 0.9453 - recall: 0.9453 - val_auc: 0.9655 - val_categorical_accuracy: 0.9484 - val_loss: 0.5848 - val_precision: 0.9484 - val_recall: 0.9484
# Epoch 30/50
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - auc: 0.9595 - categorical_accuracy: 0.9449 - loss: 0.8888 - precision: 0.9449 - recall: 0.9449 - val_auc: 0.9622 - val_categorical_accuracy: 0.9431 - val_loss: 0.4587 - val_precision: 0.9431 - val_recall: 0.9431
# Epoch 31/50
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - auc: 0.9595 - categorical_accuracy: 0.9439 - loss: 0.8787 - precision: 0.9439 - recall: 0.9439 - val_auc: 0.9692 - val_categorical_accuracy: 0.9538 - val_loss: 0.3746 - val_precision: 0.9538 - val_recall: 0.9538
# Epoch 32/50
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - auc: 0.9624 - categorical_accuracy: 0.9452 - loss: 0.8121 - precision: 0.9452 - recall: 0.9452 - val_auc: 0.9680 - val_categorical_accuracy: 0.9623 - val_loss: 0.9238 - val_precision: 0.9623 - val_recall: 0.9623
# Epoch 33/50
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - auc: 0.9616 - categorical_accuracy: 0.9475 - loss: 0.7841 - precision: 0.9475 - recall: 0.9475 - val_auc: 0.9675 - val_categorical_accuracy: 0.9505 - val_loss: 0.5275 - val_precision: 0.9505 - val_recall: 0.9505
# Epoch 34/50
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - auc: 0.9601 - categorical_accuracy: 0.9456 - loss: 0.8639 - precision: 0.9456 - recall: 0.9456 - val_auc: 0.9667 - val_categorical_accuracy: 0.9500 - val_loss: 0.6059 - val_precision: 0.9500 - val_recall: 0.9500
# Epoch 35/50
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - auc: 0.9613 - categorical_accuracy: 0.9465 - loss: 0.8940 - precision: 0.9465 - recall: 0.9465 - val_auc: 0.9668 - val_categorical_accuracy: 0.9499 - val_loss: 0.4421 - val_precision: 0.9499 - val_recall: 0.9499
# Epoch 36/50
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - auc: 0.9617 - categorical_accuracy: 0.9482 - loss: 0.7954 - precision: 0.9482 - recall: 0.9482 - val_auc: 0.9709 - val_categorical_accuracy: 0.9559 - val_loss: 0.3833 - val_precision: 0.9559 - val_recall: 0.9559
# Epoch 37/50
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - auc: 0.9599 - categorical_accuracy: 0.9460 - loss: 0.8528 - precision: 0.9460 - recall: 0.9460 - val_auc: 0.9672 - val_categorical_accuracy: 0.9488 - val_loss: 0.3311 - val_precision: 0.9488 - val_recall: 0.9488
# Epoch 38/50
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - auc: 0.9614 - categorical_accuracy: 0.9454 - loss: 0.8444 - precision: 0.9454 - recall: 0.9454 - val_auc: 0.9695 - val_categorical_accuracy: 0.9629 - val_loss: 0.8829 - val_precision: 0.9629 - val_recall: 0.9629
# Epoch 39/50
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - auc: 0.9626 - categorical_accuracy: 0.9470 - loss: 0.7677 - precision: 0.9470 - recall: 0.9470 - val_auc: 0.9676 - val_categorical_accuracy: 0.9555 - val_loss: 1.1815 - val_precision: 0.9555 - val_recall: 0.9555
# Epoch 40/50
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - auc: 0.9621 - categorical_accuracy: 0.9452 - loss: 0.8491 - precision: 0.9452 - recall: 0.9452 - val_auc: 0.9668 - val_categorical_accuracy: 0.9497 - val_loss: 0.4571 - val_precision: 0.9497 - val_recall: 0.9497
# Epoch 41/50
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - auc: 0.9643 - categorical_accuracy: 0.9465 - loss: 0.7439 - precision: 0.9465 - recall: 0.9465 - val_auc: 0.9703 - val_categorical_accuracy: 0.9529 - val_loss: 0.3007 - val_precision: 0.9529 - val_recall: 0.9529
# Epoch 42/50
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - auc: 0.9615 - categorical_accuracy: 0.9467 - loss: 0.8410 - precision: 0.9467 - recall: 0.9467 - val_auc: 0.9663 - val_categorical_accuracy: 0.9617 - val_loss: 1.1330 - val_precision: 0.9617 - val_recall: 0.9617
# Epoch 43/50
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - auc: 0.9632 - categorical_accuracy: 0.9476 - loss: 0.7643 - precision: 0.9476 - recall: 0.9476 - val_auc: 0.9684 - val_categorical_accuracy: 0.9506 - val_loss: 0.5605 - val_precision: 0.9506 - val_recall: 0.9506
# Epoch 44/50
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - auc: 0.9617 - categorical_accuracy: 0.9447 - loss: 0.7863 - precision: 0.9447 - recall: 0.9447 - val_auc: 0.9695 - val_categorical_accuracy: 0.9517 - val_loss: 0.3776 - val_precision: 0.9517 - val_recall: 0.9517
# Epoch 45/50
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - auc: 0.9628 - categorical_accuracy: 0.9446 - loss: 0.7726 - precision: 0.9446 - recall: 0.9446 - val_auc: 0.9724 - val_categorical_accuracy: 0.9610 - val_loss: 0.3332 - val_precision: 0.9610 - val_recall: 0.9610
# Epoch 46/50
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - auc: 0.9625 - categorical_accuracy: 0.9482 - loss: 0.7336 - precision: 0.9482 - recall: 0.9482 - val_auc: 0.9659 - val_categorical_accuracy: 0.9497 - val_loss: 0.4244 - val_precision: 0.9497 - val_recall: 0.9497
# Epoch 47/50
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - auc: 0.9624 - categorical_accuracy: 0.9485 - loss: 0.7786 - precision: 0.9485 - recall: 0.9485 - val_auc: 0.9702 - val_categorical_accuracy: 0.9627 - val_loss: 0.9490 - val_precision: 0.9627 - val_recall: 0.9627
# Epoch 48/50
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - auc: 0.9618 - categorical_accuracy: 0.9465 - loss: 0.8284 - precision: 0.9465 - recall: 0.9465 - val_auc: 0.9669 - val_categorical_accuracy: 0.9487 - val_loss: 0.3687 - val_precision: 0.9487 - val_recall: 0.9487
# Epoch 49/50
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - auc: 0.9631 - categorical_accuracy: 0.9471 - loss: 0.8246 - precision: 0.9471 - recall: 0.9471 - val_auc: 0.9687 - val_categorical_accuracy: 0.9510 - val_loss: 0.3856 - val_precision: 0.9510 - val_recall: 0.9510
# Epoch 50/50
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - auc: 0.9617 - categorical_accuracy: 0.9466 - loss: 0.8558 - precision: 0.9466 - recall: 0.9466 - val_auc: 0.9719 - val_categorical_accuracy: 0.9624 - val_loss: 0.6030 - val_precision: 0.9624 - val_recall: 0.9624

# %%
# Training and Validation Loss

plt.figure(figsize=(12,6))
plt.plot(training_history.history['loss'], label='Training Loss')
plt.plot(training_history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training and Validation Loss')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Training and Validation Accuracy
plt.figure(figsize=(12,6))
plt.plot(training_history.history['categorical_accuracy'], label='Training Accuracy')
plt.plot(training_history.history['val_categorical_accuracy'], label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Training and Validation Accuracy')
plt.legend()
plt.grid(True)
plt.ylim([0, 1])
plt.show()

# %% [markdown]
# ### 2.2.2 Full HAR Model

# %% [markdown]
# #### Train

# %%
total_epochs = 50
batch_size = 256
tag = "full_eval"
output_shape = np_train_unbalanced_labels.shape[1]  # Number of classes for classification

simclr_model = tf.keras.models.load_model(simclr_model_save_path)
full_evaluation_model = simclr_models.create_full_classification_model_from_base_model(
    simclr_model, output_shape, model_name="TPN", intermediate_layer=7, last_freeze_layer=4)

full_eval_best_model_file_name = f"{working_directory}{start_time_str}_simclr_{tag}.keras"

best_model_callback = tf.keras.callbacks.ModelCheckpoint(full_eval_best_model_file_name,
    monitor='val_loss', mode='min', save_best_only=True, save_weights_only=False, verbose=0
)

training_history = full_evaluation_model.fit(
    x = np_train_unbalanced_data,
    y = np_train_unbalanced_labels,
    batch_size=batch_size,
    shuffle=True,
    epochs=total_epochs,
    callbacks=[best_model_callback],
    validation_data=(np_val_unbalanced_data, np_val_unbalanced_labels)
)
# Out:
# WARNING:absl:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# Epoch 1/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 24s 119ms/step - auc: 0.9658 - categorical_accuracy: 0.9287 - loss: 0.3265 - precision: 0.9287 - recall: 0.9287 - val_auc: 0.9929 - val_categorical_accuracy: 0.9583 - val_loss: 0.1154 - val_precision: 0.9583 - val_recall: 0.9583
# Epoch 2/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - auc: 0.9925 - categorical_accuracy: 0.9648 - loss: 0.1108 - precision: 0.9648 - recall: 0.9648 - val_auc: 0.9943 - val_categorical_accuracy: 0.9679 - val_loss: 0.1065 - val_precision: 0.9679 - val_recall: 0.9679
# Epoch 3/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - auc: 0.9932 - categorical_accuracy: 0.9667 - loss: 0.1050 - precision: 0.9667 - recall: 0.9667 - val_auc: 0.9947 - val_categorical_accuracy: 0.9691 - val_loss: 0.1014 - val_precision: 0.9691 - val_recall: 0.9691
# Epoch 4/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - auc: 0.9937 - categorical_accuracy: 0.9689 - loss: 0.0981 - precision: 0.9689 - recall: 0.9689 - val_auc: 0.9951 - val_categorical_accuracy: 0.9707 - val_loss: 0.0918 - val_precision: 0.9707 - val_recall: 0.9707
# Epoch 5/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - auc: 0.9940 - categorical_accuracy: 0.9712 - loss: 0.0949 - precision: 0.9712 - recall: 0.9712 - val_auc: 0.9954 - val_categorical_accuracy: 0.9728 - val_loss: 0.0849 - val_precision: 0.9728 - val_recall: 0.9728
# Epoch 6/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - auc: 0.9947 - categorical_accuracy: 0.9746 - loss: 0.0864 - precision: 0.9746 - recall: 0.9746 - val_auc: 0.9957 - val_categorical_accuracy: 0.9774 - val_loss: 0.0873 - val_precision: 0.9774 - val_recall: 0.9774
# Epoch 7/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - auc: 0.9950 - categorical_accuracy: 0.9755 - loss: 0.0835 - precision: 0.9755 - recall: 0.9755 - val_auc: 0.9961 - val_categorical_accuracy: 0.9798 - val_loss: 0.0834 - val_precision: 0.9798 - val_recall: 0.9798
# Epoch 8/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - auc: 0.9951 - categorical_accuracy: 0.9757 - loss: 0.0840 - precision: 0.9757 - recall: 0.9757 - val_auc: 0.9962 - val_categorical_accuracy: 0.9790 - val_loss: 0.0776 - val_precision: 0.9790 - val_recall: 0.9790
# Epoch 9/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - auc: 0.9956 - categorical_accuracy: 0.9779 - loss: 0.0777 - precision: 0.9779 - recall: 0.9779 - val_auc: 0.9961 - val_categorical_accuracy: 0.9804 - val_loss: 0.0853 - val_precision: 0.9804 - val_recall: 0.9804
# Epoch 10/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - auc: 0.9956 - categorical_accuracy: 0.9763 - loss: 0.0797 - precision: 0.9763 - recall: 0.9763 - val_auc: 0.9962 - val_categorical_accuracy: 0.9798 - val_loss: 0.0749 - val_precision: 0.9798 - val_recall: 0.9798
# Epoch 11/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - auc: 0.9960 - categorical_accuracy: 0.9788 - loss: 0.0750 - precision: 0.9788 - recall: 0.9788 - val_auc: 0.9964 - val_categorical_accuracy: 0.9773 - val_loss: 0.0733 - val_precision: 0.9773 - val_recall: 0.9773
# Epoch 12/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - auc: 0.9960 - categorical_accuracy: 0.9794 - loss: 0.0735 - precision: 0.9794 - recall: 0.9794 - val_auc: 0.9962 - val_categorical_accuracy: 0.9799 - val_loss: 0.0717 - val_precision: 0.9799 - val_recall: 0.9799
# Epoch 13/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - auc: 0.9960 - categorical_accuracy: 0.9796 - loss: 0.0743 - precision: 0.9796 - recall: 0.9796 - val_auc: 0.9964 - val_categorical_accuracy: 0.9815 - val_loss: 0.0719 - val_precision: 0.9815 - val_recall: 0.9815
# Epoch 14/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - auc: 0.9965 - categorical_accuracy: 0.9797 - loss: 0.0710 - precision: 0.9797 - recall: 0.9797 - val_auc: 0.9964 - val_categorical_accuracy: 0.9802 - val_loss: 0.0700 - val_precision: 0.9802 - val_recall: 0.9802
# Epoch 15/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - auc: 0.9965 - categorical_accuracy: 0.9797 - loss: 0.0702 - precision: 0.9797 - recall: 0.9797 - val_auc: 0.9961 - val_categorical_accuracy: 0.9822 - val_loss: 0.0732 - val_precision: 0.9822 - val_recall: 0.9822
# Epoch 16/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - auc: 0.9964 - categorical_accuracy: 0.9809 - loss: 0.0696 - precision: 0.9809 - recall: 0.9809 - val_auc: 0.9966 - val_categorical_accuracy: 0.9825 - val_loss: 0.0715 - val_precision: 0.9825 - val_recall: 0.9825
# Epoch 17/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - auc: 0.9964 - categorical_accuracy: 0.9808 - loss: 0.0696 - precision: 0.9808 - recall: 0.9808 - val_auc: 0.9963 - val_categorical_accuracy: 0.9832 - val_loss: 0.0770 - val_precision: 0.9832 - val_recall: 0.9832
# Epoch 18/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - auc: 0.9970 - categorical_accuracy: 0.9817 - loss: 0.0655 - precision: 0.9817 - recall: 0.9817 - val_auc: 0.9968 - val_categorical_accuracy: 0.9808 - val_loss: 0.0671 - val_precision: 0.9808 - val_recall: 0.9808
# Epoch 19/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - auc: 0.9971 - categorical_accuracy: 0.9819 - loss: 0.0640 - precision: 0.9819 - recall: 0.9819 - val_auc: 0.9964 - val_categorical_accuracy: 0.9828 - val_loss: 0.0720 - val_precision: 0.9828 - val_recall: 0.9828
# Epoch 20/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - auc: 0.9970 - categorical_accuracy: 0.9829 - loss: 0.0632 - precision: 0.9829 - recall: 0.9829 - val_auc: 0.9964 - val_categorical_accuracy: 0.9803 - val_loss: 0.0699 - val_precision: 0.9803 - val_recall: 0.9803
# Epoch 21/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - auc: 0.9969 - categorical_accuracy: 0.9815 - loss: 0.0658 - precision: 0.9815 - recall: 0.9815 - val_auc: 0.9957 - val_categorical_accuracy: 0.9800 - val_loss: 0.0831 - val_precision: 0.9800 - val_recall: 0.9800
# Epoch 22/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - auc: 0.9971 - categorical_accuracy: 0.9824 - loss: 0.0652 - precision: 0.9824 - recall: 0.9824 - val_auc: 0.9961 - val_categorical_accuracy: 0.9813 - val_loss: 0.0704 - val_precision: 0.9813 - val_recall: 0.9813
# Epoch 23/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - auc: 0.9971 - categorical_accuracy: 0.9820 - loss: 0.0637 - precision: 0.9820 - recall: 0.9820 - val_auc: 0.9961 - val_categorical_accuracy: 0.9818 - val_loss: 0.0768 - val_precision: 0.9818 - val_recall: 0.9818
# Epoch 24/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - auc: 0.9971 - categorical_accuracy: 0.9823 - loss: 0.0655 - precision: 0.9823 - recall: 0.9823 - val_auc: 0.9965 - val_categorical_accuracy: 0.9816 - val_loss: 0.0740 - val_precision: 0.9816 - val_recall: 0.9816
# Epoch 25/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - auc: 0.9969 - categorical_accuracy: 0.9817 - loss: 0.0655 - precision: 0.9817 - recall: 0.9817 - val_auc: 0.9965 - val_categorical_accuracy: 0.9807 - val_loss: 0.0685 - val_precision: 0.9807 - val_recall: 0.9807
# Epoch 26/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - auc: 0.9973 - categorical_accuracy: 0.9829 - loss: 0.0618 - precision: 0.9829 - recall: 0.9829 - val_auc: 0.9953 - val_categorical_accuracy: 0.9815 - val_loss: 0.0799 - val_precision: 0.9815 - val_recall: 0.9815
# Epoch 27/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - auc: 0.9969 - categorical_accuracy: 0.9830 - loss: 0.0656 - precision: 0.9830 - recall: 0.9830 - val_auc: 0.9949 - val_categorical_accuracy: 0.9820 - val_loss: 0.0802 - val_precision: 0.9820 - val_recall: 0.9820
# Epoch 28/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - auc: 0.9975 - categorical_accuracy: 0.9815 - loss: 0.0641 - precision: 0.9815 - recall: 0.9815 - val_auc: 0.9957 - val_categorical_accuracy: 0.9828 - val_loss: 0.0729 - val_precision: 0.9828 - val_recall: 0.9828
# Epoch 29/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - auc: 0.9976 - categorical_accuracy: 0.9832 - loss: 0.0603 - precision: 0.9832 - recall: 0.9832 - val_auc: 0.9955 - val_categorical_accuracy: 0.9800 - val_loss: 0.0730 - val_precision: 0.9800 - val_recall: 0.9800
# Epoch 30/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - auc: 0.9975 - categorical_accuracy: 0.9829 - loss: 0.0634 - precision: 0.9829 - recall: 0.9829 - val_auc: 0.9950 - val_categorical_accuracy: 0.9812 - val_loss: 0.0747 - val_precision: 0.9812 - val_recall: 0.9812
# Epoch 31/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - auc: 0.9974 - categorical_accuracy: 0.9821 - loss: 0.0627 - precision: 0.9821 - recall: 0.9821 - val_auc: 0.9952 - val_categorical_accuracy: 0.9825 - val_loss: 0.0798 - val_precision: 0.9825 - val_recall: 0.9825
# Epoch 32/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - auc: 0.9977 - categorical_accuracy: 0.9828 - loss: 0.0594 - precision: 0.9828 - recall: 0.9828 - val_auc: 0.9964 - val_categorical_accuracy: 0.9818 - val_loss: 0.0681 - val_precision: 0.9818 - val_recall: 0.9818
# Epoch 33/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - auc: 0.9977 - categorical_accuracy: 0.9846 - loss: 0.0584 - precision: 0.9846 - recall: 0.9846 - val_auc: 0.9948 - val_categorical_accuracy: 0.9833 - val_loss: 0.0788 - val_precision: 0.9833 - val_recall: 0.9833
# Epoch 34/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - auc: 0.9973 - categorical_accuracy: 0.9834 - loss: 0.0622 - precision: 0.9834 - recall: 0.9834 - val_auc: 0.9957 - val_categorical_accuracy: 0.9815 - val_loss: 0.0692 - val_precision: 0.9815 - val_recall: 0.9815
# Epoch 35/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - auc: 0.9980 - categorical_accuracy: 0.9841 - loss: 0.0566 - precision: 0.9841 - recall: 0.9841 - val_auc: 0.9954 - val_categorical_accuracy: 0.9812 - val_loss: 0.0734 - val_precision: 0.9812 - val_recall: 0.9812
# Epoch 36/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - auc: 0.9978 - categorical_accuracy: 0.9842 - loss: 0.0582 - precision: 0.9842 - recall: 0.9842 - val_auc: 0.9950 - val_categorical_accuracy: 0.9816 - val_loss: 0.0742 - val_precision: 0.9816 - val_recall: 0.9816
# Epoch 37/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - auc: 0.9977 - categorical_accuracy: 0.9837 - loss: 0.0593 - precision: 0.9837 - recall: 0.9837 - val_auc: 0.9957 - val_categorical_accuracy: 0.9808 - val_loss: 0.0705 - val_precision: 0.9808 - val_recall: 0.9808
# Epoch 38/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - auc: 0.9980 - categorical_accuracy: 0.9847 - loss: 0.0544 - precision: 0.9847 - recall: 0.9847 - val_auc: 0.9953 - val_categorical_accuracy: 0.9782 - val_loss: 0.0778 - val_precision: 0.9782 - val_recall: 0.9782
# Epoch 39/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - auc: 0.9975 - categorical_accuracy: 0.9829 - loss: 0.0616 - precision: 0.9829 - recall: 0.9829 - val_auc: 0.9957 - val_categorical_accuracy: 0.9808 - val_loss: 0.0716 - val_precision: 0.9808 - val_recall: 0.9808
# Epoch 40/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - auc: 0.9978 - categorical_accuracy: 0.9824 - loss: 0.0608 - precision: 0.9824 - recall: 0.9824 - val_auc: 0.9940 - val_categorical_accuracy: 0.9803 - val_loss: 0.0880 - val_precision: 0.9803 - val_recall: 0.9803
# Epoch 41/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - auc: 0.9977 - categorical_accuracy: 0.9829 - loss: 0.0598 - precision: 0.9829 - recall: 0.9829 - val_auc: 0.9956 - val_categorical_accuracy: 0.9786 - val_loss: 0.0754 - val_precision: 0.9786 - val_recall: 0.9786
# Epoch 42/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - auc: 0.9978 - categorical_accuracy: 0.9841 - loss: 0.0589 - precision: 0.9841 - recall: 0.9841 - val_auc: 0.9950 - val_categorical_accuracy: 0.9809 - val_loss: 0.0741 - val_precision: 0.9809 - val_recall: 0.9809
# Epoch 43/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - auc: 0.9982 - categorical_accuracy: 0.9845 - loss: 0.0549 - precision: 0.9845 - recall: 0.9845 - val_auc: 0.9958 - val_categorical_accuracy: 0.9816 - val_loss: 0.0709 - val_precision: 0.9816 - val_recall: 0.9816
# Epoch 44/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - auc: 0.9979 - categorical_accuracy: 0.9849 - loss: 0.0564 - precision: 0.9849 - recall: 0.9849 - val_auc: 0.9945 - val_categorical_accuracy: 0.9800 - val_loss: 0.0803 - val_precision: 0.9800 - val_recall: 0.9800
# Epoch 45/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - auc: 0.9979 - categorical_accuracy: 0.9844 - loss: 0.0572 - precision: 0.9844 - recall: 0.9844 - val_auc: 0.9948 - val_categorical_accuracy: 0.9813 - val_loss: 0.0772 - val_precision: 0.9813 - val_recall: 0.9813
# Epoch 46/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - auc: 0.9979 - categorical_accuracy: 0.9845 - loss: 0.0564 - precision: 0.9845 - recall: 0.9845 - val_auc: 0.9953 - val_categorical_accuracy: 0.9813 - val_loss: 0.0754 - val_precision: 0.9813 - val_recall: 0.9813
# Epoch 47/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - auc: 0.9976 - categorical_accuracy: 0.9834 - loss: 0.0593 - precision: 0.9834 - recall: 0.9834 - val_auc: 0.9953 - val_categorical_accuracy: 0.9822 - val_loss: 0.0749 - val_precision: 0.9822 - val_recall: 0.9822
# Epoch 48/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - auc: 0.9980 - categorical_accuracy: 0.9855 - loss: 0.0545 - precision: 0.9855 - recall: 0.9855 - val_auc: 0.9958 - val_categorical_accuracy: 0.9812 - val_loss: 0.0735 - val_precision: 0.9812 - val_recall: 0.9812
# Epoch 49/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - auc: 0.9979 - categorical_accuracy: 0.9853 - loss: 0.0553 - precision: 0.9853 - recall: 0.9853 - val_auc: 0.9952 - val_categorical_accuracy: 0.9820 - val_loss: 0.0730 - val_precision: 0.9820 - val_recall: 0.9820
# Epoch 50/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - auc: 0.9980 - categorical_accuracy: 0.9863 - loss: 0.0545 - precision: 0.9863 - recall: 0.9863 - val_auc: 0.9960 - val_categorical_accuracy: 0.9822 - val_loss: 0.0708 - val_precision: 0.9822 - val_recall: 0.9822

# %% [markdown]
# #### Plot metrics

# %%
# Training and Validation Loss

plt.figure(figsize=(12,6))
plt.plot(training_history.history['loss'], label='Training Loss')
plt.plot(training_history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training and Validation Loss')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Training and Validation Accuracy
plt.figure(figsize=(12,6))
plt.plot(training_history.history['categorical_accuracy'], label='Training Accuracy')
plt.plot(training_history.history['val_categorical_accuracy'], label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Training and Validation Accuracy')
plt.legend()
plt.grid(True)
plt.ylim([0, 1])
plt.show()
