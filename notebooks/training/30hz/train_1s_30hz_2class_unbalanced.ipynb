# %% [markdown]
# <a href="https://colab.research.google.com/github/Ziyi-star/Bachelorarbeit/blob/main/notebooks/training/train_1s_30hz_2class_unbalanced.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # SimCLR Training

# %%
# For VSCode
# %load_ext autoreload
# %autoreload 2
import os
import pickle
import scipy
import datetime
import numpy as np
import tensorflow as tf
import simclr_utitlities
import transformations
import simclr_models
import sys
import matplotlib.pyplot as plt

sys.path.append('../')   # Add parent directory to Python path
working_directory = "../models/"
sys.path.append('../../')
from utils.preprocessing import *

seed = 1
tf.random.set_seed(seed)
np.random.seed(seed)

# %%
# Update the balanced data
with open('../training_data/2class_balanced/X_train_normalized.pkl', 'rb') as f:
    np_train_data = pickle.load(f)
with open('../training_data/2class_balanced/y_train_onehot.pkl', 'rb') as f:
    np_train_labels = pickle.load(f)
with open('../training_data/2class_balanced/X_val_normalized.pkl', 'rb') as f:
    np_val_data = pickle.load(f)
with open('../training_data/2class_balanced/y_val_onehot.pkl', 'rb') as f:
    np_val_labels = pickle.load(f)

# %%
# update the unbalanced data
with open('../training_data/2class_unbalanced/X_train_normalized.pkl', 'rb') as f:
    np_train_data_unbalanced = pickle.load(f)
with open('../training_data/2class_unbalanced/y_train_onehot.pkl', 'rb') as f:
    np_train_unbalanced_labels = pickle.load(f)
with open('../training_data/2class_unbalanced/X_val_normalized.pkl', 'rb') as f:
    np_val_data_unbalanced = pickle.load(f)
with open('../training_data/2class_unbalanced/y_val_onehot.pkl', 'rb') as f:
    np_val_unbalanced_labels = pickle.load(f)
with open('../training_data/2class_unbalanced/X_test_data.pkl', 'rb') as f:
    np_test_data_unbalanced = pickle.load(f)
with open('../training_data/2class_unbalanced/y_test_onehot.pkl', 'rb') as f:
    np_test_unbalanced_labels = pickle.load(f)

# %%
print(np_train_data_unbalanced.shape, np_train_unbalanced_labels.shape)
print(np_val_data_unbalanced.shape, np_val_unbalanced_labels.shape)
print(np_test_data_unbalanced.shape, np_test_unbalanced_labels.shape)
# Out:
# (10096, 30, 3) (10096, 2)
# (2524, 30, 3) (2524, 2)
# (3155, 30, 3) (3155, 2)

# %%
# For Google Colab
# 1. Clone your repository to go to access your notebook and .py files
# !git clone https://github.com/Ziyi-star/Bachelorarbeit.git
# 2. Change working directory to where your notebook and .py files are
import os
os.chdir('/content/Bachelorarbeit/notebooks/training')
import os
import pickle
import scipy
import datetime
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import simclr_utitlities
import transformations
import simclr_models
import sys
sys.path.append('../../')
from utils.preprocessing import *



seed = 1
tf.random.set_seed(seed)
np.random.seed(seed)

# Load balanced data for simclr pretraining
# Download the file from GitHub
# !rm -f *.pkl # Remove existing pickle files
# !wget https://raw.githubusercontent.com/Ziyi-star/Bachelorarbeit/main/notebooks/training_data/2class_balanced/X_train_normalized.pkl
# !wget https://raw.githubusercontent.com/Ziyi-star/Bachelorarbeit/main/notebooks/training_data/2class_balanced/y_train_onehot.pkl
# !wget https://raw.githubusercontent.com/Ziyi-star/Bachelorarbeit/main/notebooks/training_data/2class_balanced/X_val_normalized.pkl
# !wget https://raw.githubusercontent.com/Ziyi-star/Bachelorarbeit/main/notebooks/training_data/2class_balanced/y_val_onehot.pkl

working_directory = "../models/"  # Relative path to models folder

# Load as usual
import pickle

with open('X_train_normalized.pkl', 'rb') as f:
    np_train_data = pickle.load(f)
with open('y_train_onehot.pkl', 'rb') as f:
    np_train_labels = pickle.load(f)
with open('X_val_normalized.pkl', 'rb') as f:
    np_val_data = pickle.load(f)
with open('y_val_onehot.pkl', 'rb') as f:
    np_val_labels = pickle.load(f)

print(np_train_data.shape, np_train_labels.shape)
print(np_val_data.shape, np_val_labels.shape)
# Out:
# Cloning into 'Bachelorarbeit'...
# remote: Enumerating objects: 1375, done.
# remote: Total 1375 (delta 0), reused 0 (delta 0), pack-reused 1375 (from 1)
# Receiving objects: 100% (1375/1375), 324.10 MiB | 36.60 MiB/s, done.
# Resolving deltas: 100% (817/817), done.
# Updating files: 100% (61/61), done.
# /content/Bachelorarbeit/notebooks/training/transformations.py:35: SyntaxWarning: invalid escape sequence '\&'
#   @inproceedings{TerryUm_ICMI2017, author = {Um, Terry T. and Pfister, Franz M. J. and Pichler, Daniel and Endo, Satoshi and Lang, Muriel and Hirche, Sandra and Fietzek, Urban and Kuli\'{c}, Dana}, title = {Data Augmentation of Wearable Sensor Data for Parkinson's Disease Monitoring Using Convolutional Neural Networks}, booktitle = {Proceedings of the 19th ACM International Conference on Multimodal Interaction}, series = {ICMI 2017}, year = {2017}, isbn = {978-1-4503-5543-8}, location = {Glasgow, UK}, pages = {216--220}, numpages = {5}, doi = {10.1145/3136755.3136817}, acmid = {3136817}, publisher = {ACM}, address = {New York, NY, USA}, keywords = {Parkinson\&#39;s disease, convolutional neural networks, data augmentation, health monitoring, motor state detection, wearable sensor}, }
# --2025-11-28 12:13:19--  https://raw.githubusercontent.com/Ziyi-star/Bachelorarbeit/main/notebooks/training_data/2class_balanced/X_train_normalized.pkl
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.111.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 707925 (691K) [application/octet-stream]
# Saving to: ‘X_train_normalized.pkl’
#
# X_train_normalized. 100%[===================>] 691.33K  --.-KB/s    in 0.03s
#
# 2025-11-28 12:13:19 (22.5 MB/s) - ‘X_train_normalized.pkl’ saved [707925/707925]
#
# --2025-11-28 12:13:19--  https://raw.githubusercontent.com/Ziyi-star/Bachelorarbeit/main/notebooks/training_data/2class_balanced/y_train_onehot.pkl
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.111.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 15882 (16K) [application/octet-stream]
# Saving to: ‘y_train_onehot.pkl’
#
# y_train_onehot.pkl  100%[===================>]  15.51K  --.-KB/s    in 0.001s
#
# 2025-11-28 12:13:19 (19.1 MB/s) - ‘y_train_onehot.pkl’ saved [15882/15882]
#
# --2025-11-28 12:13:19--  https://raw.githubusercontent.com/Ziyi-star/Bachelorarbeit/main/notebooks/training_data/2class_balanced/X_val_normalized.pkl
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 177284 (173K) [application/octet-stream]
# Saving to: ‘X_val_normalized.pkl’
#
# X_val_normalized.pk 100%[===================>] 173.13K  --.-KB/s    in 0.01s
#
# 2025-11-28 12:13:20 (11.6 MB/s) - ‘X_val_normalized.pkl’ saved [177284/177284]
#
# --2025-11-28 12:13:20--  https://raw.githubusercontent.com/Ziyi-star/Bachelorarbeit/main/notebooks/training_data/2class_balanced/y_val_onehot.pkl
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4089 (4.0K) [application/octet-stream]
# Saving to: ‘y_val_onehot.pkl’
#
# y_val_onehot.pkl    100%[===================>]   3.99K  --.-KB/s    in 0s
#
# 2025-11-28 12:13:20 (90.6 MB/s) - ‘y_val_onehot.pkl’ saved [4089/4089]
#
# (983, 30, 3) (983, 2)
# (246, 30, 3) (246, 2)

# %%
# Load unbalanced data for evluation
# Download the file from GitHub
# !rm -f *.pkl # Remove existing pickle files
# !wget https://raw.githubusercontent.com/Ziyi-star/Bachelorarbeit/main/notebooks/training_data/2class_unbalanced/X_train_normalized.pkl
# !wget https://raw.githubusercontent.com/Ziyi-star/Bachelorarbeit/main/notebooks/training_data/2class_unbalanced/y_train_onehot.pkl
# !wget https://raw.githubusercontent.com/Ziyi-star/Bachelorarbeit/main/notebooks/training_data/2class_unbalanced/X_val_normalized.pkl
# !wget https://raw.githubusercontent.com/Ziyi-star/Bachelorarbeit/main/notebooks/training_data/2class_unbalanced/y_val_onehot.pkl
# !wget https://raw.githubusercontent.com/Ziyi-star/Bachelorarbeit/main/notebooks/training_data/2class_unbalanced/X_test_normalized.pkl
# !wget https://raw.githubusercontent.com/Ziyi-star/Bachelorarbeit/main/notebooks/training_data/2class_unbalanced/y_test_onehot.pkl


working_directory = "../models/"  # Relative path to models folder

# Load as usual
import pickle

with open('X_train_normalized.pkl', 'rb') as f:
    np_train_data_unbalanced = pickle.load(f)
with open('y_train_onehot.pkl', 'rb') as f:
    np_train_unbalanced_labels = pickle.load(f)
with open('X_val_normalized.pkl', 'rb') as f:
    np_val_data_unbalanced = pickle.load(f)
with open('y_val_onehot.pkl', 'rb') as f:
    np_val_unbalanced_labels = pickle.load(f)
with open('X_test_normalized.pkl', 'rb') as f:
    np_test_data_unbalanced = pickle.load(f)
with open('y_test_onehot.pkl', 'rb') as f:
    np_test_unbalanced_labels = pickle.load(f)

print(np_train_data_unbalanced.shape, np_train_unbalanced_labels.shape)
print(np_val_data_unbalanced.shape, np_val_unbalanced_labels.shape)
print(np_test_data_unbalanced.shape, np_test_unbalanced_labels.shape)
# Out:
# --2025-11-28 12:14:49--  https://raw.githubusercontent.com/Ziyi-star/Bachelorarbeit/main/notebooks/training_data/2class_unbalanced/X_train_normalized.pkl
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.111.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 7269285 (6.9M) [application/octet-stream]
# Saving to: ‘X_train_normalized.pkl’
#
# X_train_normalized. 100%[===================>]   6.93M  --.-KB/s    in 0.05s
#
# 2025-11-28 12:14:50 (132 MB/s) - ‘X_train_normalized.pkl’ saved [7269285/7269285]
#
# --2025-11-28 12:14:50--  https://raw.githubusercontent.com/Ziyi-star/Bachelorarbeit/main/notebooks/training_data/2class_unbalanced/y_train_onehot.pkl
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 161699 (158K) [application/octet-stream]
# Saving to: ‘y_train_onehot.pkl’
#
# y_train_onehot.pkl  100%[===================>] 157.91K  --.-KB/s    in 0.02s
#
# 2025-11-28 12:14:50 (9.74 MB/s) - ‘y_train_onehot.pkl’ saved [161699/161699]
#
# --2025-11-28 12:14:50--  https://raw.githubusercontent.com/Ziyi-star/Bachelorarbeit/main/notebooks/training_data/2class_unbalanced/X_val_normalized.pkl
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1817445 (1.7M) [application/octet-stream]
# Saving to: ‘X_val_normalized.pkl’
#
# X_val_normalized.pk 100%[===================>]   1.73M  --.-KB/s    in 0.04s
#
# 2025-11-28 12:14:50 (41.8 MB/s) - ‘X_val_normalized.pkl’ saved [1817445/1817445]
#
# --2025-11-28 12:14:50--  https://raw.githubusercontent.com/Ziyi-star/Bachelorarbeit/main/notebooks/training_data/2class_unbalanced/y_val_onehot.pkl
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 40538 (40K) [application/octet-stream]
# Saving to: ‘y_val_onehot.pkl’
#
# y_val_onehot.pkl    100%[===================>]  39.59K  --.-KB/s    in 0.003s
#
# 2025-11-28 12:14:50 (11.1 MB/s) - ‘y_val_onehot.pkl’ saved [40538/40538]
#
# --2025-11-28 12:14:50--  https://raw.githubusercontent.com/Ziyi-star/Bachelorarbeit/main/notebooks/training_data/2class_unbalanced/X_test_normalized.pkl
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.108.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2271765 (2.2M) [application/octet-stream]
# Saving to: ‘X_test_normalized.pkl’
#
# X_test_normalized.p 100%[===================>]   2.17M  --.-KB/s    in 0.03s
#
# 2025-11-28 12:14:50 (65.1 MB/s) - ‘X_test_normalized.pkl’ saved [2271765/2271765]
#
# --2025-11-28 12:14:50--  https://raw.githubusercontent.com/Ziyi-star/Bachelorarbeit/main/notebooks/training_data/2class_unbalanced/y_test_onehot.pkl
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 50634 (49K) [application/octet-stream]
# Saving to: ‘y_test_onehot.pkl’
#
# y_test_onehot.pkl   100%[===================>]  49.45K  --.-KB/s    in 0.007s
#
# 2025-11-28 12:14:50 (6.79 MB/s) - ‘y_test_onehot.pkl’ saved [50634/50634]
#
# (10096, 30, 3) (10096, 2)
# (2524, 30, 3) (2524, 2)
# (3155, 30, 3) (3155, 2)

# %% [markdown]
# ## 1.1 Pretraining with SimCLR

# %%
# Parameters for all experiments
window_size = 30
input_shape = (window_size, 3)
batch_size = 128
#Number of samples processed together in one training step. Larger batch sizes can speed up training but require more memory.
decay_steps = 1000
#Number of steps after which the learning rate decays (used for learning rate scheduling).
epochs = 200
temperature = 0.1

# %%
#A parameter for the SimCLR loss function that controls how sharply similarities are measured.
# transform_funcs = [
#     transformations.scaling_transform_vectorized, # Use Scaling trasnformation
#     transformations.rotation_transform_vectorized # Use rotation trasnformation
# ]
transform_funcs = [
    transformations.time_segment_permutation_transform_improved,
    transformations.channel_shuffle_transform_vectorized
]
#List of data augmentation functions to apply to the input data. Here, only rotation is used.
transformation_function = simclr_utitlities.generate_composite_transform_function_simple(transform_funcs)
# Out:
# 0 <function time_segment_permutation_transform_improved at 0x7ec8159be660>
# 1 <function channel_shuffle_transform_vectorized at 0x7ec8159be5c0>

# %%
# Time
start_time = datetime.datetime.now()
start_time_str = start_time.strftime("%Y%m%d-%H%M%S")
#Formats the date and time as a string like 20250827-153045 (for filenames, logs, etc.).
tf.keras.backend.set_floatx('float32')
#Sets TensorFlow to use 32-bit floating point numbers for all computations (standard for deep learning).

# %%
# Create a cosine-decayed learning rate schedule and SGD optimizer for training.
lr_decayed_fn = tf.keras.optimizers.schedules.CosineDecay(initial_learning_rate=0.1, decay_steps=decay_steps)
optimizer = tf.keras.optimizers.SGD(lr_decayed_fn)

# Build the base model and attach the SimCLR head for contrastive learning.
base_model = simclr_models.create_base_model_small_dimensions(input_shape, model_name="base_model")
simclr_model = simclr_models.attach_simclr_head(base_model)
simclr_model.summary()

# Train the SimCLR model using the specified transformation function and optimizer.
trained_simclr_model, epoch_losses = simclr_utitlities.simclr_train_model(
    simclr_model,
    np_train_data,
    optimizer,
    batch_size,
    transformation_function,
    temperature=temperature,
    epochs=epochs,
    is_trasnform_function_vectorized=True,
    verbose=1
)

# Save the trained SimCLR model to disk for later use.
simclr_model_save_path = f"{working_directory}{start_time_str}_simclr.hdf5"
trained_simclr_model.save(simclr_model_save_path)
# Out:
# Model: "base_model_simclr"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input (InputLayer)              │ (None, 30, 3)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d (Conv1D)                 │ (None, 30, 32)         │         2,336 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 30, 32)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_1 (Conv1D)               │ (None, 30, 64)         │        32,832 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 30, 64)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_2 (Conv1D)               │ (None, 30, 96)         │        49,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 30, 96)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_max_pooling1d            │ (None, 96)             │             0 │
# │ (GlobalMaxPooling1D)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 256)            │        24,832 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation (Activation)         │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_1 (Activation)       │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 50)             │         6,450 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 148,594 (580.45 KB)
#  Trainable params: 148,594 (580.45 KB)
#  Non-trainable params: 0 (0.00 B)
# epoch: 1 loss: 9.176
# epoch: 2 loss: 8.090
# epoch: 3 loss: 7.510
# epoch: 4 loss: 6.691
# epoch: 5 loss: 6.468
# epoch: 6 loss: 6.253
# epoch: 7 loss: 6.360
# epoch: 8 loss: 6.720
# epoch: 9 loss: 6.130
# epoch: 10 loss: 5.164
# epoch: 11 loss: 4.999
# epoch: 12 loss: 4.794
# epoch: 13 loss: 4.681
# epoch: 14 loss: 4.571
# epoch: 15 loss: 4.653
# epoch: 16 loss: 4.481
# epoch: 17 loss: 4.235
# epoch: 18 loss: 4.119
# epoch: 19 loss: 3.966
# epoch: 20 loss: 3.921
# epoch: 21 loss: 3.788
# epoch: 22 loss: 3.693
# epoch: 23 loss: 3.379
# epoch: 24 loss: 3.748
# epoch: 25 loss: 3.402
# epoch: 26 loss: 3.301
# epoch: 27 loss: 3.155
# epoch: 28 loss: 2.991
# epoch: 29 loss: 2.976
# epoch: 30 loss: 2.882
# epoch: 31 loss: 2.723
# epoch: 32 loss: 2.946
# epoch: 33 loss: 2.877
# epoch: 34 loss: 2.605
# epoch: 35 loss: 2.847
# epoch: 36 loss: 2.409
# epoch: 37 loss: 2.461
# epoch: 38 loss: 2.600
# epoch: 39 loss: 2.395
# epoch: 40 loss: 2.260
# epoch: 41 loss: 2.964
# epoch: 42 loss: 2.194
# epoch: 43 loss: 2.152
# epoch: 44 loss: 2.722
# epoch: 45 loss: 2.109
# epoch: 46 loss: 2.295
# epoch: 47 loss: 2.054
# epoch: 48 loss: 1.945
# epoch: 49 loss: 2.059
# epoch: 50 loss: 2.065
# epoch: 51 loss: 1.814
# epoch: 52 loss: 1.971
# epoch: 53 loss: 1.812
# epoch: 54 loss: 1.921
# epoch: 55 loss: 1.744
# epoch: 56 loss: 1.851
# epoch: 57 loss: 1.870
# epoch: 58 loss: 2.031
# epoch: 59 loss: 1.750
# epoch: 60 loss: 1.587
# epoch: 61 loss: 1.662
# epoch: 62 loss: 1.700
# epoch: 63 loss: 1.523
# epoch: 64 loss: 1.671
# epoch: 65 loss: 1.567
# epoch: 66 loss: 1.513
# epoch: 67 loss: 1.594
# epoch: 68 loss: 1.528
# epoch: 69 loss: 1.449
# epoch: 70 loss: 1.412
# epoch: 71 loss: 1.310
# epoch: 72 loss: 1.375
# epoch: 73 loss: 1.404
# epoch: 74 loss: 1.258
# epoch: 75 loss: 1.391
# epoch: 76 loss: 1.283
# epoch: 77 loss: 1.292
# epoch: 78 loss: 1.301
# epoch: 79 loss: 1.198
# epoch: 80 loss: 1.262
# epoch: 81 loss: 1.192
# epoch: 82 loss: 1.195
# epoch: 83 loss: 1.219
# epoch: 84 loss: 1.221
# epoch: 85 loss: 1.120
# epoch: 86 loss: 1.138
# epoch: 87 loss: 1.110
# epoch: 88 loss: 1.059
# epoch: 89 loss: 1.124
# epoch: 90 loss: 1.161
# epoch: 91 loss: 1.066
# epoch: 92 loss: 1.105
# epoch: 93 loss: 1.051
# epoch: 94 loss: 1.089
# epoch: 95 loss: 1.008
# epoch: 96 loss: 0.995
# epoch: 97 loss: 1.004
# epoch: 98 loss: 1.042
# epoch: 99 loss: 1.011
# epoch: 100 loss: 1.030
# epoch: 101 loss: 0.993
# epoch: 102 loss: 1.042
# epoch: 103 loss: 0.972
# epoch: 104 loss: 1.007
# epoch: 105 loss: 0.976
# epoch: 106 loss: 1.019
# epoch: 107 loss: 1.027
# epoch: 108 loss: 0.997
# epoch: 109 loss: 0.958
# epoch: 110 loss: 0.958
# epoch: 111 loss: 0.941
# epoch: 112 loss: 0.963
# epoch: 113 loss: 0.952
# epoch: 114 loss: 0.986
# epoch: 115 loss: 0.923
# epoch: 116 loss: 0.919
# epoch: 117 loss: 0.988
# epoch: 118 loss: 0.948
# epoch: 119 loss: 0.942
# epoch: 120 loss: 0.930
# epoch: 121 loss: 0.888
# epoch: 122 loss: 0.952
# epoch: 123 loss: 0.949
# epoch: 124 loss: 0.924
# epoch: 125 loss: 0.928
# epoch: 126 loss: 0.897
# epoch: 127 loss: 0.921
# epoch: 128 loss: 0.896
# epoch: 129 loss: 0.966
# epoch: 130 loss: 0.943
# epoch: 131 loss: 0.951
# epoch: 132 loss: 0.969
# epoch: 133 loss: 0.962
# epoch: 134 loss: 0.867
# epoch: 135 loss: 0.920
# epoch: 136 loss: 0.887
# epoch: 137 loss: 0.916
# epoch: 138 loss: 0.885
# epoch: 139 loss: 0.944
# epoch: 140 loss: 0.938
# epoch: 141 loss: 0.944
# epoch: 142 loss: 0.912
# epoch: 143 loss: 0.998
# epoch: 144 loss: 0.952
# epoch: 145 loss: 0.881
# epoch: 146 loss: 0.953
# epoch: 147 loss: 0.903
# epoch: 148 loss: 0.929
# epoch: 149 loss: 0.984
# epoch: 150 loss: 0.951
# epoch: 151 loss: 0.961
# epoch: 152 loss: 0.933
# epoch: 153 loss: 0.929
# epoch: 154 loss: 0.946
# epoch: 155 loss: 0.980
# epoch: 156 loss: 0.951
# epoch: 157 loss: 0.962
# epoch: 158 loss: 0.908
# epoch: 159 loss: 0.930
# epoch: 160 loss: 0.940
# epoch: 161 loss: 0.948
# epoch: 162 loss: 0.918
# epoch: 163 loss: 1.039
# epoch: 164 loss: 0.935
# epoch: 165 loss: 0.984
# epoch: 166 loss: 0.956
# epoch: 167 loss: 0.978
# epoch: 168 loss: 1.025
# epoch: 169 loss: 0.945
# epoch: 170 loss: 0.953
# epoch: 171 loss: 0.955
# epoch: 172 loss: 0.910
# epoch: 173 loss: 0.973
# epoch: 174 loss: 0.964
# epoch: 175 loss: 0.944
# epoch: 176 loss: 0.950
# epoch: 177 loss: 0.947
# epoch: 178 loss: 0.883
# epoch: 179 loss: 0.967
# epoch: 180 loss: 0.917
# epoch: 181 loss: 0.945
# epoch: 182 loss: 0.880
# epoch: 183 loss: 0.947
# epoch: 184 loss: 0.986
# epoch: 185 loss: 0.900
# epoch: 186 loss: 0.929
# epoch: 187 loss: 0.954
# epoch: 188 loss: 0.947
# epoch: 189 loss: 0.956
# epoch: 190 loss: 0.955
# epoch: 191 loss: 0.905
# epoch: 192 loss: 0.944
# epoch: 193 loss: 0.978
# epoch: 194 loss: 0.941
# epoch: 195 loss: 0.918
# epoch: 196 loss: 0.910
# epoch: 197 loss: 0.939
# epoch: 198 loss: 0.884
# epoch: 199 loss: 0.876
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# epoch: 200 loss: 0.906

# %%
# Plot history of training losses over epochs.
plt.figure(figsize=(12,8))
plt.plot(epoch_losses)
plt.ylabel("Loss")
plt.xlabel("Epoch")
plt.show()

# %% [markdown]
# ## 1.2 Fine-tuning and Evaluation

# %% [markdown]
# ### 1.2.1 Linear Model

# %% [markdown]
# #### Train

# %%
# This block performs linear evaluation on top of the pretrained SimCLR base model.
total_epochs = 50
batch_size = 128
tag = "linear_eval"
output_shape = np_train_unbalanced_labels.shape[1]  # Number of classes for classification

# 1. Loads the SimCLR model and attaches a linear classification head on top.
simclr_model = tf.keras.models.load_model(simclr_model_save_path)
linear_evaluation_model = simclr_models.create_linear_model_from_base_model(simclr_model, output_shape, intermediate_layer=7)

# 2. Sets up a ModelCheckpoint callback to save the best model (lowest validation loss).
# This ensures we keep the model version that performs best on validation data
linear_eval_best_model_file_name = f"{working_directory}{start_time_str}_simclr_{tag}.keras"
best_model_callback = tf.keras.callbacks.ModelCheckpoint(
    linear_eval_best_model_file_name,
    monitor='val_loss',
    mode='min',
    save_best_only=True,
    save_weights_only=False,
    verbose=0
)

# 3. Trains the linear evaluation model using the training and validation data.
training_history = linear_evaluation_model.fit(
    x = np_train_data_unbalanced,
    y = np_train_unbalanced_labels,
    batch_size=batch_size,
    shuffle=True,
    epochs=total_epochs,
    callbacks=[best_model_callback],
    validation_data=(np_val_data_unbalanced, np_val_unbalanced_labels)
)
# Out:
# WARNING:absl:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# Epoch 1/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 11s 82ms/step - auc: 0.9752 - categorical_accuracy: 0.9558 - loss: 0.2069 - precision: 0.9558 - recall: 0.9558 - val_auc: 0.9979 - val_categorical_accuracy: 0.9845 - val_loss: 0.0592 - val_precision: 0.9845 - val_recall: 0.9845
# Epoch 2/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.9959 - categorical_accuracy: 0.9831 - loss: 0.0594 - precision: 0.9831 - recall: 0.9831 - val_auc: 0.9983 - val_categorical_accuracy: 0.9838 - val_loss: 0.0505 - val_precision: 0.9838 - val_recall: 0.9838
# Epoch 3/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.9962 - categorical_accuracy: 0.9835 - loss: 0.0594 - precision: 0.9835 - recall: 0.9835 - val_auc: 0.9985 - val_categorical_accuracy: 0.9849 - val_loss: 0.0477 - val_precision: 0.9849 - val_recall: 0.9849
# Epoch 4/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.9965 - categorical_accuracy: 0.9833 - loss: 0.0573 - precision: 0.9833 - recall: 0.9833 - val_auc: 0.9985 - val_categorical_accuracy: 0.9853 - val_loss: 0.0460 - val_precision: 0.9853 - val_recall: 0.9853
# Epoch 5/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.9969 - categorical_accuracy: 0.9833 - loss: 0.0522 - precision: 0.9833 - recall: 0.9833 - val_auc: 0.9986 - val_categorical_accuracy: 0.9853 - val_loss: 0.0456 - val_precision: 0.9853 - val_recall: 0.9853
# Epoch 6/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.9969 - categorical_accuracy: 0.9840 - loss: 0.0526 - precision: 0.9840 - recall: 0.9840 - val_auc: 0.9985 - val_categorical_accuracy: 0.9853 - val_loss: 0.0448 - val_precision: 0.9853 - val_recall: 0.9853
# Epoch 7/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.9970 - categorical_accuracy: 0.9841 - loss: 0.0511 - precision: 0.9841 - recall: 0.9841 - val_auc: 0.9986 - val_categorical_accuracy: 0.9857 - val_loss: 0.0439 - val_precision: 0.9857 - val_recall: 0.9857
# Epoch 8/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.9966 - categorical_accuracy: 0.9852 - loss: 0.0512 - precision: 0.9852 - recall: 0.9852 - val_auc: 0.9987 - val_categorical_accuracy: 0.9861 - val_loss: 0.0433 - val_precision: 0.9861 - val_recall: 0.9861
# Epoch 9/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.9966 - categorical_accuracy: 0.9850 - loss: 0.0529 - precision: 0.9850 - recall: 0.9850 - val_auc: 0.9986 - val_categorical_accuracy: 0.9857 - val_loss: 0.0433 - val_precision: 0.9857 - val_recall: 0.9857
# Epoch 10/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.9965 - categorical_accuracy: 0.9847 - loss: 0.0506 - precision: 0.9847 - recall: 0.9847 - val_auc: 0.9986 - val_categorical_accuracy: 0.9865 - val_loss: 0.0422 - val_precision: 0.9865 - val_recall: 0.9865
# Epoch 11/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.9966 - categorical_accuracy: 0.9848 - loss: 0.0495 - precision: 0.9848 - recall: 0.9848 - val_auc: 0.9986 - val_categorical_accuracy: 0.9853 - val_loss: 0.0441 - val_precision: 0.9853 - val_recall: 0.9853
# Epoch 12/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.9966 - categorical_accuracy: 0.9850 - loss: 0.0516 - precision: 0.9850 - recall: 0.9850 - val_auc: 0.9987 - val_categorical_accuracy: 0.9861 - val_loss: 0.0413 - val_precision: 0.9861 - val_recall: 0.9861
# Epoch 13/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.9970 - categorical_accuracy: 0.9859 - loss: 0.0493 - precision: 0.9859 - recall: 0.9859 - val_auc: 0.9986 - val_categorical_accuracy: 0.9861 - val_loss: 0.0424 - val_precision: 0.9861 - val_recall: 0.9861
# Epoch 14/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.9966 - categorical_accuracy: 0.9845 - loss: 0.0509 - precision: 0.9845 - recall: 0.9845 - val_auc: 0.9985 - val_categorical_accuracy: 0.9849 - val_loss: 0.0439 - val_precision: 0.9849 - val_recall: 0.9849
# Epoch 15/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.9968 - categorical_accuracy: 0.9843 - loss: 0.0509 - precision: 0.9843 - recall: 0.9843 - val_auc: 0.9987 - val_categorical_accuracy: 0.9869 - val_loss: 0.0412 - val_precision: 0.9869 - val_recall: 0.9869
# Epoch 16/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.9968 - categorical_accuracy: 0.9864 - loss: 0.0481 - precision: 0.9864 - recall: 0.9864 - val_auc: 0.9987 - val_categorical_accuracy: 0.9857 - val_loss: 0.0417 - val_precision: 0.9857 - val_recall: 0.9857
# Epoch 17/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.9968 - categorical_accuracy: 0.9839 - loss: 0.0515 - precision: 0.9839 - recall: 0.9839 - val_auc: 0.9988 - val_categorical_accuracy: 0.9865 - val_loss: 0.0410 - val_precision: 0.9865 - val_recall: 0.9865
# Epoch 18/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.9968 - categorical_accuracy: 0.9859 - loss: 0.0494 - precision: 0.9859 - recall: 0.9859 - val_auc: 0.9988 - val_categorical_accuracy: 0.9865 - val_loss: 0.0410 - val_precision: 0.9865 - val_recall: 0.9865
# Epoch 19/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.9970 - categorical_accuracy: 0.9841 - loss: 0.0504 - precision: 0.9841 - recall: 0.9841 - val_auc: 0.9988 - val_categorical_accuracy: 0.9869 - val_loss: 0.0403 - val_precision: 0.9869 - val_recall: 0.9869
# Epoch 20/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.9970 - categorical_accuracy: 0.9852 - loss: 0.0479 - precision: 0.9852 - recall: 0.9852 - val_auc: 0.9988 - val_categorical_accuracy: 0.9861 - val_loss: 0.0409 - val_precision: 0.9861 - val_recall: 0.9861
# Epoch 21/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.9969 - categorical_accuracy: 0.9851 - loss: 0.0500 - precision: 0.9851 - recall: 0.9851 - val_auc: 0.9987 - val_categorical_accuracy: 0.9865 - val_loss: 0.0410 - val_precision: 0.9865 - val_recall: 0.9865
# Epoch 22/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.9966 - categorical_accuracy: 0.9832 - loss: 0.0526 - precision: 0.9832 - recall: 0.9832 - val_auc: 0.9987 - val_categorical_accuracy: 0.9849 - val_loss: 0.0431 - val_precision: 0.9849 - val_recall: 0.9849
# Epoch 23/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.9970 - categorical_accuracy: 0.9856 - loss: 0.0492 - precision: 0.9856 - recall: 0.9856 - val_auc: 0.9988 - val_categorical_accuracy: 0.9873 - val_loss: 0.0400 - val_precision: 0.9873 - val_recall: 0.9873
# Epoch 24/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.9970 - categorical_accuracy: 0.9857 - loss: 0.0482 - precision: 0.9857 - recall: 0.9857 - val_auc: 0.9987 - val_categorical_accuracy: 0.9853 - val_loss: 0.0413 - val_precision: 0.9853 - val_recall: 0.9853
# Epoch 25/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.9969 - categorical_accuracy: 0.9853 - loss: 0.0483 - precision: 0.9853 - recall: 0.9853 - val_auc: 0.9988 - val_categorical_accuracy: 0.9853 - val_loss: 0.0407 - val_precision: 0.9853 - val_recall: 0.9853
# Epoch 26/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - auc: 0.9972 - categorical_accuracy: 0.9851 - loss: 0.0499 - precision: 0.9851 - recall: 0.9851 - val_auc: 0.9988 - val_categorical_accuracy: 0.9857 - val_loss: 0.0402 - val_precision: 0.9857 - val_recall: 0.9857
# Epoch 27/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.9975 - categorical_accuracy: 0.9857 - loss: 0.0481 - precision: 0.9857 - recall: 0.9857 - val_auc: 0.9987 - val_categorical_accuracy: 0.9849 - val_loss: 0.0418 - val_precision: 0.9849 - val_recall: 0.9849
# Epoch 28/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.9973 - categorical_accuracy: 0.9857 - loss: 0.0468 - precision: 0.9857 - recall: 0.9857 - val_auc: 0.9988 - val_categorical_accuracy: 0.9873 - val_loss: 0.0397 - val_precision: 0.9873 - val_recall: 0.9873
# Epoch 29/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.9970 - categorical_accuracy: 0.9845 - loss: 0.0496 - precision: 0.9845 - recall: 0.9845 - val_auc: 0.9988 - val_categorical_accuracy: 0.9853 - val_loss: 0.0404 - val_precision: 0.9853 - val_recall: 0.9853
# Epoch 30/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - auc: 0.9974 - categorical_accuracy: 0.9851 - loss: 0.0497 - precision: 0.9851 - recall: 0.9851 - val_auc: 0.9988 - val_categorical_accuracy: 0.9865 - val_loss: 0.0389 - val_precision: 0.9865 - val_recall: 0.9865
# Epoch 31/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.9968 - categorical_accuracy: 0.9856 - loss: 0.0489 - precision: 0.9856 - recall: 0.9856 - val_auc: 0.9988 - val_categorical_accuracy: 0.9873 - val_loss: 0.0388 - val_precision: 0.9873 - val_recall: 0.9873
# Epoch 32/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - auc: 0.9969 - categorical_accuracy: 0.9857 - loss: 0.0472 - precision: 0.9857 - recall: 0.9857 - val_auc: 0.9988 - val_categorical_accuracy: 0.9857 - val_loss: 0.0396 - val_precision: 0.9857 - val_recall: 0.9857
# Epoch 33/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.9972 - categorical_accuracy: 0.9859 - loss: 0.0480 - precision: 0.9859 - recall: 0.9859 - val_auc: 0.9988 - val_categorical_accuracy: 0.9853 - val_loss: 0.0401 - val_precision: 0.9853 - val_recall: 0.9853
# Epoch 34/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.9973 - categorical_accuracy: 0.9857 - loss: 0.0454 - precision: 0.9857 - recall: 0.9857 - val_auc: 0.9988 - val_categorical_accuracy: 0.9845 - val_loss: 0.0411 - val_precision: 0.9845 - val_recall: 0.9845
# Epoch 35/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.9972 - categorical_accuracy: 0.9849 - loss: 0.0489 - precision: 0.9849 - recall: 0.9849 - val_auc: 0.9988 - val_categorical_accuracy: 0.9861 - val_loss: 0.0393 - val_precision: 0.9861 - val_recall: 0.9861
# Epoch 36/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.9978 - categorical_accuracy: 0.9840 - loss: 0.0461 - precision: 0.9840 - recall: 0.9840 - val_auc: 0.9989 - val_categorical_accuracy: 0.9877 - val_loss: 0.0377 - val_precision: 0.9877 - val_recall: 0.9877
# Epoch 37/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.9969 - categorical_accuracy: 0.9865 - loss: 0.0471 - precision: 0.9865 - recall: 0.9865 - val_auc: 0.9988 - val_categorical_accuracy: 0.9865 - val_loss: 0.0392 - val_precision: 0.9865 - val_recall: 0.9865
# Epoch 38/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.9970 - categorical_accuracy: 0.9862 - loss: 0.0447 - precision: 0.9862 - recall: 0.9862 - val_auc: 0.9988 - val_categorical_accuracy: 0.9849 - val_loss: 0.0399 - val_precision: 0.9849 - val_recall: 0.9849
# Epoch 39/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.9973 - categorical_accuracy: 0.9866 - loss: 0.0455 - precision: 0.9866 - recall: 0.9866 - val_auc: 0.9988 - val_categorical_accuracy: 0.9869 - val_loss: 0.0382 - val_precision: 0.9869 - val_recall: 0.9869
# Epoch 40/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.9971 - categorical_accuracy: 0.9864 - loss: 0.0455 - precision: 0.9864 - recall: 0.9864 - val_auc: 0.9988 - val_categorical_accuracy: 0.9865 - val_loss: 0.0387 - val_precision: 0.9865 - val_recall: 0.9865
# Epoch 41/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.9977 - categorical_accuracy: 0.9861 - loss: 0.0459 - precision: 0.9861 - recall: 0.9861 - val_auc: 0.9988 - val_categorical_accuracy: 0.9865 - val_loss: 0.0384 - val_precision: 0.9865 - val_recall: 0.9865
# Epoch 42/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - auc: 0.9969 - categorical_accuracy: 0.9872 - loss: 0.0478 - precision: 0.9872 - recall: 0.9872 - val_auc: 0.9988 - val_categorical_accuracy: 0.9857 - val_loss: 0.0390 - val_precision: 0.9857 - val_recall: 0.9857
# Epoch 43/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - auc: 0.9968 - categorical_accuracy: 0.9852 - loss: 0.0478 - precision: 0.9852 - recall: 0.9852 - val_auc: 0.9988 - val_categorical_accuracy: 0.9861 - val_loss: 0.0384 - val_precision: 0.9861 - val_recall: 0.9861
# Epoch 44/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.9976 - categorical_accuracy: 0.9846 - loss: 0.0461 - precision: 0.9846 - recall: 0.9846 - val_auc: 0.9989 - val_categorical_accuracy: 0.9869 - val_loss: 0.0376 - val_precision: 0.9869 - val_recall: 0.9869
# Epoch 45/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.9972 - categorical_accuracy: 0.9870 - loss: 0.0456 - precision: 0.9870 - recall: 0.9870 - val_auc: 0.9988 - val_categorical_accuracy: 0.9857 - val_loss: 0.0389 - val_precision: 0.9857 - val_recall: 0.9857
# Epoch 46/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.9973 - categorical_accuracy: 0.9852 - loss: 0.0453 - precision: 0.9852 - recall: 0.9852 - val_auc: 0.9989 - val_categorical_accuracy: 0.9869 - val_loss: 0.0374 - val_precision: 0.9869 - val_recall: 0.9869
# Epoch 47/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.9975 - categorical_accuracy: 0.9871 - loss: 0.0431 - precision: 0.9871 - recall: 0.9871 - val_auc: 0.9988 - val_categorical_accuracy: 0.9857 - val_loss: 0.0384 - val_precision: 0.9857 - val_recall: 0.9857
# Epoch 48/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.9978 - categorical_accuracy: 0.9868 - loss: 0.0459 - precision: 0.9868 - recall: 0.9868 - val_auc: 0.9988 - val_categorical_accuracy: 0.9861 - val_loss: 0.0381 - val_precision: 0.9861 - val_recall: 0.9861
# Epoch 49/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.9977 - categorical_accuracy: 0.9855 - loss: 0.0440 - precision: 0.9855 - recall: 0.9855 - val_auc: 0.9987 - val_categorical_accuracy: 0.9838 - val_loss: 0.0420 - val_precision: 0.9838 - val_recall: 0.9838
# Epoch 50/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - auc: 0.9982 - categorical_accuracy: 0.9853 - loss: 0.0464 - precision: 0.9853 - recall: 0.9853 - val_auc: 0.9989 - val_categorical_accuracy: 0.9865 - val_loss: 0.0379 - val_precision: 0.9865 - val_recall: 0.9865

# %%
# Training and Validation Loss

plt.figure(figsize=(12,6))
plt.plot(training_history.history['loss'], label='Training Loss')
plt.plot(training_history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training and Validation Loss')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Training and Validation Accuracy
plt.figure(figsize=(12,6))
plt.plot(training_history.history['categorical_accuracy'], label='Training Accuracy')
plt.plot(training_history.history['val_categorical_accuracy'], label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Training and Validation Accuracy')
plt.legend()
plt.grid(True)
plt.ylim([0, 1])
plt.show()

# %% [markdown]
# #### Test:

# %%
# Load models and evaluate on test set on vscode
linear_eval_model_path =  linear_eval_best_model_file_name

# Load both models
# simclr_model = tf.keras.models.load_model(simclr_model_path)
linear_eval_best_model = tf.keras.models.load_model(linear_eval_model_path)

# %%
linear_eval_best_model = tf.keras.models.load_model(linear_eval_best_model_file_name)

print("Model with lowest validation Loss:")
print(simclr_utitlities.evaluate_model_simple(linear_eval_best_model.predict(np_test_data_unbalanced), np_test_unbalanced_labels, return_dict=True))
print("Model in last epoch")
print(simclr_utitlities.evaluate_model_simple(linear_evaluation_model.predict(np_test_data_unbalanced), np_test_unbalanced_labels, return_dict=True))
# Out:
# Model with lowest validation Loss:
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step
# {'Confusion Matrix': array([[3024,    8],
#        [  32,   91]]), 'F1 Macro': 0.9066247587929586, 'F1 Micro': 0.9873217115689382, 'F1 Weighted': 0.9866613887368129, 'Precision': 0.9543603575017188, 'Recall': 0.8685994379732715, 'Kappa': np.float64(0.8133290733312033)}
# Model in last epoch
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step
# {'Confusion Matrix': array([[3024,    8],
#        [  38,   85]]), 'F1 Macro': 0.8897443143833036, 'F1 Micro': 0.9854199683042789, 'F1 Weighted': 0.9844433539396552, 'Precision': 0.9507841526024876, 'Recall': 0.8442091940708325, 'Kappa': np.float64(0.7796392965706147)}

# %% [markdown]
# ### 1.2.2 Full HAR Model

# %% [markdown]
# #### Train

# %%
total_epochs = 50
batch_size = 128
tag = "full_eval"

simclr_model = tf.keras.models.load_model(simclr_model_save_path)
full_evaluation_model = simclr_models.create_full_classification_model_from_base_model(
    simclr_model, output_shape, model_name="TPN", intermediate_layer=7, last_freeze_layer=4)

full_eval_best_model_file_name = f"{working_directory}{start_time_str}_simclr_{tag}.keras"

best_model_callback = tf.keras.callbacks.ModelCheckpoint(full_eval_best_model_file_name,
    monitor='val_loss', mode='min', save_best_only=True, save_weights_only=False, verbose=0
)

training_history = full_evaluation_model.fit(
    x = np_train_data,
    y = np_train_labels,
    batch_size=batch_size,
    shuffle=True,
    epochs=total_epochs,
    callbacks=[best_model_callback],
    validation_data=(np_val_data, np_val_labels)
)
# Out:
# WARNING:absl:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# Epoch 1/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 19s 2s/step - auc: 0.9399 - categorical_accuracy: 0.8690 - loss: 0.3386 - precision: 0.8690 - recall: 0.8690 - val_auc: 0.9728 - val_categorical_accuracy: 0.9146 - val_loss: 0.2249 - val_precision: 0.9146 - val_recall: 0.9146
# Epoch 2/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - auc: 0.9770 - categorical_accuracy: 0.9254 - loss: 0.2145 - precision: 0.9254 - recall: 0.9254 - val_auc: 0.9859 - val_categorical_accuracy: 0.9472 - val_loss: 0.1568 - val_precision: 0.9472 - val_recall: 0.9472
# Epoch 3/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - auc: 0.9884 - categorical_accuracy: 0.9472 - loss: 0.1486 - precision: 0.9472 - recall: 0.9472 - val_auc: 0.9865 - val_categorical_accuracy: 0.9512 - val_loss: 0.1462 - val_precision: 0.9512 - val_recall: 0.9512
# Epoch 4/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - auc: 0.9893 - categorical_accuracy: 0.9507 - loss: 0.1432 - precision: 0.9507 - recall: 0.9507 - val_auc: 0.9899 - val_categorical_accuracy: 0.9553 - val_loss: 0.1327 - val_precision: 0.9553 - val_recall: 0.9553
# Epoch 5/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - auc: 0.9905 - categorical_accuracy: 0.9561 - loss: 0.1324 - precision: 0.9561 - recall: 0.9561 - val_auc: 0.9912 - val_categorical_accuracy: 0.9472 - val_loss: 0.1273 - val_precision: 0.9472 - val_recall: 0.9472
# Epoch 6/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - auc: 0.9919 - categorical_accuracy: 0.9485 - loss: 0.1265 - precision: 0.9485 - recall: 0.9485 - val_auc: 0.9914 - val_categorical_accuracy: 0.9472 - val_loss: 0.1277 - val_precision: 0.9472 - val_recall: 0.9472
# Epoch 7/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - auc: 0.9927 - categorical_accuracy: 0.9617 - loss: 0.1165 - precision: 0.9617 - recall: 0.9617 - val_auc: 0.9896 - val_categorical_accuracy: 0.9634 - val_loss: 0.1209 - val_precision: 0.9634 - val_recall: 0.9634
# Epoch 8/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - auc: 0.9930 - categorical_accuracy: 0.9614 - loss: 0.1164 - precision: 0.9614 - recall: 0.9614 - val_auc: 0.9920 - val_categorical_accuracy: 0.9553 - val_loss: 0.1185 - val_precision: 0.9553 - val_recall: 0.9553
# Epoch 9/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - auc: 0.9935 - categorical_accuracy: 0.9613 - loss: 0.1099 - precision: 0.9613 - recall: 0.9613 - val_auc: 0.9933 - val_categorical_accuracy: 0.9634 - val_loss: 0.1125 - val_precision: 0.9634 - val_recall: 0.9634
# Epoch 10/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - auc: 0.9935 - categorical_accuracy: 0.9609 - loss: 0.1124 - precision: 0.9609 - recall: 0.9609 - val_auc: 0.9918 - val_categorical_accuracy: 0.9512 - val_loss: 0.1214 - val_precision: 0.9512 - val_recall: 0.9512
# Epoch 11/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - auc: 0.9942 - categorical_accuracy: 0.9626 - loss: 0.1049 - precision: 0.9626 - recall: 0.9626 - val_auc: 0.9932 - val_categorical_accuracy: 0.9553 - val_loss: 0.1144 - val_precision: 0.9553 - val_recall: 0.9553
# Epoch 12/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - auc: 0.9946 - categorical_accuracy: 0.9617 - loss: 0.1022 - precision: 0.9617 - recall: 0.9617 - val_auc: 0.9927 - val_categorical_accuracy: 0.9553 - val_loss: 0.1169 - val_precision: 0.9553 - val_recall: 0.9553
# Epoch 13/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - auc: 0.9964 - categorical_accuracy: 0.9682 - loss: 0.0867 - precision: 0.9682 - recall: 0.9682 - val_auc: 0.9906 - val_categorical_accuracy: 0.9715 - val_loss: 0.1115 - val_precision: 0.9715 - val_recall: 0.9715
# Epoch 14/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - auc: 0.9961 - categorical_accuracy: 0.9707 - loss: 0.0893 - precision: 0.9707 - recall: 0.9707 - val_auc: 0.9928 - val_categorical_accuracy: 0.9675 - val_loss: 0.1120 - val_precision: 0.9675 - val_recall: 0.9675
# Epoch 15/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - auc: 0.9965 - categorical_accuracy: 0.9675 - loss: 0.0852 - precision: 0.9675 - recall: 0.9675 - val_auc: 0.9910 - val_categorical_accuracy: 0.9593 - val_loss: 0.1104 - val_precision: 0.9593 - val_recall: 0.9593
# Epoch 16/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - auc: 0.9970 - categorical_accuracy: 0.9751 - loss: 0.0779 - precision: 0.9751 - recall: 0.9751 - val_auc: 0.9940 - val_categorical_accuracy: 0.9715 - val_loss: 0.1067 - val_precision: 0.9715 - val_recall: 0.9715
# Epoch 17/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - auc: 0.9972 - categorical_accuracy: 0.9664 - loss: 0.0805 - precision: 0.9664 - recall: 0.9664 - val_auc: 0.9936 - val_categorical_accuracy: 0.9715 - val_loss: 0.1084 - val_precision: 0.9715 - val_recall: 0.9715
# Epoch 18/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - auc: 0.9959 - categorical_accuracy: 0.9700 - loss: 0.0906 - precision: 0.9700 - recall: 0.9700 - val_auc: 0.9939 - val_categorical_accuracy: 0.9675 - val_loss: 0.1070 - val_precision: 0.9675 - val_recall: 0.9675
# Epoch 19/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - auc: 0.9975 - categorical_accuracy: 0.9748 - loss: 0.0750 - precision: 0.9748 - recall: 0.9748 - val_auc: 0.9909 - val_categorical_accuracy: 0.9634 - val_loss: 0.1078 - val_precision: 0.9634 - val_recall: 0.9634
# Epoch 20/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - auc: 0.9976 - categorical_accuracy: 0.9681 - loss: 0.0726 - precision: 0.9681 - recall: 0.9681 - val_auc: 0.9946 - val_categorical_accuracy: 0.9675 - val_loss: 0.1008 - val_precision: 0.9675 - val_recall: 0.9675
# Epoch 21/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - auc: 0.9981 - categorical_accuracy: 0.9682 - loss: 0.0663 - precision: 0.9682 - recall: 0.9682 - val_auc: 0.9940 - val_categorical_accuracy: 0.9675 - val_loss: 0.1060 - val_precision: 0.9675 - val_recall: 0.9675
# Epoch 22/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - auc: 0.9970 - categorical_accuracy: 0.9777 - loss: 0.0762 - precision: 0.9777 - recall: 0.9777 - val_auc: 0.9943 - val_categorical_accuracy: 0.9715 - val_loss: 0.1037 - val_precision: 0.9715 - val_recall: 0.9715
# Epoch 23/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - auc: 0.9977 - categorical_accuracy: 0.9757 - loss: 0.0690 - precision: 0.9757 - recall: 0.9757 - val_auc: 0.9952 - val_categorical_accuracy: 0.9715 - val_loss: 0.0979 - val_precision: 0.9715 - val_recall: 0.9715
# Epoch 24/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - auc: 0.9986 - categorical_accuracy: 0.9772 - loss: 0.0589 - precision: 0.9772 - recall: 0.9772 - val_auc: 0.9946 - val_categorical_accuracy: 0.9715 - val_loss: 0.1016 - val_precision: 0.9715 - val_recall: 0.9715
# Epoch 25/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - auc: 0.9980 - categorical_accuracy: 0.9804 - loss: 0.0639 - precision: 0.9804 - recall: 0.9804 - val_auc: 0.9952 - val_categorical_accuracy: 0.9715 - val_loss: 0.0953 - val_precision: 0.9715 - val_recall: 0.9715
# Epoch 26/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - auc: 0.9991 - categorical_accuracy: 0.9838 - loss: 0.0492 - precision: 0.9838 - recall: 0.9838 - val_auc: 0.9955 - val_categorical_accuracy: 0.9675 - val_loss: 0.0942 - val_precision: 0.9675 - val_recall: 0.9675
# Epoch 27/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - auc: 0.9990 - categorical_accuracy: 0.9872 - loss: 0.0492 - precision: 0.9872 - recall: 0.9872 - val_auc: 0.9956 - val_categorical_accuracy: 0.9634 - val_loss: 0.0930 - val_precision: 0.9634 - val_recall: 0.9634
# Epoch 28/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - auc: 0.9988 - categorical_accuracy: 0.9781 - loss: 0.0558 - precision: 0.9781 - recall: 0.9781 - val_auc: 0.9942 - val_categorical_accuracy: 0.9634 - val_loss: 0.1061 - val_precision: 0.9634 - val_recall: 0.9634
# Epoch 29/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - auc: 0.9986 - categorical_accuracy: 0.9813 - loss: 0.0570 - precision: 0.9813 - recall: 0.9813 - val_auc: 0.9922 - val_categorical_accuracy: 0.9715 - val_loss: 0.1001 - val_precision: 0.9715 - val_recall: 0.9715
# Epoch 30/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - auc: 0.9991 - categorical_accuracy: 0.9822 - loss: 0.0474 - precision: 0.9822 - recall: 0.9822 - val_auc: 0.9951 - val_categorical_accuracy: 0.9675 - val_loss: 0.1039 - val_precision: 0.9675 - val_recall: 0.9675
# Epoch 31/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - auc: 0.9988 - categorical_accuracy: 0.9835 - loss: 0.0543 - precision: 0.9835 - recall: 0.9835 - val_auc: 0.9897 - val_categorical_accuracy: 0.9634 - val_loss: 0.1295 - val_precision: 0.9634 - val_recall: 0.9634
# Epoch 32/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - auc: 0.9965 - categorical_accuracy: 0.9759 - loss: 0.0700 - precision: 0.9759 - recall: 0.9759 - val_auc: 0.9960 - val_categorical_accuracy: 0.9675 - val_loss: 0.0971 - val_precision: 0.9675 - val_recall: 0.9675
# Epoch 33/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - auc: 0.9992 - categorical_accuracy: 0.9825 - loss: 0.0456 - precision: 0.9825 - recall: 0.9825 - val_auc: 0.9963 - val_categorical_accuracy: 0.9715 - val_loss: 0.0913 - val_precision: 0.9715 - val_recall: 0.9715
# Epoch 34/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - auc: 0.9990 - categorical_accuracy: 0.9824 - loss: 0.0502 - precision: 0.9824 - recall: 0.9824 - val_auc: 0.9908 - val_categorical_accuracy: 0.9634 - val_loss: 0.1168 - val_precision: 0.9634 - val_recall: 0.9634
# Epoch 35/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - auc: 0.9979 - categorical_accuracy: 0.9839 - loss: 0.0621 - precision: 0.9839 - recall: 0.9839 - val_auc: 0.9891 - val_categorical_accuracy: 0.9553 - val_loss: 0.1394 - val_precision: 0.9553 - val_recall: 0.9553
# Epoch 36/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - auc: 0.9946 - categorical_accuracy: 0.9709 - loss: 0.0878 - precision: 0.9709 - recall: 0.9709 - val_auc: 0.9933 - val_categorical_accuracy: 0.9512 - val_loss: 0.1222 - val_precision: 0.9512 - val_recall: 0.9512
# Epoch 37/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - auc: 0.9978 - categorical_accuracy: 0.9738 - loss: 0.0736 - precision: 0.9738 - recall: 0.9738 - val_auc: 0.9910 - val_categorical_accuracy: 0.9593 - val_loss: 0.1128 - val_precision: 0.9593 - val_recall: 0.9593
# Epoch 38/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - auc: 0.9948 - categorical_accuracy: 0.9692 - loss: 0.0909 - precision: 0.9692 - recall: 0.9692 - val_auc: 0.9912 - val_categorical_accuracy: 0.9715 - val_loss: 0.1120 - val_precision: 0.9715 - val_recall: 0.9715
# Epoch 39/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - auc: 0.9976 - categorical_accuracy: 0.9766 - loss: 0.0662 - precision: 0.9766 - recall: 0.9766 - val_auc: 0.9904 - val_categorical_accuracy: 0.9593 - val_loss: 0.1467 - val_precision: 0.9593 - val_recall: 0.9593
# Epoch 40/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - auc: 0.9962 - categorical_accuracy: 0.9843 - loss: 0.0620 - precision: 0.9843 - recall: 0.9843 - val_auc: 0.9926 - val_categorical_accuracy: 0.9715 - val_loss: 0.1021 - val_precision: 0.9715 - val_recall: 0.9715
# Epoch 41/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - auc: 0.9987 - categorical_accuracy: 0.9785 - loss: 0.0557 - precision: 0.9785 - recall: 0.9785 - val_auc: 0.9899 - val_categorical_accuracy: 0.9472 - val_loss: 0.1327 - val_precision: 0.9472 - val_recall: 0.9472
# Epoch 42/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - auc: 0.9971 - categorical_accuracy: 0.9851 - loss: 0.0727 - precision: 0.9851 - recall: 0.9851 - val_auc: 0.9921 - val_categorical_accuracy: 0.9675 - val_loss: 0.1088 - val_precision: 0.9675 - val_recall: 0.9675
# Epoch 43/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - auc: 0.9992 - categorical_accuracy: 0.9805 - loss: 0.0448 - precision: 0.9805 - recall: 0.9805 - val_auc: 0.9956 - val_categorical_accuracy: 0.9593 - val_loss: 0.1002 - val_precision: 0.9593 - val_recall: 0.9593
# Epoch 44/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - auc: 0.9991 - categorical_accuracy: 0.9823 - loss: 0.0482 - precision: 0.9823 - recall: 0.9823 - val_auc: 0.9965 - val_categorical_accuracy: 0.9675 - val_loss: 0.0908 - val_precision: 0.9675 - val_recall: 0.9675
# Epoch 45/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - auc: 0.9994 - categorical_accuracy: 0.9905 - loss: 0.0378 - precision: 0.9905 - recall: 0.9905 - val_auc: 0.9963 - val_categorical_accuracy: 0.9715 - val_loss: 0.0897 - val_precision: 0.9715 - val_recall: 0.9715
# Epoch 46/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - auc: 0.9996 - categorical_accuracy: 0.9871 - loss: 0.0369 - precision: 0.9871 - recall: 0.9871 - val_auc: 0.9960 - val_categorical_accuracy: 0.9634 - val_loss: 0.0949 - val_precision: 0.9634 - val_recall: 0.9634
# Epoch 47/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - auc: 0.9996 - categorical_accuracy: 0.9901 - loss: 0.0370 - precision: 0.9901 - recall: 0.9901 - val_auc: 0.9962 - val_categorical_accuracy: 0.9675 - val_loss: 0.0958 - val_precision: 0.9675 - val_recall: 0.9675
# Epoch 48/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - auc: 0.9996 - categorical_accuracy: 0.9913 - loss: 0.0330 - precision: 0.9913 - recall: 0.9913 - val_auc: 0.9959 - val_categorical_accuracy: 0.9634 - val_loss: 0.0981 - val_precision: 0.9634 - val_recall: 0.9634
# Epoch 49/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - auc: 0.9995 - categorical_accuracy: 0.9934 - loss: 0.0360 - precision: 0.9934 - recall: 0.9934 - val_auc: 0.9962 - val_categorical_accuracy: 0.9634 - val_loss: 0.0940 - val_precision: 0.9634 - val_recall: 0.9634
# Epoch 50/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - auc: 0.9998 - categorical_accuracy: 0.9909 - loss: 0.0294 - precision: 0.9909 - recall: 0.9909 - val_auc: 0.9960 - val_categorical_accuracy: 0.9634 - val_loss: 0.0980 - val_precision: 0.9634 - val_recall: 0.9634

# %% [markdown]
# #### Plot metrics

# %%
# Training and Validation Loss

plt.figure(figsize=(12,6))
plt.plot(training_history.history['loss'], label='Training Loss')
plt.plot(training_history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training and Validation Loss')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Training and Validation Accuracy
plt.figure(figsize=(12,6))
plt.plot(training_history.history['categorical_accuracy'], label='Training Accuracy')
plt.plot(training_history.history['val_categorical_accuracy'], label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Training and Validation Accuracy')
plt.legend()
plt.grid(True)
plt.ylim([0, 1])
plt.show()

# %% [markdown]
# #### Test:

# %%
full_eval_best_model = tf.keras.models.load_model(full_eval_best_model_file_name)

print("Model with lowest validation Loss:")
print(simclr_utitlities.evaluate_model_simple(full_eval_best_model.predict(np_test_data_unbalanced), np_test_unbalanced_labels, return_dict=True))
print("Model in last epoch")
print(simclr_utitlities.evaluate_model_simple(full_evaluation_model.predict(np_test_data_unbalanced), np_test_unbalanced_labels, return_dict=True))
# Out:
# Model with lowest validation Loss:
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 4s 20ms/step
# {'Confusion Matrix': array([[2262,  770],
#        [   2,  121]]), 'F1 Macro': 0.5464441921855354, 'F1 Micro': 0.7553090332805071, 'F1 Weighted': 0.830231124808269, 'Precision': 0.567459538454827, 'Recall': 0.8648910268786065, 'Kappa': np.float64(0.1826600411277377)}
# Model in last epoch
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step
# {'Confusion Matrix': array([[2359,  673],
#        [   2,  121]]), 'F1 Macro': 0.5693708937693577, 'F1 Micro': 0.786053882725832, 'F1 Weighted': 0.8510200514433451, 'Precision': 0.5757729242081387, 'Recall': 0.8808870690949654, 'Kappa': np.float64(0.21061000937426677)}

# %%
# optimize

# %%
import numpy as np
from sklearn.metrics import precision_recall_curve, roc_curve, f1_score, precision_score, recall_score, confusion_matrix
import matplotlib.pyplot as plt

def find_optimal_threshold(y_true, y_pred_proba, metric='f1'):
    """
    Find optimal classification threshold based on various metrics.

    Args:
        y_true: True labels (one-hot encoded)
        y_pred_proba: Predicted probabilities from model
        metric: 'f1', 'precision', 'recall', or 'youden'

    Returns:
        optimal_threshold: Best threshold value
        best_score: Score at optimal threshold
    """
    # Convert one-hot to class indices
    y_true_labels = np.argmax(y_true, axis=1)
    # Get probability for positive class (curb_1)
    y_scores = y_pred_proba[:, 1]

    thresholds = np.linspace(0, 1, 100)
    scores = []

    for threshold in thresholds:
        y_pred = (y_scores >= threshold).astype(int)

        if metric == 'f1':
            score = f1_score(y_true_labels, y_pred, average='binary')
        elif metric == 'precision':
            score = precision_score(y_true_labels, y_pred, average='binary', zero_division=0)
        elif metric == 'recall':
            score = recall_score(y_true_labels, y_pred, average='binary', zero_division=0)
        elif metric == 'youden':
            tn, fp, fn, tp = confusion_matrix(y_true_labels, y_pred).ravel()
            sensitivity = tp / (tp + fn) if (tp + fn) > 0 else 0
            specificity = tn / (tn + fp) if (tn + fp) > 0 else 0
            score = sensitivity + specificity - 1  # Youden's J statistic

        scores.append(score)

    best_idx = np.argmax(scores)
    optimal_threshold = thresholds[best_idx]
    best_score = scores[best_idx]

    return optimal_threshold, best_score, thresholds, scores

def plot_threshold_analysis(y_true, y_pred_proba):
    """
    Plot threshold analysis for different metrics.
    """
    fig, axes = plt.subplots(2, 2, figsize=(15, 10))

    metrics = ['f1', 'precision', 'recall', 'youden']
    titles = ['F1-Score', 'Precision', 'Recall', 'Youden Index']

    for idx, (metric, title) in enumerate(zip(metrics, titles)):
        ax = axes[idx // 2, idx % 2]

        opt_thresh, best_score, thresholds, scores = find_optimal_threshold(
            y_true, y_pred_proba, metric=metric
        )

        ax.plot(thresholds, scores, linewidth=2)
        ax.axvline(opt_thresh, color='r', linestyle='--',
                   label=f'Optimal: {opt_thresh:.3f}\nScore: {best_score:.3f}')
        ax.set_xlabel('Threshold')
        ax.set_ylabel(title)
        ax.set_title(f'{title} vs Threshold')
        ax.legend()
        ax.grid(True)

    plt.tight_layout()
    plt.show()

def evaluate_with_threshold(model, X_test, y_test, threshold=0.5):
    """
    Evaluate model with custom threshold.
    """
    y_pred_proba = model.predict(X_test)
    y_pred = (y_pred_proba[:, 1] >= threshold).astype(int)

    # Convert to one-hot for evaluate_model_simple
    y_pred_onehot = np.zeros_like(y_pred_proba)
    y_pred_onehot[np.arange(len(y_pred)), y_pred] = 1

    results = simclr_utitlities.evaluate_model_simple(y_pred_onehot, y_test, return_dict=True)

    return results, y_pred_proba

# %%
# Load the best model
full_eval_best_model = tf.keras.models.load_model(full_eval_best_model_file_name)

# Get predictions
y_pred_proba = full_eval_best_model.predict(np_test_data_unbalanced)

# Analyze thresholds
print("=== Threshold Analysis ===")
plot_threshold_analysis(np_test_unbalanced_labels, y_pred_proba)

# Find optimal thresholds for different metrics
print("\n=== Optimal Thresholds ===")
for metric in ['f1', 'precision', 'recall', 'youden']:
    opt_thresh, best_score, _, _ = find_optimal_threshold(np_test_unbalanced_labels, y_pred_proba, metric=metric)
    print(f"{metric.upper()}: Threshold = {opt_thresh:.3f}, Score = {best_score:.3f}")

# Evaluate with default threshold (0.5)
print("\n=== Default Threshold (0.5) ===")
results_default, _ = evaluate_with_threshold(full_eval_best_model, np_test_data_unbalanced, np_test_unbalanced_labels, threshold=0.5)
print(results_default)

# Evaluate with optimal F1 threshold
opt_f1_thresh, _, _, _ = find_optimal_threshold(np_test_unbalanced_labels, y_pred_proba, metric='f1')
print(f"\n=== Optimal F1 Threshold ({opt_f1_thresh:.3f}) ===")
results_optimal, _ = evaluate_with_threshold(full_eval_best_model, np_test_data_unbalanced, np_test_unbalanced_labels, threshold=opt_f1_thresh)
print(results_optimal)

# Compare both models
print("\n=== Comparison: Linear vs Full Model ===")
linear_eval_best_model = tf.keras.models.load_model(linear_eval_best_model_file_name)

# Linear model with optimal threshold
y_pred_proba_linear = linear_eval_best_model.predict(np_test_data_unbalanced)
opt_thresh_linear, _, _, _ = find_optimal_threshold(np_test_unbalanced_labels, y_pred_proba_linear, metric='f1')
print(f"Linear Model - Optimal F1 Threshold: {opt_thresh_linear:.3f}")
results_linear, _ = evaluate_with_threshold(linear_eval_best_model, np_test_data_unbalanced, np_test_unbalanced_labels, threshold=opt_thresh_linear)
print(results_linear)

# Full model with optimal threshold
print(f"\nFull Model - Optimal F1 Threshold: {opt_f1_thresh:.3f}")
print(results_optimal)
# Out:
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step
# === Threshold Analysis ===
# === Optimal Thresholds ===
# F1: Threshold = 1.000, Score = 0.756
# PRECISION: Threshold = 1.000, Score = 0.642
# RECALL: Threshold = 0.000, Score = 1.000
# YOUDEN: Threshold = 1.000, Score = 0.898
#
# === Default Threshold (0.5) ===
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# {'Confusion Matrix': array([[2262,  770],
#        [   2,  121]]), 'F1 Macro': 0.5464441921855354, 'F1 Micro': 0.7553090332805071, 'F1 Weighted': 0.830231124808269, 'Precision': 0.567459538454827, 'Recall': 0.8648910268786065, 'Kappa': np.float64(0.1826600411277377)}
#
# === Optimal F1 Threshold (1.000) ===
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# {'Confusion Matrix': array([[2969,   63],
#        [  10,  113]]), 'F1 Macro': 0.8718542204397846, 'F1 Micro': 0.9768621236133121, 'F1 Weighted': 0.978810799687611, 'Precision': 0.8193443116970307, 'Recall': 0.9489604114378875, 'Kappa': np.float64(0.7441083763217335)}
#
# === Comparison: Linear vs Full Model ===
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step
# Linear Model - Optimal F1 Threshold: 0.364
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# {'Confusion Matrix': array([[3022,   10],
#        [  26,   97]]), 'F1 Macro': 0.9187786041189931, 'F1 Micro': 0.9885895404120444, 'F1 Weighted': 0.9882076686237747, 'Precision': 0.9490059361738661, 'Recall': 0.8926598665722805, 'Kappa': np.float64(0.8375869406058387)}
#
# Full Model - Optimal F1 Threshold: 1.000
# {'Confusion Matrix': array([[2969,   63],
#        [  10,  113]]), 'F1 Macro': 0.8718542204397846, 'F1 Micro': 0.9768621236133121, 'F1 Weighted': 0.978810799687611, 'Precision': 0.8193443116970307, 'Recall': 0.9489604114378875, 'Kappa': np.float64(0.7441083763217335)}

# %% [markdown]
# ## Extra: t-SNE Plots

# %% [markdown]
# ### Parameters

# %%
import sklearn.manifold
import seaborn as sns

# %% [markdown]
# ### t-SNE Representations

# %%
# First load the model from the file path
target_model_path = simclr_model_save_path
loaded_model = tf.keras.models.load_model(target_model_path)
perplexity = 30.0

# Then extract the intermediate model
intermediate_model = simclr_models.extract_intermediate_model_from_base_model(loaded_model, intermediate_layer=7)
intermediate_model.summary()

# Continue with your t-SNE code
embeddings = intermediate_model.predict(np_test_data_unbalanced, batch_size=600)
tsne_model = sklearn.manifold.TSNE(perplexity=perplexity, verbose=1, random_state=42)
tsne_projections = tsne_model.fit_transform(embeddings)
# Out:
# WARNING:absl:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# Model: "base_model_simclr_layer_7"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input (InputLayer)              │ (None, 30, 3)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d (Conv1D)                 │ (None, 30, 32)         │         2,336 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 30, 32)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_1 (Conv1D)               │ (None, 30, 64)         │        32,832 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 30, 64)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_2 (Conv1D)               │ (None, 30, 96)         │        49,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 30, 96)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_max_pooling1d            │ (None, 96)             │             0 │
# │ (GlobalMaxPooling1D)            │                        │               │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 84,416 (329.75 KB)
#  Trainable params: 84,416 (329.75 KB)
#  Non-trainable params: 0 (0.00 B)
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 3155 samples in 0.001s...
# [t-SNE] Computed neighbors for 3155 samples in 0.124s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 3155
# [t-SNE] Computed conditional probabilities for sample 2000 / 3155
# [t-SNE] Computed conditional probabilities for sample 3000 / 3155
# [t-SNE] Computed conditional probabilities for sample 3155 / 3155
# [t-SNE] Mean sigma: 0.042715
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 62.088062
# [t-SNE] KL divergence after 1000 iterations: 0.674622

# %% [markdown]
# ### Plotting

# %%
# Define colors
other_class_color = "#1f77b4"  # Blue
curb_1_color = "#ff7f0e"      # Yellow

# Get the true labels (class indices) from the one-hot encoded test labels
labels_argmax = np.argmax(np_test_unbalanced_labels, axis=1)
unique_labels = np.unique(labels_argmax)

# Create custom color palette
custom_palette = [other_class_color, curb_1_color]  # First color for non_curb (0), second for curb_1 (1)

# Create the t-SNE visualization
plt.figure(figsize=(16,8))
graph = sns.scatterplot(
    x=tsne_projections[:,0], y=tsne_projections[:,1],
    hue=labels_argmax,
    palette=custom_palette,  # Use custom palette instead of "hsv"
    s=50,
    alpha=1.0,
    rasterized=True
)
plt.xticks([], [])
plt.yticks([], [])

plt.title("t-SNE Visualization of SimCLR Embeddings")

# Define your activity names
label_list_full_name = ["non_curb", "curb_1"]

# Update legend with custom colors
try:
    plt.legend(loc='lower left', bbox_to_anchor=(0.25, -0.3), ncol=2)
    legend = graph.legend_
    if 'label_list_full_name' in globals():
        for j, label in enumerate(unique_labels):
            if label < len(label_list_full_name):
                legend.get_texts()[j].set_text(label_list_full_name[label])
except Exception as e:
    print(f"Warning: Could not customize legend - {e}")
    plt.legend(loc='lower left', bbox_to_anchor=(0.25, -0.3), ncol=2)
