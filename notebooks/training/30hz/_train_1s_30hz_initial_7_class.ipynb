# %% [markdown]
# <a href="https://colab.research.google.com/github/Ziyi-star/Bachelorarbeit/blob/main/notebooks/training/_train_1s_30hz_initial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # SimCLR Training

# %%
# For VSCode
# %load_ext autoreload
# %autoreload 2

import os
import pickle
import scipy
import datetime
import numpy as np
import tensorflow as tf
import simclr_utitlities
import transformations
import simclr_models
import sys
import matplotlib.pyplot as plt

sys.path.append('../')   # Add parent directory to Python path
working_directory = "../models/"
sys.path.append('../../')
from utils.preprocessing import *

seed = 1
tf.random.set_seed(seed)
np.random.seed(seed)

with open('../data_1s_30hz/TrainTest/X_train_normalized.pkl', 'rb') as f:
    np_train_data = pickle.load(f)
with open('../data_1s_30hz/TrainTest/y_train_onehot.pkl', 'rb') as f:
    np_train_labels = pickle.load(f)
with open('../data_1s_30hz/TrainTest/X_val_normalized.pkl', 'rb') as f:
    np_val_data = pickle.load(f)
with open('../data_1s_30hz/TrainTest/y_val_onehot.pkl', 'rb') as f:
    np_val_labels = pickle.load(f)
with open('../data_1s_30hz/TrainTest/X_test_data.pkl', 'rb') as f:
    np_test_data = pickle.load(f)
with open('../data_1s_30hz/TrainTest/y_test_onehot.pkl', 'rb') as f:
    np_test_labels = pickle.load(f)

np_train_data.shape, np_train_labels.shape, np_val_data.shape, np_val_labels.shape, np_test_labels.shape
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# ((2640, 30, 3), (2640, 7), (660, 30, 3), (660, 7), (825, 7))

# %%
# For Google Colab
# 1. Clone your repository to go to access your notebook and .py files
# !git clone https://github.com/Ziyi-star/Bachelorarbeit.git
# 2. Change working directory to where your notebook and .py files are
import os
os.chdir('/content/Bachelorarbeit/notebooks/training')
import os
import pickle
import scipy
import datetime
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import simclr_utitlities
import transformations
import simclr_models
import sys
sys.path.append('../../')
from utils.preprocessing import *



seed = 1
tf.random.set_seed(seed)
np.random.seed(seed)

# Load data
# Download the file from GitHub
# !rm -f *.pkl # Remove existing pickle files
# !wget https://raw.githubusercontent.com/Ziyi-star/Bachelorarbeit/main/notebooks/data_1s_30hz/TrainTest/X_train_normalized.pkl
# !wget https://raw.githubusercontent.com/Ziyi-star/Bachelorarbeit/main/notebooks/data_1s_30hz/TrainTest/y_train_onehot.pkl
# !wget https://raw.githubusercontent.com/Ziyi-star/Bachelorarbeit/main/notebooks/data_1s_30hz/TrainTest/X_val_normalized.pkl
# !wget https://raw.githubusercontent.com/Ziyi-star/Bachelorarbeit/main/notebooks/data_1s_30hz/TrainTest/y_val_onehot.pkl
# !wget https://raw.githubusercontent.com/Ziyi-star/Bachelorarbeit/main/notebooks/data_1s_30hz/TrainTest/X_test_data.pkl
# !wget https://raw.githubusercontent.com/Ziyi-star/Bachelorarbeit/main/notebooks/data_1s_30hz/TrainTest/y_test_onehot.pkl


working_directory = "../models/"  # Relative path to models folder

# Load as usual
import pickle

with open('X_train_normalized.pkl', 'rb') as f:
    np_train_data = pickle.load(f)
with open('y_train_onehot.pkl', 'rb') as f:
    np_train_labels = pickle.load(f)
with open('X_val_normalized.pkl', 'rb') as f:
    np_val_data = pickle.load(f)
with open('y_val_onehot.pkl', 'rb') as f:
    np_val_labels = pickle.load(f)
with open('X_test_data.pkl', 'rb') as f:
    np_test_data = pickle.load(f)
with open('y_test_onehot.pkl', 'rb') as f:
    np_test_labels = pickle.load(f)

print(np_train_data.shape, np_train_labels.shape)
print(np_val_data.shape, np_val_labels.shape)
# Out:
# fatal: destination path 'Bachelorarbeit' already exists and is not an empty directory.
# --2025-09-30 13:46:47--  https://raw.githubusercontent.com/Ziyi-star/Bachelorarbeit/main/notebooks/data_1s_30hz/TrainTest/X_train_normalized.pkl
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.108.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1900965 (1.8M) [application/octet-stream]
# Saving to: ‘X_train_normalized.pkl’
#
# X_train_normalized. 100%[===================>]   1.81M  --.-KB/s    in 0.04s
#
# 2025-09-30 13:46:48 (43.8 MB/s) - ‘X_train_normalized.pkl’ saved [1900965/1900965]
#
# --2025-09-30 13:46:48--  https://raw.githubusercontent.com/Ziyi-star/Bachelorarbeit/main/notebooks/data_1s_30hz/TrainTest/y_train_onehot.pkl
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.111.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 148003 (145K) [application/octet-stream]
# Saving to: ‘y_train_onehot.pkl’
#
# y_train_onehot.pkl  100%[===================>] 144.53K  --.-KB/s    in 0.02s
#
# 2025-09-30 13:46:48 (8.88 MB/s) - ‘y_train_onehot.pkl’ saved [148003/148003]
#
# --2025-09-30 13:46:48--  https://raw.githubusercontent.com/Ziyi-star/Bachelorarbeit/main/notebooks/data_1s_30hz/TrainTest/X_val_normalized.pkl
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 475365 (464K) [application/octet-stream]
# Saving to: ‘X_val_normalized.pkl’
#
# X_val_normalized.pk 100%[===================>] 464.22K  --.-KB/s    in 0.02s
#
# 2025-09-30 13:46:48 (19.1 MB/s) - ‘X_val_normalized.pkl’ saved [475365/475365]
#
# --2025-09-30 13:46:48--  https://raw.githubusercontent.com/Ziyi-star/Bachelorarbeit/main/notebooks/data_1s_30hz/TrainTest/y_val_onehot.pkl
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 37114 (36K) [application/octet-stream]
# Saving to: ‘y_val_onehot.pkl’
#
# y_val_onehot.pkl    100%[===================>]  36.24K  --.-KB/s    in 0.003s
#
# 2025-09-30 13:46:48 (14.0 MB/s) - ‘y_val_onehot.pkl’ saved [37114/37114]
#
# --2025-09-30 13:46:48--  https://raw.githubusercontent.com/Ziyi-star/Bachelorarbeit/main/notebooks/data_1s_30hz/TrainTest/X_test_data.pkl
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 623248 (609K) [application/octet-stream]
# Saving to: ‘X_test_data.pkl’
#
# X_test_data.pkl     100%[===================>] 608.64K  --.-KB/s    in 0.02s
#
# 2025-09-30 13:46:49 (24.5 MB/s) - ‘X_test_data.pkl’ saved [623248/623248]
#
# --2025-09-30 13:46:49--  https://raw.githubusercontent.com/Ziyi-star/Bachelorarbeit/main/notebooks/data_1s_30hz/TrainTest/y_test_onehot.pkl
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 46354 (45K) [application/octet-stream]
# Saving to: ‘y_test_onehot.pkl’
#
# y_test_onehot.pkl   100%[===================>]  45.27K  --.-KB/s    in 0.008s
#
# 2025-09-30 13:46:49 (5.81 MB/s) - ‘y_test_onehot.pkl’ saved [46354/46354]
#
# (2640, 30, 3) (2640, 7)
# (660, 30, 3) (660, 7)

# %% [markdown]
# ## 1.1 Pretraining with SimCLR

# %%
# Parameters for all experiments
window_size = 30
input_shape = (window_size, 3)
batch_size = 512
#Number of samples processed together in one training step. Larger batch sizes can speed up training but require more memory.
decay_steps = 1000
#Number of steps after which the learning rate decays (used for learning rate scheduling).
epochs = 200
temperature = 0.1

# %%
#A parameter for the SimCLR loss function that controls how sharply similarities are measured.
# transform_funcs = [
#     transformations.scaling_transform_vectorized, # Use Scaling trasnformation
#     transformations.rotation_transform_vectorized # Use rotation trasnformation
# ]
transform_funcs = [
    transformations.time_segment_permutation_transform_improved,
    transformations.channel_shuffle_transform_vectorized
]
#List of data augmentation functions to apply to the input data. Here, only rotation is used.
transformation_function = simclr_utitlities.generate_composite_transform_function_simple(transform_funcs)
# Out:
# 0 <function time_segment_permutation_transform_improved at 0x000002A685D914E0>
# 1 <function channel_shuffle_transform_vectorized at 0x000002A685D91440>

# %%
# Time
start_time = datetime.datetime.now()
start_time_str = start_time.strftime("%Y%m%d-%H%M%S")
#Formats the date and time as a string like 20250827-153045 (for filenames, logs, etc.).
tf.keras.backend.set_floatx('float32')
#Sets TensorFlow to use 32-bit floating point numbers for all computations (standard for deep learning).

# %%
# Create a cosine-decayed learning rate schedule and SGD optimizer for training.
lr_decayed_fn = tf.keras.optimizers.schedules.CosineDecay(initial_learning_rate=0.1, decay_steps=decay_steps)
optimizer = tf.keras.optimizers.SGD(lr_decayed_fn)

# Build the base model and attach the SimCLR head for contrastive learning.
base_model = simclr_models.create_base_model_small_dimensions(input_shape, model_name="base_model")
simclr_model = simclr_models.attach_simclr_head(base_model)
simclr_model.summary()

# Train the SimCLR model using the specified transformation function and optimizer.
trained_simclr_model, epoch_losses = simclr_utitlities.simclr_train_model(
    simclr_model,
    np_train_data,
    optimizer,
    batch_size,
    transformation_function,
    temperature=temperature,
    epochs=epochs,
    is_trasnform_function_vectorized=True,
    verbose=1
)

# Save the trained SimCLR model to disk for later use.
simclr_model_save_path = f"{working_directory}{start_time_str}_simclr.hdf5"
trained_simclr_model.save(simclr_model_save_path)
# Out:
# Model: "base_model_simclr"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input (InputLayer)              │ (None, 30, 3)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_2 (Conv1D)               │ (None, 30, 32)         │         2,336 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 30, 32)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_3 (Conv1D)               │ (None, 30, 64)         │        32,832 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 30, 64)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_4 (Conv1D)               │ (None, 30, 96)         │        49,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 30, 96)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_max_pooling1d            │ (None, 96)             │             0 │
# │ (GlobalMaxPooling1D)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 256)            │        24,832 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation (Activation)         │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_1 (Activation)       │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 50)             │         6,450 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 148,594 (580.45 KB)
#  Trainable params: 148,594 (580.45 KB)
#  Non-trainable params: 0 (0.00 B)
# epoch: 1 loss: 12.237
# epoch: 2 loss: 11.195
# epoch: 3 loss: 11.200
# epoch: 4 loss: 9.671
# epoch: 5 loss: 9.473
# epoch: 6 loss: 9.382
# epoch: 7 loss: 9.081
# epoch: 8 loss: 9.203
# epoch: 9 loss: 8.659
# epoch: 10 loss: 8.463
# epoch: 11 loss: 8.201
# epoch: 12 loss: 8.710
# epoch: 13 loss: 8.732
# epoch: 14 loss: 7.612
# epoch: 15 loss: 7.372
# epoch: 16 loss: 7.037
# epoch: 17 loss: 6.782
# epoch: 18 loss: 6.771
# epoch: 19 loss: 6.611
# epoch: 20 loss: 6.358
# epoch: 21 loss: 6.052
# epoch: 22 loss: 6.584
# epoch: 23 loss: 6.356
# epoch: 24 loss: 6.109
# epoch: 25 loss: 6.679
# epoch: 26 loss: 6.271
# epoch: 27 loss: 5.869
# epoch: 28 loss: 5.843
# epoch: 29 loss: 5.530
# epoch: 30 loss: 5.329
# epoch: 31 loss: 5.653
# epoch: 32 loss: 5.449
# epoch: 33 loss: 5.222
# epoch: 34 loss: 5.672
# epoch: 35 loss: 5.909
# epoch: 36 loss: 5.177
# epoch: 37 loss: 4.966
# epoch: 38 loss: 5.033
# epoch: 39 loss: 4.891
# epoch: 40 loss: 4.797
# epoch: 41 loss: 5.108
# epoch: 42 loss: 4.701
# epoch: 43 loss: 4.860
# epoch: 44 loss: 5.159
# epoch: 45 loss: 4.676
# epoch: 46 loss: 4.471
# epoch: 47 loss: 4.409
# epoch: 48 loss: 4.854
# epoch: 49 loss: 4.685
# epoch: 50 loss: 4.234
# epoch: 51 loss: 4.436
# epoch: 52 loss: 4.493
# epoch: 53 loss: 4.184
# epoch: 54 loss: 4.312
# epoch: 55 loss: 4.401
# epoch: 56 loss: 4.361
# epoch: 57 loss: 4.054
# epoch: 58 loss: 4.051
# epoch: 59 loss: 3.862
# epoch: 60 loss: 4.016
# epoch: 61 loss: 3.853
# epoch: 62 loss: 3.903
# epoch: 63 loss: 4.027
# epoch: 64 loss: 3.795
# epoch: 65 loss: 3.533
# epoch: 66 loss: 3.583
# epoch: 67 loss: 3.735
# epoch: 68 loss: 3.808
# epoch: 69 loss: 3.619
# epoch: 70 loss: 3.733
# epoch: 71 loss: 3.639
# epoch: 72 loss: 3.413
# epoch: 73 loss: 3.631
# epoch: 74 loss: 3.480
# epoch: 75 loss: 3.626
# epoch: 76 loss: 3.302
# epoch: 77 loss: 3.285
# epoch: 78 loss: 3.280
# epoch: 79 loss: 3.182
# epoch: 80 loss: 3.156
# epoch: 81 loss: 3.171
# epoch: 82 loss: 3.247
# epoch: 83 loss: 3.062
# epoch: 84 loss: 3.099
# epoch: 85 loss: 3.073
# epoch: 86 loss: 3.204
# epoch: 87 loss: 3.043
# epoch: 88 loss: 3.016
# epoch: 89 loss: 2.992
# epoch: 90 loss: 3.066
# epoch: 91 loss: 3.037
# epoch: 92 loss: 2.930
# epoch: 93 loss: 2.938
# epoch: 94 loss: 2.899
# epoch: 95 loss: 2.875
# epoch: 96 loss: 2.823
# epoch: 97 loss: 2.822
# epoch: 98 loss: 2.859
# epoch: 99 loss: 2.722
# epoch: 100 loss: 2.747
# epoch: 101 loss: 2.670
# epoch: 102 loss: 2.645
# epoch: 103 loss: 2.723
# epoch: 104 loss: 2.653
# epoch: 105 loss: 2.695
# epoch: 106 loss: 2.636
# epoch: 107 loss: 2.602
# epoch: 108 loss: 2.543
# epoch: 109 loss: 2.560
# epoch: 110 loss: 2.562
# epoch: 111 loss: 2.520
# epoch: 112 loss: 2.539
# epoch: 113 loss: 2.453
# epoch: 114 loss: 2.587
# epoch: 115 loss: 2.530
# epoch: 116 loss: 2.421
# epoch: 117 loss: 2.471
# epoch: 118 loss: 2.482
# epoch: 119 loss: 2.449
# epoch: 120 loss: 2.450
# epoch: 121 loss: 2.402
# epoch: 122 loss: 2.425
# epoch: 123 loss: 2.440
# epoch: 124 loss: 2.379
# epoch: 125 loss: 2.377
# epoch: 126 loss: 2.319
# epoch: 127 loss: 2.377
# epoch: 128 loss: 2.358
# epoch: 129 loss: 2.325
# epoch: 130 loss: 2.346
# epoch: 131 loss: 2.356
# epoch: 132 loss: 2.318
# epoch: 133 loss: 2.292
# epoch: 134 loss: 2.308
# epoch: 135 loss: 2.335
# epoch: 136 loss: 2.270
# epoch: 137 loss: 2.295
# epoch: 138 loss: 2.264
# epoch: 139 loss: 2.295
# epoch: 140 loss: 2.260
# epoch: 141 loss: 2.301
# epoch: 142 loss: 2.393
# epoch: 143 loss: 2.260
# epoch: 144 loss: 2.277
# epoch: 145 loss: 2.215
# epoch: 146 loss: 2.257
# epoch: 147 loss: 2.270
# epoch: 148 loss: 2.250
# epoch: 149 loss: 2.244
# epoch: 150 loss: 2.242
# epoch: 151 loss: 2.254
# epoch: 152 loss: 2.258
# epoch: 153 loss: 2.209
# epoch: 154 loss: 2.214
# epoch: 155 loss: 2.227
# epoch: 156 loss: 2.223
# epoch: 157 loss: 2.159
# epoch: 158 loss: 2.188
# epoch: 159 loss: 2.244
# epoch: 160 loss: 2.218
# epoch: 161 loss: 2.210
# epoch: 162 loss: 2.205
# epoch: 163 loss: 2.153
# epoch: 164 loss: 2.225
# epoch: 165 loss: 2.175
# epoch: 166 loss: 2.221
# epoch: 167 loss: 2.204
# epoch: 168 loss: 2.165
# epoch: 169 loss: 2.225
# epoch: 170 loss: 2.171
# epoch: 171 loss: 2.181
# epoch: 172 loss: 2.206
# epoch: 173 loss: 2.166
# epoch: 174 loss: 2.170
# epoch: 175 loss: 2.191
# epoch: 176 loss: 2.184
# epoch: 177 loss: 2.281
# epoch: 178 loss: 2.195
# epoch: 179 loss: 2.179
# epoch: 180 loss: 2.231
# epoch: 181 loss: 2.212
# epoch: 182 loss: 2.214
# epoch: 183 loss: 2.169
# epoch: 184 loss: 2.200
# epoch: 185 loss: 2.219
# epoch: 186 loss: 2.227
# epoch: 187 loss: 2.175
# epoch: 188 loss: 2.181
# epoch: 189 loss: 2.162
# epoch: 190 loss: 2.170
# epoch: 191 loss: 2.208
# epoch: 192 loss: 2.205
# epoch: 193 loss: 2.152
# epoch: 194 loss: 2.214
# epoch: 195 loss: 2.211
# epoch: 196 loss: 2.197
# epoch: 197 loss: 2.206
# epoch: 198 loss: 2.185
# epoch: 199 loss: 2.228
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# epoch: 200 loss: 2.203

# %%
# Plot history of training losses over epochs.
plt.figure(figsize=(12,8))
plt.plot(epoch_losses)
plt.ylabel("Loss")
plt.xlabel("Epoch")
plt.show()

# %% [markdown]
# ## 1.2 Fine-tuning and Evaluation

# %% [markdown]
# ### 1.2.1 Linear Model

# %% [markdown]
# #### Train

# %%
# This block performs linear evaluation on top of the pretrained SimCLR base model.
total_epochs = 50
batch_size = 200
tag = "linear_eval"
output_shape = np_train_labels.shape[1]  # Number of classes for classification

# 1. Loads the SimCLR model and attaches a linear classification head on top.
simclr_model = tf.keras.models.load_model(simclr_model_save_path)
linear_evaluation_model = simclr_models.create_linear_model_from_base_model(simclr_model, output_shape, intermediate_layer=7)

# 2. Sets up a ModelCheckpoint callback to save the best model (lowest validation loss).
# This ensures we keep the model version that performs best on validation data
linear_eval_best_model_file_name = f"{working_directory}{start_time_str}_simclr_{tag}.keras"
best_model_callback = tf.keras.callbacks.ModelCheckpoint(
    linear_eval_best_model_file_name,
    monitor='val_loss',
    mode='min',
    save_best_only=True,
    save_weights_only=False,
    verbose=0
)

# 3. Trains the linear evaluation model using the training and validation data.
training_history = linear_evaluation_model.fit(
    x = np_train_data,
    y = np_train_labels,
    batch_size=batch_size,
    shuffle=True,
    epochs=total_epochs,
    callbacks=[best_model_callback],
    validation_data=(np_val_data, np_val_labels)
)
# Out:
# WARNING:absl:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# Epoch 1/50
# c:\Users\liuzi\miniconda3\Lib\site-packages\keras\src\models\functional.py:238: UserWarning: The structure of `inputs` doesn't match the expected structure.
# Expected: ['input']
# Received: inputs=Tensor(shape=(None, 30, 3))
#   warnings.warn(msg)
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - auc: 0.6803 - categorical_accuracy: 0.2843 - loss: 1.7571 - precision: 0.6880 - recall: 0.0917 - val_auc: 0.7970 - val_categorical_accuracy: 0.4379 - val_loss: 1.5026 - val_precision: 0.9343 - val_recall: 0.1939
# Epoch 2/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - auc: 0.8058 - categorical_accuracy: 0.4444 - loss: 1.5075 - precision: 0.8609 - recall: 0.1603 - val_auc: 0.8215 - val_categorical_accuracy: 0.4576 - val_loss: 1.4283 - val_precision: 0.9122 - val_recall: 0.2045
# Epoch 3/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - auc: 0.8220 - categorical_accuracy: 0.4641 - loss: 1.4461 - precision: 0.8563 - recall: 0.1676 - val_auc: 0.8313 - val_categorical_accuracy: 0.4864 - val_loss: 1.3894 - val_precision: 0.9032 - val_recall: 0.2121
# Epoch 4/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - auc: 0.8282 - categorical_accuracy: 0.4747 - loss: 1.4150 - precision: 0.8350 - recall: 0.1776 - val_auc: 0.8367 - val_categorical_accuracy: 0.5076 - val_loss: 1.3650 - val_precision: 0.8974 - val_recall: 0.2121
# Epoch 5/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - auc: 0.8329 - categorical_accuracy: 0.4823 - loss: 1.3920 - precision: 0.8403 - recall: 0.1863 - val_auc: 0.8395 - val_categorical_accuracy: 0.5152 - val_loss: 1.3491 - val_precision: 0.8994 - val_recall: 0.2167
# Epoch 6/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - auc: 0.8350 - categorical_accuracy: 0.4841 - loss: 1.3748 - precision: 0.8394 - recall: 0.1943 - val_auc: 0.8425 - val_categorical_accuracy: 0.5136 - val_loss: 1.3354 - val_precision: 0.8889 - val_recall: 0.2182
# Epoch 7/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - auc: 0.8381 - categorical_accuracy: 0.4926 - loss: 1.3595 - precision: 0.8324 - recall: 0.2015 - val_auc: 0.8447 - val_categorical_accuracy: 0.5045 - val_loss: 1.3246 - val_precision: 0.8788 - val_recall: 0.2197
# Epoch 8/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - auc: 0.8402 - categorical_accuracy: 0.4984 - loss: 1.3489 - precision: 0.8331 - recall: 0.2028 - val_auc: 0.8454 - val_categorical_accuracy: 0.5167 - val_loss: 1.3190 - val_precision: 0.8795 - val_recall: 0.2212
# Epoch 9/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - auc: 0.8412 - categorical_accuracy: 0.4905 - loss: 1.3432 - precision: 0.8389 - recall: 0.2076 - val_auc: 0.8466 - val_categorical_accuracy: 0.5121 - val_loss: 1.3129 - val_precision: 0.8802 - val_recall: 0.2227
# Epoch 10/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - auc: 0.8427 - categorical_accuracy: 0.5001 - loss: 1.3343 - precision: 0.8389 - recall: 0.2094 - val_auc: 0.8485 - val_categorical_accuracy: 0.5091 - val_loss: 1.3054 - val_precision: 0.8713 - val_recall: 0.2258
# Epoch 11/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - auc: 0.8442 - categorical_accuracy: 0.4940 - loss: 1.3294 - precision: 0.8325 - recall: 0.2137 - val_auc: 0.8489 - val_categorical_accuracy: 0.5136 - val_loss: 1.3021 - val_precision: 0.8659 - val_recall: 0.2348
# Epoch 12/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - auc: 0.8461 - categorical_accuracy: 0.5073 - loss: 1.3192 - precision: 0.8446 - recall: 0.2163 - val_auc: 0.8501 - val_categorical_accuracy: 0.5121 - val_loss: 1.2969 - val_precision: 0.8441 - val_recall: 0.2379
# Epoch 13/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - auc: 0.8460 - categorical_accuracy: 0.5040 - loss: 1.3207 - precision: 0.8255 - recall: 0.2158 - val_auc: 0.8504 - val_categorical_accuracy: 0.5106 - val_loss: 1.2945 - val_precision: 0.8533 - val_recall: 0.2379
# Epoch 14/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - auc: 0.8474 - categorical_accuracy: 0.5010 - loss: 1.3160 - precision: 0.8241 - recall: 0.2209 - val_auc: 0.8518 - val_categorical_accuracy: 0.5061 - val_loss: 1.2895 - val_precision: 0.8474 - val_recall: 0.2439
# Epoch 15/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - auc: 0.8466 - categorical_accuracy: 0.5049 - loss: 1.3166 - precision: 0.8255 - recall: 0.2160 - val_auc: 0.8524 - val_categorical_accuracy: 0.5136 - val_loss: 1.2872 - val_precision: 0.8377 - val_recall: 0.2424
# Epoch 16/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - auc: 0.8477 - categorical_accuracy: 0.5122 - loss: 1.3123 - precision: 0.8262 - recall: 0.2237 - val_auc: 0.8524 - val_categorical_accuracy: 0.5121 - val_loss: 1.2855 - val_precision: 0.8209 - val_recall: 0.2500
# Epoch 17/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - auc: 0.8489 - categorical_accuracy: 0.5134 - loss: 1.3063 - precision: 0.8201 - recall: 0.2277 - val_auc: 0.8525 - val_categorical_accuracy: 0.5106 - val_loss: 1.2846 - val_precision: 0.8137 - val_recall: 0.2515
# Epoch 18/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - auc: 0.8488 - categorical_accuracy: 0.5087 - loss: 1.3055 - precision: 0.8340 - recall: 0.2321 - val_auc: 0.8540 - val_categorical_accuracy: 0.5106 - val_loss: 1.2796 - val_precision: 0.8267 - val_recall: 0.2530
# Epoch 19/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - auc: 0.8503 - categorical_accuracy: 0.5082 - loss: 1.3012 - precision: 0.8317 - recall: 0.2331 - val_auc: 0.8540 - val_categorical_accuracy: 0.5091 - val_loss: 1.2790 - val_precision: 0.8086 - val_recall: 0.2561
# Epoch 20/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - auc: 0.8502 - categorical_accuracy: 0.5154 - loss: 1.3000 - precision: 0.8141 - recall: 0.2316 - val_auc: 0.8548 - val_categorical_accuracy: 0.5091 - val_loss: 1.2760 - val_precision: 0.8173 - val_recall: 0.2576
# Epoch 21/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - auc: 0.8501 - categorical_accuracy: 0.5128 - loss: 1.3021 - precision: 0.8227 - recall: 0.2365 - val_auc: 0.8549 - val_categorical_accuracy: 0.5091 - val_loss: 1.2757 - val_precision: 0.8056 - val_recall: 0.2636
# Epoch 22/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - auc: 0.8516 - categorical_accuracy: 0.5105 - loss: 1.2944 - precision: 0.8201 - recall: 0.2439 - val_auc: 0.8550 - val_categorical_accuracy: 0.5182 - val_loss: 1.2745 - val_precision: 0.8122 - val_recall: 0.2621
# Epoch 23/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - auc: 0.8517 - categorical_accuracy: 0.5113 - loss: 1.2961 - precision: 0.8201 - recall: 0.2364 - val_auc: 0.8558 - val_categorical_accuracy: 0.5106 - val_loss: 1.2719 - val_precision: 0.7991 - val_recall: 0.2652
# Epoch 24/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - auc: 0.8523 - categorical_accuracy: 0.5127 - loss: 1.2930 - precision: 0.8209 - recall: 0.2471 - val_auc: 0.8564 - val_categorical_accuracy: 0.5106 - val_loss: 1.2707 - val_precision: 0.7972 - val_recall: 0.2621
# Epoch 25/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - auc: 0.8535 - categorical_accuracy: 0.5140 - loss: 1.2888 - precision: 0.8243 - recall: 0.2467 - val_auc: 0.8574 - val_categorical_accuracy: 0.5152 - val_loss: 1.2660 - val_precision: 0.8009 - val_recall: 0.2682
# Epoch 26/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - auc: 0.8536 - categorical_accuracy: 0.5198 - loss: 1.2891 - precision: 0.8253 - recall: 0.2482 - val_auc: 0.8570 - val_categorical_accuracy: 0.5152 - val_loss: 1.2672 - val_precision: 0.7930 - val_recall: 0.2727
# Epoch 27/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - auc: 0.8542 - categorical_accuracy: 0.5165 - loss: 1.2866 - precision: 0.8369 - recall: 0.2555 - val_auc: 0.8570 - val_categorical_accuracy: 0.5152 - val_loss: 1.2669 - val_precision: 0.7965 - val_recall: 0.2727
# Epoch 28/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - auc: 0.8535 - categorical_accuracy: 0.5172 - loss: 1.2880 - precision: 0.8341 - recall: 0.2554 - val_auc: 0.8583 - val_categorical_accuracy: 0.5182 - val_loss: 1.2621 - val_precision: 0.8165 - val_recall: 0.2697
# Epoch 29/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - auc: 0.8544 - categorical_accuracy: 0.5264 - loss: 1.2864 - precision: 0.8104 - recall: 0.2518 - val_auc: 0.8583 - val_categorical_accuracy: 0.5182 - val_loss: 1.2621 - val_precision: 0.8108 - val_recall: 0.2727
# Epoch 30/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - auc: 0.8559 - categorical_accuracy: 0.5248 - loss: 1.2793 - precision: 0.8224 - recall: 0.2544 - val_auc: 0.8569 - val_categorical_accuracy: 0.5242 - val_loss: 1.2660 - val_precision: 0.8018 - val_recall: 0.2758
# Epoch 31/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - auc: 0.8552 - categorical_accuracy: 0.5230 - loss: 1.2799 - precision: 0.8194 - recall: 0.2621 - val_auc: 0.8583 - val_categorical_accuracy: 0.5212 - val_loss: 1.2617 - val_precision: 0.8125 - val_recall: 0.2758
# Epoch 32/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - auc: 0.8562 - categorical_accuracy: 0.5281 - loss: 1.2805 - precision: 0.8230 - recall: 0.2547 - val_auc: 0.8579 - val_categorical_accuracy: 0.5212 - val_loss: 1.2621 - val_precision: 0.8125 - val_recall: 0.2758
# Epoch 33/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - auc: 0.8559 - categorical_accuracy: 0.5189 - loss: 1.2788 - precision: 0.8163 - recall: 0.2643 - val_auc: 0.8583 - val_categorical_accuracy: 0.5197 - val_loss: 1.2609 - val_precision: 0.8089 - val_recall: 0.2758
# Epoch 34/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - auc: 0.8562 - categorical_accuracy: 0.5149 - loss: 1.2738 - precision: 0.8272 - recall: 0.2691 - val_auc: 0.8582 - val_categorical_accuracy: 0.5212 - val_loss: 1.2604 - val_precision: 0.8125 - val_recall: 0.2758
# Epoch 35/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - auc: 0.8573 - categorical_accuracy: 0.5196 - loss: 1.2717 - precision: 0.8169 - recall: 0.2644 - val_auc: 0.8580 - val_categorical_accuracy: 0.5182 - val_loss: 1.2621 - val_precision: 0.8043 - val_recall: 0.2803
# Epoch 36/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - auc: 0.8574 - categorical_accuracy: 0.5263 - loss: 1.2710 - precision: 0.8156 - recall: 0.2661 - val_auc: 0.8594 - val_categorical_accuracy: 0.5273 - val_loss: 1.2572 - val_precision: 0.8035 - val_recall: 0.2788
# Epoch 37/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - auc: 0.8566 - categorical_accuracy: 0.5181 - loss: 1.2752 - precision: 0.8103 - recall: 0.2643 - val_auc: 0.8589 - val_categorical_accuracy: 0.5227 - val_loss: 1.2584 - val_precision: 0.8087 - val_recall: 0.2818
# Epoch 38/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - auc: 0.8563 - categorical_accuracy: 0.5213 - loss: 1.2736 - precision: 0.8100 - recall: 0.2705 - val_auc: 0.8593 - val_categorical_accuracy: 0.5227 - val_loss: 1.2566 - val_precision: 0.8186 - val_recall: 0.2803
# Epoch 39/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - auc: 0.8569 - categorical_accuracy: 0.5204 - loss: 1.2754 - precision: 0.8189 - recall: 0.2731 - val_auc: 0.8595 - val_categorical_accuracy: 0.5227 - val_loss: 1.2552 - val_precision: 0.8079 - val_recall: 0.2803
# Epoch 40/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - auc: 0.8576 - categorical_accuracy: 0.5232 - loss: 1.2732 - precision: 0.8181 - recall: 0.2723 - val_auc: 0.8595 - val_categorical_accuracy: 0.5227 - val_loss: 1.2556 - val_precision: 0.8122 - val_recall: 0.2818
# Epoch 41/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - auc: 0.8577 - categorical_accuracy: 0.5296 - loss: 1.2698 - precision: 0.8180 - recall: 0.2792 - val_auc: 0.8592 - val_categorical_accuracy: 0.5273 - val_loss: 1.2566 - val_precision: 0.7983 - val_recall: 0.2818
# Epoch 42/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - auc: 0.8580 - categorical_accuracy: 0.5349 - loss: 1.2686 - precision: 0.8075 - recall: 0.2754 - val_auc: 0.8607 - val_categorical_accuracy: 0.5273 - val_loss: 1.2515 - val_precision: 0.8122 - val_recall: 0.2818
# Epoch 43/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - auc: 0.8594 - categorical_accuracy: 0.5207 - loss: 1.2631 - precision: 0.8210 - recall: 0.2775 - val_auc: 0.8594 - val_categorical_accuracy: 0.5242 - val_loss: 1.2574 - val_precision: 0.7957 - val_recall: 0.2833
# Epoch 44/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - auc: 0.8588 - categorical_accuracy: 0.5226 - loss: 1.2669 - precision: 0.8147 - recall: 0.2794 - val_auc: 0.8605 - val_categorical_accuracy: 0.5242 - val_loss: 1.2525 - val_precision: 0.8087 - val_recall: 0.2818
# Epoch 45/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - auc: 0.8595 - categorical_accuracy: 0.5221 - loss: 1.2643 - precision: 0.8176 - recall: 0.2761 - val_auc: 0.8610 - val_categorical_accuracy: 0.5258 - val_loss: 1.2505 - val_precision: 0.8112 - val_recall: 0.2864
# Epoch 46/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - auc: 0.8597 - categorical_accuracy: 0.5282 - loss: 1.2614 - precision: 0.8277 - recall: 0.2849 - val_auc: 0.8599 - val_categorical_accuracy: 0.5227 - val_loss: 1.2544 - val_precision: 0.8043 - val_recall: 0.2864
# Epoch 47/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - auc: 0.8591 - categorical_accuracy: 0.5316 - loss: 1.2655 - precision: 0.8070 - recall: 0.2813 - val_auc: 0.8607 - val_categorical_accuracy: 0.5258 - val_loss: 1.2524 - val_precision: 0.7983 - val_recall: 0.2879
# Epoch 48/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - auc: 0.8594 - categorical_accuracy: 0.5263 - loss: 1.2623 - precision: 0.8260 - recall: 0.2903 - val_auc: 0.8610 - val_categorical_accuracy: 0.5258 - val_loss: 1.2505 - val_precision: 0.8085 - val_recall: 0.2879
# Epoch 49/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - auc: 0.8605 - categorical_accuracy: 0.5290 - loss: 1.2587 - precision: 0.8127 - recall: 0.2815 - val_auc: 0.8606 - val_categorical_accuracy: 0.5258 - val_loss: 1.2526 - val_precision: 0.7992 - val_recall: 0.2894
# Epoch 50/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - auc: 0.8605 - categorical_accuracy: 0.5350 - loss: 1.2593 - precision: 0.8117 - recall: 0.2799 - val_auc: 0.8601 - val_categorical_accuracy: 0.5258 - val_loss: 1.2549 - val_precision: 0.7884 - val_recall: 0.2879

# %%
# Training and Validation Loss

plt.figure(figsize=(12,6))
plt.plot(training_history.history['loss'], label='Training Loss')
plt.plot(training_history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training and Validation Loss')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Training and Validation Accuracy
plt.figure(figsize=(12,6))
plt.plot(training_history.history['categorical_accuracy'], label='Training Accuracy')
plt.plot(training_history.history['val_categorical_accuracy'], label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Training and Validation Accuracy')
plt.legend()
plt.grid(True)
plt.ylim([0, 1])
plt.show()

# %% [markdown]
# #### Test:

# %%
# Load models and evaluate on test set on vscode
linear_eval_model_path =  linear_eval_best_model_file_name

# Load both models
# simclr_model = tf.keras.models.load_model(simclr_model_path)
linear_eval_best_model = tf.keras.models.load_model(linear_eval_model_path)

# %% [markdown]
# #### Normalize test data

# %%
# You can also use it for test data (but should fit the scaler only on training data)
X_test_normalized = normalize_3d_data(np_test_data)

# %%
linear_eval_best_model = tf.keras.models.load_model(linear_eval_best_model_file_name)

print("Model with lowest validation Loss:")
print(simclr_utitlities.evaluate_model_simple(linear_eval_best_model.predict(X_test_normalized), np_test_labels, return_dict=True))
print("Model in last epoch")
print(simclr_utitlities.evaluate_model_simple(linear_evaluation_model.predict(X_test_normalized), np_test_labels, return_dict=True))
# Out:
# Model with lowest validation Loss:
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# c:\Users\liuzi\miniconda3\Lib\site-packages\keras\src\models\functional.py:238: UserWarning: The structure of `inputs` doesn't match the expected structure.
# Expected: ['input']
# Received: inputs=Tensor(shape=(32, 30, 3))
#   warnings.warn(msg)
# c:\Users\liuzi\miniconda3\Lib\site-packages\keras\src\models\functional.py:238: UserWarning: The structure of `inputs` doesn't match the expected structure.
# Expected: ['input']
# Received: inputs=Tensor(shape=(None, 30, 3))
#   warnings.warn(msg)
# {'Confusion Matrix': array([[120,   1,   1,   6,   0,   9,   4],
#        [  8,  54,   2,   5,   8,  16,   4],
#        [ 41,  17,  14,   3,   3,  16,   2],
#        [ 21,   1,   4,  81,   0,  11,   5],
#        [  0,   3,   2,   3, 111,   1,   3],
#        [ 44,   1,   2,   2,   0,  54,  13],
#        [ 65,   3,   9,   5,   3,  31,  13]]), 'F1 Macro': 0.5074545894587686, 'F1 Micro': 0.5418181818181819, 'F1 Weighted': 0.5127056340586985, 'Precision': 0.5477557090333852, 'Recall': 0.5258380341403229, 'Kappa': np.float64(0.45997007626396613)}
# Model in last epoch
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# {'Confusion Matrix': array([[121,   1,   1,   6,   0,   9,   3],
#        [  8,  54,   2,   5,   8,  17,   3],
#        [ 42,  16,  15,   3,   3,  15,   2],
#        [ 23,   1,   4,  80,   0,  11,   4],
#        [  0,   3,   2,   3, 111,   1,   3],
#        [ 45,   1,   1,   2,   0,  55,  12],
#        [ 68,   3,   9,   4,   3,  31,  11]]), 'F1 Macro': 0.507259876270339, 'F1 Micro': 0.5418181818181819, 'F1 Weighted': 0.5115872295608497, 'Precision': 0.5526733926824919, 'Recall': 0.5261945480879792, 'Kappa': np.float64(0.4598512837300659)}
# c:\Users\liuzi\miniconda3\Lib\site-packages\keras\src\models\functional.py:238: UserWarning: The structure of `inputs` doesn't match the expected structure.
# Expected: ['input']
# Received: inputs=Tensor(shape=(32, 30, 3))
#   warnings.warn(msg)
# c:\Users\liuzi\miniconda3\Lib\site-packages\keras\src\models\functional.py:238: UserWarning: The structure of `inputs` doesn't match the expected structure.
# Expected: ['input']
# Received: inputs=Tensor(shape=(None, 30, 3))
#   warnings.warn(msg)

# %% [markdown]
# ### 1.2.2 Full HAR Model

# %% [markdown]
# #### Train

# %%
total_epochs = 50
batch_size = 200
tag = "full_eval"

simclr_model = tf.keras.models.load_model(simclr_model_save_path)
full_evaluation_model = simclr_models.create_full_classification_model_from_base_model(
    simclr_model, output_shape, model_name="TPN", intermediate_layer=7, last_freeze_layer=4)

full_eval_best_model_file_name = f"{working_directory}{start_time_str}_simclr_{tag}.keras"

best_model_callback = tf.keras.callbacks.ModelCheckpoint(full_eval_best_model_file_name,
    monitor='val_loss', mode='min', save_best_only=True, save_weights_only=False, verbose=0
)

training_history = full_evaluation_model.fit(
    x = np_train_data,
    y = np_train_labels,
    batch_size=batch_size,
    shuffle=True,
    epochs=total_epochs,
    callbacks=[best_model_callback],
    validation_data=(np_val_data, np_val_labels)
)
# Out:
# WARNING:absl:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# Epoch 1/50
# c:\Users\liuzi\miniconda3\Lib\site-packages\keras\src\models\functional.py:238: UserWarning: The structure of `inputs` doesn't match the expected structure.
# Expected: ['input']
# Received: inputs=Tensor(shape=(None, 30, 3))
#   warnings.warn(msg)
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - auc: 0.7263 - categorical_accuracy: 0.3695 - loss: 1.6650 - precision: 0.7442 - recall: 0.1543 - val_auc: 0.8504 - val_categorical_accuracy: 0.5121 - val_loss: 1.3021 - val_precision: 0.8350 - val_recall: 0.2606
# Epoch 2/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - auc: 0.8500 - categorical_accuracy: 0.4975 - loss: 1.3164 - precision: 0.7565 - recall: 0.2632 - val_auc: 0.8632 - val_categorical_accuracy: 0.5333 - val_loss: 1.2497 - val_precision: 0.8349 - val_recall: 0.2682
# Epoch 3/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - auc: 0.8640 - categorical_accuracy: 0.5213 - loss: 1.2492 - precision: 0.7826 - recall: 0.3153 - val_auc: 0.8681 - val_categorical_accuracy: 0.5424 - val_loss: 1.2305 - val_precision: 0.8253 - val_recall: 0.2864
# Epoch 4/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - auc: 0.8745 - categorical_accuracy: 0.5462 - loss: 1.2002 - precision: 0.8161 - recall: 0.3379 - val_auc: 0.8690 - val_categorical_accuracy: 0.5455 - val_loss: 1.2229 - val_precision: 0.8008 - val_recall: 0.3167
# Epoch 5/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - auc: 0.8804 - categorical_accuracy: 0.5502 - loss: 1.1731 - precision: 0.8047 - recall: 0.3637 - val_auc: 0.8716 - val_categorical_accuracy: 0.5500 - val_loss: 1.2109 - val_precision: 0.8189 - val_recall: 0.3152
# Epoch 6/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - auc: 0.8893 - categorical_accuracy: 0.5641 - loss: 1.1334 - precision: 0.8105 - recall: 0.3648 - val_auc: 0.8763 - val_categorical_accuracy: 0.5652 - val_loss: 1.1915 - val_precision: 0.8148 - val_recall: 0.3333
# Epoch 7/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - auc: 0.8963 - categorical_accuracy: 0.5717 - loss: 1.1014 - precision: 0.8191 - recall: 0.3751 - val_auc: 0.8788 - val_categorical_accuracy: 0.5727 - val_loss: 1.1811 - val_precision: 0.7832 - val_recall: 0.3394
# Epoch 8/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - auc: 0.9021 - categorical_accuracy: 0.5921 - loss: 1.0728 - precision: 0.8149 - recall: 0.3970 - val_auc: 0.8820 - val_categorical_accuracy: 0.5712 - val_loss: 1.1652 - val_precision: 0.7945 - val_recall: 0.3515
# Epoch 9/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - auc: 0.9059 - categorical_accuracy: 0.5911 - loss: 1.0548 - precision: 0.8110 - recall: 0.3910 - val_auc: 0.8831 - val_categorical_accuracy: 0.5727 - val_loss: 1.1638 - val_precision: 0.7727 - val_recall: 0.3606
# Epoch 10/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - auc: 0.9080 - categorical_accuracy: 0.6004 - loss: 1.0405 - precision: 0.8248 - recall: 0.4156 - val_auc: 0.8866 - val_categorical_accuracy: 0.5833 - val_loss: 1.1466 - val_precision: 0.7795 - val_recall: 0.3803
# Epoch 11/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - auc: 0.9137 - categorical_accuracy: 0.6152 - loss: 1.0136 - precision: 0.8165 - recall: 0.4365 - val_auc: 0.8856 - val_categorical_accuracy: 0.5682 - val_loss: 1.1538 - val_precision: 0.7570 - val_recall: 0.3682
# Epoch 12/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - auc: 0.9168 - categorical_accuracy: 0.6121 - loss: 0.9972 - precision: 0.8101 - recall: 0.4373 - val_auc: 0.8851 - val_categorical_accuracy: 0.5712 - val_loss: 1.1556 - val_precision: 0.7736 - val_recall: 0.3727
# Epoch 13/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - auc: 0.9198 - categorical_accuracy: 0.6279 - loss: 0.9780 - precision: 0.8287 - recall: 0.4581 - val_auc: 0.8858 - val_categorical_accuracy: 0.5636 - val_loss: 1.1528 - val_precision: 0.7479 - val_recall: 0.3955
# Epoch 14/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - auc: 0.9204 - categorical_accuracy: 0.6177 - loss: 0.9738 - precision: 0.8170 - recall: 0.4623 - val_auc: 0.8833 - val_categorical_accuracy: 0.5591 - val_loss: 1.1633 - val_precision: 0.7609 - val_recall: 0.3955
# Epoch 15/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - auc: 0.9239 - categorical_accuracy: 0.6331 - loss: 0.9569 - precision: 0.8077 - recall: 0.4649 - val_auc: 0.8849 - val_categorical_accuracy: 0.5576 - val_loss: 1.1574 - val_precision: 0.7563 - val_recall: 0.4091
# Epoch 16/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - auc: 0.9251 - categorical_accuracy: 0.6463 - loss: 0.9494 - precision: 0.8106 - recall: 0.4803 - val_auc: 0.8803 - val_categorical_accuracy: 0.5500 - val_loss: 1.1837 - val_precision: 0.7379 - val_recall: 0.3924
# Epoch 17/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - auc: 0.9281 - categorical_accuracy: 0.6364 - loss: 0.9301 - precision: 0.8272 - recall: 0.4815 - val_auc: 0.8794 - val_categorical_accuracy: 0.5455 - val_loss: 1.1904 - val_precision: 0.7275 - val_recall: 0.3803
# Epoch 18/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - auc: 0.9302 - categorical_accuracy: 0.6645 - loss: 0.9205 - precision: 0.8306 - recall: 0.4862 - val_auc: 0.8831 - val_categorical_accuracy: 0.5515 - val_loss: 1.1794 - val_precision: 0.7263 - val_recall: 0.4182
# Epoch 19/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - auc: 0.9322 - categorical_accuracy: 0.6532 - loss: 0.9060 - precision: 0.8176 - recall: 0.4931 - val_auc: 0.8885 - val_categorical_accuracy: 0.5636 - val_loss: 1.1470 - val_precision: 0.7521 - val_recall: 0.4136
# Epoch 20/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - auc: 0.9361 - categorical_accuracy: 0.6710 - loss: 0.8825 - precision: 0.8337 - recall: 0.5051 - val_auc: 0.8813 - val_categorical_accuracy: 0.5409 - val_loss: 1.1994 - val_precision: 0.7005 - val_recall: 0.4076
# Epoch 21/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 70ms/step - auc: 0.9373 - categorical_accuracy: 0.6709 - loss: 0.8761 - precision: 0.8140 - recall: 0.5065 - val_auc: 0.8832 - val_categorical_accuracy: 0.5515 - val_loss: 1.1925 - val_precision: 0.7099 - val_recall: 0.4227
# Epoch 22/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - auc: 0.9397 - categorical_accuracy: 0.6669 - loss: 0.8589 - precision: 0.8184 - recall: 0.5243 - val_auc: 0.8840 - val_categorical_accuracy: 0.5455 - val_loss: 1.1865 - val_precision: 0.7299 - val_recall: 0.4258
# Epoch 23/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 62ms/step - auc: 0.9410 - categorical_accuracy: 0.6655 - loss: 0.8491 - precision: 0.8292 - recall: 0.5320 - val_auc: 0.8883 - val_categorical_accuracy: 0.5621 - val_loss: 1.1698 - val_precision: 0.7036 - val_recall: 0.4424
# Epoch 24/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - auc: 0.9446 - categorical_accuracy: 0.6845 - loss: 0.8269 - precision: 0.8296 - recall: 0.5466 - val_auc: 0.8871 - val_categorical_accuracy: 0.5606 - val_loss: 1.1892 - val_precision: 0.6965 - val_recall: 0.4485
# Epoch 25/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - auc: 0.9437 - categorical_accuracy: 0.6798 - loss: 0.8315 - precision: 0.8038 - recall: 0.5422 - val_auc: 0.8900 - val_categorical_accuracy: 0.5576 - val_loss: 1.1608 - val_precision: 0.7253 - val_recall: 0.4561
# Epoch 26/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - auc: 0.9474 - categorical_accuracy: 0.6842 - loss: 0.8060 - precision: 0.8304 - recall: 0.5504 - val_auc: 0.8856 - val_categorical_accuracy: 0.5621 - val_loss: 1.2010 - val_precision: 0.6848 - val_recall: 0.4576
# Epoch 27/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 63ms/step - auc: 0.9449 - categorical_accuracy: 0.6950 - loss: 0.8216 - precision: 0.8185 - recall: 0.5516 - val_auc: 0.8906 - val_categorical_accuracy: 0.5667 - val_loss: 1.1800 - val_precision: 0.6993 - val_recall: 0.4758
# Epoch 28/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 69ms/step - auc: 0.9458 - categorical_accuracy: 0.6845 - loss: 0.8143 - precision: 0.7988 - recall: 0.5668 - val_auc: 0.8901 - val_categorical_accuracy: 0.5621 - val_loss: 1.1589 - val_precision: 0.6966 - val_recall: 0.4348
# Epoch 29/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 71ms/step - auc: 0.9516 - categorical_accuracy: 0.7032 - loss: 0.7765 - precision: 0.8262 - recall: 0.5649 - val_auc: 0.8905 - val_categorical_accuracy: 0.5591 - val_loss: 1.1690 - val_precision: 0.6839 - val_recall: 0.4621
# Epoch 30/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - auc: 0.9521 - categorical_accuracy: 0.6959 - loss: 0.7701 - precision: 0.8151 - recall: 0.5751 - val_auc: 0.8907 - val_categorical_accuracy: 0.5606 - val_loss: 1.1735 - val_precision: 0.6841 - val_recall: 0.4561
# Epoch 31/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - auc: 0.9548 - categorical_accuracy: 0.7135 - loss: 0.7487 - precision: 0.8346 - recall: 0.6013 - val_auc: 0.8848 - val_categorical_accuracy: 0.5364 - val_loss: 1.2193 - val_precision: 0.6667 - val_recall: 0.4667
# Epoch 32/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - auc: 0.9555 - categorical_accuracy: 0.7169 - loss: 0.7426 - precision: 0.8341 - recall: 0.6065 - val_auc: 0.8886 - val_categorical_accuracy: 0.5576 - val_loss: 1.1981 - val_precision: 0.6623 - val_recall: 0.4576
# Epoch 33/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - auc: 0.9532 - categorical_accuracy: 0.7218 - loss: 0.7597 - precision: 0.8253 - recall: 0.6120 - val_auc: 0.8823 - val_categorical_accuracy: 0.5500 - val_loss: 1.2393 - val_precision: 0.6580 - val_recall: 0.4576
# Epoch 34/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - auc: 0.9569 - categorical_accuracy: 0.7335 - loss: 0.7334 - precision: 0.8493 - recall: 0.6194 - val_auc: 0.8849 - val_categorical_accuracy: 0.5591 - val_loss: 1.2231 - val_precision: 0.6768 - val_recall: 0.4727
# Epoch 35/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - auc: 0.9574 - categorical_accuracy: 0.7191 - loss: 0.7291 - precision: 0.8251 - recall: 0.6134 - val_auc: 0.8862 - val_categorical_accuracy: 0.5667 - val_loss: 1.2139 - val_precision: 0.6711 - val_recall: 0.4576
# Epoch 36/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - auc: 0.9613 - categorical_accuracy: 0.7373 - loss: 0.6975 - precision: 0.8471 - recall: 0.6366 - val_auc: 0.8883 - val_categorical_accuracy: 0.5667 - val_loss: 1.2054 - val_precision: 0.6870 - val_recall: 0.4788
# Epoch 37/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - auc: 0.9593 - categorical_accuracy: 0.7289 - loss: 0.7132 - precision: 0.8255 - recall: 0.6307 - val_auc: 0.8862 - val_categorical_accuracy: 0.5727 - val_loss: 1.2217 - val_precision: 0.6638 - val_recall: 0.4727
# Epoch 38/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - auc: 0.9618 - categorical_accuracy: 0.7380 - loss: 0.6936 - precision: 0.8431 - recall: 0.6446 - val_auc: 0.8825 - val_categorical_accuracy: 0.5742 - val_loss: 1.2465 - val_precision: 0.6711 - val_recall: 0.4636
# Epoch 39/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - auc: 0.9619 - categorical_accuracy: 0.7385 - loss: 0.6915 - precision: 0.8447 - recall: 0.6293 - val_auc: 0.8836 - val_categorical_accuracy: 0.5697 - val_loss: 1.2395 - val_precision: 0.6775 - val_recall: 0.4742
# Epoch 40/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - auc: 0.9641 - categorical_accuracy: 0.7476 - loss: 0.6745 - precision: 0.8468 - recall: 0.6548 - val_auc: 0.8829 - val_categorical_accuracy: 0.5773 - val_loss: 1.2459 - val_precision: 0.6565 - val_recall: 0.4545
# Epoch 41/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - auc: 0.9643 - categorical_accuracy: 0.7541 - loss: 0.6704 - precision: 0.8466 - recall: 0.6528 - val_auc: 0.8814 - val_categorical_accuracy: 0.5667 - val_loss: 1.2528 - val_precision: 0.6586 - val_recall: 0.4561
# Epoch 42/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - auc: 0.9641 - categorical_accuracy: 0.7439 - loss: 0.6740 - precision: 0.8498 - recall: 0.6487 - val_auc: 0.8789 - val_categorical_accuracy: 0.5727 - val_loss: 1.2796 - val_precision: 0.6582 - val_recall: 0.4727
# Epoch 43/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - auc: 0.9661 - categorical_accuracy: 0.7549 - loss: 0.6560 - precision: 0.8489 - recall: 0.6591 - val_auc: 0.8756 - val_categorical_accuracy: 0.5470 - val_loss: 1.3210 - val_precision: 0.6299 - val_recall: 0.4591
# Epoch 44/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - auc: 0.9650 - categorical_accuracy: 0.7532 - loss: 0.6630 - precision: 0.8489 - recall: 0.6613 - val_auc: 0.8808 - val_categorical_accuracy: 0.5758 - val_loss: 1.2887 - val_precision: 0.6528 - val_recall: 0.4758
# Epoch 45/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - auc: 0.9696 - categorical_accuracy: 0.7755 - loss: 0.6256 - precision: 0.8597 - recall: 0.6817 - val_auc: 0.8709 - val_categorical_accuracy: 0.5470 - val_loss: 1.3664 - val_precision: 0.6329 - val_recall: 0.4727
# Epoch 46/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - auc: 0.9694 - categorical_accuracy: 0.7688 - loss: 0.6249 - precision: 0.8573 - recall: 0.6815 - val_auc: 0.8748 - val_categorical_accuracy: 0.5545 - val_loss: 1.3349 - val_precision: 0.6380 - val_recall: 0.4727
# Epoch 47/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - auc: 0.9688 - categorical_accuracy: 0.7620 - loss: 0.6317 - precision: 0.8529 - recall: 0.6809 - val_auc: 0.8742 - val_categorical_accuracy: 0.5667 - val_loss: 1.3629 - val_precision: 0.6304 - val_recall: 0.4652
# Epoch 48/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - auc: 0.9695 - categorical_accuracy: 0.7642 - loss: 0.6243 - precision: 0.8582 - recall: 0.6684 - val_auc: 0.8773 - val_categorical_accuracy: 0.5606 - val_loss: 1.3337 - val_precision: 0.6547 - val_recall: 0.4712
# Epoch 49/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - auc: 0.9703 - categorical_accuracy: 0.7655 - loss: 0.6154 - precision: 0.8542 - recall: 0.6853 - val_auc: 0.8784 - val_categorical_accuracy: 0.5530 - val_loss: 1.3418 - val_precision: 0.6257 - val_recall: 0.4939
# Epoch 50/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - auc: 0.9707 - categorical_accuracy: 0.7697 - loss: 0.6114 - precision: 0.8604 - recall: 0.6975 - val_auc: 0.8754 - val_categorical_accuracy: 0.5545 - val_loss: 1.3461 - val_precision: 0.6440 - val_recall: 0.4742

# %% [markdown]
# #### Plot metrics

# %%
# Training and Validation Loss

plt.figure(figsize=(12,6))
plt.plot(training_history.history['loss'], label='Training Loss')
plt.plot(training_history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training and Validation Loss')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Training and Validation Accuracy
plt.figure(figsize=(12,6))
plt.plot(training_history.history['categorical_accuracy'], label='Training Accuracy')
plt.plot(training_history.history['val_categorical_accuracy'], label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Training and Validation Accuracy')
plt.legend()
plt.grid(True)
plt.ylim([0, 1])
plt.show()

# %% [markdown]
# #### Test:

# %%
full_eval_best_model = tf.keras.models.load_model(full_eval_best_model_file_name)

print("Model with lowest validation Loss:")
print(simclr_utitlities.evaluate_model_simple(full_eval_best_model.predict(X_test_normalized), np_test_labels, return_dict=True))
print("Model in last epoch")
print(simclr_utitlities.evaluate_model_simple(full_evaluation_model.predict(X_test_normalized), np_test_labels, return_dict=True))
# Out:
# Model with lowest validation Loss:
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# c:\Users\liuzi\miniconda3\Lib\site-packages\keras\src\models\functional.py:238: UserWarning: The structure of `inputs` doesn't match the expected structure.
# Expected: ['input']
# Received: inputs=Tensor(shape=(32, 30, 3))
#   warnings.warn(msg)
# {'Confusion Matrix': array([[112,   1,   2,   5,   1,  15,   5],
#        [ 10,  71,   0,   3,   6,   6,   1],
#        [ 29,  15,  26,   4,   2,  16,   4],
#        [ 16,   5,   4,  81,   0,  11,   6],
#        [  0,   6,   0,   2, 115,   0,   0],
#        [ 30,   4,   5,   9,   0,  56,  12],
#        [ 54,   8,  10,   5,   1,  34,  17]]), 'F1 Macro': 0.5547282386967429, 'F1 Micro': 0.5793939393939394, 'F1 Weighted': 0.5555619355309487, 'Precision': 0.5845079027915112, 'Recall': 0.5721651198200174, 'Kappa': np.float64(0.5059598900349811)}
# Model in last epoch
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# c:\Users\liuzi\miniconda3\Lib\site-packages\keras\src\models\functional.py:238: UserWarning: The structure of `inputs` doesn't match the expected structure.
# Expected: ['input']
# Received: inputs=Tensor(shape=(32, 30, 3))
#   warnings.warn(msg)
# c:\Users\liuzi\miniconda3\Lib\site-packages\keras\src\models\functional.py:238: UserWarning: The structure of `inputs` doesn't match the expected structure.
# Expected: ['input']
# Received: inputs=Tensor(shape=(None, 30, 3))
#   warnings.warn(msg)
# {'Confusion Matrix': array([[ 70,   1,  20,   8,   0,   9,  33],
#        [  6,  72,   2,   4,   3,   6,   4],
#        [ 11,  15,  25,   5,   1,  21,  18],
#        [  6,   2,   7,  88,   0,   8,  12],
#        [  0,   3,   0,   0, 119,   0,   1],
#        [  7,   6,  13,   6,   0,  55,  29],
#        [ 23,   3,  20,   7,   0,  32,  44]]), 'F1 Macro': 0.5708836215971433, 'F1 Micro': 0.5733333333333334, 'F1 Weighted': 0.5742100361905228, 'Precision': 0.5724986883330355, 'Recall': 0.5710412343190864, 'Kappa': np.float64(0.5010377864221798)}

# %% [markdown]
# ## Extra: t-SNE Plots

# %% [markdown]
# ### Parameters

# %%
import sklearn.manifold
import seaborn as sns

# %% [markdown]
# ### t-SNE Representations

# %%
# First load the model from the file path
target_model_path = simclr_model_save_path
loaded_model = tf.keras.models.load_model(target_model_path)
perplexity = 30.0

# Then extract the intermediate model
intermediate_model = simclr_models.extract_intermediate_model_from_base_model(loaded_model, intermediate_layer=7)
intermediate_model.summary()

# Continue with your t-SNE code
embeddings = intermediate_model.predict(X_test_normalized, batch_size=600)
tsne_model = sklearn.manifold.TSNE(perplexity=perplexity, verbose=1, random_state=42)
tsne_projections = tsne_model.fit_transform(embeddings)
# Out:
# WARNING:absl:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# Model: "base_model_simclr_layer_7"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input (InputLayer)              │ (None, 30, 3)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_2 (Conv1D)               │ (None, 30, 32)         │         2,336 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 30, 32)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_3 (Conv1D)               │ (None, 30, 64)         │        32,832 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 30, 64)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_4 (Conv1D)               │ (None, 30, 96)         │        49,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 30, 96)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_max_pooling1d            │ (None, 96)             │             0 │
# │ (GlobalMaxPooling1D)            │                        │               │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 84,416 (329.75 KB)
#  Trainable params: 84,416 (329.75 KB)
#  Non-trainable params: 0 (0.00 B)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# c:\Users\liuzi\miniconda3\Lib\site-packages\keras\src\models\functional.py:238: UserWarning: The structure of `inputs` doesn't match the expected structure.
# Expected: ['input']
# Received: inputs=Tensor(shape=(600, 30, 3))
#   warnings.warn(msg)
# c:\Users\liuzi\miniconda3\Lib\site-packages\keras\src\models\functional.py:238: UserWarning: The structure of `inputs` doesn't match the expected structure.
# Expected: ['input']
# Received: inputs=Tensor(shape=(None, 30, 3))
#   warnings.warn(msg)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 825 samples in 0.000s...
# [t-SNE] Computed neighbors for 825 samples in 0.322s...
# [t-SNE] Computed conditional probabilities for sample 825 / 825
# [t-SNE] Mean sigma: 1.609893
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 59.563572
# [t-SNE] KL divergence after 1000 iterations: 0.611223

# %% [markdown]
# ### Plotting

# %%
# Get the true labels (class indices) from the one-hot encoded test labels
labels_argmax = np.argmax(np_test_labels, axis=1)
unique_labels = np.unique(labels_argmax)

# Create the t-SNE visualization
plt.figure(figsize=(16,8))
graph = sns.scatterplot(
    x=tsne_projections[:,0], y=tsne_projections[:,1],
    hue=labels_argmax,
    palette=sns.color_palette("hsv", len(unique_labels)),
    s=50,
    alpha=1.0,
    rasterized=True
)
plt.xticks([], [])
plt.yticks([], [])

plt.title("t-SNE Visualization of SimCLR Embeddings")

# If you have class names, use them for the legend
# Define your activity names if needed
label_list_full_name = ["asphalt", "cobblestone", "compact_gravel", "curb_0", "curb_1", "dirt", "paving_stone"]  # Replace with your actual class names

# Update legend with class names if available
try:
    plt.legend(loc='lower left', bbox_to_anchor=(0.25, -0.3), ncol=2)
    legend = graph.legend_
    if 'label_list_full_name' in globals():  # Check if variable exists
        for j, label in enumerate(unique_labels):
            if label < len(label_list_full_name):
                legend.get_texts()[j].set_text(label_list_full_name[label])
except Exception as e:
    print(f"Warning: Could not customize legend - {e}")
    plt.legend(loc='lower left', bbox_to_anchor=(0.25, -0.3), ncol=2)

# %%
# Create a figure with 6 subplots (3x2 grid) to compare curb_1 with each other class
plt.figure(figsize=(20, 15))

# Get the true labels (class indices) from the one-hot encoded test labels
labels_argmax = np.argmax(np_test_labels, axis=1)
unique_labels = np.unique(labels_argmax)
curb_1_index = 4  # Based on your label_list_full_name where "curb_1" is at index 4

# Define your surface type names
label_list_full_name = ["asphalt", "cobblestone", "compact_gravel", "curb_0", "curb_1", "dirt", "paving_stone"]

# Loop through each class (except curb_1) and create a subplot
subplot_index = 1
for class_index in unique_labels:
    # Skip curb_1 as we're comparing others against it
    if class_index == curb_1_index:
        continue

    # Create binary mask for current pair (curb_1 and current class)
    mask = np.logical_or(labels_argmax == curb_1_index, labels_argmax == class_index)

    # Create binary labels: 0 for current class, 1 for curb_1
    binary_labels = np.zeros(np.sum(mask))
    binary_labels[labels_argmax[mask] == curb_1_index] = 1

    # Get the filtered t-SNE projections
    filtered_projections = tsne_projections[mask]

    # Create subplot
    plt.subplot(3, 2, subplot_index)

    # Plot the scatter points
    sns.scatterplot(
        x=filtered_projections[:, 0],
        y=filtered_projections[:, 1],
        hue=binary_labels,
        palette=["#1f77b4", "#ff7f0e"],  # Blue for other class, Orange for curb_1
        s=60,
        alpha=0.8
    )

    # Remove axes ticks for cleaner visualization
    plt.xticks([], [])
    plt.yticks([], [])

    # Set subplot title
    plt.title(f"curb_1 vs. {label_list_full_name[class_index]}", fontsize=14)

    # Custom legend
    plt.legend([label_list_full_name[class_index], "curb_1"], fontsize=12)

    # Increment subplot index
    subplot_index += 1

# Add overall title
plt.suptitle("t-SNE Comparison of Curb_1 vs. Each Other Surface Type", fontsize=18, y=0.98)
plt.tight_layout()
plt.show()
