# %% [markdown]
# # Segmentation for Dirt for all People

# %%
# Author: Ziyi Liu
# Project: Bachelor's Thesis - Cyclist Curb Detection under Varying Road Roughness
# Institution: Universität Kassel
# License: GNU General Public License v3.0

# %load_ext autoreload
# %autoreload 2

# %%
import sys
import numpy as np
import random
sys.path.append('../../')   # Add parent directory to Python path
from utils.preprocessing import *
from utils.segmentation import *
from utils.visualization import *
from utils.automation import *

# %% [markdown]
# ## 1S Segmentation of 100hz

# %%
# List of files to segment
files = [
    "../../data/RoadRoughness/Raw/Dirt/P1/Accelerometer_filtered_e1_100hz.csv",

    "../../data/RoadRoughness/Raw/Dirt/P2/Accelerometer_filtered_e1_100hz.csv",
    "../../data/RoadRoughness/Raw/Dirt/P2/Accelerometer_filtered_e2_100hz.csv",

    "../../data/RoadRoughness/Raw/Dirt/P3/Accelerometer_filtered_e1_100hz.csv",
    "../../data/RoadRoughness/Raw/Dirt/P3/Accelerometer_filtered_e2_100hz.csv",

    "../../data/RoadRoughness/Raw/Dirt/P4/Accelerometer_filtered_e1_100hz.csv",

    "../../data/RoadRoughness/Raw/Dirt/P5/Accelerometer_filtered_e1_100hz.csv",
    "../../data/RoadRoughness/Raw/Dirt/P5/Accelerometer_filtered_e2_100hz.csv",

    "../../data/RoadRoughness/Raw/Dirt/P6/Accelerometer_filtered_e1_100hz.csv",

    "../../data/RoadRoughness/Raw/Dirt/P7/Accelerometer_filtered_e1_100hz.csv",
    "../../data/RoadRoughness/Raw/Dirt/P7/Accelerometer_filtered_e2_100hz.csv",

    "../../data/RoadRoughness/Raw/Dirt/P8/Accelerometer_filtered_e1_100hz.csv",

    "../../data/RoadRoughness/Raw/Dirt/P9/Accelerometer_filtered_e1_100hz.csv",
    "../../data/RoadRoughness/Raw/Dirt/P9/Accelerometer_filtered_e2_100hz.csv",

    "../../data/RoadRoughness/Raw/Dirt/P10/Accelerometer_filtered_e1_100hz.csv",
]

# %%
# Define segmentation parameters
window_size = 100  # 1 second at 100Hz
overlap = 50       # 50% overlap
channels = ['Acc-X', 'Acc-Y', 'Acc-Z']

# Process each file
for file_path in files:
    df = pd.read_csv(file_path)
    
    # Ensure NTP is in datetime format
    df['NTP'] = pd.to_datetime(df['NTP'])
    
    # Apply segmentation
    segments = segment_acceleration_data_overlapping_numpy(
        df,
        window_size=window_size,
        overlap=overlap,
        channels=channels
    )
    
    # Create output filename
    output_path = file_path.replace('.csv', f'_segments_1s_{overlap}overlap.npz')
    # Save segments to NPZ file
    np.savez(output_path, segments=segments)

# %% [markdown]
# ## 1S Segmentation of 30hz

# %%
# List of files to segment
files = [
    "../../data/RoadRoughness/Raw/Dirt/P1/Accelerometer_filtered_e1_30hz.csv",

    "../../data/RoadRoughness/Raw/Dirt/P2/Accelerometer_filtered_e1_30hz.csv",
    "../../data/RoadRoughness/Raw/Dirt/P2/Accelerometer_filtered_e2_30hz.csv",

    "../../data/RoadRoughness/Raw/Dirt/P3/Accelerometer_filtered_e1_30hz.csv",
    "../../data/RoadRoughness/Raw/Dirt/P3/Accelerometer_filtered_e2_30hz.csv",

    "../../data/RoadRoughness/Raw/Dirt/P4/Accelerometer_filtered_e1_30hz.csv",

    "../../data/RoadRoughness/Raw/Dirt/P5/Accelerometer_filtered_e1_30hz.csv",
    "../../data/RoadRoughness/Raw/Dirt/P5/Accelerometer_filtered_e2_30hz.csv",

    "../../data/RoadRoughness/Raw/Dirt/P6/Accelerometer_filtered_e1_30hz.csv",

    "../../data/RoadRoughness/Raw/Dirt/P7/Accelerometer_filtered_e1_30hz.csv",
    "../../data/RoadRoughness/Raw/Dirt/P7/Accelerometer_filtered_e2_30hz.csv",

    "../../data/RoadRoughness/Raw/Dirt/P8/Accelerometer_filtered_e1_30hz.csv",

    "../../data/RoadRoughness/Raw/Dirt/P9/Accelerometer_filtered_e1_30hz.csv",
    "../../data/RoadRoughness/Raw/Dirt/P9/Accelerometer_filtered_e2_30hz.csv",

    "../../data/RoadRoughness/Raw/Dirt/P10/Accelerometer_filtered_e1_30hz.csv",
]

# %%
# Define segmentation parameters
window_size = 30  # 1 second at 30Hz
overlap = 50       # 50% overlap
channels = ['Acc-X', 'Acc-Y', 'Acc-Z']

# Process each file
for file_path in files:
    df = pd.read_csv(file_path)
    
    # Ensure NTP is in datetime format
    df['NTP'] = pd.to_datetime(df['NTP'])
    
    # Apply segmentation
    segments = segment_acceleration_data_overlapping_numpy(
        df,
        window_size=window_size,
        overlap=overlap,
        channels=channels
    )
    
    # Create output filename
    output_path = file_path.replace('.csv', f'_segments_1s_{overlap}overlap.npz')
    # Save segments to NPZ file
    np.savez(output_path, segments=segments)
