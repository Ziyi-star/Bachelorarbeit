# %% [markdown]
# # Combine all datasets

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
import numpy as np
import pickle

sys.path.append('../../../')   # Add parent directory to Python path
from utils.preprocessing import *
from utils.segmentation import *
from utils.visualization import *
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import LabelEncoder
from keras.utils import to_categorical
from sklearn.model_selection import train_test_split

np.random.seed(42)  # For reproducibility

# %% [markdown]
# # 1.1 Curb

# %%
#P3
data = np.load('../../data/Curb/P3/handlebar/Accelerometer/segments_30hz_1s_50overlap.npz')
curb_p3_0 = data['segments_0']
curb_p3_1 = data['segments_1']
# P6
data = np.load('../../data/Curb/P6/handlebar/Accelerometer/Accelerometer_data_combined_30hz_scene0_segments_1s_50overlap.npz')
curb_p6_0 = data['segments']
data = np.load('../../data/Curb/P6/handlebar/Accelerometer/Accelerometer_data_combined_30hz_scene1_segments_1s_50overlap.npz')
curb_p6_1 = data['segments']
# P11
data = np.load('../../data/Curb/P11/handlebar/Accelerometer/Accelerometer_data_combined_30hz_scene0_segments_1s_50overlap.npz')
curb_p11_0 = data['segments']
data = np.load('../../data/Curb/P11/handlebar/Accelerometer/Accelerometer_data_combined_30hz_scene1_segments_1s_50overlap.npz')
curb_p11_1 = data['segments']
# P12
data = np.load('../../data/Curb/P12/handlebar/Accelerometer/Accelerometer_data_combined_30hz_scene0_segments_1s_50overlap.npz')
curb_p12_0 = data['segments']
data = np.load('../../data/Curb/P12/handlebar/Accelerometer/Accelerometer_data_combined_30hz_scene1_segments_1s_50overlap.npz')
curb_p12_1 = data['segments']
# P18
data = np.load('../../data/Curb/P18/handlebar/Accelerometer/Accelerometer_data_combined_30hz_scene0_segments_1s_50overlap.npz')
curb_p18_0 = data['segments']
data = np.load('../../data/Curb/P18/handlebar/Accelerometer/Accelerometer_data_combined_30hz_scene1_segments_1s_50overlap.npz')
curb_p18_1 = data['segments']
# P21
data = np.load('../../data/Curb/P21/handlebar/Accelerometer/Accelerometer_data_combined_30hz_scene0_segments_1s_50overlap.npz')
curb_p21_0 = data['segments']
data = np.load('../../data/Curb/P21/handlebar/Accelerometer/Accelerometer_data_combined_30hz_scene1_segments_1s_50overlap.npz')
curb_p21_1 = data['segments']

# %%
# After loading all the curb datasets
# 1. First get the count for each participant's scene 1 data
p6_count = curb_p6_1.shape[0]
p11_count = curb_p11_1.shape[0]
p12_count = curb_p12_1.shape[0]
p18_count = curb_p18_1.shape[0]
p21_count = curb_p21_1.shape[0]

# 2. Randomly select the same number of samples from scene 0 data
curb_p6_0 = select_random_samples(curb_p6_0, p6_count)
curb_p11_0 = select_random_samples(curb_p11_0, p11_count)
curb_p12_0 = select_random_samples(curb_p12_0, p12_count)
curb_p18_0 = select_random_samples(curb_p18_0, p18_count)
curb_p21_0 = select_random_samples(curb_p21_0, p21_count)

# 3. Print shape to verify
print("After balancing:")
print("Curb P3 (scene 0):", curb_p3_0.shape)
print("Curb P3 (scene 1):", curb_p3_1.shape)
print("Curb P6 (scene 0):", curb_p6_0.shape)
print("Curb P6 (scene 1):", curb_p6_1.shape)
print("Curb P11 (scene 0):", curb_p11_0.shape)
print("Curb P11 (scene 1):", curb_p11_1.shape)
print("Curb P12 (scene 0):", curb_p12_0.shape)
print("Curb P12 (scene 1):", curb_p12_1.shape)
print("Curb P18 (scene 0):", curb_p18_0.shape)
print("Curb P18 (scene 1):", curb_p18_1.shape)
print("Curb P21 (scene 0):", curb_p21_0.shape)
print("Curb P21 (scene 1):", curb_p21_1.shape)

# 4. Combine all curb data
data_curb_0 = np.concatenate([curb_p3_0, curb_p6_0, curb_p11_0, curb_p12_0, curb_p18_0, curb_p21_0])
data_curb_1 = np.concatenate([curb_p3_1, curb_p6_1, curb_p11_1, curb_p12_1, curb_p18_1, curb_p21_1])

print(f"Total curb scene 0 samples: {data_curb_0.shape[0]}")
print(f"Total curb scene 1 samples: {data_curb_1.shape[0]}")
# Out:
# After balancing:
# Curb P3 (scene 0): (97, 30, 3)
# Curb P3 (scene 1): (97, 30, 3)
# Curb P6 (scene 0): (87, 30, 3)
# Curb P6 (scene 1): (87, 30, 3)
# Curb P11 (scene 0): (129, 30, 3)
# Curb P11 (scene 1): (129, 30, 3)
# Curb P12 (scene 0): (101, 30, 3)
# Curb P12 (scene 1): (101, 30, 3)
# Curb P18 (scene 0): (87, 30, 3)
# Curb P18 (scene 1): (87, 30, 3)
# Curb P21 (scene 0): (116, 30, 3)
# Curb P21 (scene 1): (116, 30, 3)
# Total curb scene 0 samples: 617
# Total curb scene 1 samples: 617

# %%
# save the combined curb data
with open('../data_1s_30hz/curb_1s_combined_all.pkl', 'wb') as f:
    pickle.dump({'scene_0': data_curb_0, 'scene_1': data_curb_1}, f)

# %% [markdown]
# # 1.2 Asphalt

# %% [markdown]
# #### Round 1

# %%
#P1
data= np.load('../../data/RoadRoughness/Raw/Asphalt/P1/Accelerometer_filtered_e1_30hz_segments_1s_50overlap.npz')
asphalt_p1= data['segments']
#P2
data= np.load('../../data/RoadRoughness/Raw/Asphalt/P2/Accelerometer_filtered_e1_30hz_segments_1s_50overlap.npz')
asphalt_p2= data['segments']
# P3
data = np.load('../../data/RoadRoughness/Raw/Asphalt/P3/Accelerometer_filtered_e1_30hz_segments_1s_50overlap.npz')
asphalt_p3 = data['segments']
# P4
data = np.load('../../data/RoadRoughness/Raw/Asphalt/P4/Accelerometer_filtered_e1_30hz_segments_1s_50overlap.npz')
asphalt_p4 = data['segments']
# P5
data = np.load('../../data/RoadRoughness/Raw/Asphalt/P5/Accelerometer_filtered_e1_30hz_segments_1s_50overlap.npz')
asphalt_p5 = data['segments']
# P6
data = np.load('../../data/RoadRoughness/Raw/Asphalt/P6/Accelerometer_filtered_e1_30hz_segments_1s_50overlap.npz')
asphalt_p6 = data['segments']
# P7
data = np.load('../../data/RoadRoughness/Raw/Asphalt/P7/Accelerometer_filtered_e1_30hz_segments_1s_50overlap.npz')
asphalt_p7 = data['segments']
# P8
data = np.load('../../data/RoadRoughness/Raw/Asphalt/P8/Accelerometer_filtered_e1_30hz_segments_1s_50overlap.npz')
asphalt_p8 = data['segments']
# P9
data = np.load('../../data/RoadRoughness/Raw/Asphalt/P9/Accelerometer_filtered_e1_30hz_segments_1s_50overlap.npz')
asphalt_p9 = data['segments']
# P10
data = np.load('../../data/RoadRoughness/Raw/Asphalt/P10/Accelerometer_filtered_e1_30hz_segments_1s_50overlap.npz')
asphalt_p10 = data['segments']

# %% [markdown]
# #### Round 2

# %%
# P2
data = np.load('../../data/RoadRoughness/Raw/Asphalt/P2/Accelerometer_filtered_e2_30hz_segments_1s_50overlap.npz')
asphalt_p2_e2 = data['segments']
# P3
data = np.load('../../data/RoadRoughness/Raw/Asphalt/P3/Accelerometer_filtered_e2_30hz_segments_1s_50overlap.npz')
asphalt_p3_e2 = data['segments']
# P5
data = np.load('../../data/RoadRoughness/Raw/Asphalt/P5/Accelerometer_filtered_e2_30hz_segments_1s_50overlap.npz')
asphalt_p5_e2 = data['segments']
# P7
data = np.load('../../data/RoadRoughness/Raw/Asphalt/P7/Accelerometer_filtered_e2_30hz_segments_1s_50overlap.npz')
asphalt_p7_e2 = data['segments']
# P9
data = np.load('../../data/RoadRoughness/Raw/Asphalt/P9/Accelerometer_filtered_e2_30hz_segments_1s_50overlap.npz')
asphalt_p9_e2 = data['segments']

# %%
# combine and save all asphalt data
data_asphalt = np.concatenate([asphalt_p1, asphalt_p2, asphalt_p3, asphalt_p4, asphalt_p5, 
                              asphalt_p6, asphalt_p7, asphalt_p8, asphalt_p9, asphalt_p10, 
                              asphalt_p2_e2, asphalt_p3_e2, asphalt_p5_e2, asphalt_p7_e2, asphalt_p9_e2])
print("Combined asphalt data shape:", data_asphalt.shape)
with open('../data_1s_30hz/asphalt_1s_combined_all.pkl', 'wb') as f:
    pickle.dump(data_asphalt, f)
# Out:
# Combined asphalt data shape: (704, 30, 3)

# %% [markdown]
# # 1.3 Cobblestone

# %%
#P1
data = np.load('../../data/RoadRoughness/Raw/Cobblestone/P1/Accelerometer_filtered_e1_30hz_segments_1s_50overlap.npz')
cobblestone_p1 = data['segments']
#P2
data = np.load('../../data/RoadRoughness/Raw/Cobblestone/P2/Accelerometer_filtered_e1_30hz_segments_1s_50overlap.npz')
cobblestone_p2 = data['segments']
# P3
data = np.load('../../data/RoadRoughness/Raw/Cobblestone/P3/Accelerometer_filtered_e1_30hz_segments_1s_50overlap.npz')
cobblestone_p3 = data['segments']
# P4
data = np.load('../../data/RoadRoughness/Raw/Cobblestone/P4/Accelerometer_filtered_e1_30hz_segments_1s_50overlap.npz')
cobblestone_p4 = data['segments']
# P5
data = np.load('../../data/RoadRoughness/Raw/Cobblestone/P5/Accelerometer_filtered_e1_30hz_segments_1s_50overlap.npz')
cobblestone_p5 = data['segments']
# P6
data = np.load('../../data/RoadRoughness/Raw/Cobblestone/P6/Accelerometer_filtered_e1_30hz_segments_1s_50overlap.npz')
cobblestone_p6 = data['segments']
# P7
data = np.load('../../data/RoadRoughness/Raw/Cobblestone/P7/Accelerometer_filtered_e1_30hz_segments_1s_50overlap.npz')
cobblestone_p7 = data['segments']
# P8
data = np.load('../../data/RoadRoughness/Raw/Cobblestone/P8/Accelerometer_filtered_e1_30hz_segments_1s_50overlap.npz')
cobblestone_p8 = data['segments']
# P9
data = np.load('../../data/RoadRoughness/Raw/Cobblestone/P9/Accelerometer_filtered_e1_30hz_segments_1s_50overlap.npz')
cobblestone_p9 = data['segments']
# P10
data = np.load('../../data/RoadRoughness/Raw/Cobblestone/P10/Accelerometer_filtered_e1_30hz_segments_1s_50overlap.npz')
cobblestone_p10 = data['segments']

# %% [markdown]
# ## Round 2

# %%
# P2
data = np.load('../../data/RoadRoughness/Raw/Cobblestone/P2/Accelerometer_filtered_e2_30hz_segments_1s_50overlap.npz')
cobblestone_p2_e2 = data['segments']
# P3
data = np.load('../../data/RoadRoughness/Raw/Cobblestone/P3/Accelerometer_filtered_e2_30hz_segments_1s_50overlap.npz')
cobblestone_p3_e2 = data['segments']
# P5
data = np.load('../../data/RoadRoughness/Raw/Cobblestone/P5/Accelerometer_filtered_e2_30hz_segments_1s_50overlap.npz')
cobblestone_p5_e2 = data['segments']
# P7
data = np.load('../../data/RoadRoughness/Raw/Cobblestone/P7/Accelerometer_filtered_e2_30hz_segments_1s_50overlap.npz')
cobblestone_p7_e2 = data['segments']
# P9
data = np.load('../../data/RoadRoughness/Raw/Cobblestone/P9/Accelerometer_filtered_e2_30hz_segments_1s_50overlap.npz')
cobblestone_p9_e2 = data['segments']

# %%
# combine and save all cobblestone data
data_cobblestone = np.concatenate([cobblestone_p1, cobblestone_p2, cobblestone_p3, cobblestone_p4, cobblestone_p5, 
                                  cobblestone_p6, cobblestone_p7, cobblestone_p8, cobblestone_p9, cobblestone_p10,
                                  cobblestone_p2_e2, cobblestone_p3_e2, cobblestone_p5_e2, cobblestone_p7_e2, cobblestone_p9_e2])
print("Combined cobblestone data shape:", data_cobblestone.shape)
with open('../data_1s_30hz/cobblestone_1s_combined_all.pkl', 'wb') as f:
    pickle.dump(data_cobblestone, f)
# Out:
# Combined cobblestone data shape: (486, 30, 3)

# %% [markdown]
# # 1.4 CompactGravel

# %% [markdown]
# ## Round 1

# %%
#P1
data = np.load('../../data/RoadRoughness/Raw/CompactGravel/P1/Accelerometer_filtered_e1_30hz_segments_1s_50overlap.npz')
compactgravel_p1 = data['segments']
#P2
data = np.load('../../data/RoadRoughness/Raw/CompactGravel/P2/Accelerometer_filtered_e1_30hz_segments_1s_50overlap.npz')
compactgravel_p2 = data['segments']
# P3
data = np.load('../../data/RoadRoughness/Raw/CompactGravel/P3/Accelerometer_filtered_e1_30hz_segments_1s_50overlap.npz')
compactgravel_p3 = data['segments']
# P4
data = np.load('../../data/RoadRoughness/Raw/CompactGravel/P4/Accelerometer_filtered_e1_30hz_segments_1s_50overlap.npz')
compactgravel_p4 = data['segments']
# P5
data = np.load('../../data/RoadRoughness/Raw/CompactGravel/P5/Accelerometer_filtered_e1_30hz_segments_1s_50overlap.npz')
compactgravel_p5 = data['segments']
# P6
data = np.load('../../data/RoadRoughness/Raw/CompactGravel/P6/Accelerometer_filtered_e1_30hz_segments_1s_50overlap.npz')
compactgravel_p6 = data['segments']
# P7
data = np.load('../../data/RoadRoughness/Raw/CompactGravel/P7/Accelerometer_filtered_e1_30hz_segments_1s_50overlap.npz')
compactgravel_p7 = data['segments']
# P8
data = np.load('../../data/RoadRoughness/Raw/CompactGravel/P8/Accelerometer_filtered_e1_30hz_segments_1s_50overlap.npz')
compactgravel_p8 = data['segments']
# P9
data = np.load('../../data/RoadRoughness/Raw/CompactGravel/P9/Accelerometer_filtered_e1_30hz_segments_1s_50overlap.npz')
compactgravel_p9 = data['segments']
# P10
data = np.load('../../data/RoadRoughness/Raw/CompactGravel/P10/Accelerometer_filtered_e1_30hz_segments_1s_50overlap.npz')
compactgravel_p10 = data['segments']

# %% [markdown]
# ## Round 2

# %%
# P2
data = np.load('../../data/RoadRoughness/Raw/CompactGravel/P2/Accelerometer_filtered_e2_30hz_segments_1s_50overlap.npz')
compactgravel_p2_e2 = data['segments']
# P3
data = np.load('../../data/RoadRoughness/Raw/CompactGravel/P3/Accelerometer_filtered_e2_30hz_segments_1s_50overlap.npz')
compactgravel_p3_e2 = data['segments']
# P5
data = np.load('../../data/RoadRoughness/Raw/CompactGravel/P5/Accelerometer_filtered_e2_30hz_segments_1s_50overlap.npz')
compactgravel_p5_e2 = data['segments']
# P7
data = np.load('../../data/RoadRoughness/Raw/CompactGravel/P7/Accelerometer_filtered_e2_30hz_segments_1s_50overlap.npz')
compactgravel_p7_e2 = data['segments']
# P9
data = np.load('../../data/RoadRoughness/Raw/CompactGravel/P9/Accelerometer_filtered_e2_30hz_segments_1s_50overlap.npz')
compactgravel_p9_e2 = data['segments']

# %%
# combine and save all compact gravel data
data_compactgravel = np.concatenate([compactgravel_p1, compactgravel_p2, compactgravel_p3, compactgravel_p4, compactgravel_p5, 
                                   compactgravel_p6, compactgravel_p7, compactgravel_p8, compactgravel_p9, compactgravel_p10,
                                   compactgravel_p2_e2, compactgravel_p3_e2, compactgravel_p5_e2, compactgravel_p7_e2, compactgravel_p9_e2])
print("Combined compact gravel data shape:", data_compactgravel.shape)
with open('../data_1s_30hz/compactgravel_1s_combined_all.pkl', 'wb') as f:
    pickle.dump(data_compactgravel, f)
# Out:
# Combined compact gravel data shape: (479, 30, 3)

# %% [markdown]
# # 1.5 Dirt

# %% [markdown]
# ## Round 1

# %%
#P1
data = np.load('../../data/RoadRoughness/Raw/Dirt/P1/Accelerometer_filtered_e1_30hz_segments_1s_50overlap.npz')
dirt_p1 = data['segments']
#P2
data = np.load('../../data/RoadRoughness/Raw/Dirt/P2/Accelerometer_filtered_e1_30hz_segments_1s_50overlap.npz')
dirt_p2 = data['segments']
# P3
data = np.load('../../data/RoadRoughness/Raw/Dirt/P3/Accelerometer_filtered_e1_30hz_segments_1s_50overlap.npz')
dirt_p3 = data['segments']
# P4
data = np.load('../../data/RoadRoughness/Raw/Dirt/P4/Accelerometer_filtered_e1_30hz_segments_1s_50overlap.npz')
dirt_p4 = data['segments']
# P5
data = np.load('../../data/RoadRoughness/Raw/Dirt/P5/Accelerometer_filtered_e1_30hz_segments_1s_50overlap.npz')
dirt_p5 = data['segments']
# P6
data = np.load('../../data/RoadRoughness/Raw/Dirt/P6/Accelerometer_filtered_e1_30hz_segments_1s_50overlap.npz')
dirt_p6 = data['segments']
# P7
data = np.load('../../data/RoadRoughness/Raw/Dirt/P7/Accelerometer_filtered_e1_30hz_segments_1s_50overlap.npz')
dirt_p7 = data['segments']
# P8
data = np.load('../../data/RoadRoughness/Raw/Dirt/P8/Accelerometer_filtered_e1_30hz_segments_1s_50overlap.npz')
dirt_p8 = data['segments']
# P9
data = np.load('../../data/RoadRoughness/Raw/Dirt/P9/Accelerometer_filtered_e1_30hz_segments_1s_50overlap.npz')
dirt_p9 = data['segments']
# P10
data = np.load('../../data/RoadRoughness/Raw/Dirt/P10/Accelerometer_filtered_e1_30hz_segments_1s_50overlap.npz')
dirt_p10 = data['segments']

# %% [markdown]
# ## Round 2

# %%
# P2
data = np.load('../../data/RoadRoughness/Raw/Dirt/P2/Accelerometer_filtered_e2_30hz_segments_1s_50overlap.npz')
dirt_p2_e2 = data['segments']
# P3
data = np.load('../../data/RoadRoughness/Raw/Dirt/P3/Accelerometer_filtered_e2_30hz_segments_1s_50overlap.npz')
dirt_p3_e2 = data['segments']
# P5
data = np.load('../../data/RoadRoughness/Raw/Dirt/P5/Accelerometer_filtered_e2_30hz_segments_1s_50overlap.npz')
dirt_p5_e2 = data['segments']
# P7
data = np.load('../../data/RoadRoughness/Raw/Dirt/P7/Accelerometer_filtered_e2_30hz_segments_1s_50overlap.npz')
dirt_p7_e2 = data['segments']
# P9
data = np.load('../../data/RoadRoughness/Raw/Dirt/P9/Accelerometer_filtered_e2_30hz_segments_1s_50overlap.npz')
dirt_p9_e2 = data['segments']

# %%
# combine and save all dirt data
data_dirt = np.concatenate([dirt_p1, dirt_p2, dirt_p3, dirt_p4, dirt_p5, 
                           dirt_p6, dirt_p7, dirt_p8, dirt_p9, dirt_p10,
                           dirt_p2_e2, dirt_p3_e2, dirt_p5_e2, dirt_p7_e2, dirt_p9_e2])
print("Combined dirt data shape:", data_dirt.shape)
with open('../data_1s_30hz/dirt_1s_combined_all.pkl', 'wb') as f:
    pickle.dump(data_dirt, f)
# Out:
# Combined dirt data shape: (577, 30, 3)

# %% [markdown]
# # 1.6 PavingStone

# %% [markdown]
# ## Round 1

# %%
#P1
data = np.load('../../data/RoadRoughness/Raw/PavingStone/P1/Accelerometer_filtered_e1_30hz_segments_1s_50overlap.npz')
pavingstone_p1 = data['segments']
#P2
data = np.load('../../data/RoadRoughness/Raw/PavingStone/P2/Accelerometer_filtered_e1_30hz_segments_1s_50overlap.npz')
pavingstone_p2 = data['segments']
# P3
data = np.load('../../data/RoadRoughness/Raw/PavingStone/P3/Accelerometer_filtered_e1_30hz_segments_1s_50overlap.npz')
pavingstone_p3 = data['segments']
# P4
data = np.load('../../data/RoadRoughness/Raw/PavingStone/P4/Accelerometer_filtered_e1_30hz_segments_1s_50overlap.npz')
pavingstone_p4 = data['segments']
# P5
data = np.load('../../data/RoadRoughness/Raw/PavingStone/P5/Accelerometer_filtered_e1_30hz_segments_1s_50overlap.npz')
pavingstone_p5 = data['segments']
# P6
data = np.load('../../data/RoadRoughness/Raw/PavingStone/P6/Accelerometer_filtered_e1_30hz_segments_1s_50overlap.npz')
pavingstone_p6 = data['segments']
# P7
data = np.load('../../data/RoadRoughness/Raw/PavingStone/P7/Accelerometer_filtered_e1_30hz_segments_1s_50overlap.npz')
pavingstone_p7 = data['segments']
# P8
data = np.load('../../data/RoadRoughness/Raw/PavingStone/P8/Accelerometer_filtered_e2_30hz_segments_1s_50overlap.npz')
pavingstone_p8 = data['segments']
# P9
data = np.load('../../data/RoadRoughness/Raw/PavingStone/P9/Accelerometer_filtered_e1_30hz_segments_1s_50overlap.npz')
pavingstone_p9 = data['segments']
# P10
data = np.load('../../data/RoadRoughness/Raw/PavingStone/P10/Accelerometer_filtered_e2_30hz_segments_1s_50overlap.npz')
pavingstone_p10 = data['segments']

# %% [markdown]
# ## Round 2

# %%
# P2
data = np.load('../../data/RoadRoughness/Raw/PavingStone/P2/Accelerometer_filtered_e2_30hz_segments_1s_50overlap.npz')
pavingstone_p2_e2 = data['segments']
# P3
data = np.load('../../data/RoadRoughness/Raw/PavingStone/P3/Accelerometer_filtered_e2_30hz_segments_1s_50overlap.npz')
pavingstone_p3_e2 = data['segments']
# P5
data = np.load('../../data/RoadRoughness/Raw/PavingStone/P5/Accelerometer_filtered_e2_30hz_segments_1s_50overlap.npz')
pavingstone_p5_e2 = data['segments']
# P7
data = np.load('../../data/RoadRoughness/Raw/PavingStone/P7/Accelerometer_filtered_e2_30hz_segments_1s_50overlap.npz')
pavingstone_p7_e2 = data['segments']
# P9
data = np.load('../../data/RoadRoughness/Raw/PavingStone/P9/Accelerometer_filtered_e2_30hz_segments_1s_50overlap.npz')
pavingstone_p9_e2 = data['segments']

# %%
# combine and save all paving stone data
data_pavingstone = np.concatenate([pavingstone_p1, pavingstone_p2, pavingstone_p3, pavingstone_p4, pavingstone_p5, 
                                  pavingstone_p6, pavingstone_p7, pavingstone_p8, pavingstone_p9, pavingstone_p10,
                                  pavingstone_p2_e2, pavingstone_p3_e2, pavingstone_p5_e2, pavingstone_p7_e2, pavingstone_p9_e2])
print("Combined pavingstone data shape:", data_pavingstone.shape)
with open('../data_1s_30hz/pavingstone_1s_combined_all.pkl', 'wb') as f:
    pickle.dump(data_pavingstone, f)
# Out:
# Combined pavingstone data shape: (645, 30, 3)

# %% [markdown]
# # 1.7 Real World data of 3 people

# %%
# AB - 08.07
data = np.load('../../../data/Real_world_cycling/AB - 08.07/Accelerometer_labeled_9_class_scene0_segments_1s_50overlap.npz')
curb_AB_0 = data['segments']
data = np.load('../../../data/Real_world_cycling/AB - 08.07/Accelerometer_labeled_9_class_scene1_segments_1s_50overlap.npz')
curb_AB_1 = data['segments']

# IK - 26.02.25
data = np.load('../../../data/Real_world_cycling/IK - 26.02.25/Accelerometer_labeled_9_class_scene0_segments_1s_50overlap.npz')
curb_IK_0 = data['segments']
data = np.load('../../../data/Real_world_cycling/IK - 26.02.25/Accelerometer_labeled_9_class_scene1_segments_1s_50overlap.npz')
curb_IK_1 = data['segments']

# JG - 03.07
data = np.load('../../../data/Real_world_cycling/JG - 03.07/Accelerometer_labeled_9_class_scene0_segments_1s_50overlap.npz')
curb_JG_0 = data['segments']
data = np.load('../../../data/Real_world_cycling/JG - 03.07/Accelerometer_labeled_9_class_scene1_segments_1s_50overlap.npz')
curb_JG_1 = data['segments']

# %%
# Print shapes to verify loading
print("\nData shapes for each person:")
print(f"AB - Scene 0: {curb_AB_0.shape}, Scene 1: {curb_AB_1.shape}")
print(f"IK - Scene 0: {curb_IK_0.shape}, Scene 1: {curb_IK_1.shape}")
print(f"JG - Scene 0: {curb_JG_0.shape}, Scene 1: {curb_JG_1.shape}")
# Out:
# Data shapes for each person:
# AB - Scene 0: (4122, 30, 3), Scene 1: (82, 30, 3)
# IK - Scene 0: (3555, 30, 3), Scene 1: (76, 30, 3)
# JG - Scene 0: (3669, 30, 3), Scene 1: (106, 30, 3)

# %%
curb_AB_0_random = select_random_samples(curb_AB_0, len(curb_AB_1))
curb_IK_0_random = select_random_samples(curb_IK_0, len(curb_IK_1))
curb_JG_0_random = select_random_samples(curb_JG_0, len(curb_JG_1))

# %%
# Combine all segments for both scenes
with open('../../data/1s_30hz_7class/real_world_1s_combined_3people.pkl', 'wb') as f:
    pickle.dump({
        'scene_0': np.concatenate([curb_AB_0_random, curb_IK_0_random, curb_JG_0_random]),
        'scene_1': np.concatenate([curb_AB_1, curb_IK_1, curb_JG_1])
    }, f)
