# %% [markdown]
# ## Segmentation for PavingStone for all People

# %%
# Enable autoload for just updated files
# %load_ext autoreload
# %autoreload 2

# %%
import sys
import numpy as np
import random
sys.path.append('../../')   # Add parent directory to Python path
from utils.preprocessing import *
from utils.segmentation import *
from utils.visualization import *
from utils.automatisierung import *

# %% [markdown]
# ## 0.5S Segmentation

# %%
folders = [
    {
        "PavingStone": "../../data/RoadRoughness/Raw/PavingStone/P1/Accelerometer_filtered_e1.csv",
        "window_sizes": [50, 15],  # 0.5s at 100Hz and 30Hz
        "freq_list": [100, 30],
        "overlap": 50,
        "channels": ['Acc-X', 'Acc-Y', 'Acc-Z']
    },
    {
        "PavingStone": "../../data/RoadRoughness/Raw/PavingStone/P2/Accelerometer_filtered_e1.csv",
        "window_sizes": [50, 15],  # 0.5s at 100Hz and 30Hz
        "freq_list": [100, 30],
        "overlap": 50,
        "channels": ['Acc-X', 'Acc-Y', 'Acc-Z']
    },
    {
        "PavingStone": "../../data/RoadRoughness/Raw/PavingStone/P3/Accelerometer_filtered_e2.csv",
        "freq_list": [100, 30],
        "window_sizes": [50, 15],  # 0.5s at 100Hz and 30Hz
        "overlap": 50,
        "channels": ['Acc-X', 'Acc-Y', 'Acc-Z']
    },
    {
        "PavingStone": "../../data/RoadRoughness/Raw/PavingStone/P4/Accelerometer_filtered_e1.csv",
        "freq_list": [100, 30],
        "window_sizes": [50, 15],  # 0.5s at 100Hz and 30Hz
        "overlap": 50,
        "channels": ['Acc-X', 'Acc-Y', 'Acc-Z']
    },
    {
        "PavingStone": "../../data/RoadRoughness/Raw/PavingStone/P5/Accelerometer_filtered_e1.csv",
        "freq_list": [100, 30],
        "window_sizes": [50, 15],  # 0.5s at 100Hz and 30Hz
        "overlap": 50,
        "channels": ['Acc-X', 'Acc-Y', 'Acc-Z']
    },
    {
        "PavingStone": "../../data/RoadRoughness/Raw/PavingStone/P6/Accelerometer_filtered_e1.csv",
        "freq_list": [100, 30],
        "window_sizes": [50, 15],  # 0.5s at 100Hz and 30Hz
        "overlap": 50,
        "channels": ['Acc-X', 'Acc-Y', 'Acc-Z']
    },
    {
        "PavingStone": "../../data/RoadRoughness/Raw/PavingStone/P7/Accelerometer_filtered_e1.csv",
        "freq_list": [100, 30],
        "window_sizes": [50, 15],  # 0.5s at 100Hz and 30Hz
        "overlap": 50,
        "channels": ['Acc-X', 'Acc-Y', 'Acc-Z']
    },
    {
        "PavingStone": "../../data/RoadRoughness/Raw/PavingStone/P8/Accelerometer_filtered_e2.csv",
        "freq_list": [100, 30],
        "window_sizes": [50, 15],  # 0.5s at 100Hz and 30Hz
        "overlap": 50,
        "channels": ['Acc-X', 'Acc-Y', 'Acc-Z']
    },
    {
        "PavingStone": "../../data/RoadRoughness/Raw/PavingStone/P9/Accelerometer_filtered_e2.csv",
        "freq_list": [100, 30],
        "window_sizes": [50, 15],  # 0.5s at 100Hz and 30Hz
        "overlap": 50,
        "channels": ['Acc-X', 'Acc-Y', 'Acc-Z']
    },
    {
        "PavingStone": "../../data/RoadRoughness/Raw/PavingStone/P10/Accelerometer_filtered_e2.csv",
        "freq_list": [100, 30],
        "window_sizes": [50, 15],  # 0.5s at 100Hz and 30Hz
        "overlap": 50,
        "channels": ['Acc-X', 'Acc-Y', 'Acc-Z']
    },
]

for f in folders:
    preprocess_and_segment_road(f["PavingStone"], f["freq_list"], f["window_sizes"], f["overlap"], f["channels"])

# %%
folders = [
     {
    "PavingStone": "../../data/RoadRoughness/Raw/PavingStone/P2/Accelerometer_filtered_e2.csv",
        "window_sizes": [50, 15],  # 0.5s at 100Hz and 30Hz
        "freq_list": [100, 30],
        "overlap": 50,
        "channels": ['Acc-X', 'Acc-Y', 'Acc-Z']
    },
    {
        "PavingStone": "../../data/RoadRoughness/Raw/PavingStone/P3/Accelerometer_filtered_e1.csv",
        "window_sizes": [50, 15],  # 0.5s at 100Hz and 30Hz
        "freq_list": [100, 30],
        "overlap": 50,
        "channels": ['Acc-X', 'Acc-Y', 'Acc-Z']
    },
    {
        "PavingStone": "../../data/RoadRoughness/Raw/PavingStone/P5/Accelerometer_filtered_e2.csv",
        "freq_list": [100, 30],
        "window_sizes": [50, 15],  # 0.5s at 100Hz and 30Hz
        "overlap": 50,
        "channels": ['Acc-X', 'Acc-Y', 'Acc-Z']
    },
    {
        "PavingStone": "../../data/RoadRoughness/Raw/PavingStone/P7/Accelerometer_filtered_e2.csv",
        "freq_list": [100, 30],
        "window_sizes": [50, 15],  # 0.5s at 100Hz and 30Hz
        "overlap": 50,
        "channels": ['Acc-X', 'Acc-Y', 'Acc-Z']
    },
    {
        "PavingStone": "../../data/RoadRoughness/Raw/PavingStone/P9/Accelerometer_filtered_e1.csv",
        "freq_list": [100, 30],
        "window_sizes": [50, 15],  # 0.5s at 100Hz and 30Hz
        "overlap": 50,
        "channels": ['Acc-X', 'Acc-Y', 'Acc-Z']
    }
    ]

for f in folders:
    preprocess_and_segment_road(
        f["PavingStone"], f["freq_list"], f["window_sizes"], f["overlap"], f["channels"])

# %% [markdown]
# ## 1S Segmentation

# %%
# List of files to segment
files = [
    "../../data/RoadRoughness/Raw/PavingStone/P1/Accelerometer_filtered_e1_100hz.csv",

    "../../data/RoadRoughness/Raw/PavingStone/P2/Accelerometer_filtered_e1_100hz.csv",
    "../../data/RoadRoughness/Raw/PavingStone/P2/Accelerometer_filtered_e2_100hz.csv",

    "../../data/RoadRoughness/Raw/PavingStone/P3/Accelerometer_filtered_e1_100hz.csv",
    "../../data/RoadRoughness/Raw/PavingStone/P3/Accelerometer_filtered_e2_100hz.csv",

    "../../data/RoadRoughness/Raw/PavingStone/P4/Accelerometer_filtered_e1_100hz.csv",

    "../../data/RoadRoughness/Raw/PavingStone/P5/Accelerometer_filtered_e1_100hz.csv",
    "../../data/RoadRoughness/Raw/PavingStone/P5/Accelerometer_filtered_e2_100hz.csv",

    "../../data/RoadRoughness/Raw/PavingStone/P6/Accelerometer_filtered_e1_100hz.csv",

    "../../data/RoadRoughness/Raw/PavingStone/P7/Accelerometer_filtered_e1_100hz.csv",
    "../../data/RoadRoughness/Raw/PavingStone/P7/Accelerometer_filtered_e2_100hz.csv",

    "../../data/RoadRoughness/Raw/PavingStone/P8/Accelerometer_filtered_e2_100hz.csv",

    "../../data/RoadRoughness/Raw/PavingStone/P9/Accelerometer_filtered_e1_100hz.csv",
    "../../data/RoadRoughness/Raw/PavingStone/P9/Accelerometer_filtered_e2_100hz.csv",

    "../../data/RoadRoughness/Raw/PavingStone/P10/Accelerometer_filtered_e2_100hz.csv",
]

# %%
# Define segmentation parameters
window_size = 100  # 1 second at 100Hz
overlap = 50       # 50% overlap
channels = ['Acc-X', 'Acc-Y', 'Acc-Z']

# Process each file
for file_path in files:
    df = pd.read_csv(file_path)
    
    # Ensure NTP is in datetime format
    df['NTP'] = pd.to_datetime(df['NTP'])
    
    # Apply segmentation
    segments = segment_acceleration_data_overlapping_numpy(
        df,
        window_size=window_size,
        overlap=overlap,
        channels=channels
    )
    
    # Create output filename
    output_path = file_path.replace('.csv', f'_segments_1s_{overlap}overlap.npz')
    # Save segments to NPZ file
    np.savez(output_path, segments=segments)
